# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
# data prep and model-tuning
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, QuantileTransformer
from scipy.stats import shapiro
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV

# types of models we'll fit
from sklearn.linear_model import ElasticNetCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR

import pickle
from copy import deepcopy

# %% [markdown]
# ## Our Data

# %%
DATA = '../data/processed/training_data_annual.csv'
df = pd.read_csv(DATA)
df = df.dropna()
print('{:,d} samples'.format(len(df)))
print('Columns:', df.columns.values)
# Out:
# 4,721 samples
# Columns: ['uuid' 'lidar_year' 'lat' 'lon' 'orig_id' 'source' 'meas_yr' 'ecoregion3'
#  'agency' 'plot_size_ac' 'num_returns' 'strat0_return-proportion'
#  'strat1_return-proportion' 'strat2_return-proportion'
#  'strat3_return-proportion' 'strat4_return-proportion'
#  'strat5_return-proportion' 'strat0_intensity-median'
#  'strat1_intensity-median' 'strat2_intensity-median'
#  'strat3_intensity-median' 'strat4_intensity-median'
#  'strat5_intensity-median' 'height_05-percentile' 'height_25-percentile'
#  'height_50-percentile' 'height_75-percentile' 'height_95_percentile'
#  'height_max' 'cover' 'lidar_acq' 'potential_volume' 'stddev_height'
#  'surface_area_ratio' 'surface_volume' 'surface_volume_ratio' 'aspect'
#  'elevation' 'overall_curvature' 'plan_curvature' 'profile_curvature'
#  'slope' 'solar_radiation_index' 'mat' 'mwmt' 'mcmt' 'td' 'map' 'msp'
#  'ahm' 'shm' 'dd_0' 'dd5' 'dd_18' 'dd18' 'nffd' 'bffp' 'effp' 'ffp' 'pas'
#  'emt' 'ext' 'eref' 'cmd' 'rh' 'green' 'blue' 'red' 'nir' 'endvi' 'ndvi'
#  'savi' 'swir1' 'swir2' 'wetness' 'greenness' 'brightness' 'landsat_year'
#  'clim_year' 'distance_to_water_m' 'bulk_dens' 'soil_depth'
#  'pct_clay_surf' 'pct_rock_surf' 'pct_sand_surf' 'pot_veg_type' 'tpa' 'ba'
#  'sdi' 'ccf' 'qmd' 'tcuft' 'topht' 'number_of_strata' 'total_cover'
#  'structure_class' 'canopy_baseheight' 'canopy_bulkdensity'
#  'aboveground_biomass' 'aboveground_carbon' 'gs_tpa' 'AF' 'AS' 'BM' 'BO'
#  'CH' 'CW' 'DF' 'DG' 'ES' 'GC' 'GF' 'IC' 'JP' 'KP' 'LO' 'LP' 'MA' 'MC'
#  'MH' 'NF' 'OH' 'OS' 'OT' 'PC' 'PL' 'PP' 'PY' 'RA' 'RC' 'RF' 'SF' 'SH'
#  'SP' 'SS' 'TO' 'WA' 'WB' 'WF' 'WH' 'WI' 'WJ' 'WL' 'WO' 'WP' 'YC'
#  'TRUE_FIR' 'OTHER_HARDWOOD' 'MAPLE' 'OAK' 'DOUGLAS_FIR' 'SPRUCE' 'CEDAR'
#  'PONDEROSA_PINE' 'OTHER_SOFTWOOD' 'LODGEPOLE_PINE' 'HEMLOCK' 'RED_ALDER'
#  'TANOAK' 'JUNIPER' 'LARCH' 'fvs_year' 'year_diff' 'returns_per_m2']

# %% [markdown]
# ## Filter out some of the training data
# We can exclude some of the training data based on how far separated the inventory data (interpolated using FVS simulations) is from the year the lidar was collected. Similarly, we can screen out training examples that had relatively low density of lidar returns.

# %%
df['year_diff'] = abs(df['fvs_year'] - df['lidar_year']).astype(int)
df = df.loc[df['year_diff'] < 10]
df = df.loc[df['returns_per_m2'] >= 4.0]

# %% [markdown]
# ## Inspect how many samples we have for different years, regions, etc.

# %%
df.groupby(by=['lidar_year'])[['uuid']].count().rename({'uuid':'count'}, axis=1)
# Out:
#             count
# lidar_year
# 2006          191
# 2008          857
# 2009          113
# 2010           21
# 2011          161
# 2012          720
# 2013          269
# 2014          368
# 2015          680
# 2016          604
# 2017          191
# 2018           35

# %%
pd.pivot_table(df, 
               values='uuid', 
               aggfunc='count', 
               index=['meas_yr'], 
               columns=['lidar_year'], 
               fill_value=0)
# Out:
# lidar_year  2006  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# meas_yr
# 2010           0   475     0     0     0     4     0     2     7     0     0
# 2011           0   377     0     0     0     1     0     2     3     0     0
# 2013         168     0    18     0    37   466    54     6    11    14    28
# 2014           5     0    60     2    28   132    45    50    44    99    40
# 2015          18     4     5     0    55    18    13    16   217   114    25
# 2016           0     1    18    15    26    45    90    59   284    77    36
# 2017           0     0     9     2    12    44    43   182    58   104    51
# 2018           0     0     3     2     3    10    24    51    56   196    11
#
# lidar_year  2018
# meas_yr
# 2010           0
# 2011           0
# 2013           2
# 2014           1
# 2015           6
# 2016          26
# 2017           0
# 2018           0

# %%
ecoreg_counts = df.groupby(by=['ecoregion3'])[['uuid']].count()
ecoreg_counts
# Out:
#                                                     uuid
# ecoregion3
# blue_mountains                                       108
# cascades                                             747
# coast_range                                         1809
# columbia_plateau                                      14
# eastern_cascades_slopes_and_foothills                409
# klamath_mountains_california_high_north_coast_r...   323
# north_cascades                                       505
# northern_rockies                                     103
# puget_lowland                                        149
# willamette_valley                                     43

# %% [markdown]
# ## Available features
# First, we'll use one-hot encoding for categorical features

# %%
# convert agency, ecoregion, and lidar acquisition into one-hot encoded set of variables
df = pd.get_dummies(df, prefix='agency', columns=['agency'])
# df = pd.get_dummies(df, prefix='eco', columns=['ecoregion3'])
# df = pd.get_dummies(df, prefix='acq', columns=['lidar_acq'])

# %% [markdown]
# The different types of predictor variables we can use to predict a forest attribute, including climate, lidar-derived, soil, and satellite imagery.

# %%
CLIM_COLS = ['mat', 'mwmt', 'mcmt', 'td', 'map', 'msp', 'ahm', 'shm', 
             'dd_0', 'dd5', 'dd_18', 'dd18', 'nffd', 'bffp', 'effp', 
             'ffp', 'pas', 'emt', 'ext', 'eref', 'cmd', 'rh']
LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
       'strat1_return-proportion', 'strat2_return-proportion',
       'strat3_return-proportion', 'strat4_return-proportion',
       'strat5_return-proportion', 'strat0_intensity-median',
       'strat1_intensity-median', 'strat2_intensity-median',
       'strat3_intensity-median', 'strat4_intensity-median',
       'strat5_intensity-median', 'height_05-percentile',
       'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
       'height_95_percentile', 'height_max', 'cover', 'potential_volume',
       'stddev_height', 'surface_area_ratio', 'surface_volume',
       'surface_volume_ratio', 'aspect', 'elevation', 'overall_curvature',
       'plan_curvature', 'profile_curvature', 'slope', 'solar_radiation_index']

SOIL_COLS = ['bulk_dens', 'soil_depth', 'pct_clay_surf', 'pct_rock_surf', 'pct_sand_surf']

LANDSAT_COLS = ['green', 'blue', 'red', 'nir', 'endvi', 'ndvi', 'savi',
                'swir1', 'swir2', 'wetness', 'greenness', 'brightness']

AGENCY_COLS = ['agency_BLM', 'agency_USFS', 'agency_WADNR']

# ECOREGIONS = [col for col in df.columns if col.startswith('eco_')]

# %% [markdown]
# ## Selecting initial features and targets
# This is the first step in determining what features we want to use, and what we want to predict. Later, we can still apply some procedures to choose a subset of these features to make simpler models.

# %%
X_COLS = LIDAR_COLS + ['plot_size_ac', 'ecoregion3', 'distance_to_water_m'] + LANDSAT_COLS + CLIM_COLS
Y_COLS = ['ba']

# %% [markdown]
# ## Split the data into training and testing sets
# Since some plot_ids have multiple observations, we want all observations for each plot_id to fall entirely in train_set or entirely the training or testing sets because these samples are definitely not independent.

# %%
# a dataframe with unique plot ids
splits = pd.DataFrame(pd.unique(df['uuid']), columns=['uuid']).set_index('uuid')

# randomly assign each plot-id to train(0) or test(1) sets
np.random.seed(127)
splits['train0_test1'] = np.random.choice(2,
                                          size=len(splits),
                                          p=[0.8,0.2])

# add set assignments to the dataframe
df['train0_test1'] = splits.loc[df['uuid']]['train0_test1'].values

# %%
train_plots = df.loc[df['train0_test1'] == 0]
test_plots = df.loc[df['train0_test1'] == 1]
len(train_plots), len(test_plots)
# Out:
# (3355, 855)

# %%
x_train, x_test = train_plots[X_COLS].reset_index(drop=True), test_plots[X_COLS].reset_index(drop=True)
y_train, y_test = train_plots[Y_COLS].reset_index(drop=True), test_plots[Y_COLS].reset_index(drop=True)

# %% [markdown]
# ## Standardize features
# Scale all predictive features to have 0 mean and unit variance (subtracting mean, dividing by standard deviation).

# %%
x_scaler = StandardScaler()
x_scaler.fit(df[X_COLS].drop(['ecoregion3'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Consider a few transformations for the target variable

# %%
fig, axs = plt.subplots(1,6, figsize=(15,2.5))
axs.ravel()[0].hist(y_train.values, bins=20)

qtrans = QuantileTransformer(output_distribution='normal', random_state=127)
box_cox = PowerTransformer(method='box-cox')
yeo_johnson = PowerTransformer(method='yeo-johnson')

VALS = [y_train.values,
        np.log1p(y_train.values),
        np.sqrt(y_train.values),
        qtrans.fit_transform(y_train.values),
        box_cox.fit_transform(y_train.values + 1e-9),
        yeo_johnson.fit_transform(y_train.values)]

TITLES = ['Raw', 'Log', 'SQRT', 'Quantile', 'Box-Cox', 'Yeo-Johnson']
SHAPIRO_ps = [shapiro(vals)[-1] for vals in VALS]

for i, vals in enumerate(VALS):
    axs.ravel()[i].hist(vals, bins=20)
    axs.ravel()[i].set_title(TITLES[i])
    
plt.show();

# %%
# identify the closest to normally-distributed
TITLES[np.array(SHAPIRO_ps).argmax()]
# Out:
# 'SQRT'

# %%
# choose your transformer here
transformer = FunctionTransformer(np.sqrt, np.square, validate=False)

# %%
transformer.fit(df[Y_COLS])
y_train.loc[:,Y_COLS], y_test.loc[:,Y_COLS] = transformer.transform(y_train), transformer.transform(y_test)

# %% [markdown]
# ## Split datasets by ecoregion
# We want to explore model transferability between regions, so we'll train models independently on subsets of the data within a single ecoregion, as well as a model that is trained on all available ecoregions.

# %%
ecoregions = [reg for reg in pd.unique(df.ecoregion3) if ecoreg_counts.loc[reg]['uuid'] > 20]

eco_train_idx = [x_train.loc[x_train.ecoregion3 == eco].index.values for eco in ecoregions]
eco_test_idx = [x_test.loc[x_test.ecoregion3 == eco].index.values for eco in ecoregions]

eco_xtrain_dfs = [x_train.loc[x_train.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytrain_dfs = [y_train.loc[idx].values.ravel() for idx in eco_train_idx]
eco_xtest_dfs = [x_test.loc[x_test.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytest_dfs = [y_test.loc[idx].values.ravel() for idx in eco_test_idx]

# append a "global" model that contains data from all ecoregions
ecoregions.append('all')
ecoregion_names = ['_'.join(x.split('_')[0:2]) for x in ecoregions]
eco_xtrain_dfs.append(x_train.drop(['ecoregion3'], axis=1))
eco_ytrain_dfs.append(y_train.values.ravel())
eco_xtest_dfs.append(x_test.drop(['ecoregion3'], axis=1))
eco_ytest_dfs.append(y_test.values.ravel())

# %% [markdown]
# ## Scoring
# We'll use Root Mean Square Error to evaluate model performance.

# %%
def rmse(pred, obs):
    # use our transformer to calculate RMSE on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return np.sqrt((np.square(obs-pred)).mean())

# %%
def nrmse(pred, obs):
    # use our transformer to calculate percent RMSE on the original data scale
    this_rmse = rmse(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return this_rmse/obs.mean()

# %%
def mae(pred, obs):
    # use our transformer to calculate mean absolute error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return abs(pred - obs).mean()

# %%
def mape(pred, obs):
    # use our transformer to calculate mean average percent error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return abs(pred - obs).mean() / obs.mean()

# %%
def bias(pred, obs):
    # use our transformer to calculate mean bias on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return (pred - obs).mean()

# %% [markdown]
# This helper function will calculate RMSE scores for each regionally-trained model and the global model on each ecoregion.

# %%
def get_score_df(models, metric=rmse, feature_selectors=None):
    regional_scores = []
    global_scores = []
    counts = []
    
    for i, mod in enumerate(models):
        X_test = x_scaler.transform(eco_xtest_dfs[i])
        if feature_selectors:
            X_test = feature_selectors[i].transform(X_test)
        y_test = eco_ytest_dfs[i].reshape(-1, 1)
        reg_score = metric(mod.predict(X_test), y_test)
        regional_scores.append(reg_score.round(3))
        
        if feature_selectors:
            X_test = x_scaler.transform(eco_xtest_dfs[i])
            X_test = feature_selectors[-1].transform(X_test)
        glob_score = metric(models[-1].predict(X_test), y_test)
        global_scores.append(glob_score.round(3))
        count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
        counts.append(count)
        
    data = list(zip(regional_scores, global_scores, counts))
    res_df = pd.DataFrame(data=data,
                          columns=['regional_model', 'global_model', 'n'],
                          index=ecoregion_names)
    
    return res_df

# %% [markdown]
# ## Fit some models
# For each type of model, we'll employ cross-validation to tune model hyperparameters, generating a tuned model for each ecoregion as well as a tuned model using all training data. We'll work our way through:
#
# #### ElasticNet Regression
# Linear model that employs a mix of L1 and L2 regularization to penalize model complexity
#
# #### LASSO Regression
# Linear model that employs L1 regularization to penalize model complexity. We'll also work with a feature-selection process to fit models capped to an explicitly-predefined number of features.
#
# #### K-Nearest Neighbor Regression
#
# #### Random Forest Regression
#
# #### Gradient Boosting Trees Regression
#
# #### Support Vector Machine Regression

# %% [markdown]
# ## ElasticNet (Linear Model)

# %%
best_lms = []

for i in range(len(ecoregions)):
    lm = ElasticNetCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    lm.fit(X, y)
    best_lms.append(lm)

# %%
elastic_res = get_score_df(best_lms, rmse)
elastic_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             17.314        18.672   108
# coast_range                81.293        87.721  1646
# eastern_cascades           39.755        39.829   403
# north_cascades             62.186        66.456   490
# cascades                   78.817        80.484   728
# klamath_mountains          96.939       105.107   321
# northern_rockies           61.657        67.651   103
# puget_lowland              67.989        75.617   147
# willamette_valley          52.497        66.093    43
# all                        80.324        80.324  3355

# %%
coefs = np.array([lm.coef_ for lm in best_lms])
count_nonzero = [(~np.isclose(coef, 0, atol=1e-3)).sum() for coef in coefs]
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.189
# eastern_cascades_slopes_and_foothills                      -0.156
# north_cascades                                               0.15
# cascades                                                    0.051
# klamath_mountains_california_high_north_coast_r...          0.027
# northern_rockies                                               --
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                         0.088
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                       -0.941
# coast_range                                                          -0.124
# eastern_cascades_slopes_and_foothills                                 -0.05
# north_cascades                                                           --
# cascades                                                             -0.601
# klamath_mountains_california_high_north_coast_r...                   -0.047
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                  -0.142
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.787
# coast_range                                                          -0.567
# eastern_cascades_slopes_and_foothills                                -0.081
# north_cascades                                                        -0.78
# cascades                                                             -0.037
# klamath_mountains_california_high_north_coast_r...                   -0.229
# northern_rockies                                                     -0.796
# puget_lowland                                                        -0.911
# willamette_valley                                                        --
# all                                                                  -0.223
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        0.124
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                       -0.321
# cascades                                                              0.186
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                        -0.034
# willamette_valley                                                     -0.43
# all                                                                   0.274
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.587
# coast_range                                                           0.307
# eastern_cascades_slopes_and_foothills                                 0.421
# north_cascades                                                           --
# cascades                                                              0.133
# klamath_mountains_california_high_north_coast_r...                    0.976
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.036
# all                                                                   0.697
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.728
# coast_range                                                             0.2
# eastern_cascades_slopes_and_foothills                                 0.192
# north_cascades                                                        0.612
# cascades                                                              0.462
# klamath_mountains_california_high_north_coast_r...                    0.545
# northern_rockies                                                         --
# puget_lowland                                                         0.206
# willamette_valley                                                        --
# all                                                                   0.914
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.454
# eastern_cascades_slopes_and_foothills                                 0.952
# north_cascades                                                           --
# cascades                                                              0.551
# klamath_mountains_california_high_north_coast_r...                     2.08
# northern_rockies                                                      0.533
# puget_lowland                                                         0.211
# willamette_valley                                                     0.788
# all                                                                   2.056
#
#                                                    strat0_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                0.395
# north_cascades                                                       -0.16
# cascades                                                             0.473
# klamath_mountains_california_high_north_coast_r...                  -0.759
# northern_rockies                                                        --
# puget_lowland                                                       -0.123
# willamette_valley                                                       --
# all                                                                  0.068
#
#                                                    strat1_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.262
# cascades                                                            -0.752
# klamath_mountains_california_high_north_coast_r...                  -0.577
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.075
#
#                                                    strat2_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                          -0.18
# eastern_cascades_slopes_and_foothills                               -0.472
# north_cascades                                                      -0.161
# cascades                                                            -0.134
# klamath_mountains_california_high_north_coast_r...                  -0.587
# northern_rockies                                                        --
# puget_lowland                                                       -0.059
# willamette_valley                                                       --
# all                                                                 -0.304
#
#                                                     ...   nffd   bffp   effp  \
# blue_mountains                                      ...     --     --     --
# coast_range                                         ...     --     --     --
# eastern_cascades_slopes_and_foothills               ...     --     -- -0.048
# north_cascades                                      ...     --  0.019     --
# cascades                                            ...  -0.43     --  0.811
# klamath_mountains_california_high_north_coast_r...  ... -0.184  0.562     --
# northern_rockies                                    ...     --     --     --
# puget_lowland                                       ...     --     --     --
# willamette_valley                                   ...     --     --     --
# all                                                 ... -0.334     --  0.548
#
#                                                       ffp    pas    emt  \
# blue_mountains                                         --     --     --
# coast_range                                            --     --  0.003
# eastern_cascades_slopes_and_foothills                  --     --     --
# north_cascades                                         --  0.518     --
# cascades                                            0.047 -0.097 -1.084
# klamath_mountains_california_high_north_coast_r... -0.387  0.044 -0.512
# northern_rockies                                       --     --     --
# puget_lowland                                          --     --     --
# willamette_valley                                      --     --     --
# all                                                    -- -0.086     --
#
#                                                       ext   eref    cmd     rh
# blue_mountains                                         --     -- -0.035     --
# coast_range                                        -0.016     --     --  0.559
# eastern_cascades_slopes_and_foothills              -0.313     --     --     --
# north_cascades                                         --     --     --     --
# cascades                                               --  0.582  0.155  0.338
# klamath_mountains_california_high_north_coast_r... -0.429     --     --  0.728
# northern_rockies                                       --     --     --     --
# puget_lowland                                          --     --     --     --
# willamette_valley                                      --     --     --     --
# all                                                -0.596   1.29  0.757  0.863
#
# [10 rows x 67 columns]

# %% [markdown]
# ## LASSO (Linear Model)
# Starting with implicit feature selection via L1 regularization of coefficients.

# %%
best_lassos = []

for i in range(len(ecoregions)):
    lasso = LassoCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000, n_alphas=1000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    lasso.fit(X, y)
    best_lassos.append(lasso)

# %%
lasso_res = get_score_df(best_lassos)
lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             17.738        19.648   108
# coast_range                80.963        87.614  1646
# eastern_cascades           45.955        39.789   403
# north_cascades             62.191        66.731   490
# cascades                   78.724        80.699   728
# klamath_mountains          97.171       104.650   321
# northern_rockies           61.294        67.797   103
# puget_lowland              80.453        74.930   147
# willamette_valley          52.523        65.840    43
# all                        80.265        80.265  3355

# %%
coefs = np.array([lm.coef_ for lm in best_lassos])
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.178
# eastern_cascades_slopes_and_foothills                          --
# north_cascades                                               0.11
# cascades                                                    0.038
# klamath_mountains_california_high_north_coast_r...             --
# northern_rockies                                               --
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                         0.098
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                             -0.426
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.386
# coast_range                                                          -0.499
# eastern_cascades_slopes_and_foothills                                -0.188
# north_cascades                                                       -0.919
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.212
# northern_rockies                                                      -0.96
# puget_lowland                                                        -1.438
# willamette_valley                                                        --
# all                                                                  -0.116
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                       -0.149
# cascades                                                              0.131
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.238
# all                                                                   0.361
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.294
# coast_range                                                           0.286
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                              0.055
# klamath_mountains_california_high_north_coast_r...                    1.103
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.806
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.694
# coast_range                                                           0.156
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                        0.753
# cascades                                                              0.376
# klamath_mountains_california_high_north_coast_r...                    0.742
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   1.011
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.318
# eastern_cascades_slopes_and_foothills                                 0.105
# north_cascades                                                           --
# cascades                                                              0.394
# klamath_mountains_california_high_north_coast_r...                    2.839
# northern_rockies                                                      0.954
# puget_lowland                                                            --
# willamette_valley                                                     0.916
# all                                                                   2.301
#
#                                                    strat0_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.047
# cascades                                                             0.453
# klamath_mountains_california_high_north_coast_r...                  -1.055
# northern_rockies                                                        --
# puget_lowland                                                       -0.039
# willamette_valley                                                       --
# all                                                                  0.047
#
#                                                    strat1_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.396
# cascades                                                             -0.75
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.033
#
#                                                    strat2_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                          -0.18
# eastern_cascades_slopes_and_foothills                               -0.089
# north_cascades                                                       -0.09
# cascades                                                            -0.051
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.306
#
#                                                     ...   nffd   bffp   effp  \
# blue_mountains                                      ...     --     --     --
# coast_range                                         ...     --     --     --
# eastern_cascades_slopes_and_foothills               ...     --     --     --
# north_cascades                                      ...     --     --     --
# cascades                                            ...     --     --  0.903
# klamath_mountains_california_high_north_coast_r...  ...     --  0.472     --
# northern_rockies                                    ...     --     --     --
# puget_lowland                                       ...     --     --     --
# willamette_valley                                   ...     --     --     --
# all                                                 ... -0.105 -0.017  0.719
#
#                                                       ffp    pas    emt  \
# blue_mountains                                         --     --     --
# coast_range                                            --     --     --
# eastern_cascades_slopes_and_foothills                  --     --     --
# north_cascades                                         --   0.51     --
# cascades                                               -- -0.086 -1.718
# klamath_mountains_california_high_north_coast_r... -0.089     --     --
# northern_rockies                                       --     --     --
# puget_lowland                                          --     --     --
# willamette_valley                                      --     --     --
# all                                                    -- -0.136 -0.079
#
#                                                       ext   eref    cmd     rh
# blue_mountains                                         --     --     --     --
# coast_range                                            --     --     --  0.627
# eastern_cascades_slopes_and_foothills                  --     --     --     --
# north_cascades                                         --     --     --     --
# cascades                                               --  0.117     --     --
# klamath_mountains_california_high_north_coast_r... -0.464     --     --  0.223
# northern_rockies                                       --     --     --     --
# puget_lowland                                          --     --     --     --
# willamette_valley                                      --     --     --     --
# all                                                -0.756  1.765  0.879  0.957
#
# [10 rows x 65 columns]

# %% [markdown]
# Now we'll explicitly define the maximum number of features to use for fitting a linear model. We'll trim features by iteratively increasing a threshold for coefficients using LASSO regression

# %%
MAX_FEATURES = 5
sfms = [] # transformers that filter X features
trimmed_lassos = [] # re-fit lasso regressions on the subset of the features

for i, lasso in enumerate(best_lassos):
    lasso = deepcopy(lasso)
    sfm = SelectFromModel(lasso, threshold=0.001)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    Y = (eco_ytrain_dfs[i].ravel())
    sfm.fit(X, Y)
    n_features = sfm.transform(X).shape[1]

    # Reset the threshold till the number of features equals two.
    # Note that the attribute can be set directly instead of repeatedly
    # fitting the metatransformer.
    while n_features > MAX_FEATURES:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    
    sfms.append(sfm)
    try:
        trimmed_lassos.append(lasso.fit(sfm.transform(X), Y))
    except ValueError:
        print(ecoregion_names[i])
        raise
    
trimmed_regional_scores = []
trimmed_global_scores = []
counts = []

for i, lasso in enumerate(trimmed_lassos):
    X_reg = sfms[i].transform(x_scaler.transform(eco_xtest_dfs[i]))
    X_glob = sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i]))
    observed = eco_ytest_dfs[i]
    
    reg_score = rmse(lasso.predict(X_reg), observed)
    glob_score = rmse(trimmed_lassos[-1].predict(X_glob), observed)
    
    trimmed_regional_scores.append(reg_score.round(3))
    trimmed_global_scores.append(glob_score.round(3))
    
    count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
    counts.append(count)
    

trimmed_lasso_res = pd.DataFrame(data=list(zip(trimmed_regional_scores, trimmed_global_scores, counts)),
                      columns=['regional_model', 'global_model', 'n'],
                      index=ecoregion_names)
trimmed_lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             16.635        55.195   108
# coast_range                83.831       121.308  1646
# eastern_cascades           44.646        65.134   403
# north_cascades             73.588        91.635   490
# cascades                   83.130       120.397   728
# klamath_mountains         106.403       133.976   321
# northern_rockies           61.262        69.851   103
# puget_lowland              81.270       110.583   147
# willamette_valley          51.934        90.857    43
# all                       112.054       112.054  3355

# %%
coefs = []
for i in range(len(ecoregions)):
    cols = np.zeros(eco_xtest_dfs[i].columns.shape)
    cols[sfms[i].get_support()] = trimmed_lassos[i].coef_
    coefs.append(cols)
    
coefs = np.array(coefs)

coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -1.213
# coast_range                                                           -0.78
# eastern_cascades_slopes_and_foothills                                 -0.31
# north_cascades                                                       -1.632
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                     -0.932
# puget_lowland                                                        -1.552
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.247
# all                                                                      --
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.897
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                        1.508
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -1.678
# northern_rockies                                                      1.512
# puget_lowland                                                            --
# willamette_valley                                                     0.947
# all                                                                    3.69
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# eastern_cascades_slopes_and_foothills                                --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# northern_rockies                                                     --
# puget_lowland                                                     0.216
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_50-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# eastern_cascades_slopes_and_foothills                                --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# northern_rockies                                                     --
# puget_lowland                                                     0.114
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_75-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# eastern_cascades_slopes_and_foothills                             2.499
# north_cascades                                                    1.961
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                10.08
# northern_rockies                                                   0.53
# puget_lowland                                                     0.644
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_95_percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# eastern_cascades_slopes_and_foothills                                --
# north_cascades                                                    0.042
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                3.633
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_max  cover  ...  \
# blue_mountains                                             --   3.16  ...
# coast_range                                                --  1.091  ...
# eastern_cascades_slopes_and_foothills                      --  0.183  ...
# north_cascades                                             --     --  ...
# cascades                                                   --     --  ...
# klamath_mountains_california_high_north_coast_r...         --     --  ...
# northern_rockies                                           --  0.129  ...
# puget_lowland                                              --     --  ...
# willamette_valley                                          --     --  ...
# all                                                    -1.161     --  ...
#
#                                                      ndvi  swir2 wetness  \
# blue_mountains                                     -0.803     --      --
# coast_range                                            --     --      --
# eastern_cascades_slopes_and_foothills                  -- -0.976      --
# north_cascades                                         --     --      --
# cascades                                               -- -3.281      --
# klamath_mountains_california_high_north_coast_r...     --     --      --
# northern_rockies                                       --     --    0.76
# puget_lowland                                          --     --      --
# willamette_valley                                      --     --      --
# all                                                    --     --      --
#
#                                                     mwmt    map    dd5  dd_18  \
# blue_mountains                                        --     --     --     --
# coast_range                                           --     --     --     --
# eastern_cascades_slopes_and_foothills              -0.84     --     --     --
# north_cascades                                        --  1.133     --     --
# cascades                                              --     --  0.542     --
# klamath_mountains_california_high_north_coast_r...    --     --     --     --
# northern_rockies                                      --     --     --     --
# puget_lowland                                         --     --     --     --
# willamette_valley                                     --     --     --     --
# all                                                   --     -- -3.606 -3.691
#
#                                                       emt   eref     rh
# blue_mountains                                         --     --     --
# coast_range                                            --     --  1.243
# eastern_cascades_slopes_and_foothills                  --     --     --
# north_cascades                                         --     --     --
# cascades                                           -3.661     --     --
# klamath_mountains_california_high_north_coast_r...     --     --     --
# northern_rockies                                       --     --     --
# puget_lowland                                          --     --     --
# willamette_valley                                      --     --     --
# all                                                    --  0.735     --
#
# [10 rows x 25 columns]

# %% [markdown]
# ## K-Nearest Neighbors Regression

# %%
# Set the parameters by cross-validation
knn_params = {'n_neighbors': [1,2,3,4,5,10,20],
              'weights': ['uniform', 'distance'],
              'metric': ['minkowski', 'manhattan']}


knn_gs = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=knn_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_knns = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    knn_gs.fit(X, y)
    best_fit = knn_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_knns.append(best_fit)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    2.7s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    2.9s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.2s remaining:    0.5s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    1.7s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    2.0s finished

# %%
knn_res = get_score_df(best_knns)
knn_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             30.522        30.425   108
# coast_range                88.696        87.550  1646
# eastern_cascades           51.891        51.825   403
# north_cascades             64.431        66.752   490
# cascades                   93.939        85.019   728
# klamath_mountains         100.937       102.045   321
# northern_rockies           70.097        69.236   103
# puget_lowland              77.115        81.300   147
# willamette_valley          38.000        49.303    43
# all                        81.503        81.503  3355

# %% [markdown]
# ## Random Forest Regression

# %%
# Set the parameters by cross-validation
rf_params = {'n_estimators': [100, 500, 1000, 5000],
             'max_features': ['sqrt'],
             'max_depth': [3, 5, 10, 25, 50],
             'min_samples_leaf': [1,2,4],
             'bootstrap': [True, False]}


rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=rf_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_rfs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    rf_gs.fit(X, y)
    best_fit = rf_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_rfs.append(best_fit)
# Out:
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 297 out of 360 | elapsed:   22.0s remaining:    4.7s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   28.9s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   19.1s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  2.4min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   58.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:   15.8s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.1min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:   18.8s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 297 out of 360 | elapsed:   60.0s remaining:   12.7s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.4min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:   16.0s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   51.0s finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 297 out of 360 | elapsed:   28.3s remaining:    6.0s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   37.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 297 out of 360 | elapsed:   30.4s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   40.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   33.6s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   53.7s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  7.0min finished

# %%
rf_res = get_score_df(best_rfs)
rf_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             20.967        20.141   108
# coast_range                80.482        80.344  1646
# eastern_cascades           47.897        46.075   403
# north_cascades             64.173        57.968   490
# cascades                   82.630        73.732   728
# klamath_mountains         108.864       107.942   321
# northern_rockies           64.643        65.803   103
# puget_lowland              66.823        66.575   147
# willamette_valley          43.236        61.525    43
# all                        74.922        74.922  3355

# %%
### Employing feature selection to try and improve random forest regression

# %%
importances = best_rfs[-1].feature_importances_
indices = np.argsort(importances)[::-1]
features = eco_xtrain_dfs[-1].columns[indices]

# Print the feature ranking
print("Feature ranking:")

for f in range(eco_xtrain_dfs[-1].shape[1]):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. surface_volume (0.132349)
# 2. height_50-percentile (0.080714)
# 3. potential_volume (0.077353)
# 4. height_25-percentile (0.062422)
# 5. cover (0.055310)
# 6. height_75-percentile (0.052970)
# 7. strat1_return-proportion (0.034273)
# 8. strat5_return-proportion (0.030275)
# 9. swir2 (0.028145)
# 10. strat0_return-proportion (0.026203)
# 11. swir1 (0.025219)
# 12. surface_area_ratio (0.023724)
# 13. stddev_height (0.017025)
# 14. height_95_percentile (0.016138)
# 15. wetness (0.015784)
# 16. red (0.011728)
# 17. strat2_return-proportion (0.010486)
# 18. ndvi (0.010135)
# 19. savi (0.009979)
# 20. plot_size_ac (0.009811)
# 21. green (0.009777)
# 22. height_max (0.009609)
# 23. strat4_return-proportion (0.008980)
# 24. emt (0.008006)
# 25. strat3_return-proportion (0.007791)
# 26. brightness (0.007485)
# 27. elevation (0.007273)
# 28. strat0_intensity-median (0.006989)
# 29. height_05-percentile (0.006941)
# 30. map (0.006549)
# 31. strat1_intensity-median (0.006485)
# 32. strat2_intensity-median (0.006407)
# 33. cmd (0.006292)
# 34. blue (0.006264)
# 35. td (0.006243)
# 36. profile_curvature (0.006214)
# 37. overall_curvature (0.006197)
# 38. slope (0.006050)
# 39. solar_radiation_index (0.006014)
# 40. plan_curvature (0.005924)
# 41. strat3_intensity-median (0.005844)
# 42. ext (0.005789)
# 43. msp (0.005787)
# 44. shm (0.005726)
# 45. nir (0.005655)
# 46. greenness (0.005640)
# 47. ahm (0.005411)
# 48. strat4_intensity-median (0.005364)
# 49. eref (0.005083)
# 50. endvi (0.005029)
# 51. strat5_intensity-median (0.005017)
# 52. mcmt (0.004858)
# 53. aspect (0.004814)
# 54. distance_to_water_m (0.004798)
# 55. pas (0.004692)
# 56. dd18 (0.004617)
# 57. dd5 (0.004609)
# 58. dd_0 (0.004489)
# 59. bffp (0.004458)
# 60. nffd (0.004256)
# 61. returns_per_m2 (0.004232)
# 62. dd_18 (0.004118)
# 63. ffp (0.004062)
# 64. mwmt (0.003983)
# 65. effp (0.003753)
# 66. rh (0.003265)
# 67. mat (0.003120)
# 68. surface_volume_ratio (0.000000)

# %% [markdown]
# ## Gradient Boosting Trees Regression

# %%
# Set the parameters by cross-validation
gb_params = {'n_estimators': [100, 500, 1000, 5000],
             'learning_rate': [0.01, 0.1],
             'max_depth': [2, 3, 4, 5, 10],
             'max_features': ['sqrt'] 
            }

gb_gs = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=gb_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_gbs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    gb_gs.fit(X, y)
    best_fit = gb_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_gbs.append(best_fit)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    5.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   17.7s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.3s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    3.2s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.0s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    8.3s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.7s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.7s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.6s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.8s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.5s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.5s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.3s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.5s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   44.3s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   45.8s finished

# %%
gb_res = get_score_df(best_gbs)
gb_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             21.533        18.680   108
# coast_range                79.225        79.293  1646
# eastern_cascades           49.930        44.644   403
# north_cascades             56.915        59.333   490
# cascades                   78.641        73.379   728
# klamath_mountains         109.907       106.761   321
# northern_rockies           59.825        65.385   103
# puget_lowland              66.956        65.886   147
# willamette_valley          70.231        61.345    43
# all                        74.227        74.227  3355

# %%
### Employing feature selection to try and improve gradient boosting regression

# %% [markdown]
# ## Support Vector Machines Regression

# %%
# Set the parameters by cross-validation
svm_params = {'kernel': ['linear', 'rbf'],
              'gamma': ['scale', 'auto'],
              'C': [0.1,1,10,100,1000]
              }

svm_gs = GridSearchCV(estimator=SVR(), param_grid=svm_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_svms = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    svm_gs.fit(X, y)
    best_fit = svm_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_svms.append(best_fit)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   11.0s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.5s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  4.9min finished
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.1min finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   13.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    8.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    3.2s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 15.7min finished

# %%
svm_res = get_score_df(best_svms)
svm_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             23.335        18.907   108
# coast_range                80.909        78.892  1646
# eastern_cascades           37.877        44.405   403
# north_cascades             59.793        61.070   490
# cascades                   86.114        78.787   728
# klamath_mountains          97.758       102.251   321
# northern_rockies           64.980        69.349   103
# puget_lowland              79.253        72.291   147
# willamette_valley          60.917        76.718    43
# all                        75.048        75.048  3355

# %%
### Employing feature selection to try and improve support vector regression

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

def scatter_graphs(model_dict):
    names = MODELS.keys()
    EXTEND_PCT = 0.10
    
    fig, axs = plt.subplots(len(ecoregion_names), len(names), 
                            sharex=True, sharey=True,
                            figsize=(12,15)
                           )
    
    all_obs = transformer.inverse_transform(eco_ytest_dfs[-1].reshape(-1,1))
    obs_min = all_obs.min()
    obs_max = all_obs.max()
    rng = obs_max - obs_min
        
    for i, ecoreg in enumerate(ecoregion_names):
        observed = transformer.inverse_transform(eco_ytest_dfs[i].reshape(-1,1))
        
        for j, name in enumerate(names):
            axs[0,j].set_title(name)
            axs[i,0].set_ylabel(ecoreg)
            axs[i,j].set_xlim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_ylim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_aspect('equal')
            
            if name == 'LASSO_{}'.format(MAX_FEATURES):
                predicted = MODELS[name][-1].predict(sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i])))
            else:
                predicted = MODELS[name][-1].predict(x_scaler.transform(eco_xtest_dfs[i]))
            
            predicted = transformer.inverse_transform(predicted.reshape(-1,1))
            axs[i,j].scatter(observed, predicted, s=0.5)
            axs[i,j].plot((obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng), 
                          (obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng),
                         color='k', lw=0.5)
            
    plt.tight_layout(pad=0.001)

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

scatter_graphs(MODELS)

# %% [markdown]
# ## View scores for regional and global models

# %%
MODEL_NAMES = ['ElasticNet', 'LASSO', 'LASSO_{}'.format(MAX_FEATURES), 'KNN', 'RF', 'GB', 'SVM']
BEST_MODELS = [best_lms, best_lassos, trimmed_lassos, best_knns, best_rfs, best_gbs, best_svms]
    
def compare_models(metric):
    score_dfs = []

    for name, best_models in list(zip(MODEL_NAMES, BEST_MODELS)):
        if name == 'LASSO_{}'.format(MAX_FEATURES):
            score_df = get_score_df(best_models, metric, sfms) 
            score_dfs.append(score_df)
        else:
            score_df = get_score_df(best_models, metric) 
            score_dfs.append(score_df)
        
    counts = np.array(score_dfs[-1]['n'].values)
    regional_data = np.array([df['regional_model'].values for df in score_dfs])
    global_data = np.array([df['global_model'].values for df in score_dfs])
    
    return regional_data, global_data, counts

# %%
def highlight_best(s):
    '''
    highlight the closest value to zero in a Series yellow.
    '''
    lowest_idx = abs(s).idxmin()
    return ['background-color: yellow' if idx==lowest_idx else '' for idx in s.index]

# %%
print('Regional Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores
 .style
 .format('{:,.0f}')
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, RMSE
# <style  type="text/css" >
#     #T_daa14924_4ed1_11ea_815b_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_daa14924_4ed1_11ea_815b_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_daa14924_4ed1_11ea_815b_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_daa14924_4ed1_11ea_815b_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_daa14924_4ed1_11ea_815b_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_daa14924_4ed1_11ea_815b_00505683952erow5_col0 {
#             background-color:  yellow;
#         }    #T_daa14924_4ed1_11ea_815b_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_daa14924_4ed1_11ea_815b_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_daa14924_4ed1_11ea_815b_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_daa14924_4ed1_11ea_815b_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_daa14924_4ed1_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_daa14924_4ed1_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow0_col1" class="data row0 col1" >18</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow0_col2" class="data row0 col2" >17</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow0_col3" class="data row0 col3" >31</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow0_col4" class="data row0 col4" >21</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow0_col5" class="data row0 col5" >22</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow0_col6" class="data row0 col6" >23</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_daa14924_4ed1_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow1_col0" class="data row1 col0" >81</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow1_col1" class="data row1 col1" >81</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow1_col2" class="data row1 col2" >84</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow1_col3" class="data row1 col3" >89</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow1_col4" class="data row1 col4" >80</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow1_col5" class="data row1 col5" >79</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow1_col6" class="data row1 col6" >81</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_daa14924_4ed1_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow2_col0" class="data row2 col0" >40</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow2_col1" class="data row2 col1" >46</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow2_col2" class="data row2 col2" >45</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow2_col3" class="data row2 col3" >52</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow2_col4" class="data row2 col4" >48</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow2_col5" class="data row2 col5" >50</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow2_col6" class="data row2 col6" >38</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_daa14924_4ed1_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow3_col0" class="data row3 col0" >62</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow3_col1" class="data row3 col1" >62</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow3_col2" class="data row3 col2" >74</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow3_col3" class="data row3 col3" >64</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow3_col4" class="data row3 col4" >64</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow3_col5" class="data row3 col5" >57</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow3_col6" class="data row3 col6" >60</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_daa14924_4ed1_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow4_col0" class="data row4 col0" >79</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow4_col1" class="data row4 col1" >79</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow4_col2" class="data row4 col2" >83</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow4_col3" class="data row4 col3" >94</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow4_col4" class="data row4 col4" >83</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow4_col5" class="data row4 col5" >79</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow4_col6" class="data row4 col6" >86</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_daa14924_4ed1_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow5_col0" class="data row5 col0" >97</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow5_col1" class="data row5 col1" >97</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow5_col2" class="data row5 col2" >106</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow5_col3" class="data row5 col3" >101</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow5_col4" class="data row5 col4" >109</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow5_col5" class="data row5 col5" >110</td>
#                         <td id="T_daa14924_4ed1_11ea_815b_00505683952erow5_col6" class="data row5 co

# %%
print('Regional Models, RMSE%')
regional_data, global_data, counts = compare_models(nrmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores[regional_scores.columns[:-1]]
 .style
 .format("{:.0%}")
 .highlight_min(color='yellow', axis=1))
# Out:
# Regional Models, RMSE%
# <style  type="text/css" >
#     #T_e0c36fd0_4ed1_11ea_815b_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_e0c36fd0_4ed1_11ea_815b_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_e0c36fd0_4ed1_11ea_815b_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_e0c36fd0_4ed1_11ea_815b_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_e0c36fd0_4ed1_11ea_815b_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_e0c36fd0_4ed1_11ea_815b_00505683952erow5_col0 {
#             background-color:  yellow;
#         }    #T_e0c36fd0_4ed1_11ea_815b_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_e0c36fd0_4ed1_11ea_815b_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_e0c36fd0_4ed1_11ea_815b_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_e0c36fd0_4ed1_11ea_815b_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_e0c36fd0_4ed1_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e0c36fd0_4ed1_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow0_col0" class="data row0 col0" >28%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow0_col1" class="data row0 col1" >29%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow0_col2" class="data row0 col2" >27%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow0_col3" class="data row0 col3" >49%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow0_col4" class="data row0 col4" >34%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow0_col5" class="data row0 col5" >35%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow0_col6" class="data row0 col6" >38%</td>
#             </tr>
#             <tr>
#                         <th id="T_e0c36fd0_4ed1_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow1_col0" class="data row1 col0" >38%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow1_col1" class="data row1 col1" >38%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow1_col2" class="data row1 col2" >40%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow1_col3" class="data row1 col3" >42%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow1_col4" class="data row1 col4" >38%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow1_col5" class="data row1 col5" >38%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow1_col6" class="data row1 col6" >38%</td>
#             </tr>
#             <tr>
#                         <th id="T_e0c36fd0_4ed1_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow2_col0" class="data row2 col0" >35%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow2_col1" class="data row2 col1" >41%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow2_col2" class="data row2 col2" >40%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow2_col3" class="data row2 col3" >46%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow2_col4" class="data row2 col4" >42%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow2_col5" class="data row2 col5" >44%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow2_col6" class="data row2 col6" >34%</td>
#             </tr>
#             <tr>
#                         <th id="T_e0c36fd0_4ed1_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow3_col0" class="data row3 col0" >38%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow3_col1" class="data row3 col1" >38%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow3_col2" class="data row3 col2" >45%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow3_col3" class="data row3 col3" >40%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow3_col4" class="data row3 col4" >39%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow3_col5" class="data row3 col5" >35%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow3_col6" class="data row3 col6" >37%</td>
#             </tr>
#             <tr>
#                         <th id="T_e0c36fd0_4ed1_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow4_col0" class="data row4 col0" >38%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow4_col1" class="data row4 col1" >38%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow4_col2" class="data row4 col2" >40%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow4_col3" class="data row4 col3" >45%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow4_col4" class="data row4 col4" >40%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow4_col5" class="data row4 col5" >38%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow4_col6" class="data row4 col6" >41%</td>
#             </tr>
#             <tr>
#                         <th id="T_e0c36fd0_4ed1_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow5_col0" class="data row5 col0" >48%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow5_col1" class="data row5 col1" >49%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow5_col2" class="data row5 col2" >53%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow5_col3" class="data row5 col3" >50%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow5_col4" class="data row5 col4" >55%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow5_col5" class="data row5 col5" >55%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow5_col6" class="data row5 col6" >49%</td>
#             </tr>
#             <tr>
#                         <th id="T_e0c36fd0_4ed1_11ea_815b_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow6_col0" class="data row6 col0" >57%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow6_col1" class="data row6 col1" >57%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b_00505683952erow6_col2" class="data row6 col2" >57%</td>
#                         <td id="T_e0c36fd0_4ed1_11ea_815b

# %%
print('Regional Models, Bias')
regional_data, global_data, counts = compare_models(bias)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores
 .style
 .format('{:,.0f}')
 .apply(highlight_best, axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, Bias
# <style  type="text/css" >
#     #T_e6e4d84a_4ed1_11ea_815b_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_e6e4d84a_4ed1_11ea_815b_00505683952erow1_col1 {
#             background-color:  yellow;
#         }    #T_e6e4d84a_4ed1_11ea_815b_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_e6e4d84a_4ed1_11ea_815b_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_e6e4d84a_4ed1_11ea_815b_00505683952erow4_col3 {
#             background-color:  yellow;
#         }    #T_e6e4d84a_4ed1_11ea_815b_00505683952erow5_col3 {
#             background-color:  yellow;
#         }    #T_e6e4d84a_4ed1_11ea_815b_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_e6e4d84a_4ed1_11ea_815b_00505683952erow7_col3 {
#             background-color:  yellow;
#         }    #T_e6e4d84a_4ed1_11ea_815b_00505683952erow8_col1 {
#             background-color:  yellow;
#         }    #T_e6e4d84a_4ed1_11ea_815b_00505683952erow9_col3 {
#             background-color:  yellow;
#         }</style><table id="T_e6e4d84a_4ed1_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e6e4d84a_4ed1_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow0_col0" class="data row0 col0" >-2</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow0_col1" class="data row0 col1" >-3</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow0_col2" class="data row0 col2" >-0</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow0_col3" class="data row0 col3" >-9</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow0_col4" class="data row0 col4" >-6</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow0_col5" class="data row0 col5" >-5</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow0_col6" class="data row0 col6" >-4</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e4d84a_4ed1_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow1_col0" class="data row1 col0" >-4</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow1_col1" class="data row1 col1" >-3</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow1_col2" class="data row1 col2" >-4</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow1_col3" class="data row1 col3" >-8</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow1_col4" class="data row1 col4" >-8</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow1_col5" class="data row1 col5" >-8</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow1_col6" class="data row1 col6" >-4</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e4d84a_4ed1_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow2_col0" class="data row2 col0" >-5</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow2_col1" class="data row2 col1" >-8</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow2_col2" class="data row2 col2" >-6</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow2_col3" class="data row2 col3" >-10</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow2_col4" class="data row2 col4" >-8</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow2_col5" class="data row2 col5" >-3</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow2_col6" class="data row2 col6" >-2</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e4d84a_4ed1_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow3_col0" class="data row3 col0" >-13</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow3_col1" class="data row3 col1" >-12</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow3_col2" class="data row3 col2" >-15</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow3_col3" class="data row3 col3" >-10</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow3_col4" class="data row3 col4" >-17</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow3_col5" class="data row3 col5" >-10</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow3_col6" class="data row3 col6" >-4</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e4d84a_4ed1_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow4_col0" class="data row4 col0" >-6</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow4_col1" class="data row4 col1" >-6</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow4_col2" class="data row4 col2" >-15</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow4_col3" class="data row4 col3" >3</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow4_col4" class="data row4 col4" >-8</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow4_col5" class="data row4 col5" >-5</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow4_col6" class="data row4 col6" >-8</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e4d84a_4ed1_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow5_col0" class="data row5 col0" >-19</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow5_col1" class="data row5 col1" >-20</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow5_col2" class="data row5 col2" >-19</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow5_col3" class="data row5 col3" >-13</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow5_col4" class="data row5 col4" >-24</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow5_col5" class="data row5 col5" >-24</td>
#                         <td id="T_e6e4d84a_4ed1_11ea_815b_00505683952erow5_col6" class="dat

# %%
print('Regional Models, MAE')
regional_data, global_data, counts = compare_models(mae)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores
 .style
 .format('{:,.0f}')
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, MAE
# <style  type="text/css" >
#     #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow6_col2 {
#             background-color:  yellow;
#         }    #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_ecf0f9b2_4ed1_11ea_815b_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_ecf0f9b2_4ed1_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ecf0f9b2_4ed1_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow0_col0" class="data row0 col0" >13</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow0_col1" class="data row0 col1" >13</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow0_col2" class="data row0 col2" >13</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow0_col3" class="data row0 col3" >21</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow0_col4" class="data row0 col4" >14</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow0_col5" class="data row0 col5" >15</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow0_col6" class="data row0 col6" >16</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_ecf0f9b2_4ed1_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow1_col0" class="data row1 col0" >57</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow1_col1" class="data row1 col1" >57</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow1_col2" class="data row1 col2" >59</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow1_col3" class="data row1 col3" >63</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow1_col4" class="data row1 col4" >56</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow1_col5" class="data row1 col5" >55</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow1_col6" class="data row1 col6" >56</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_ecf0f9b2_4ed1_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow2_col0" class="data row2 col0" >28</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow2_col1" class="data row2 col1" >31</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow2_col2" class="data row2 col2" >30</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow2_col3" class="data row2 col3" >35</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow2_col4" class="data row2 col4" >32</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow2_col5" class="data row2 col5" >32</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow2_col6" class="data row2 col6" >27</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_ecf0f9b2_4ed1_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow3_col0" class="data row3 col0" >44</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow3_col1" class="data row3 col1" >44</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow3_col2" class="data row3 col2" >52</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow3_col3" class="data row3 col3" >44</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow3_col4" class="data row3 col4" >42</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow3_col5" class="data row3 col5" >40</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow3_col6" class="data row3 col6" >42</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_ecf0f9b2_4ed1_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow4_col0" class="data row4 col0" >55</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow4_col1" class="data row4 col1" >55</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow4_col2" class="data row4 col2" >58</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow4_col3" class="data row4 col3" >63</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow4_col4" class="data row4 col4" >52</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow4_col5" class="data row4 col5" >51</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow4_col6" class="data row4 col6" >52</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_ecf0f9b2_4ed1_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow5_col0" class="data row5 col0" >65</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow5_col1" class="data row5 col1" >65</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow5_col2" class="data row5 col2" >72</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow5_col3" class="data row5 col3" >72</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow5_col4" class="data row5 col4" >72</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow5_col5" class="data row5 col5" >71</td>
#                         <td id="T_ecf0f9b2_4ed1_11ea_815b_00505683952erow5_col6" class="data row5 col6"

# %%
print('Regional Models, MAPE')
regional_data, global_data, counts = compare_models(mape)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores[regional_scores.columns[:-1]]
 .style
 .format("{:.0%}")
 .highlight_min(color='yellow', axis=1))
# Out:
# Regional Models, MAPE
# <style  type="text/css" >
#     #T_f3028c44_4ed1_11ea_815b_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_f3028c44_4ed1_11ea_815b_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_f3028c44_4ed1_11ea_815b_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_f3028c44_4ed1_11ea_815b_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_f3028c44_4ed1_11ea_815b_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_f3028c44_4ed1_11ea_815b_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_f3028c44_4ed1_11ea_815b_00505683952erow6_col2 {
#             background-color:  yellow;
#         }    #T_f3028c44_4ed1_11ea_815b_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_f3028c44_4ed1_11ea_815b_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_f3028c44_4ed1_11ea_815b_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_f3028c44_4ed1_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f3028c44_4ed1_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow0_col0" class="data row0 col0" >22%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow0_col1" class="data row0 col1" >20%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow0_col2" class="data row0 col2" >20%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow0_col3" class="data row0 col3" >33%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow0_col4" class="data row0 col4" >23%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow0_col5" class="data row0 col5" >24%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow0_col6" class="data row0 col6" >26%</td>
#             </tr>
#             <tr>
#                         <th id="T_f3028c44_4ed1_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow1_col0" class="data row1 col0" >27%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow1_col1" class="data row1 col1" >27%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow1_col2" class="data row1 col2" >28%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow1_col3" class="data row1 col3" >30%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow1_col4" class="data row1 col4" >26%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow1_col5" class="data row1 col5" >26%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow1_col6" class="data row1 col6" >27%</td>
#             </tr>
#             <tr>
#                         <th id="T_f3028c44_4ed1_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow2_col0" class="data row2 col0" >25%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow2_col1" class="data row2 col1" >27%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow2_col2" class="data row2 col2" >26%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow2_col3" class="data row2 col3" >31%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow2_col4" class="data row2 col4" >28%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow2_col5" class="data row2 col5" >29%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow2_col6" class="data row2 col6" >24%</td>
#             </tr>
#             <tr>
#                         <th id="T_f3028c44_4ed1_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow3_col0" class="data row3 col0" >27%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow3_col1" class="data row3 col1" >27%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow3_col2" class="data row3 col2" >32%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow3_col3" class="data row3 col3" >27%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow3_col4" class="data row3 col4" >26%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow3_col5" class="data row3 col5" >25%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow3_col6" class="data row3 col6" >26%</td>
#             </tr>
#             <tr>
#                         <th id="T_f3028c44_4ed1_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow4_col0" class="data row4 col0" >26%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow4_col1" class="data row4 col1" >27%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow4_col2" class="data row4 col2" >28%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow4_col3" class="data row4 col3" >30%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow4_col4" class="data row4 col4" >25%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow4_col5" class="data row4 col5" >25%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow4_col6" class="data row4 col6" >25%</td>
#             </tr>
#             <tr>
#                         <th id="T_f3028c44_4ed1_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow5_col0" class="data row5 col0" >32%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow5_col1" class="data row5 col1" >32%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow5_col2" class="data row5 col2" >36%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow5_col3" class="data row5 col3" >36%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow5_col4" class="data row5 col4" >36%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow5_col5" class="data row5 col5" >36%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow5_col6" class="data row5 col6" >32%</td>
#             </tr>
#             <tr>
#                         <th id="T_f3028c44_4ed1_11ea_815b_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow6_col0" class="data row6 col0" >43%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow6_col1" class="data row6 col1" >42%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b_00505683952erow6_col2" class="data row6 col2" >42%</td>
#                         <td id="T_f3028c44_4ed1_11ea_815b

# %%
print('Global Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores[global_scores.columns[:-1]]
 .style
 .format('{:,.0f}')
 .highlight_min(color='yellow', axis=1))
# Out:
# Global Models, RMSE
# <style  type="text/css" >
#     #T_f9183516_4ed1_11ea_815b_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_f9183516_4ed1_11ea_815b_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_f9183516_4ed1_11ea_815b_00505683952erow2_col1 {
#             background-color:  yellow;
#         }    #T_f9183516_4ed1_11ea_815b_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_f9183516_4ed1_11ea_815b_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_f9183516_4ed1_11ea_815b_00505683952erow5_col3 {
#             background-color:  yellow;
#         }    #T_f9183516_4ed1_11ea_815b_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_f9183516_4ed1_11ea_815b_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_f9183516_4ed1_11ea_815b_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_f9183516_4ed1_11ea_815b_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_f9183516_4ed1_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f9183516_4ed1_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow0_col0" class="data row0 col0" >19</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow0_col1" class="data row0 col1" >20</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow0_col2" class="data row0 col2" >55</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow0_col3" class="data row0 col3" >30</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow0_col4" class="data row0 col4" >20</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow0_col5" class="data row0 col5" >19</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow0_col6" class="data row0 col6" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_f9183516_4ed1_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow1_col0" class="data row1 col0" >88</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow1_col1" class="data row1 col1" >88</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow1_col2" class="data row1 col2" >121</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow1_col3" class="data row1 col3" >88</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow1_col4" class="data row1 col4" >80</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow1_col5" class="data row1 col5" >79</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow1_col6" class="data row1 col6" >79</td>
#             </tr>
#             <tr>
#                         <th id="T_f9183516_4ed1_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow2_col0" class="data row2 col0" >40</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow2_col1" class="data row2 col1" >40</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow2_col2" class="data row2 col2" >65</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow2_col3" class="data row2 col3" >52</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow2_col4" class="data row2 col4" >46</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow2_col5" class="data row2 col5" >45</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow2_col6" class="data row2 col6" >44</td>
#             </tr>
#             <tr>
#                         <th id="T_f9183516_4ed1_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow3_col0" class="data row3 col0" >66</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow3_col1" class="data row3 col1" >67</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow3_col2" class="data row3 col2" >92</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow3_col3" class="data row3 col3" >67</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow3_col4" class="data row3 col4" >58</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow3_col5" class="data row3 col5" >59</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow3_col6" class="data row3 col6" >61</td>
#             </tr>
#             <tr>
#                         <th id="T_f9183516_4ed1_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow4_col0" class="data row4 col0" >80</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow4_col1" class="data row4 col1" >81</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow4_col2" class="data row4 col2" >120</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow4_col3" class="data row4 col3" >85</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow4_col4" class="data row4 col4" >74</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow4_col5" class="data row4 col5" >73</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow4_col6" class="data row4 col6" >79</td>
#             </tr>
#             <tr>
#                         <th id="T_f9183516_4ed1_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow5_col0" class="data row5 col0" >105</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow5_col1" class="data row5 col1" >105</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow5_col2" class="data row5 col2" >134</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow5_col3" class="data row5 col3" >102</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow5_col4" class="data row5 col4" >108</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow5_col5" class="data row5 col5" >107</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow5_col6" class="data row5 col6" >102</td>
#             </tr>
#             <tr>
#                         <th id="T_f9183516_4ed1_11ea_815b_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow6_col0" class="data row6 col0" >68</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow6_col1" class="data row6 col1" >68</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow6_col2" class="data row6 col2" >70</td>
#                         <td id="T_f9183516_4ed1_11ea_815b_00505683952erow6_col3" class="data

# %%
print('Global Models, RMSE%')
regional_data, global_data, counts = compare_models(nrmse)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores[global_scores.columns[:-1]]
 .style
 .format("{:.0%}")
 .highlight_min(color='yellow', axis=1))
# Out:
# Global Models, RMSE%
# <style  type="text/css" >
#     #T_ff2a0466_4ed1_11ea_815b_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow0_col5 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow2_col0 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow2_col1 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow5_col3 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_ff2a0466_4ed1_11ea_815b_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_ff2a0466_4ed1_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff2a0466_4ed1_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow0_col0" class="data row0 col0" >30%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow0_col1" class="data row0 col1" >32%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow0_col2" class="data row0 col2" >89%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow0_col3" class="data row0 col3" >49%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow0_col4" class="data row0 col4" >32%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow0_col5" class="data row0 col5" >30%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow0_col6" class="data row0 col6" >30%</td>
#             </tr>
#             <tr>
#                         <th id="T_ff2a0466_4ed1_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow1_col0" class="data row1 col0" >42%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow1_col1" class="data row1 col1" >42%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow1_col2" class="data row1 col2" >57%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow1_col3" class="data row1 col3" >42%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow1_col4" class="data row1 col4" >38%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow1_col5" class="data row1 col5" >38%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow1_col6" class="data row1 col6" >37%</td>
#             </tr>
#             <tr>
#                         <th id="T_ff2a0466_4ed1_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow2_col0" class="data row2 col0" >35%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow2_col1" class="data row2 col1" >35%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow2_col2" class="data row2 col2" >58%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow2_col3" class="data row2 col3" >46%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow2_col4" class="data row2 col4" >41%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow2_col5" class="data row2 col5" >40%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow2_col6" class="data row2 col6" >39%</td>
#             </tr>
#             <tr>
#                         <th id="T_ff2a0466_4ed1_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow3_col0" class="data row3 col0" >41%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow3_col1" class="data row3 col1" >41%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow3_col2" class="data row3 col2" >56%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow3_col3" class="data row3 col3" >41%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow3_col4" class="data row3 col4" >36%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow3_col5" class="data row3 col5" >36%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow3_col6" class="data row3 col6" >37%</td>
#             </tr>
#             <tr>
#                         <th id="T_ff2a0466_4ed1_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow4_col0" class="data row4 col0" >39%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow4_col1" class="data row4 col1" >39%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow4_col2" class="data row4 col2" >58%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow4_col3" class="data row4 col3" >41%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow4_col4" class="data row4 col4" >36%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow4_col5" class="data row4 col5" >35%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow4_col6" class="data row4 col6" >38%</td>
#             </tr>
#             <tr>
#                         <th id="T_ff2a0466_4ed1_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow5_col0" class="data row5 col0" >53%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow5_col1" class="data row5 col1" >52%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow5_col2" class="data row5 col2" >67%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow5_col3" class="data row5 col3" >51%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow5_col4" class="data row5 col4" >54%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow5_col5" class="data row5 col5" >53%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow5_col6" class="data row5 col6" >51%</td>
#             </tr>
#             <tr>
#                         <th id="T_ff2a0466_4ed1_11ea_815b_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow6_col0" class="data row6 col0" >63%</td>
#                         <td id="T_ff2a0466_4ed1_11ea_815b_00505683952erow6_col1

# %%
print('Global Models, Bias')
regional_data, global_data, counts = compare_models(bias)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores
 .style
 .format('{:,.0f}')
 .apply(highlight_best, axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, Bias
# <style  type="text/css" >
#     #T_05320db8_4ed2_11ea_815b_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_05320db8_4ed2_11ea_815b_00505683952erow1_col1 {
#             background-color:  yellow;
#         }    #T_05320db8_4ed2_11ea_815b_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_05320db8_4ed2_11ea_815b_00505683952erow3_col3 {
#             background-color:  yellow;
#         }    #T_05320db8_4ed2_11ea_815b_00505683952erow4_col3 {
#             background-color:  yellow;
#         }    #T_05320db8_4ed2_11ea_815b_00505683952erow5_col3 {
#             background-color:  yellow;
#         }    #T_05320db8_4ed2_11ea_815b_00505683952erow6_col2 {
#             background-color:  yellow;
#         }    #T_05320db8_4ed2_11ea_815b_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_05320db8_4ed2_11ea_815b_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_05320db8_4ed2_11ea_815b_00505683952erow9_col3 {
#             background-color:  yellow;
#         }</style><table id="T_05320db8_4ed2_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_05320db8_4ed2_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow0_col0" class="data row0 col0" >-6</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow0_col1" class="data row0 col1" >-7</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow0_col2" class="data row0 col2" >12</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow0_col3" class="data row0 col3" >-13</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow0_col4" class="data row0 col4" >-7</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow0_col5" class="data row0 col5" >-5</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow0_col6" class="data row0 col6" >0</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_05320db8_4ed2_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow1_col0" class="data row1 col0" >-4</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow1_col1" class="data row1 col1" >-4</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow1_col2" class="data row1 col2" >-18</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow1_col3" class="data row1 col3" >-6</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow1_col4" class="data row1 col4" >-6</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow1_col5" class="data row1 col5" >-5</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow1_col6" class="data row1 col6" >-5</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_05320db8_4ed2_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow2_col0" class="data row2 col0" >-4</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow2_col1" class="data row2 col1" >-3</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow2_col2" class="data row2 col2" >-5</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow2_col3" class="data row2 col3" >-7</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow2_col4" class="data row2 col4" >-9</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow2_col5" class="data row2 col5" >-9</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow2_col6" class="data row2 col6" >-3</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_05320db8_4ed2_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow3_col0" class="data row3 col0" >-11</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow3_col1" class="data row3 col1" >-11</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow3_col2" class="data row3 col2" >7</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow3_col3" class="data row3 col3" >-7</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow3_col4" class="data row3 col4" >-8</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow3_col5" class="data row3 col5" >-10</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow3_col6" class="data row3 col6" >-7</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_05320db8_4ed2_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow4_col0" class="data row4 col0" >-8</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow4_col1" class="data row4 col1" >-8</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow4_col2" class="data row4 col2" >-25</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow4_col3" class="data row4 col3" >-3</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow4_col4" class="data row4 col4" >-10</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow4_col5" class="data row4 col5" >-8</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow4_col6" class="data row4 col6" >-5</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_05320db8_4ed2_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow5_col0" class="data row5 col0" >-34</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow5_col1" class="data row5 col1" >-33</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow5_col2" class="data row5 col2" >-61</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow5_col3" class="data row5 col3" >-15</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow5_col4" class="data row5 col4" >-34</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow5_col5" class="data row5 col5" >-31</td>
#                         <td id="T_05320db8_4ed2_11ea_815b_00505683952erow5_col6" class="data

# %%
print('Global Models, MAE')
regional_data, global_data, counts = compare_models(mae)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores
 .style
 .format('{:,.0f}')
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, MAE
# <style  type="text/css" >
#     #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow4_col4 {
#             background-color:  yellow;
#         }    #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow6_col0 {
#             background-color:  yellow;
#         }    #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_0b3ef4c8_4ed2_11ea_815b_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_0b3ef4c8_4ed2_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b3ef4c8_4ed2_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow0_col0" class="data row0 col0" >14</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow0_col1" class="data row0 col1" >15</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow0_col2" class="data row0 col2" >46</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow0_col3" class="data row0 col3" >21</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow0_col4" class="data row0 col4" >16</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow0_col5" class="data row0 col5" >15</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow0_col6" class="data row0 col6" >16</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3ef4c8_4ed2_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow1_col0" class="data row1 col0" >63</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow1_col1" class="data row1 col1" >62</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow1_col2" class="data row1 col2" >92</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow1_col3" class="data row1 col3" >62</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow1_col4" class="data row1 col4" >55</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow1_col5" class="data row1 col5" >54</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow1_col6" class="data row1 col6" >54</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3ef4c8_4ed2_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow2_col0" class="data row2 col0" >29</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow2_col1" class="data row2 col1" >29</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow2_col2" class="data row2 col2" >45</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow2_col3" class="data row2 col3" >36</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow2_col4" class="data row2 col4" >30</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow2_col5" class="data row2 col5" >29</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow2_col6" class="data row2 col6" >28</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3ef4c8_4ed2_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow3_col0" class="data row3 col0" >47</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow3_col1" class="data row3 col1" >47</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow3_col2" class="data row3 col2" >69</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow3_col3" class="data row3 col3" >48</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow3_col4" class="data row3 col4" >41</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow3_col5" class="data row3 col5" >42</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow3_col6" class="data row3 col6" >43</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3ef4c8_4ed2_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow4_col0" class="data row4 col0" >54</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow4_col1" class="data row4 col1" >55</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow4_col2" class="data row4 col2" >90</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow4_col3" class="data row4 col3" >55</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow4_col4" class="data row4 col4" >47</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow4_col5" class="data row4 col5" >47</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow4_col6" class="data row4 col6" >49</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_0b3ef4c8_4ed2_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow5_col0" class="data row5 col0" >71</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow5_col1" class="data row5 col1" >70</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow5_col2" class="data row5 col2" >98</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow5_col3" class="data row5 col3" >74</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow5_col4" class="data row5 col4" >71</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow5_col5" class="data row5 col5" >70</td>
#                         <td id="T_0b3ef4c8_4ed2_11ea_815b_00505683952erow5_col6" class="data row5 col6"

# %%
print('Global Models, MAPE')
regional_data, global_data, counts = compare_models(mape)
global_rmse = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_rmse[global_rmse.columns[:-1]]
 .style
 .format("{:.0%}")
 .highlight_min(color='yellow', axis=1))
# Out:
# Global Models, MAPE
# <style  type="text/css" >
#     #T_1157a3e6_4ed2_11ea_815b_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow4_col4 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow6_col0 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow6_col1 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_1157a3e6_4ed2_11ea_815b_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_1157a3e6_4ed2_11ea_815b_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1157a3e6_4ed2_11ea_815b_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow0_col0" class="data row0 col0" >23%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow0_col1" class="data row0 col1" >25%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow0_col2" class="data row0 col2" >74%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow0_col3" class="data row0 col3" >33%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow0_col4" class="data row0 col4" >25%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow0_col5" class="data row0 col5" >23%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow0_col6" class="data row0 col6" >26%</td>
#             </tr>
#             <tr>
#                         <th id="T_1157a3e6_4ed2_11ea_815b_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow1_col0" class="data row1 col0" >30%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow1_col1" class="data row1 col1" >30%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow1_col2" class="data row1 col2" >44%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow1_col3" class="data row1 col3" >29%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow1_col4" class="data row1 col4" >26%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow1_col5" class="data row1 col5" >26%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow1_col6" class="data row1 col6" >26%</td>
#             </tr>
#             <tr>
#                         <th id="T_1157a3e6_4ed2_11ea_815b_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow2_col0" class="data row2 col0" >25%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow2_col1" class="data row2 col1" >25%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow2_col2" class="data row2 col2" >40%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow2_col3" class="data row2 col3" >32%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow2_col4" class="data row2 col4" >27%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow2_col5" class="data row2 col5" >26%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow2_col6" class="data row2 col6" >25%</td>
#             </tr>
#             <tr>
#                         <th id="T_1157a3e6_4ed2_11ea_815b_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow3_col0" class="data row3 col0" >29%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow3_col1" class="data row3 col1" >29%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow3_col2" class="data row3 col2" >42%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow3_col3" class="data row3 col3" >29%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow3_col4" class="data row3 col4" >25%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow3_col5" class="data row3 col5" >26%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow3_col6" class="data row3 col6" >27%</td>
#             </tr>
#             <tr>
#                         <th id="T_1157a3e6_4ed2_11ea_815b_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow4_col0" class="data row4 col0" >26%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow4_col1" class="data row4 col1" >26%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow4_col2" class="data row4 col2" >44%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow4_col3" class="data row4 col3" >26%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow4_col4" class="data row4 col4" >23%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow4_col5" class="data row4 col5" >23%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow4_col6" class="data row4 col6" >23%</td>
#             </tr>
#             <tr>
#                         <th id="T_1157a3e6_4ed2_11ea_815b_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow5_col0" class="data row5 col0" >35%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow5_col1" class="data row5 col1" >35%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow5_col2" class="data row5 col2" >49%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow5_col3" class="data row5 col3" >37%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow5_col4" class="data row5 col4" >35%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow5_col5" class="data row5 col5" >35%</td>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow5_col6" class="data row5 col6" >34%</td>
#             </tr>
#             <tr>
#                         <th id="T_1157a3e6_4ed2_11ea_815b_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_1157a3e6_4ed2_11ea_815b_00505683952erow6_col0" class="da

# %%
METRIC = 'basal_area'

MODELS = {'ElasticNet': best_lms,
          'LASSO': best_lassos,
          'LASSO{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

pickle.dump(x_scaler, 
            open('../models/{}/sklearn/x_scaler.pkl'.format(METRIC), 'wb'))
pickle.dump(transformer, 
            open('../models/{}/sklearn/y_scaler.pkl'.format(METRIC), 'wb'))

for i in range(len(ecoregion_names)):
    for key in MODELS.keys():
        fname = ecoregion_names[i] + '_{}.pkl'.format(key)
        path_to_file = '../models/{}/sklearn/{}'.format(METRIC, fname)
        pickle.dump(MODELS[key][i], 
                    open(path_to_file, 'wb'))
        
        if key == 'LASSO{}'.format(MAX_FEATURES):
            sfm_name = ecoregion_names[i] + '_LASSO{}_featureselect.pkl'.format(MAX_FEATURES)
            path_to_file = '../models/{}/sklearn/{}'.format(METRIC, sfm_name)
            pickle.dump(sfms[i], 
                        open(path_to_file, 'wb'))
