# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
# data prep and model-tuning
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, QuantileTransformer
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV

# types of models we'll fit
from sklearn.linear_model import ElasticNetCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR

from scipy.stats import shapiro

import pickle
from copy import deepcopy

# %% [markdown]
# ## Our Data

# %%
DATA = '../data/processed/training_data_annual.csv'
df = pd.read_csv(DATA)
df = df.dropna()
print('{:,d} samples'.format(len(df)))
print('Columns:', df.columns.values)
# Out:
# 3,529 samples
# Columns: ['uuid' 'lidar_year' 'lat' 'lon' 'orig_id' 'source' 'meas_yr' 'ecoregion3'
#  'agency' 'plot_size_ac' 'num_returns' 'strat0_return-proportion'
#  'strat1_return-proportion' 'strat2_return-proportion'
#  'strat3_return-proportion' 'strat4_return-proportion'
#  'strat5_return-proportion' 'skewness' 'kurtosis'
#  'strat0_intensity-median' 'strat1_intensity-median'
#  'strat2_intensity-median' 'strat3_intensity-median'
#  'strat4_intensity-median' 'strat5_intensity-median'
#  'height_05-percentile' 'height_25-percentile' 'height_50-percentile'
#  'height_75-percentile' 'height_95_percentile' 'height_max' 'cover'
#  'lidar_acq' 'potential_volume' 'stddev_height' 'surface_area_ratio'
#  'surface_volume' 'surface_volume_ratio' 'aspect' 'elevation'
#  'overall_curvature' 'plan_curvature' 'profile_curvature' 'slope'
#  'solar_radiation_index' 'mat' 'mwmt' 'mcmt' 'td' 'map' 'msp' 'ahm' 'shm'
#  'dd_0' 'dd5' 'dd_18' 'dd18' 'nffd' 'bffp' 'effp' 'ffp' 'pas' 'emt' 'ext'
#  'eref' 'cmd' 'rh' 'dormancy' 'evi_amplitude' 'evi_area' 'evi_minimum'
#  'greenup' 'maturity' 'midgreendown' 'midgreenup' 'numcycles' 'peak'
#  'green' 'blue' 'red' 'nir' 'endvi' 'ndvi' 'savi' 'swir1' 'swir2'
#  'wetness' 'greenness' 'brightness' 'landsat_year' 'clim_year'
#  'distance_to_water_m' 'bulk_dens' 'soil_depth' 'pct_clay_surf'
#  'pct_rock_surf' 'pct_sand_surf' 'pot_veg_type' 'tpa' 'ba' 'sdi' 'ccf'
#  'qmd' 'tcuft' 'topht' 'number_of_strata' 'total_cover' 'structure_class'
#  'canopy_baseheight' 'canopy_bulkdensity' 'aboveground_biomass'
#  'aboveground_carbon' 'gs_tpa' 'AF' 'AS' 'BM' 'BO' 'CH' 'CW' 'DF' 'DG'
#  'ES' 'GC' 'GF' 'IC' 'JP' 'KP' 'LO' 'LP' 'MA' 'MC' 'MH' 'NF' 'OH' 'OS'
#  'OT' 'PC' 'PL' 'PP' 'PY' 'RA' 'RC' 'RF' 'SF' 'SH' 'SP' 'SS' 'TO' 'WA'
#  'WB' 'WF' 'WH' 'WI' 'WJ' 'WL' 'WO' 'WP' 'YC' 'TRUE_FIR' 'OTHER_HARDWOOD'
#  'MAPLE' 'OAK' 'DOUGLAS_FIR' 'SPRUCE' 'CEDAR' 'PONDEROSA_PINE'
#  'OTHER_SOFTWOOD' 'LODGEPOLE_PINE' 'HEMLOCK' 'RED_ALDER' 'TANOAK'
#  'JUNIPER' 'LARCH' 'fvs_year' 'year_diff' 'returns_per_m2']

# %% [markdown]
# ## Filter out some of the training data
# We can exclude some of the training data based on how far separated the inventory data (interpolated using FVS simulations) is from the year the lidar was collected. Similarly, we can screen out training examples that had relatively low density of lidar returns.

# %%
df['year_diff'] = abs(df['fvs_year'] - df['lidar_year']).astype(int)

# %%
len(df.loc[df['year_diff'] >= 5])
# Out:
# 224

# %%
df = df.loc[df['year_diff'] < 5]

# %%
len(df.loc[df['returns_per_m2'] < 4.0])
# Out:
# 93

# %%
df = df.loc[df['returns_per_m2'] >= 4.0]

# %%
lidar_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['topht'].values.reshape(-1, 1))

lidar_height_transformed = lidar_height_transformer.transform(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformed = fvs_height_transformer.transform(df['topht'].values.reshape(-1, 1))

diff_height_transformed = abs(lidar_height_transformed - fvs_height_transformed)


fig, axs = plt.subplots(1,2, figsize=(15,5))

# select outliers
OUTLIER_THRESH = 3.05
outliers = diff_height_transformed > OUTLIER_THRESH
outliers = np.logical_or(outliers, (df['height_95_percentile'] > 275/3.28084).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 60/3.28084) & (df['topht'] > 105)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 10/3.28084) & (df['topht'] > 40)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])/df['topht']) > 1.0).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])) > 100).values.reshape(-1, 1))

axs[0].hist(diff_height_transformed, bins=20)
axs[0].axvline(OUTLIER_THRESH, color='k')
axs[0].set_title('Differences between transformed lidar and fvs canopy height')

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[~outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[~outliers],
            s=1, label='Inliers (n={:,d})'.format((~outliers).sum()))

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[outliers],
            s=5, label='Outliers (n={:,d})'.format(outliers.sum()))

axs[1].set_xlabel('Lidar Canopy Height, ft')
axs[1].set_ylabel('FVS Canopy Height, ft')
axs[1].plot([0,400],[0,400], color='k', lw=2, label='1:1')
axs[1].set_xlim(-10, 400)
axs[1].set_ylim(-10, 400)
axs[1].set_aspect('equal')
axs[1].legend();

# %%
# filter out the height outliers
df = df[~outliers]

# %% [markdown]
# ## Inspect how many samples we have for different years, regions, etc.

# %%
df.groupby(by=['lidar_year'])[['uuid']].count().rename({'uuid':'count'}, axis=1)
# Out:
#             count
# lidar_year
# 2008          686
# 2009           12
# 2010            2
# 2011           76
# 2012          527
# 2013          199
# 2014          298
# 2015          475
# 2016          478
# 2017          165
# 2018           25

# %%
pd.pivot_table(df, 
               values='uuid', 
               aggfunc='count', 
               index=['meas_yr'], 
               columns=['lidar_year'], 
               fill_value=0)
# Out:
# lidar_year  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# meas_yr
# 2010         395     0     0     0     2     0     2     6     0     0     0
# 2011         291     0     0     0     1     0     2     1     0     0     0
# 2013           0    12     0    33   345    45     3     6    13    25     2
# 2014           0     0     2    26   124    39    28    38    83    34     0
# 2015           0     0     0    17    16    12    15   122    95    24     2
# 2016           0     0     0     0    39    73    39   214    63    32    21
# 2017           0     0     0     0     0    30   163    47    78    40     0
# 2018           0     0     0     0     0     0    46    41   146    10     0

# %%
ecoreg_counts = df.groupby(by=['ecoregion3'])[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
ecoreg_counts
# Out:
#                                                     uuid  lidar_acq  \
# ecoregion3
# blue_mountains                                        29          2
# cascades                                             480         21
# coast_range                                         1399         18
# columbia_plateau                                       4          3
# eastern_cascades_slopes_and_foothills                124          9
# klamath_mountains_california_high_north_coast_r...   190          6
# north_cascades                                       339         18
# northern_rockies                                      68          4
# puget_lowland                                        106         13
# willamette_valley                                     41          2
#
#                                                     lidar_year  plot_size_ac
# ecoregion3
# blue_mountains                                               2             1
# cascades                                                     9             3
# coast_range                                                  9             2
# columbia_plateau                                             3             1
# eastern_cascades_slopes_and_foothills                        5             2
# klamath_mountains_california_high_north_coast_r...           5             2
# north_cascades                                               6             2
# northern_rockies                                             3             1
# puget_lowland                                                7             1
# willamette_valley                                            2             2

# %%
df[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
# Out:
# uuid            2780
# lidar_acq         67
# lidar_year        11
# plot_size_ac       3
# dtype: int64

# %% [markdown]
# ## Available features
# First, we'll use one-hot encoding for categorical features

# %%
# convert agency, ecoregion, and lidar acquisition into one-hot encoded set of variables
df = pd.get_dummies(df, prefix='agency', columns=['agency'])
# df = pd.get_dummies(df, prefix='eco', columns=['ecoregion3'])
# df = pd.get_dummies(df, prefix='acq', columns=['lidar_acq'])

# %% [markdown]
# The different types of predictor variables we can use to predict a forest attribute, including climate, lidar-derived, soil, and satellite imagery.

# %%
CLIM_COLS = ['mat', 'mwmt', 'mcmt', 'td', 'map', 'msp', 'ahm', 'shm', 
             'dd_0', 'dd5', 'dd_18', 'dd18', 'nffd', 'bffp', 'effp', 
             'ffp', 'pas', 'emt', 'ext', 'eref', 'cmd', 'rh']

LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
       'strat1_return-proportion', 'strat2_return-proportion',
       'strat3_return-proportion', 'strat4_return-proportion',
       'strat5_return-proportion', 'strat0_intensity-median',
       'strat1_intensity-median', 'strat2_intensity-median',
       'strat3_intensity-median', 'strat4_intensity-median',
       'strat5_intensity-median', 'height_05-percentile',
       'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
       'height_95_percentile', 'height_max', 'cover', 'potential_volume',
       'stddev_height', 'surface_area_ratio', 'surface_volume',
       'surface_volume_ratio', 'aspect', 'elevation', 'overall_curvature',
       'plan_curvature', 'profile_curvature', 'slope', 'solar_radiation_index', 
              'kurtosis', 'skewnewss']

USE_LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
                  'strat1_return-proportion', 'strat2_return-proportion',
                  'strat3_return-proportion', 'strat4_return-proportion',
                  'strat5_return-proportion', 'height_05-percentile',
                  'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
                  'height_95_percentile', 'cover', 'potential_volume',
                  'stddev_height', 'surface_volume',
                  'aspect', 'elevation', 'slope', 'solar_radiation_index',
                  'kurtosis', 'skewness']

SOIL_COLS = ['bulk_dens', 'soil_depth', 'pct_clay_surf', 'pct_rock_surf', 'pct_sand_surf']

LANDSAT_COLS = ['green', 'blue', 'red', 'nir', 'endvi', 'ndvi', 'savi',
                'swir1', 'swir2', 'wetness', 'greenness', 'brightness']

AGENCY_COLS = ['agency_BLM', 'agency_USFS', 'agency_WADNR']

# ECOREGIONS = [col for col in df.columns if col.startswith('eco_')]

# %% [markdown]
# ## Selecting initial features and targets
# This is the first step in determining what features we want to use, and what we want to predict. Later, we can still apply some procedures to choose a subset of these features to make simpler models.

# %%
X_COLS = USE_LIDAR_COLS + ['ecoregion3'] 
Y_COLS = ['ba']

# %%
USE_REGIONS = ['blue_mountains', 'coast_range', 'north_cascades', 'cascades',
               'klamath_mountains_california_high_north_coast_range', 
               'eastern_cascades_slopes_and_foothills', 'northern_rockies',
               'puget_lowland', 'willamette_valley']
display(df.groupby('ecoregion3')[Y_COLS].mean().round(0).astype(int).loc[USE_REGIONS])
display(df[Y_COLS].mean().round(0).astype(int))
# Out:
#                                                      ba
# ecoregion3
# blue_mountains                                       58
# coast_range                                         230
# north_cascades                                      170
# cascades                                            203
# klamath_mountains_california_high_north_coast_r...  205
# eastern_cascades_slopes_and_foothills               134
# northern_rockies                                     98
# puget_lowland                                       180
# willamette_valley                                   232
# ba    204
# dtype: int64

# %% [markdown]
# ## Split the data into training and testing sets
# Since some plot_ids have multiple observations, we want all observations for each plot_id to fall entirely in train_set or entirely the training or testing sets because these samples are definitely not independent.

# %%
# a dataframe with unique plot ids
splits = pd.DataFrame(pd.unique(df['uuid']), columns=['uuid']).set_index('uuid')

# randomly assign each plot-id to train(0) or test(1) sets
np.random.seed(127)
splits['train0_test1'] = np.random.choice(2,
                                          size=len(splits),
                                          p=[0.8,0.2])

# add set assignments to the dataframe
df['train0_test1'] = splits.loc[df['uuid']]['train0_test1'].values

# %%
train_plots = df.loc[df['train0_test1'] == 0]
test_plots = df.loc[df['train0_test1'] == 1]
len(train_plots), len(test_plots)
# Out:
# (2769, 704)

# %%
x_train, x_test = train_plots[X_COLS], test_plots[X_COLS]
y_train, y_test = train_plots[Y_COLS], test_plots[Y_COLS]

# %% [markdown]
# ## Standardize features
# Scale all predictive features to have 0 mean and unit variance (subtracting mean, dividing by standard deviation).

# %%
x_scaler = StandardScaler()
x_scaler.fit(df[X_COLS].drop(['ecoregion3'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Consider a few transformations for the target variable

# %%
fig, axs = plt.subplots(1,6, figsize=(15,2.5))

quantile = QuantileTransformer(output_distribution='normal', random_state=127)
box_cox = PowerTransformer(method='box-cox')
yeo_johnson = PowerTransformer(method='yeo-johnson')

VALS = [y_train.values,
        np.log1p(y_train.values),
        np.sqrt(y_train.values),
        quantile.fit_transform(y_train.values),
        box_cox.fit_transform(y_train.values + 1e-9),
        yeo_johnson.fit_transform(y_train.values)]

TITLES = ['Raw', 'Log', 'SQRT', 'Quantile', 'Box-Cox', 'Yeo-Johnson']
SHAPIRO_ps = [shapiro(vals)[-1] for vals in VALS]

for i, vals in enumerate(VALS):
    axs.ravel()[i].hist(vals, bins=20)
    axs.ravel()[i].set_title(TITLES[i])
    
plt.show();

# %%
# identify the closest to normally-distributed
TITLES[np.array(SHAPIRO_ps).argmax()]
# Out:
# 'SQRT'

# %%
# choose your transformer here
transformer = FunctionTransformer(np.sqrt, np.square)

# %%
transformer.fit(df[Y_COLS])
y_train.loc[:,Y_COLS], y_test.loc[:,Y_COLS] = transformer.transform(y_train), transformer.transform(y_test)
# Out:
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Split datasets by ecoregion
# We want to explore model transferability between regions, so we'll train models independently on subsets of the data within a single ecoregion, as well as a model that is trained on all available ecoregions.

# %%
ecoregions = [reg for reg in pd.unique(df.ecoregion3) if ecoreg_counts.loc[reg]['uuid'] > 20]

eco_train_idx = [x_train.loc[x_train.ecoregion3 == eco].index.values for eco in ecoregions]
eco_test_idx = [x_test.loc[x_test.ecoregion3 == eco].index.values for eco in ecoregions]

eco_xtrain_dfs = [x_train.loc[x_train.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytrain_dfs = [y_train.loc[idx].values.ravel() for idx in eco_train_idx]
eco_xtest_dfs = [x_test.loc[x_test.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytest_dfs = [y_test.loc[idx].values.ravel() for idx in eco_test_idx]

# append a "global" model that contains data from all ecoregions
ecoregions.append('all')
ecoregion_names = ['_'.join(x.split('_')[0:2]) for x in ecoregions]
eco_xtrain_dfs.append(x_train.drop(['ecoregion3'], axis=1))
eco_ytrain_dfs.append(y_train.values.ravel())
eco_xtest_dfs.append(x_test.drop(['ecoregion3'], axis=1))
eco_ytest_dfs.append(y_test.values.ravel())

# %% [markdown]
# ## Scoring
# We'll use Root Mean Square Error to evaluate model performance.

# %%
def rmse(pred, obs):
    # use our transformer to calculate RMSE on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return np.sqrt((np.square(obs-pred)).mean())

# %%
def nrmse(pred, obs):
    # use our transformer to calculate percent RMSE on the original data scale
    this_rmse = rmse(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return this_rmse/obs.mean()

# %%
def mae(pred, obs):
    # use our transformer to calculate mean absolute error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean()

# %%
def mape(pred, obs):
    # use our transformer to calculate mean average percent error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean() / obs.mean()

# %%
def bias(pred, obs):
    # use our transformer to calculate mean bias on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return (pred - obs).mean()

# %%
def rel_bias(pred, obs):
    # use our transformer to calculate mean relative bias on the original data scale
    this_bias = bias(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1))  
    
    return this_bias/obs.mean()

# %% [markdown]
# This helper function will calculate RMSE scores for each regionally-trained model and the global model on each ecoregion.

# %%
def get_score_df(models, metric=rmse, feature_selectors=None):
    regional_scores = []
    global_scores = []
    counts = []
    
    for i, mod in enumerate(models):
        X_test = x_scaler.transform(eco_xtest_dfs[i])
        if feature_selectors:
            X_test = feature_selectors[i].transform(X_test)
        y_test = eco_ytest_dfs[i]
        reg_score = metric(mod.predict(X_test), y_test)
        regional_scores.append(reg_score.round(3))
        
        if feature_selectors:
            X_test = x_scaler.transform(eco_xtest_dfs[i])
            X_test = feature_selectors[-1].transform(X_test)
        glob_score = metric(models[-1].predict(X_test), y_test)
        global_scores.append(glob_score.round(3))
        count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
        counts.append(count)
        
    data = list(zip(regional_scores, global_scores, counts))
    res_df = pd.DataFrame(data=data,
                          columns=['regional_model', 'global_model', 'n'],
                          index=ecoregion_names)
    
    return res_df

# %% [markdown]
# ## Fit some models
# For each type of model, we'll employ cross-validation to tune model hyperparameters, generating a tuned model for each ecoregion as well as a tuned model using all training data. We'll work our way through:
#
# #### ElasticNet Regression
# Linear model that employs a mix of L1 and L2 regularization to penalize model complexity
#
# #### LASSO Regression
# Linear model that employs L1 regularization to penalize model complexity. We'll also work with a feature-selection process to fit models capped to an explicitly-predefined number of features.
#
# #### K-Nearest Neighbor Regression
#
# #### Random Forest Regression
#
# #### Gradient Boosting Trees Regression
#
# #### Support Vector Machine Regression

# %% [markdown]
# ## ElasticNet (Linear Model)

# %%
best_lms = []

for i in range(len(ecoregions)):
    lm = ElasticNetCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    lm.fit(X, y)
    best_lms.append(lm)

# %%
elastic_res = get_score_df(best_lms)
elastic_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             18.424        21.994   104
# coast_range               110.876       109.923  1580
# north_cascades             76.533        83.620   443
# cascades                   67.746        65.874   613
# klamath_mountains          81.177        77.649   275
# eastern_cascades           43.630        41.761   203
# northern_rockies           34.242        31.936    83
# puget_lowland              54.413        50.795   122
# willamette_valley         121.051       131.419    41
# all                        89.427        89.427  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lms])
count_nonzero = [(~np.isclose(coef, 0, atol=1e-3)).sum() for coef in coefs]
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                             -0.122
# coast_range                                                 0.241
# north_cascades                                             -0.184
# cascades                                                    0.112
# klamath_mountains_california_high_north_coast_r...         -0.208
# eastern_cascades_slopes_and_foothills                       0.002
# northern_rockies                                            0.551
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                         0.083
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                       -0.361
# coast_range                                                          -0.127
# north_cascades                                                       -0.674
# cascades                                                              -0.01
# klamath_mountains_california_high_north_coast_r...                   -0.592
# eastern_cascades_slopes_and_foothills                                -0.436
# northern_rockies                                                     -0.433
# puget_lowland                                                        -0.363
# willamette_valley                                                    -0.309
# all                                                                  -0.428
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -1.039
# coast_range                                                          -0.329
# north_cascades                                                           --
# cascades                                                             -0.186
# klamath_mountains_california_high_north_coast_r...                   -0.155
# eastern_cascades_slopes_and_foothills                                -0.227
# northern_rockies                                                     -0.253
# puget_lowland                                                        -0.209
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        0.185
# coast_range                                                              --
# north_cascades                                                        0.135
# cascades                                                              0.426
# klamath_mountains_california_high_north_coast_r...                   -0.395
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.468
# puget_lowland                                                            --
# willamette_valley                                                    -0.054
# all                                                                   0.316
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.237
# north_cascades                                                        0.615
# cascades                                                              0.773
# klamath_mountains_california_high_north_coast_r...                    0.616
# eastern_cascades_slopes_and_foothills                                 0.527
# northern_rockies                                                         --
# puget_lowland                                                         0.039
# willamette_valley                                                        --
# all                                                                   0.746
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        1.147
# coast_range                                                            0.04
# north_cascades                                                        0.565
# cascades                                                              0.446
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                          0.23
# willamette_valley                                                        --
# all                                                                   0.548
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.201
# north_cascades                                                        0.482
# cascades                                                              0.088
# klamath_mountains_california_high_north_coast_r...                    0.083
# eastern_cascades_slopes_and_foothills                                 0.368
# northern_rockies                                                      0.075
# puget_lowland                                                            --
# willamette_valley                                                     0.419
# all                                                                   0.808
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.336
# north_cascades                                                       --
# cascades                                                          -0.09
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                  0.051
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                 0.2
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.361
# north_cascades                                                    0.522
# cascades                                                          0.638
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                     0.238
# willamette_valley                                                 0.153
# all                                                               0.143
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                    0.064  ...
# coast_range                                                          --  ...
# north_cascades                                                    0.174  ...
# cascades                                                          0.175  ...
# klamath_mountains_california_high_north_coast_r...                0.227  ...
# eastern_cascades_slopes_and_foothills                             0.956  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                     0.517  ...
# willamette_valley                                                 0.338  ...
# all                                                              -0.105  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                      0.833               --
# coast_range                                         0.413            0.477
# north_cascades                                        0.5            0.748
# cascades                                            0.265            0.591
# klamath_mountains_california_high_north_coast_r...   0.77               --
# eastern_cascades_slopes_and_foothills               0.656            0.536
# northern_rockies                                    0.659               --
# puget_lowland                                       0.585            0.437
# willamette_valley                                   0.298            0.616
# all                                                 0.287            0.344
#
#                                                    stddev_height  \
# blue_mountains                                             0.389
# coast_range                                               -0.314
# north_cascades                                            -0.408
# cascades                                                   0.248
# klamath_mountains_california_high_north_coast_r...        -0.337
# eastern_cascades_slopes_and_foothills                      0.204
# northern_rockies                                          -0.461
# puget_lowland                                                 --
# willamette_valley                                          0.122
# all                                                       -0.416
#
#                                                    surface_volume aspect  \
# blue_mountains                                              0.237  0.128
# coast_range                                                 0.699  0.103
# north_cascades                                              0.184  0.009
# cascades                                                    1.098 -0.094
# klamath_mountains_california_high_north_coast_r...             --  0.047
# eastern_cascades_slopes_and_foothills                       0.364 -0.104
# northern_rockies                                            0.827 -0.027
# puget_lowland                                               0.771     --
# willamette_valley                                           0.323     --
# all                                                         0.649  0.035
#
#                                                    elevation  slope  \
# blue_mountains                                            --  0.005
# coast_range                                            0.799 -0.072
# north_cascades                                         0.972     --
# cascades                                               1.208 -0.324
# klamath_mountains_california_high_north_coast_r...     0.507 -0.319
# eastern_cascades_slopes_and_foothills                  0.295 -0.303
# northern_rockies                                          --     --
# puget_lowland                                             --  0.333
# willamette_valley                                         --     --
# all                                                    0.797 -0.129
#
#                                                    solar_radiation_index  \
# blue_mountains                                                     0.105
# coast_range                                                        0.421
# north_cascades                                                        --
# cascades                                                           0.069
# klamath_mountains_california_high_north_coast_r...                 0.305
# eastern_cascades_slopes_and_foothills                             -0.024
# northern_rockies                                                   0.046
# puget_lowland                                                         --
# willamette_valley                                                     --
# all                                                                0.298
#
#                                                    kurtosis skewness
# blue_mountains                                           --   -1.122
# coast_range                                              --   -0.569
# north_cascades                                        0.066   -0.221
# cascades                                                 --   -0.453
# klamath_mountains_california_high_north_coast_r...       --   -0.343
# eastern_cascades_slopes_and_foothills                    --   -0.192
# northern_rockies                                         --    -0.73
# puget_lowland                                            --   -0.313
# willamette_valley                                        --    -0.07
# all                                                    0.19   -0.507
#
# [10 rows x 22 columns]

# %% [markdown]
# ## LASSO (Linear Model)
# Starting with implicit feature selection via L1 regularization of coefficients.

# %%
best_lassos = []

for i in range(len(ecoregions)):
    lasso = LassoCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000, n_alphas=1000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    lasso.fit(X, y)
    best_lassos.append(lasso)

# %%
lasso_res = get_score_df(best_lassos)
lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             18.765        22.153   104
# coast_range               110.670       109.934  1580
# north_cascades             76.618        83.208   443
# cascades                   67.513        65.731   613
# klamath_mountains          82.751        77.718   275
# eastern_cascades           44.391        41.831   203
# northern_rockies           40.075        32.145    83
# puget_lowland              56.975        50.985   122
# willamette_valley         104.821       130.959    41
# all                        89.370        89.370  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lassos])
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                             -0.064
# coast_range                                                 0.228
# north_cascades                                             -0.164
# cascades                                                    0.097
# klamath_mountains_california_high_north_coast_r...         -0.151
# eastern_cascades_slopes_and_foothills                          --
# northern_rockies                                            0.102
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                          0.08
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                       -0.648
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.107
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     -0.36
# all                                                                  -0.488
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.994
# coast_range                                                          -0.295
# north_cascades                                                        0.148
# cascades                                                             -0.172
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                -0.074
# northern_rockies                                                     -0.018
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        0.241
# coast_range                                                              --
# north_cascades                                                        0.599
# cascades                                                              0.445
# klamath_mountains_california_high_north_coast_r...                   -0.344
# eastern_cascades_slopes_and_foothills                                  0.22
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.367
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.185
# north_cascades                                                        1.144
# cascades                                                              0.769
# klamath_mountains_california_high_north_coast_r...                    0.593
# eastern_cascades_slopes_and_foothills                                 0.798
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.811
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        1.637
# coast_range                                                              --
# north_cascades                                                        1.096
# cascades                                                              0.427
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                         0.053
# willamette_valley                                                        --
# all                                                                    0.62
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                            0.04
# north_cascades                                                        1.338
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                 0.132
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                    0.94
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.334
# north_cascades                                                       --
# cascades                                                         -0.073
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                               0.199
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.395
# north_cascades                                                    0.096
# cascades                                                          0.656
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                 0.242
# all                                                               0.119
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                       --  ...
# coast_range                                                          --  ...
# north_cascades                                                       --  ...
# cascades                                                             --  ...
# klamath_mountains_california_high_north_coast_r...                0.016  ...
# eastern_cascades_slopes_and_foothills                             1.786  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                        --  ...
# willamette_valley                                                    --  ...
# all                                                              -0.207  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                      1.267               --
# coast_range                                         0.524            0.249
# north_cascades                                         --            1.244
# cascades                                            0.231            0.355
# klamath_mountains_california_high_north_coast_r...  1.255               --
# eastern_cascades_slopes_and_foothills               0.737            0.293
# northern_rockies                                    1.838               --
# puget_lowland                                       1.226               --
# willamette_valley                                      --               --
# all                                                 0.167            0.272
#
#                                                    stddev_height  \
# blue_mountains                                             0.338
# coast_range                                               -0.272
# north_cascades                                            -1.125
# cascades                                                   0.261
# klamath_mountains_california_high_north_coast_r...        -0.557
# eastern_cascades_slopes_and_foothills                      0.067
# northern_rockies                                              --
# puget_lowland                                                 --
# willamette_valley                                             --
# all                                                       -0.443
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --  0.136
# coast_range                                                 0.822  0.091
# north_cascades                                                 --  0.041
# cascades                                                    1.403 -0.089
# klamath_mountains_california_high_north_coast_r...             --  0.035
# eastern_cascades_slopes_and_foothills                          -- -0.117
# northern_rockies                                               --     --
# puget_lowland                                               2.542     --
# willamette_valley                                              --     --
# all                                                         0.687  0.036
#
#                                                    elevation  slope  \
# blue_mountains                                            --  0.001
# coast_range                                            0.797 -0.058
# north_cascades                                         1.128 -0.024
# cascades                                               1.227 -0.322
# klamath_mountains_california_high_north_coast_r...     0.457 -0.311
# eastern_cascades_slopes_and_foothills                  0.356 -0.374
# northern_rockies                                          --     --
# puget_lowland                                             --  0.182
# willamette_valley                                         --     --
# all                                                    0.808 -0.132
#
#                                                    solar_radiation_index  \
# blue_mountains                                                     0.112
# coast_range                                                        0.418
# north_cascades                                                     0.012
# cascades                                                           0.065
# klamath_mountains_california_high_north_coast_r...                 0.298
# eastern_cascades_slopes_and_foothills                              -0.03
# northern_rockies                                                      --
# puget_lowland                                                         --
# willamette_valley                                                     --
# all                                                                0.299
#
#                                                    kurtosis skewness
# blue_mountains                                           --   -1.207
# coast_range                                              --   -0.594
# north_cascades                                        0.083    -0.23
# cascades                                                 --   -0.464
# klamath_mountains_california_high_north_coast_r...       --   -0.318
# eastern_cascades_slopes_and_foothills                    --       --
# northern_rockies                                         --   -0.739
# puget_lowland                                            --       --
# willamette_valley                                        --       --
# all                                                   0.192   -0.507
#
# [10 rows x 22 columns]

# %% [markdown]
# Now we'll explicitly define the maximum number of features to use for fitting a linear model. We'll trim features by iteratively increasing a threshold for coefficients using LASSO regression

# %%
MAX_FEATURES = 5
sfms = [] # transformers that filter X features
trimmed_lassos = [] # re-fit lasso regressions on the subset of the features

for i, lasso in enumerate(best_lassos):
    lasso = deepcopy(lasso)
    sfm = SelectFromModel(lasso, threshold=0.001)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    Y = (eco_ytrain_dfs[i].ravel())
    sfm.fit(X, Y)
    n_features = sfm.transform(X).shape[1]

    # Reset the threshold till the number of features equals two.
    # Note that the attribute can be set directly instead of repeatedly
    # fitting the metatransformer.
    while n_features > MAX_FEATURES:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    
    sfms.append(sfm)
    try:
        trimmed_lassos.append(lasso.fit(sfm.transform(X), Y))
    except ValueError:
        print(ecoregion_names[i])
        raise

# %%
coefs = []
for i in range(len(ecoregions)):
    cols = np.zeros(eco_xtest_dfs[i].columns.shape)
    cols[sfms[i].get_support()] = trimmed_lassos[i].coef_
    coefs.append(cols)
    
coefs = np.array(coefs)

coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                    --
# north_cascades                                                 --
# cascades                                                       --
# klamath_mountains_california_high_north_coast_r...             --
# eastern_cascades_slopes_and_foothills                          --
# northern_rockies                                            0.639
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.788
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -1.033
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                        1.445
# cascades                                                              1.179
# klamath_mountains_california_high_north_coast_r...                     0.82
# eastern_cascades_slopes_and_foothills                                 0.953
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   1.214
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        1.424
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                         0.107
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                        1.045
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.532
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                          0.497
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                 0.249
# all                                                                  --
#
#                                                    height_50-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                             1.867
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_75-percentile  \
# blue_mountains                                                    0.887
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                1.954
# eastern_cascades_slopes_and_foothills                             1.315
# northern_rockies                                                  0.604
# puget_lowland                                                        --
# willamette_valley                                                 3.097
# all                                                               3.731
#
#                                                    height_95_percentile  \
# blue_mountains                                                       --
# coast_range                                                       1.428
# north_cascades                                                    3.632
# cascades                                                          1.965
# klamath_mountains_california_high_north_coast_r...                2.408
# eastern_cascades_slopes_and_foothills                             1.466
# northern_rockies                                                  1.036
# puget_lowland                                                     1.088
# willamette_valley                                                 1.025
# all                                                               0.339
#
#                                                     cover potential_volume  \
# blue_mountains                                       1.39               --
# coast_range                                            --               --
# north_cascades                                         --             1.26
# cascades                                               --               --
# klamath_mountains_california_high_north_coast_r...  0.915               --
# eastern_cascades_slopes_and_foothills                0.67               --
# northern_rockies                                    1.826               --
# puget_lowland                                       1.546               --
# willamette_valley                                      --               --
# all                                                    --               --
#
#                                                    stddev_height  \
# blue_mountains                                                --
# coast_range                                                   --
# north_cascades                                                --
# cascades                                                      --
# klamath_mountains_california_high_north_coast_r...        -0.901
# eastern_cascades_slopes_and_foothills                         --
# northern_rockies                                              --
# puget_lowland                                                 --
# willamette_valley                                             --
# all                                                           --
#
#                                                    surface_volume elevation  \
# blue_mountains                                                 --        --
# coast_range                                                 2.174     1.011
# north_cascades                                                 --     0.535
# cascades                                                    2.422     1.286
# klamath_mountains_california_high_north_coast_r...             --        --
# eastern_cascades_slopes_and_foothills                          --        --
# northern_rockies                                               --        --
# puget_lowland                                               2.325        --
# willamette_valley                                              --        --
# all                                                            --     0.476
#
#                                                     slope skewness
# blue_mountains                                         --   -1.378
# coast_range                                            --   -1.206
# north_cascades                                         --       --
# cascades                                               --       --
# klamath_mountains_california_high_north_coast_r...     --       --
# eastern_cascades_slopes_and_foothills                  --       --
# northern_rockies                                       --   -0.601
# puget_lowland                                       0.406       --
# willamette_valley                                      --       --
# all                                                    --       --

# %%
trimmed_lasso_res = get_score_df(trimmed_lassos, feature_selectors=sfms)
trimmed_lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             19.178        24.780   104
# coast_range               112.088       112.856  1580
# north_cascades             98.757        86.647   443
# cascades                   68.009        73.176   613
# klamath_mountains          87.210        90.885   275
# eastern_cascades           47.188        49.672   203
# northern_rockies           37.676        36.310    83
# puget_lowland              57.603        55.172   122
# willamette_valley          94.316       117.306    41
# all                        93.642        93.642  3473

# %% [markdown]
# ## K-Nearest Neighbors Regression

# %%
# Set the parameters by cross-validation
knn_params = {'n_neighbors': [1,2,3,4,5,10,20],
              'weights': ['uniform', 'distance'],
              'metric': ['minkowski', 'manhattan']}


knn_gs = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=knn_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_knns = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    knn_gs.fit(X, y)
    best_fit = knn_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_knns.append(best_fit)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    2.0s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    2.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.7s finished

# %%
knn_res = get_score_df(best_knns)
knn_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             23.121        25.681   104
# coast_range               113.150       112.819  1580
# north_cascades             65.189        72.705   443
# cascades                   70.593        73.068   613
# klamath_mountains          83.419        75.321   275
# eastern_cascades           46.583        42.143   203
# northern_rockies           50.953        27.815    83
# puget_lowland              66.388        54.146   122
# willamette_valley         150.539       152.199    41
# all                        90.861        90.861  3473

# %% [markdown]
# ## Random Forest Regression

# %%
# Set the parameters by cross-validation
rf_params = {'n_estimators': [100, 500, 1000, 5000],
             'max_features': ['sqrt'],
             'max_depth': [3, 5, 10, 25, 50],
             'min_samples_leaf': [1,2,4],
             'bootstrap': [True]}


rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=rf_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_rfs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    rf_gs.fit(X, y)
    best_fit = rf_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_rfs.append(best_fit)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    9.0s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   18.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   16.9s remaining:    9.1s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   45.5s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   25.2s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   15.3s remaining:    8.3s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   30.7s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.3s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   25.0s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    9.1s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   22.7s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    9.6s remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.4s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.7s remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  1.4min finished

# %%
rf_res = get_score_df(best_rfs)
rf_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             22.548        22.200   104
# coast_range               111.004       110.225  1580
# north_cascades             70.130        71.421   443
# cascades                   70.115        68.575   613
# klamath_mountains          78.902        74.134   275
# eastern_cascades           44.942        43.750   203
# northern_rockies           45.423        26.636    83
# puget_lowland              54.040        55.634   122
# willamette_valley         142.725       136.973    41
# all                        88.396        88.396  3473

# %%
### Employing feature selection to try and improve random forest regression

# %%
importances = best_rfs[-1].feature_importances_
indices = np.argsort(importances)[::-1]
features = eco_xtrain_dfs[-1].columns[indices]

# Print the feature ranking
print("Feature ranking:")

for f in range(eco_xtrain_dfs[-1].shape[1]):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. surface_volume (0.147033)
# 2. height_50-percentile (0.139482)
# 3. height_75-percentile (0.120767)
# 4. potential_volume (0.088069)
# 5. height_95_percentile (0.077792)
# 6. strat5_return-proportion (0.059160)
# 7. height_25-percentile (0.058602)
# 8. cover (0.049555)
# 9. skewness (0.032818)
# 10. strat4_return-proportion (0.029269)
# 11. strat0_return-proportion (0.028361)
# 12. strat3_return-proportion (0.021987)
# 13. elevation (0.021370)
# 14. strat1_return-proportion (0.020882)
# 15. stddev_height (0.018467)
# 16. strat2_return-proportion (0.016185)
# 17. kurtosis (0.016068)
# 18. solar_radiation_index (0.011907)
# 19. slope (0.011211)
# 20. height_05-percentile (0.010546)
# 21. returns_per_m2 (0.010444)
# 22. aspect (0.010026)

# %% [markdown]
# ## Gradient Boosting Trees Regression

# %%
# Set the parameters by cross-validation
gb_params = {'n_estimators': [100, 500, 1000, 5000],
             'learning_rate': [0.01, 0.1],
             'max_depth': [2, 3, 4, 5, 10],
             'max_features': ['sqrt'] 
            }

gb_gs = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=gb_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_gbs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    gb_gs.fit(X, y)
    best_fit = gb_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_gbs.append(best_fit)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    4.6s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.8s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   14.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   17.8s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    8.0s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    4.8s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   10.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   10.3s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.4s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    3.0s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.5s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.3s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.1s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.2s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   40.5s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   43.2s finished

# %%
gb_res = get_score_df(best_gbs)
gb_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             24.418        22.703   104
# coast_range               111.467       110.228  1580
# north_cascades             70.597        69.537   443
# cascades                   69.661        67.119   613
# klamath_mountains          78.676        73.459   275
# eastern_cascades           42.423        42.938   203
# northern_rockies           44.803        26.146    83
# puget_lowland              53.908        57.145   122
# willamette_valley         137.717       135.443    41
# all                        87.932        87.932  3473

# %%
### Employing feature selection to try and improve gradient boosting regression

# %% [markdown]
# ## Support Vector Machines Regression

# %%
# Set the parameters by cross-validation
svm_params = {'kernel': ['linear', 'rbf'],
              'gamma': ['scale', 'auto'],
              'C': [0.1,1,10,100,1000]
              }

svm_gs = GridSearchCV(estimator=SVR(), param_grid=svm_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_svms = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    svm_gs.fit(X, y)
    best_fit = svm_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_svms.append(best_fit)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   28.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   12.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   11.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    3.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    4.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    7.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.9s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.4min finished

# %%
svm_res = get_score_df(best_svms)
svm_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             18.497        20.606   104
# coast_range               111.359       110.651  1580
# north_cascades             69.952        83.708   443
# cascades                   67.655        66.239   613
# klamath_mountains          78.522        77.968   275
# eastern_cascades           41.285        41.387   203
# northern_rockies           33.707        30.876    83
# puget_lowland              56.156        51.863   122
# willamette_valley         127.630       132.200    41
# all                        89.905        89.905  3473

# %%
### Employing feature selection to try and improve support vector regression

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

def scatter_graphs(model_dict):
    names = MODELS.keys()
    EXTEND_PCT = 0.10
    
    fig, axs = plt.subplots(len(ecoregion_names), len(names), 
                            sharex=True, sharey=True,
                            figsize=(11,15)
                           )
    
    all_obs = transformer.inverse_transform(eco_ytest_dfs[-1].reshape(-1,1))
    obs_min = all_obs.min()
    obs_max = all_obs.max()
    rng = obs_max - obs_min
        
    for i, ecoreg in enumerate(ecoregion_names):
        observed = transformer.inverse_transform(eco_ytest_dfs[i].reshape(-1,1))
        
        for j, name in enumerate(names):
            axs[0,j].set_title(name)
            axs[i,0].set_ylabel('\n'.join(ecoreg.split('_')).upper())
            axs[i,j].set_xlim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_ylim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_aspect('equal')
            
            if name == 'LASSO_{}'.format(MAX_FEATURES):
                predicted = MODELS[name][-1].predict(sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i])))
            else:
                predicted = MODELS[name][-1].predict(x_scaler.transform(eco_xtest_dfs[i]))
            
            predicted = transformer.inverse_transform(predicted.reshape(-1,1))
            axs[i,j].scatter(observed, predicted, s=0.5)
            axs[i,j].plot((obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng), 
                          (obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng),
                         color='k', lw=0.5)
            
    plt.tight_layout(pad=0.5)

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

scatter_graphs(MODELS)

# %% [markdown]
# ## View scores for regional and global models

# %%
MODEL_NAMES = ['ElasticNet', 'LASSO', 'LASSO_{}'.format(MAX_FEATURES), 'KNN', 'RF', 'GB', 'SVM']
BEST_MODELS = [best_lms, best_lassos, trimmed_lassos, best_knns, best_rfs, best_gbs, best_svms]

def compare_models(metric):
    score_dfs = []
    for name, best_models in list(zip(MODEL_NAMES, BEST_MODELS)):
        if name == 'LASSO_{}'.format(MAX_FEATURES):
            score_df = get_score_df(best_models, metric, sfms) 
            score_dfs.append(score_df)
        else:
            score_df = get_score_df(best_models, metric) 
            score_dfs.append(score_df)
        
    counts = np.array(score_dfs[-1]['n'].values)
    regional_data = np.array([df['regional_model'].values for df in score_dfs])
    global_data = np.array([df['global_model'].values for df in score_dfs])
    
    return regional_data, global_data, counts

# %%
def highlight_best(s):
    '''
    highlight the closest value to zero in a Series yellow.
    '''
    lowest_idx = abs(s).idxmin()
    return ['background-color: yellow' if idx==lowest_idx else '' for idx in s.index]

# %%
print('Regional Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, RMSE
# <style  type="text/css" >
#     #T_2c56625a_5534_11ea_bb3a_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_2c56625a_5534_11ea_bb3a_00505683952erow1_col1 {
#             background-color:  yellow;
#         }    #T_2c56625a_5534_11ea_bb3a_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_2c56625a_5534_11ea_bb3a_00505683952erow3_col1 {
#             background-color:  yellow;
#         }    #T_2c56625a_5534_11ea_bb3a_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_2c56625a_5534_11ea_bb3a_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_2c56625a_5534_11ea_bb3a_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_2c56625a_5534_11ea_bb3a_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_2c56625a_5534_11ea_bb3a_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T
</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow0_col3" class="data row0 col3" >37%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow0_col4" class="data row0 col4" >36%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow0_col5" class="data row0 col5" >39%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow0_col6" class="data row0 col6" >30%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_2db2c62a_5534_11ea_bb3a_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow1_col0" class="data row1 col0" >45%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow1_col1" class="data row1 col1" >45%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow1_col2" class="data row1 col2" >45%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow1_col3" class="data row1 col3" >46%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow1_col4" class="data row1 col4" >45%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow1_col5" class="data row1 col5" >45%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow1_col6" class="data row1 col6" >45%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_2db2c62a_5534_11ea_bb3a_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow2_col0" class="data row2 col0" >44%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow2_col1" class="data row2 col1" >44%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow2_col2" class="data row2 col2" >57%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow2_col3" class="data row2 col3" >38%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow2_col4" class="data row2 col4" >40%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow2_col5" class="data row2 col5" >41%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow2_col6" class="data row2 col6" >40%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_2db2c62a_5534_11ea_bb3a_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow3_col0" class="data row3 col0" >33%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow3_col1" class="data row3 col1" >32%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow3_col2" class="data row3 col2" >33%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow3_col3" class="data row3 col3" >34%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow3_col4" class="data row3 col4" >34%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow3_col5" class="data row3 col5" >34%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow3_col6" class="data row3 col6" >33%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_2db2c62a_5534_11ea_bb3a_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow4_col0" class="data row4 col0" >40%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow4_col1" class="data row4 col1" >40%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow4_col2" class="data row4 col2" >43%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow4_col3" class="data row4 col3" >41%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow4_col4" class="data row4 col4" >39%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow4_col5" class="data row4 col5" >38%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow4_col6" class="data row4 col6" >38%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_2db2c62a_5534_11ea_bb3a_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow5_col0" class="data row5 col0" >38%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow5_col1" class="data row5 col1" >39%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow5_col2" class="data row5 col2" >41%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow5_col3" class="data row5 col3" >41%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow5_col4" class="data row5 col4" >39%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow5_col5" class="data row5 col5" >37%</td>
#                         <td id="T_2db2c62a_5534_11ea_bb3a_00505683952erow5_col6" class="data row5 col6" >36%</td>

# %%
print('Regional Models, Bias')
regional_data, global_data, counts = compare_models(bias)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .apply(highlight_best, axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, Bias
# <style  type="text/css" >
#     #T_2f129914_5534_11ea_bb3a_00505683952erow0_col4 {
#             background-color:  yellow;
#         }    #T_2f129914_5534_11ea_bb3a_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_2f129914_5534_11ea_bb3a_00505683952erow2_col1 {
#             background-color:  yellow;
#         }    #T_2f129914_5534_11ea_bb3a_00505683952erow3_col3 {
#             background-color:  yellow;
#         }    #T_2f129914_5534_11ea_bb3a_00505683952erow4_col1 {
#             background-color:  yellow;
#         }    #T_2f129914_5534_11ea_bb3a_00505683952erow5_col5 {
#             background-color:  yellow;
#         }    #T_2f129914_5534_11ea_bb3a_00505683952erow6_col0 {
#             background-color:  yellow;
#         }    #T_2f129914_5534_11ea_bb3a_00505683952erow7_col2 {
#             background-color:  yellow;
#         }    #T_2f129914_5534_11ea_bb3a_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_2f129914_5534_11ea_bb3a_00505683952erow9_col1 {
#             background-color:  yellow;
#         }</style><table id="T_2f129914_5534_11ea_bb3a_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2f129914_5534_11ea_bb3a_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_2f129914_5534_11ea_bb3a_00505683952erow0_col0" class="data row0 col0" >2.0</td>
#                         <td id="T_2f129914_5534_11ea_bb3a_00505683952erow0_col1" class="data row0 col1" >2.2</td>
#                         <td id="T_2f129914_5534_11ea_bb3a_00505683952erow0_col2" class="data row0 col2" >1.3</td>
#                         <td id="T_2f129914_5534_11ea_bb3a_00505683952erow0_col3" class="data row0 col3" >2.1</td>
#                         <td id="T_2f129914_5534_11ea_bb3a_00505683952erow0_col4" class="data row0 col4" >1.3</td>
#                         <td id="T_2f129914_5534_11ea_bb3a_00505683952erow0_col5" class="data row0 col5" >2.8</td>
#                         <td id="T_2f129914_5534_11ea_bb3a_00505683952er
</td>
#                         <td id="T_349bacfe_5534_11ea_bb3a_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_349bacfe_5534_11ea_bb3a_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_349bacfe_5534_11ea_bb3a_00505683952erow5_col0" class="data row5 col0" >36%</td>
#                         <td id="T_349bacfe_5534_11ea_bb3a_00505683952erow5_col1" class="data row5 col1" >37%</td>
#                         <td id="T_349bacfe_5534_11ea_bb3a_00505683952erow5_col2" class="data row5 col2" >43%</td>
#                         <td id="T_349bacfe_5534_11ea_bb3a_00505683952erow5_col3" class="data row5 col3" >37%</td>
#                         <td id="T_349bacfe_5534_11ea_bb3a_00505683952erow5_col4" class="data row5 col4" >38%</td>
#                         <td id="T_349bacfe_5534_11ea_bb3a_00505683952erow5_col5" class="data row5 col5" >38%</td>

# %%
print('Global Models, Bias')
regional_data, global_data, counts = compare_models(bias)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=global_scores.columns[:-1])
 .apply(highlight_best, axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, Bias
# <style  type="text/css" >
#     #T_35f7bbc4_5534_11ea_bb3a_00505683952erow0_col4 {
#             background-color:  yellow;
#         }    #T_35f7bbc4_5534_11ea_bb3a_00505683952erow1_col4 {
#             background-color:  yellow;
#         }    #T_35f7bbc4_5534_11ea_bb3a_00505683952erow2_col1 {
#             background-color:  yellow;
#         }    #T_35f7bbc4_5534_11ea_bb3a_00505683952erow3_col1 {
#             background-color:  yellow;
#         }    #T_35f7bbc4_5534_11ea_bb3a_00505683952erow4_col2 {
#             background-color:  yellow;
#         }    #T_35f7bbc4_5534_11ea_bb3a_00505683952erow5_col2 {
#             background-color:  yellow;
#         }    #T_35f7bbc4_5534_11ea_bb3a_00505683952erow6_col2 {
#             background-color:  yellow;
#         }    #T_35f7bbc4_5534_11ea_bb3a_00505683952erow7_col3 {
#             background-color:  yellow;
#         }    #T_35f7bbc4_5534_11ea_bb3a_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_35f7bbc4_5534_11ea_bb3a_00505683952erow9_col1 {
#             background-color:  yellow;
#         }</style><table id="T_35f7bbc4_5534_11ea_bb3a_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_35f7bbc4_5534_11ea_bb3a_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow0_col0" class="data row0 col0" >6.5</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow0_col1" class="data row0 col1" >6.6</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow0_col2" class="data row0 col2" >13.5</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow0_col3" class="data row0 col3" >2.2</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow0_col4" class="data row0 col4" >-0.2</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow0_col5" class="data row0 col5" >2.0</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow0_col6" class="data row0 col6" >4.8</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_35f7bbc4_5534_11ea_bb3a_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow1_col0" class="data row1 col0" >-20.6</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow1_col1" class="data row1 col1" >-20.7</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow1_col2" class="data row1 col2" >-19.4</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow1_col3" class="data row1 col3" >-20.1</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow1_col4" class="data row1 col4" >-17.1</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow1_col5" class="data row1 col5" >-19.2</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow1_col6" class="data row1 col6" >-23.0</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_35f7bbc4_5534_11ea_bb3a_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow2_col0" class="data row2 col0" >-9.4</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow2_col1" class="data row2 col1" >-9.2</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow2_col2" class="data row2 col2" >-13.0</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow2_col3" class="data row2 col3" >-15.3</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow2_col4" class="data row2 col4" >-13.1</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow2_col5" class="data row2 col5" >-13.5</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow2_col6" class="data row2 col6" >-11.5</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_35f7bbc4_5534_11ea_bb3a_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow3_col0" class="data row3 col0" >-9.8</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow3_col1" class="data row3 col1" >-9.5</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow3_col2" class="data row3 col2" >-20.3</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow3_col3" class="data row3 col3" >-17.5</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow3_col4" class="data row3 col4" >-15.5</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow3_col5" class="data row3 col5" >-13.3</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow3_col6" class="data row3 col6" >-11.1</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_35f7bbc4_5534_11ea_bb3a_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow4_col0" class="data row4 col0" >-12.7</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952erow4_col1" class="data row4 col1" >-12.2</td>
#                         <td id="T_35f7bbc4_5534_11ea_bb3a_00505683952er
</td>
#                         <td id="T_38b3cbb4_5534_11ea_bb3a_00505683952erow5_col1" class="data row5 col1" >24%</td>
#                         <td id="T_38b3cbb4_5534_11ea_bb3a_00505683952erow5_col2" class="data row5 col2" >33%</td>
#                         <td id="T_38b3cbb4_5534_11ea_bb3a_00505683952erow5_col3" class="data row5 col3" >25%</td>
#                         <td id="T_38b

# %%
print('Global vs. Regional Models, ΔRMSE')
regional_data, global_data, counts = compare_models(rmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔRMSE
# <style  type="text/css" >
#     #T_3a0e1f32_5534_11ea_bb3a_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 72.3%, transparent 72.3%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 71.2%, transparent 71.2%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 85.0%, transparent 85.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 66.0%, transparent 66.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.8%, orange 47.8%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.3%, orange 39.3%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 63.2%, transparent 63.2%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.0%, orange 44.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.4%, orange 45.4%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.8%, transparent 54.8%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.9%, orange 47.9%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.1%, orange 45.1%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.3%, orange 42.3%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.6%, orange 45.6%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 94.3%, transparent 94.3%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 91.2%, transparent 91.2%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 97.0%, transparent 97.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.1%, transparent 58.1%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.4%, orange 43.4%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 100.0%, transparent 100.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.3%, orange 38.3%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.9%, orange 38.9%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 82.3%, transparent 82.3%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 65.5%, transparent 65.5%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.4%, orange 40.4%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.1%, orange 34.1%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.1%, orange 41.1%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.9%, orange 27.9%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 18.5%, orange 18.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 73.0%, transparent 73.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 20.2%, orange 20.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 17.4%, orange 17.4%, orange 50.0%, transparent 50.0%);
#         }    #T_3a0e1f32_5534_11ea_bb3a_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.5%, orange 46.5%, orange 50.0%, trans

# %%
print('Global vs. Regional Models, ΔRMSE%')
regional_data, global_data, counts = compare_models(nrmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.2, vmax=0.2))
# Out:
# Global vs. Regional Models, ΔRMSE%
# <style  type="text/css" >
#     #T_3b6a45e0_5534_11ea_bb3a_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 64.2%, transparent 64.2%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 63.7%, transparent 63.7%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 72.5%, transparent 72.5%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.5%, transparent 60.5%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, orange 48.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.2%, orange 43.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.5%, transparent 58.5%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.0%, orange 49.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.7%, transparent 50.7%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.0%, orange 49.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, orange 48.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.2%, transparent 60.2%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 59.2%, transparent 59.2%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.5%, orange 32.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.7%, transparent 60.7%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.0%, transparent 52.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, orange 48.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 69.7%, transparent 69.7%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.2%, transparent 56.2%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.0%, transparent 53.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.0%, orange 48.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.0%, orange 47.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.2%, orange 48.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.7%, orange 45.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.7%, orange 43.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.5%, transparent 54.5%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.2%, orange 40.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.2%, orange 44.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.7%, orange 43.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3b6a45e0_5534_11ea_bb3a_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gr

# %%
print('Global vs. Regional Models, ΔMAE')
regional_data, global_data, counts = compare_models(mae)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔMAE
# <style  type="text/css" >
#     #T_3cc4805e_5534_11ea_bb3a_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 63.1%, transparent 63.1%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.1%, transparent 62.1%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 75.1%, transparent 75.1%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.2%, orange 40.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.2%, orange 37.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.5%, orange 44.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 57.5%, transparent 57.5%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.2%, orange 44.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.6%, orange 45.6%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.8%, transparent 61.8%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.4%, transparent 55.4%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.0%, transparent 54.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.7%, orange 43.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.6%, orange 45.6%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.2%, transparent 61.2%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 64.7%, transparent 64.7%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 80.9%, transparent 80.9%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.4%, transparent 50.4%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.2%, orange 46.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 80.7%, transparent 80.7%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.5%, orange 46.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.8%, orange 46.8%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 80.9%, transparent 80.9%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 70.3%, transparent 70.3%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.0%, orange 46.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, orange 44.9%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.8%, transparent 52.8%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.5%, orange 31.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 26.6%, orange 26.6%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 66.2%, transparent 66.2%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 11.4%, orange 11.4%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 22.5%, orange 22.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 13.3%, orange 13.3%, orange 50.0%, transparent 50.0%);
#         }    #T_3cc4805e_5534_11ea_bb3a_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, orange 44

# %%
print('Global vs. Regional Models, Δbias%')
regional_data, global_data, counts = compare_models(rel_bias)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.4, vmax=0.4))
# Out:
# Global vs. Regional Models, Δbias%
# <style  type="text/css" >
#     #T_3e1e10b4_5534_11ea_bb3a_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 59.1%, transparent 59.1%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.9%, transparent 58.9%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 74.5%, transparent 74.5%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.9%, orange 46.9%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.2%, orange 48.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.7%, transparent 55.7%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, orange 49.6%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.7%, transparent 50.7%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.5%, transparent 51.5%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.7%, transparent 51.7%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.2%, transparent 50.2%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.0%, orange 49.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.5%, orange 45.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, orange 44.9%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.2%, orange 43.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.1%, orange 43.1%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.4%, orange 45.4%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.4%, orange 47.4%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.4%, transparent 52.4%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.2%, transparent 53.2%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.5%, transparent 53.5%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.6%, orange 47.6%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.2%, transparent 50.2%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.4%, transparent 51.4%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.2%, transparent 53.2%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.5%, orange 43.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.5%, orange 42.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.7%, orange 45.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.5%, orange 41.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, orange 44.7%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, orange 46.6%, orange 50.0%, transparent 50.0%);
#         }    #T_3e1e10b4_5534_11ea_bb3a_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradie

# %%
METRIC = 'basal_area'

MODELS = {'ElasticNet': best_lms,
          'LASSO': best_lassos,
          'LASSO{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

pickle.dump(x_scaler, 
            open('../models/{}/sklearn/x_scaler.pkl'.format(METRIC), 'wb'))
pickle.dump(transformer, 
            open('../models/{}/sklearn/y_scaler.pkl'.format(METRIC), 'wb'))

for i in range(len(ecoregion_names)):
    for key in MODELS.keys():
        fname = ecoregion_names[i] + '_{}.pkl'.format(key)
        path_to_file = '../models/{}/sklearn/{}'.format(METRIC, fname)
        pickle.dump(MODELS[key][i], 
                    open(path_to_file, 'wb'))
        
        if key == 'LASSO{}'.format(MAX_FEATURES):
            sfm_name = ecoregion_names[i] + '_LASSO{}_featureselect.pkl'.format(MAX_FEATURES)
            path_to_file = '../models/{}/sklearn/{}'.format(METRIC, sfm_name)
            pickle.dump(sfms[i], 
                        open(path_to_file, 'wb'))
