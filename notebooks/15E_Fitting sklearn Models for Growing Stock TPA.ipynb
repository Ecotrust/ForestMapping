# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
# data prep and model-tuning
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, QuantileTransformer
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV

# types of models we'll fit
from sklearn.linear_model import ElasticNetCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR

from scipy.stats import shapiro

import pickle
from copy import deepcopy

# %% [markdown]
# ## Our Data

# %%
DATA = '../data/processed/training_data_annual.csv'
df = pd.read_csv(DATA)
df = df.dropna()
print('{:,d} samples'.format(len(df)))
print('Columns:', df.columns.values)
# Out:
# 4,721 samples
# Columns: ['uuid' 'lidar_year' 'lat' 'lon' 'orig_id' 'source' 'meas_yr' 'ecoregion3'
#  'agency' 'plot_size_ac' 'num_returns' 'strat0_return-proportion'
#  'strat1_return-proportion' 'strat2_return-proportion'
#  'strat3_return-proportion' 'strat4_return-proportion'
#  'strat5_return-proportion' 'skewness' 'kurtosis'
#  'strat0_intensity-median' 'strat1_intensity-median'
#  'strat2_intensity-median' 'strat3_intensity-median'
#  'strat4_intensity-median' 'strat5_intensity-median'
#  'height_05-percentile' 'height_25-percentile' 'height_50-percentile'
#  'height_75-percentile' 'height_95_percentile' 'height_max' 'cover'
#  'lidar_acq' 'potential_volume' 'stddev_height' 'surface_area_ratio'
#  'surface_volume' 'surface_volume_ratio' 'aspect' 'elevation'
#  'overall_curvature' 'plan_curvature' 'profile_curvature' 'slope'
#  'solar_radiation_index' 'mat' 'mwmt' 'mcmt' 'td' 'map' 'msp' 'ahm' 'shm'
#  'dd_0' 'dd5' 'dd_18' 'dd18' 'nffd' 'bffp' 'effp' 'ffp' 'pas' 'emt' 'ext'
#  'eref' 'cmd' 'rh' 'green' 'blue' 'red' 'nir' 'endvi' 'ndvi' 'savi'
#  'swir1' 'swir2' 'wetness' 'greenness' 'brightness' 'landsat_year'
#  'clim_year' 'distance_to_water_m' 'bulk_dens' 'soil_depth'
#  'pct_clay_surf' 'pct_rock_surf' 'pct_sand_surf' 'pot_veg_type' 'tpa' 'ba'
#  'sdi' 'ccf' 'qmd' 'tcuft' 'topht' 'number_of_strata' 'total_cover'
#  'structure_class' 'canopy_baseheight' 'canopy_bulkdensity'
#  'aboveground_biomass' 'aboveground_carbon' 'gs_tpa' 'AF' 'AS' 'BM' 'BO'
#  'CH' 'CW' 'DF' 'DG' 'ES' 'GC' 'GF' 'IC' 'JP' 'KP' 'LO' 'LP' 'MA' 'MC'
#  'MH' 'NF' 'OH' 'OS' 'OT' 'PC' 'PL' 'PP' 'PY' 'RA' 'RC' 'RF' 'SF' 'SH'
#  'SP' 'SS' 'TO' 'WA' 'WB' 'WF' 'WH' 'WI' 'WJ' 'WL' 'WO' 'WP' 'YC'
#  'TRUE_FIR' 'OTHER_HARDWOOD' 'MAPLE' 'OAK' 'DOUGLAS_FIR' 'SPRUCE' 'CEDAR'
#  'PONDEROSA_PINE' 'OTHER_SOFTWOOD' 'LODGEPOLE_PINE' 'HEMLOCK' 'RED_ALDER'
#  'TANOAK' 'JUNIPER' 'LARCH' 'fvs_year' 'year_diff' 'returns_per_m2']

# %% [markdown]
# ## Filter out some of the training data
# We can exclude some of the training data based on how far separated the inventory data (interpolated using FVS simulations) is from the year the lidar was collected. Similarly, we can screen out training examples that had relatively low density of lidar returns.

# %%
df['year_diff'] = abs(df['fvs_year'] - df['lidar_year']).astype(int)

# %%
len(df.loc[df['year_diff'] >= 5])
# Out:
# 829

# %%
df = df.loc[df['year_diff'] < 5]

# %%
len(df.loc[df['returns_per_m2'] < 4.0])
# Out:
# 103

# %%
df = df.loc[df['returns_per_m2'] >= 4.0]

# %%
lidar_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['topht'].values.reshape(-1, 1))

lidar_height_transformed = lidar_height_transformer.transform(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformed = fvs_height_transformer.transform(df['topht'].values.reshape(-1, 1))

diff_height_transformed = abs(lidar_height_transformed - fvs_height_transformed)


fig, axs = plt.subplots(1,2, figsize=(15,5))

# select outliers
OUTLIER_THRESH = 3.05
outliers = diff_height_transformed > OUTLIER_THRESH
outliers = np.logical_or(outliers, (df['height_95_percentile'] > 275/3.28084).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 60/3.28084) & (df['topht'] > 105)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 10/3.28084) & (df['topht'] > 40)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])/df['topht']) > 1.0).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])) > 100).values.reshape(-1, 1))

axs[0].hist(diff_height_transformed, bins=20)
axs[0].axvline(OUTLIER_THRESH, color='k')
axs[0].set_title('Differences between transformed lidar and fvs canopy height')

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[~outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[~outliers],
            s=1, label='Inliers (n={:,d})'.format((~outliers).sum()))

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[outliers],
            s=5, label='Outliers (n={:,d})'.format(outliers.sum()))

axs[1].set_xlabel('Lidar Canopy Height, ft')
axs[1].set_ylabel('FVS Canopy Height, ft')
axs[1].plot([0,400],[0,400], color='k', lw=2, label='1:1')
axs[1].set_xlim(-10, 400)
axs[1].set_ylim(-10, 400)
axs[1].set_aspect('equal')
axs[1].legend();

# %%
# filter out the height outliers
df = df[~outliers]

# %% [markdown]
# ## Inspect how many samples we have for different years, regions, etc.

# %%
df.groupby(by=['lidar_year'])[['uuid']].count().rename({'uuid':'count'}, axis=1)
# Out:
#             count
# lidar_year
# 2008          747
# 2009           18
# 2010            2
# 2011          120
# 2012          613
# 2013          232
# 2014          342
# 2015          646
# 2016          543
# 2017          177
# 2018           33

# %%
pd.pivot_table(df, 
               values='uuid', 
               aggfunc='count', 
               index=['meas_yr'], 
               columns=['lidar_year'], 
               fill_value=0)
# Out:
# lidar_year  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# meas_yr
# 2010         419     0     0     0     3     0     2     7     0     0     0
# 2011         328     0     0     0     1     0     2     2     0     0     0
# 2013           0    18     0    37   421    49     3    10    13    26     2
# 2014           0     0     2    29   130    43    47    41    86    36     0
# 2015           0     0     0    54    16    12    16   202   105    24     5
# 2016           0     0     0     0    42    86    48   275    67    35    26
# 2017           0     0     0     0     0    42   177    54    93    46     0
# 2018           0     0     0     0     0     0    47    55   179    10     0

# %%
ecoreg_counts = df.groupby(by=['ecoregion3'])[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
ecoreg_counts
# Out:
#                                                     uuid  lidar_acq  \
# ecoregion3
# blue_mountains                                       104          2
# cascades                                             579         21
# coast_range                                         1511         18
# columbia_plateau                                       8          4
# eastern_cascades_slopes_and_foothills                202         11
# klamath_mountains_california_high_north_coast_r...   253          7
# north_cascades                                       405         18
# northern_rockies                                      71          4
# puget_lowland                                        110         14
# willamette_valley                                     41          2
#
#                                                     lidar_year  plot_size_ac
# ecoregion3
# blue_mountains                                               2             1
# cascades                                                     9             3
# coast_range                                                  9             2
# columbia_plateau                                             4             1
# eastern_cascades_slopes_and_foothills                        6             2
# klamath_mountains_california_high_north_coast_r...           5             2
# north_cascades                                               6             2
# northern_rockies                                             3             1
# puget_lowland                                                7             1
# willamette_valley                                            2             2

# %%
df[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
# Out:
# uuid            3284
# lidar_acq         70
# lidar_year        11
# plot_size_ac       3
# dtype: int64

# %% [markdown]
# ## Available features
# First, we'll use one-hot encoding for categorical features

# %%
# convert agency, ecoregion, and lidar acquisition into one-hot encoded set of variables
df = pd.get_dummies(df, prefix='agency', columns=['agency'])
# df = pd.get_dummies(df, prefix='eco', columns=['ecoregion3'])
# df = pd.get_dummies(df, prefix='acq', columns=['lidar_acq'])

# %% [markdown]
# The different types of predictor variables we can use to predict a forest attribute, including climate, lidar-derived, soil, and satellite imagery.

# %%
CLIM_COLS = ['mat', 'mwmt', 'mcmt', 'td', 'map', 'msp', 'ahm', 'shm', 
             'dd_0', 'dd5', 'dd_18', 'dd18', 'nffd', 'bffp', 'effp', 
             'ffp', 'pas', 'emt', 'ext', 'eref', 'cmd', 'rh']

LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
       'strat1_return-proportion', 'strat2_return-proportion',
       'strat3_return-proportion', 'strat4_return-proportion',
       'strat5_return-proportion', 'strat0_intensity-median',
       'strat1_intensity-median', 'strat2_intensity-median',
       'strat3_intensity-median', 'strat4_intensity-median',
       'strat5_intensity-median', 'height_05-percentile',
       'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
       'height_95_percentile', 'height_max', 'cover', 'potential_volume',
       'stddev_height', 'surface_area_ratio', 'surface_volume',
       'surface_volume_ratio', 'aspect', 'elevation', 'overall_curvature',
       'plan_curvature', 'profile_curvature', 'slope', 'solar_radiation_index', 
              'kurtosis', 'skewnewss']

USE_LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
                  'strat1_return-proportion', 'strat2_return-proportion',
                  'strat3_return-proportion', 'strat4_return-proportion',
                  'strat5_return-proportion', 'height_05-percentile',
                  'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
                  'height_95_percentile', 'cover', 'potential_volume',
                  'stddev_height', 'surface_volume',
                  'aspect', 'elevation', 'slope', 'solar_radiation_index',
                  'kurtosis', 'skewness']

SOIL_COLS = ['bulk_dens', 'soil_depth', 'pct_clay_surf', 'pct_rock_surf', 'pct_sand_surf']

LANDSAT_COLS = ['green', 'blue', 'red', 'nir', 'endvi', 'ndvi', 'savi',
                'swir1', 'swir2', 'wetness', 'greenness', 'brightness']

AGENCY_COLS = ['agency_BLM', 'agency_USFS', 'agency_WADNR']

# ECOREGIONS = [col for col in df.columns if col.startswith('eco_')]

# %% [markdown]
# ## Selecting initial features and targets
# This is the first step in determining what features we want to use, and what we want to predict. Later, we can still apply some procedures to choose a subset of these features to make simpler models.

# %%
X_COLS = USE_LIDAR_COLS + ['ecoregion3'] 
Y_COLS = ['gs_tpa']

# %% [markdown]
# ## Split the data into training and testing sets
# Since some plot_ids have multiple observations, we want all observations for each plot_id to fall entirely in train_set or entirely the training or testing sets because these samples are definitely not independent.

# %%
# a dataframe with unique plot ids
splits = pd.DataFrame(pd.unique(df['uuid']), columns=['uuid']).set_index('uuid')

# randomly assign each plot-id to train(0) or test(1) sets
np.random.seed(127)
splits['train0_test1'] = np.random.choice(2,
                                          size=len(splits),
                                          p=[0.8,0.2])

# add set assignments to the dataframe
df['train0_test1'] = splits.loc[df['uuid']]['train0_test1'].values

# %%
train_plots = df.loc[df['train0_test1'] == 0]
test_plots = df.loc[df['train0_test1'] == 1]
len(train_plots), len(test_plots)
# Out:
# (2769, 704)

# %%
x_train, x_test = train_plots[X_COLS], test_plots[X_COLS]
y_train, y_test = train_plots[Y_COLS], test_plots[Y_COLS]

# %% [markdown]
# ## Standardize features
# Scale all predictive features to have 0 mean and unit variance (subtracting mean, dividing by standard deviation).

# %%
x_scaler = StandardScaler()
x_scaler.fit(df[X_COLS].drop(['ecoregion3'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Consider a few transformations for the target variable

# %%
fig, axs = plt.subplots(1,6, figsize=(15,2.5))

quantile = QuantileTransformer(output_distribution='normal', random_state=127)
box_cox = PowerTransformer(method='box-cox')
yeo_johnson = PowerTransformer(method='yeo-johnson')

VALS = [y_train.values,
        np.log1p(y_train.values),
        np.sqrt(y_train.values),
        quantile.fit_transform(y_train.values),
        box_cox.fit_transform(y_train.values + 1e-9),
        yeo_johnson.fit_transform(y_train.values)]

TITLES = ['Raw', 'Log', 'SQRT', 'Quantile', 'Box-Cox', 'Yeo-Johnson']
SHAPIRO_ps = [shapiro(vals)[-1] for vals in VALS]

for i, vals in enumerate(VALS):
    axs.ravel()[i].hist(vals, bins=20)
    axs.ravel()[i].set_title(TITLES[i])
    
plt.show();

# %%
# identify the closest to normally-distributed
TITLES[np.array(SHAPIRO_ps).argmax()]
# Out:
# 'Yeo-Johnson'

# %%
# choose your transformer here
transformer = yeo_johnson

# %%
transformer.fit(df[Y_COLS])
y_train.loc[:,Y_COLS], y_test.loc[:,Y_COLS] = transformer.transform(y_train), transformer.transform(y_test)
# Out:
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Split datasets by ecoregion
# We want to explore model transferability between regions, so we'll train models independently on subsets of the data within a single ecoregion, as well as a model that is trained on all available ecoregions.

# %%
ecoregions = [reg for reg in pd.unique(df.ecoregion3) if ecoreg_counts.loc[reg]['uuid'] > 20]

eco_train_idx = [x_train.loc[x_train.ecoregion3 == eco].index.values for eco in ecoregions]
eco_test_idx = [x_test.loc[x_test.ecoregion3 == eco].index.values for eco in ecoregions]

eco_xtrain_dfs = [x_train.loc[x_train.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytrain_dfs = [y_train.loc[idx].values.ravel() for idx in eco_train_idx]
eco_xtest_dfs = [x_test.loc[x_test.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytest_dfs = [y_test.loc[idx].values.ravel() for idx in eco_test_idx]

# append a "global" model that contains data from all ecoregions
ecoregions.append('all')
ecoregion_names = ['_'.join(x.split('_')[0:2]) for x in ecoregions]
eco_xtrain_dfs.append(x_train.drop(['ecoregion3'], axis=1))
eco_ytrain_dfs.append(y_train.values.ravel())
eco_xtest_dfs.append(x_test.drop(['ecoregion3'], axis=1))
eco_ytest_dfs.append(y_test.values.ravel())

# %% [markdown]
# ## Scoring
# We'll use Root Mean Square Error to evaluate model performance.

# %%
def rmse(pred, obs):
    # use our transformer to calculate RMSE on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return np.sqrt((np.square(obs-pred)).mean())

# %%
def nrmse(pred, obs):
    # use our transformer to calculate percent RMSE on the original data scale
    this_rmse = rmse(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return this_rmse/obs.mean()

# %%
def mae(pred, obs):
    # use our transformer to calculate mean absolute error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean()

# %%
def mape(pred, obs):
    # use our transformer to calculate mean average percent error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean() / obs.mean()

# %%
def bias(pred, obs):
    # use our transformer to calculate mean bias on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return (pred - obs).mean()

# %%
def rel_bias(pred, obs):
    # use our transformer to calculate mean relative bias on the original data scale
    this_bias = bias(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1))  
    
    return this_bias/obs.mean()

# %% [markdown]
# This helper function will calculate RMSE scores for each regionally-trained model and the global model on each ecoregion.

# %%
def get_score_df(models, metric=rmse, feature_selectors=None):
    regional_scores = []
    global_scores = []
    counts = []
    
    for i, mod in enumerate(models):
        X_test = x_scaler.transform(eco_xtest_dfs[i])
        if feature_selectors:
            X_test = feature_selectors[i].transform(X_test)
        y_test = eco_ytest_dfs[i]
        reg_score = metric(mod.predict(X_test), y_test)
        regional_scores.append(reg_score.round(3))
        
        if feature_selectors:
            X_test = x_scaler.transform(eco_xtest_dfs[i])
            X_test = feature_selectors[-1].transform(X_test)
        glob_score = metric(models[-1].predict(X_test), y_test)
        global_scores.append(glob_score.round(3))
        count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
        counts.append(count)
        
    data = list(zip(regional_scores, global_scores, counts))
    res_df = pd.DataFrame(data=data,
                          columns=['regional_model', 'global_model', 'n'],
                          index=ecoregion_names)
    
    return res_df

# %% [markdown]
# ## Fit some models
# For each type of model, we'll employ cross-validation to tune model hyperparameters, generating a tuned model for each ecoregion as well as a tuned model using all training data. We'll work our way through:
#
# #### ElasticNet Regression
# Linear model that employs a mix of L1 and L2 regularization to penalize model complexity
#
# #### LASSO Regression
# Linear model that employs L1 regularization to penalize model complexity. We'll also work with a feature-selection process to fit models capped to an explicitly-predefined number of features.
#
# #### K-Nearest Neighbor Regression
#
# #### Random Forest Regression
#
# #### Gradient Boosting Trees Regression
#
# #### Support Vector Machine Regression

# %% [markdown]
# ## ElasticNet (Linear Model)

# %%
best_lms = []

for i in range(len(ecoregions)):
    lm = ElasticNetCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    lm.fit(X, y)
    best_lms.append(lm)

# %%
elastic_res = get_score_df(best_lms)
elastic_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             24.041        28.945   104
# coast_range                80.486        80.142  1580
# north_cascades             99.762        92.494   443
# cascades                   82.509        82.032   613
# klamath_mountains          75.487        74.405   275
# eastern_cascades           64.830        67.437   203
# northern_rockies           65.940        69.660    83
# puget_lowland             102.928       107.141   122
# willamette_valley          50.739        51.625    41
# all                        80.482        80.482  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lms])
count_nonzero = [(~np.isclose(coef, 0, atol=1e-3)).sum() for coef in coefs]
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.003
# north_cascades                                              -0.07
# cascades                                                   -0.037
# klamath_mountains_california_high_north_coast_r...             --
# eastern_cascades_slopes_and_foothills                      -0.026
# northern_rockies                                            0.338
# puget_lowland                                               0.232
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                       -0.161
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.115
# eastern_cascades_slopes_and_foothills                                -0.099
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.084
# all                                                                  -0.005
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.161
# coast_range                                                          -0.129
# north_cascades                                                        0.046
# cascades                                                             -0.034
# klamath_mountains_california_high_north_coast_r...                   -0.127
# eastern_cascades_slopes_and_foothills                                -0.101
# northern_rockies                                                     -0.067
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                  -0.009
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        0.503
# coast_range                                                           0.265
# north_cascades                                                        0.423
# cascades                                                              0.356
# klamath_mountains_california_high_north_coast_r...                    0.008
# eastern_cascades_slopes_and_foothills                                 0.273
# northern_rockies                                                      0.265
# puget_lowland                                                         0.176
# willamette_valley                                                        --
# all                                                                   0.297
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.131
# coast_range                                                           0.286
# north_cascades                                                         0.43
# cascades                                                              0.344
# klamath_mountains_california_high_north_coast_r...                    0.427
# eastern_cascades_slopes_and_foothills                                 0.153
# northern_rockies                                                      0.346
# puget_lowland                                                         0.274
# willamette_valley                                                     0.083
# all                                                                   0.367
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.158
# north_cascades                                                        0.211
# cascades                                                              0.182
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                         0.031
# willamette_valley                                                     0.023
# all                                                                   0.207
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.132
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.158
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.096
# north_cascades                                                    0.089
# cascades                                                          0.003
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                  0.174
# puget_lowland                                                     0.003
# willamette_valley                                                    --
# all                                                               0.073
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                         -0.076
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                             0.015
# northern_rockies                                                  0.301
# puget_lowland                                                        --
# willamette_valley                                                 0.001
# all                                                              -0.021
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                       --  ...
# coast_range                                                      -0.079  ...
# north_cascades                                                       --  ...
# cascades                                                         -0.169  ...
# klamath_mountains_california_high_north_coast_r...                   --  ...
# eastern_cascades_slopes_and_foothills                             0.095  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                     0.378  ...
# willamette_valley                                                    --  ...
# all                                                              -0.126  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                      0.386               --
# coast_range                                          0.05           -0.029
# north_cascades                                     -0.007            0.184
# cascades                                            0.037            0.308
# klamath_mountains_california_high_north_coast_r...  0.338               --
# eastern_cascades_slopes_and_foothills               0.316               --
# northern_rockies                                    0.019               --
# puget_lowland                                          --               --
# willamette_valley                                      --               --
# all                                                 0.191               --
#
#                                                    stddev_height  \
# blue_mountains                                                --
# coast_range                                               -0.192
# north_cascades                                            -0.365
# cascades                                                  -0.199
# klamath_mountains_california_high_north_coast_r...        -0.186
# eastern_cascades_slopes_and_foothills                     -0.154
# northern_rockies                                          -0.476
# puget_lowland                                             -0.152
# willamette_valley                                         -0.085
# all                                                       -0.204
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --  0.015
# coast_range                                                 0.066  0.033
# north_cascades                                              0.311  0.035
# cascades                                                    0.388 -0.081
# klamath_mountains_california_high_north_coast_r...             -- -0.053
# eastern_cascades_slopes_and_foothills                       0.039 -0.062
# northern_rockies                                            0.572 -0.016
# puget_lowland                                                  -- -0.089
# willamette_valley                                              --     --
# all                                                           0.2 -0.005
#
#                                                    elevation  slope  \
# blue_mountains                                            --     --
# coast_range                                            0.089  0.016
# north_cascades                                         0.249 -0.031
# cascades                                               0.219 -0.116
# klamath_mountains_california_high_north_coast_r...    -0.019 -0.061
# eastern_cascades_slopes_and_foothills                  0.002 -0.118
# northern_rockies                                          --  0.027
# puget_lowland                                         -0.283     --
# willamette_valley                                         --     --
# all                                                    0.128 -0.025
#
#                                                    solar_radiation_index  \
# blue_mountains                                                        --
# coast_range                                                        0.069
# north_cascades                                                    -0.069
# cascades                                                          -0.003
# klamath_mountains_california_high_north_coast_r...                    --
# eastern_cascades_slopes_and_foothills                             -0.201
# northern_rockies                                                   -0.05
# puget_lowland                                                         --
# willamette_valley                                                     --
# all                                                                 0.03
#
#                                                    kurtosis skewness
# blue_mountains                                           --   -0.011
# coast_range                                           0.012   -0.228
# north_cascades                                        0.109   -0.255
# cascades                                              0.498   -0.559
# klamath_mountains_california_high_north_coast_r...       --       --
# eastern_cascades_slopes_and_foothills                    --       --
# northern_rockies                                         --   -0.264
# puget_lowland                                            --   -0.567
# willamette_valley                                        --       --
# all                                                   0.102   -0.243
#
# [10 rows x 22 columns]

# %% [markdown]
# ## LASSO (Linear Model)
# Starting with implicit feature selection via L1 regularization of coefficients.

# %%
best_lassos = []

for i in range(len(ecoregions)):
    lasso = LassoCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000, n_alphas=1000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    lasso.fit(X, y)
    best_lassos.append(lasso)

# %%
lasso_res = get_score_df(best_lassos)
lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             24.133        28.984   104
# coast_range                80.597        80.120  1580
# north_cascades            100.591        92.471   443
# cascades                   82.526        82.038   613
# klamath_mountains          75.555        74.401   275
# eastern_cascades           64.382        67.483   203
# northern_rockies           65.581        69.727    83
# puget_lowland             102.663       107.126   122
# willamette_valley          51.531        51.701    41
# all                        80.473        80.473  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lassos])
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.002
# north_cascades                                              -0.07
# cascades                                                   -0.038
# klamath_mountains_california_high_north_coast_r...             --
# eastern_cascades_slopes_and_foothills                      -0.009
# northern_rockies                                            0.305
# puget_lowland                                               0.229
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.044
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.109
# coast_range                                                          -0.132
# north_cascades                                                         0.05
# cascades                                                             -0.033
# klamath_mountains_california_high_north_coast_r...                   -0.076
# eastern_cascades_slopes_and_foothills                                -0.072
# northern_rockies                                                      -0.06
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                  -0.005
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        0.524
# coast_range                                                           0.266
# north_cascades                                                        0.438
# cascades                                                              0.357
# klamath_mountains_california_high_north_coast_r...                    0.002
# eastern_cascades_slopes_and_foothills                                 0.232
# northern_rockies                                                      0.282
# puget_lowland                                                         0.162
# willamette_valley                                                        --
# all                                                                   0.302
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.117
# coast_range                                                           0.284
# north_cascades                                                         0.44
# cascades                                                              0.343
# klamath_mountains_california_high_north_coast_r...                     0.44
# eastern_cascades_slopes_and_foothills                                 0.116
# northern_rockies                                                      0.363
# puget_lowland                                                         0.267
# willamette_valley                                                      0.06
# all                                                                   0.372
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.153
# north_cascades                                                        0.217
# cascades                                                              0.181
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                         0.015
# willamette_valley                                                        --
# all                                                                   0.213
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.114
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.166
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.096
# north_cascades                                                    0.088
# cascades                                                          0.002
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                  0.104
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                               0.072
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                         -0.078
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                  0.173
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                               -0.02
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                       --  ...
# coast_range                                                      -0.041  ...
# north_cascades                                                       --  ...
# cascades                                                         -0.174  ...
# klamath_mountains_california_high_north_coast_r...                   --  ...
# eastern_cascades_slopes_and_foothills                             0.032  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                     0.321  ...
# willamette_valley                                                    --  ...
# all                                                              -0.128  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                      0.571               --
# coast_range                                         0.038               --
# north_cascades                                      -0.03            0.205
# cascades                                            0.035            0.313
# klamath_mountains_california_high_north_coast_r...  0.489               --
# eastern_cascades_slopes_and_foothills                0.49               --
# northern_rockies                                       --               --
# puget_lowland                                          --               --
# willamette_valley                                      --               --
# all                                                 0.191               --
#
#                                                    stddev_height  \
# blue_mountains                                                --
# coast_range                                               -0.204
# north_cascades                                            -0.379
# cascades                                                  -0.199
# klamath_mountains_california_high_north_coast_r...        -0.191
# eastern_cascades_slopes_and_foothills                     -0.149
# northern_rockies                                          -0.532
# puget_lowland                                             -0.162
# willamette_valley                                         -0.056
# all                                                       -0.205
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --  0.012
# coast_range                                                  0.03  0.033
# north_cascades                                              0.304  0.035
# cascades                                                    0.392 -0.081
# klamath_mountains_california_high_north_coast_r...             -- -0.053
# eastern_cascades_slopes_and_foothills                          --  -0.06
# northern_rockies                                            0.796     --
# puget_lowland                                                  -- -0.077
# willamette_valley                                              --     --
# all                                                           0.2 -0.005
#
#                                                    elevation  slope  \
# blue_mountains                                            --     --
# coast_range                                            0.084  0.014
# north_cascades                                         0.251 -0.031
# cascades                                               0.219 -0.116
# klamath_mountains_california_high_north_coast_r...    -0.015 -0.068
# eastern_cascades_slopes_and_foothills                     -- -0.113
# northern_rockies                                          --     --
# puget_lowland                                         -0.247     --
# willamette_valley                                         --     --
# all                                                    0.128 -0.025
#
#                                                    solar_radiation_index  \
# blue_mountains                                                        --
# coast_range                                                        0.068
# north_cascades                                                    -0.069
# cascades                                                          -0.003
# klamath_mountains_california_high_north_coast_r...                    --
# eastern_cascades_slopes_and_foothills                             -0.203
# northern_rockies                                                  -0.038
# puget_lowland                                                         --
# willamette_valley                                                     --
# all                                                                0.029
#
#                                                    kurtosis skewness
# blue_mountains                                           --       --
# coast_range                                              --   -0.226
# north_cascades                                        0.108   -0.254
# cascades                                              0.511   -0.567
# klamath_mountains_california_high_north_coast_r...       --       --
# eastern_cascades_slopes_and_foothills                    --       --
# northern_rockies                                         --   -0.244
# puget_lowland                                            --   -0.608
# willamette_valley                                        --       --
# all                                                   0.102   -0.243
#
# [10 rows x 22 columns]

# %% [markdown]
# Now we'll explicitly define the maximum number of features to use for fitting a linear model. We'll trim features by iteratively increasing a threshold for coefficients using LASSO regression

# %%
MAX_FEATURES = 5
sfms = [] # transformers that filter X features
trimmed_lassos = [] # re-fit lasso regressions on the subset of the features

for i, lasso in enumerate(best_lassos):
    lasso = deepcopy(lasso)
    sfm = SelectFromModel(lasso, threshold=0.001)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    Y = (eco_ytrain_dfs[i].ravel())
    sfm.fit(X, Y)
    n_features = sfm.transform(X).shape[1]

    # Reset the threshold till the number of features equals two.
    # Note that the attribute can be set directly instead of repeatedly
    # fitting the metatransformer.
    while n_features > MAX_FEATURES:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    
    sfms.append(sfm)
    try:
        trimmed_lassos.append(lasso.fit(sfm.transform(X), Y))
    except ValueError:
        print(ecoregion_names[i])
        raise

# %%
coefs = []
for i in range(len(ecoregions)):
    cols = np.zeros(eco_xtest_dfs[i].columns.shape)
    cols[sfms[i].get_support()] = trimmed_lassos[i].coef_
    coefs.append(cols)
    
coefs = np.array(coefs)

coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                    --
# north_cascades                                                 --
# cascades                                                       --
# klamath_mountains_california_high_north_coast_r...             --
# eastern_cascades_slopes_and_foothills                          --
# northern_rockies                                             0.32
# puget_lowland                                               0.229
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.076
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.216
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.073
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        0.527
# coast_range                                                           0.212
# north_cascades                                                        0.371
# cascades                                                              0.309
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                 0.221
# northern_rockies                                                      0.349
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.258
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.183
# coast_range                                                           0.255
# north_cascades                                                        0.452
# cascades                                                              0.404
# klamath_mountains_california_high_north_coast_r...                    0.459
# eastern_cascades_slopes_and_foothills                                 0.178
# northern_rockies                                                      0.412
# puget_lowland                                                         0.266
# willamette_valley                                                     0.073
# all                                                                   0.355
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.115
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.221
#
#                                                    height_75-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                    0.492
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_95_percentile  \
# blue_mountains                                                   -0.339
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                     cover stddev_height  \
# blue_mountains                                      0.684            --
# coast_range                                            --        -0.155
# north_cascades                                         --        -0.331
# cascades                                               --            --
# klamath_mountains_california_high_north_coast_r...  0.544        -0.213
# eastern_cascades_slopes_and_foothills                0.48        -0.194
# northern_rockies                                       --        -0.621
# puget_lowland                                          --            --
# willamette_valley                                      --        -0.075
# all                                                    --        -0.098
#
#                                                    surface_volume elevation  \
# blue_mountains                                                 --        --
# coast_range                                                    --        --
# north_cascades                                              0.506        --
# cascades                                                    0.051        --
# klamath_mountains_california_high_north_coast_r...             --        --
# eastern_cascades_slopes_and_foothills                          --        --
# northern_rockies                                            1.426        --
# puget_lowland                                                  --     -0.21
# willamette_valley                                              --        --
# all                                                            --        --
#
#                                                     slope  \
# blue_mountains                                         --
# coast_range                                            --
# north_cascades                                         --
# cascades                                               --
# klamath_mountains_california_high_north_coast_r... -0.141
# eastern_cascades_slopes_and_foothills                  --
# northern_rockies                                       --
# puget_lowland                                          --
# willamette_valley                                      --
# all                                                    --
#
#                                                    solar_radiation_index  \
# blue_mountains                                                        --
# coast_range                                                           --
# north_cascades                                                        --
# cascades                                                              --
# klamath_mountains_california_high_north_coast_r...                    --
# eastern_cascades_slopes_and_foothills                              -0.23
# northern_rockies                                                      --
# puget_lowland                                                         --
# willamette_valley                                                     --
# all                                                                   --
#
#                                                    kurtosis skewness
# blue_mountains                                           --       --
# coast_range                                              --   -0.378
# north_cascades                                           --       --
# cascades                                               0.57   -0.629
# klamath_mountains_california_high_north_coast_r...       --       --
# eastern_cascades_slopes_and_foothills                    --       --
# northern_rockies                                         --       --
# puget_lowland                                            --   -0.839
# willamette_valley                                        --       --
# all                                                      --   -0.302

# %%
trimmed_lasso_res = get_score_df(trimmed_lassos, feature_selectors=sfms)
trimmed_lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             27.218        32.046   104
# coast_range                80.849        82.181  1580
# north_cascades            107.940        98.869   443
# cascades                   89.159        85.041   613
# klamath_mountains          76.068        74.193   275
# eastern_cascades           63.261        66.627   203
# northern_rockies           65.770        77.047    83
# puget_lowland             102.472       107.461   122
# willamette_valley          50.122        58.854    41
# all                        83.248        83.248  3473

# %% [markdown]
# ## K-Nearest Neighbors Regression

# %%
# Set the parameters by cross-validation
knn_params = {'n_neighbors': [1,2,3,4,5,10,20],
              'weights': ['uniform', 'distance'],
              'metric': ['minkowski', 'manhattan']}


knn_gs = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=knn_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_knns = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    knn_gs.fit(X, y)
    best_fit = knn_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_knns.append(best_fit)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    2.1s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    2.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.8s finished

# %%
knn_res = get_score_df(best_knns)
knn_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             30.597        36.528   104
# coast_range                80.494        78.968  1580
# north_cascades             96.600        96.113   443
# cascades                   75.564        80.072   613
# klamath_mountains          71.990        74.474   275
# eastern_cascades           65.060        64.443   203
# northern_rockies           93.854        75.535    83
# puget_lowland             111.975        99.808   122
# willamette_valley          61.104        57.711    41
# all                        80.018        80.018  3473

# %% [markdown]
# ## Random Forest Regression

# %%
# Set the parameters by cross-validation
rf_params = {'n_estimators': [100, 500, 1000, 5000],
             'max_features': ['sqrt'],
             'max_depth': [3, 5, 10, 25, 50],
             'min_samples_leaf': [1,2,4],
             'bootstrap': [True]}


rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=rf_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_rfs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    rf_gs.fit(X, y)
    best_fit = rf_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_rfs.append(best_fit)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    9.2s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   19.7s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   17.4s remaining:    9.4s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   45.4s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   24.9s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   14.6s remaining:    7.8s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   29.5s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.2s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   25.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    9.9s remaining:    5.3s
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   23.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    9.1s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.9s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   20.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  1.5min finished

# %%
rf_res = get_score_df(best_rfs)
rf_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             33.846        35.822   104
# coast_range                78.087        77.031  1580
# north_cascades             95.623        93.433   443
# cascades                   72.396        80.111   613
# klamath_mountains          69.603        74.019   275
# eastern_cascades           64.751        62.794   203
# northern_rockies           93.837        76.285    83
# puget_lowland             107.324       107.630   122
# willamette_valley          61.713        52.203    41
# all                        78.905        78.905  3473

# %%
### Employing feature selection to try and improve random forest regression

# %%
importances = best_rfs[-1].feature_importances_
indices = np.argsort(importances)[::-1]
features = eco_xtrain_dfs[-1].columns[indices]

# Print the feature ranking
print("Feature ranking:")

for f in range(eco_xtrain_dfs[-1].shape[1]):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. stddev_height (0.087527)
# 2. cover (0.085853)
# 3. height_50-percentile (0.081699)
# 4. strat3_return-proportion (0.081308)
# 5. height_75-percentile (0.076626)
# 6. surface_volume (0.053226)
# 7. height_25-percentile (0.052455)
# 8. height_95_percentile (0.048351)
# 9. potential_volume (0.046711)
# 10. skewness (0.046121)
# 11. strat1_return-proportion (0.045626)
# 12. strat0_return-proportion (0.042801)
# 13. kurtosis (0.036109)
# 14. strat2_return-proportion (0.036031)
# 15. elevation (0.033686)
# 16. strat5_return-proportion (0.024800)
# 17. returns_per_m2 (0.022462)
# 18. strat4_return-proportion (0.022128)
# 19. aspect (0.021111)
# 20. slope (0.021072)
# 21. solar_radiation_index (0.020531)
# 22. height_05-percentile (0.013766)

# %% [markdown]
# ## Gradient Boosting Trees Regression

# %%
# Set the parameters by cross-validation
gb_params = {'n_estimators': [100, 500, 1000, 5000],
             'learning_rate': [0.01, 0.1],
             'max_depth': [2, 3, 4, 5, 10],
             'max_features': ['sqrt'] 
            }

gb_gs = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=gb_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_gbs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    gb_gs.fit(X, y)
    best_fit = gb_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_gbs.append(best_fit)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    5.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.6s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   14.0s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   16.4s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.5s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   13.8s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.5s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.0s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.6s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.4s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.4s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.0s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.1s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   39.4s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   40.7s finished

# %%
gb_res = get_score_df(best_gbs)
gb_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             33.769        35.460   104
# coast_range                78.399        78.055  1580
# north_cascades             97.685        90.348   443
# cascades                   73.315        79.161   613
# klamath_mountains          69.429        75.504   275
# eastern_cascades           61.580        65.750   203
# northern_rockies           94.391        69.281    83
# puget_lowland              95.568       111.929   122
# willamette_valley          63.777        47.677    41
# all                        78.939        78.939  3473

# %%
### Employing feature selection to try and improve gradient boosting regression

# %% [markdown]
# ## Support Vector Machines Regression

# %%
# Set the parameters by cross-validation
svm_params = {'kernel': ['linear', 'rbf'],
              'gamma': ['scale', 'auto'],
              'C': [0.1,1,10,100,1000]
              }

svm_gs = GridSearchCV(estimator=SVR(), param_grid=svm_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_svms = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    svm_gs.fit(X, y)
    best_fit = svm_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_svms.append(best_fit)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.3s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   16.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   19.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   47.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    7.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   15.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    7.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    1.3s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  4.1min finished

# %%
svm_res = get_score_df(best_svms)
svm_res
# Out:
#                    regional_model  global_model     n
# blue_mountains             23.547        26.965   104
# coast_range                80.892        79.434  1580
# north_cascades            114.106        90.251   443
# cascades                   82.774        77.485   613
# klamath_mountains          72.365        73.604   275
# eastern_cascades           68.353        64.398   203
# northern_rockies           69.313        68.984    83
# puget_lowland             114.124       105.833   122
# willamette_valley          63.673        41.090    41
# all                        78.622        78.622  3473

# %%
### Employing feature selection to try and improve support vector regression

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

def scatter_graphs(model_dict):
    names = MODELS.keys()
    EXTEND_PCT = 0.10
    
    fig, axs = plt.subplots(len(ecoregion_names), len(names), 
                            sharex=True, sharey=True,
                            figsize=(11,15)
                           )
    
    all_obs = transformer.inverse_transform(eco_ytest_dfs[-1].reshape(-1,1))
    obs_min = all_obs.min()
    obs_max = all_obs.max()
    rng = obs_max - obs_min
        
    for i, ecoreg in enumerate(ecoregion_names):
        observed = transformer.inverse_transform(eco_ytest_dfs[i].reshape(-1,1))
        
        for j, name in enumerate(names):
            axs[0,j].set_title(name)
            axs[i,0].set_ylabel('\n'.join(ecoreg.split('_')).upper())
            axs[i,j].set_xlim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_ylim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_aspect('equal')
            
            if name == 'LASSO_{}'.format(MAX_FEATURES):
                predicted = MODELS[name][-1].predict(sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i])))
            else:
                predicted = MODELS[name][-1].predict(x_scaler.transform(eco_xtest_dfs[i]))
            
            predicted = transformer.inverse_transform(predicted.reshape(-1,1))
            axs[i,j].scatter(observed, predicted, s=0.5)
            axs[i,j].plot((obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng), 
                          (obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng),
                         color='k', lw=0.5)
            
    plt.tight_layout(pad=0.5)

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

scatter_graphs(MODELS)

# %% [markdown]
# ## View scores for regional and global models

# %%
MODEL_NAMES = ['ElasticNet', 'LASSO', 'LASSO_{}'.format(MAX_FEATURES), 'KNN', 'RF', 'GB', 'SVM']
BEST_MODELS = [best_lms, best_lassos, trimmed_lassos, best_knns, best_rfs, best_gbs, best_svms]

def compare_models(metric):
    score_dfs = []
    for name, best_models in list(zip(MODEL_NAMES, BEST_MODELS)):
        if name == 'LASSO_{}'.format(MAX_FEATURES):
            score_df = get_score_df(best_models, metric, sfms) 
            score_dfs.append(score_df)
        else:
            score_df = get_score_df(best_models, metric) 
            score_dfs.append(score_df)
        
    counts = np.array(score_dfs[-1]['n'].values)
    regional_data = np.array([df['regional_model'].values for df in score_dfs])
    global_data = np.array([df['global_model'].values for df in score_dfs])
    
    return regional_data, global_data, counts

# %%
def highlight_best(s):
    '''
    highlight the closest value to zero in a Series yellow.
    '''
    lowest_idx = abs(s).idxmin()
    return ['background-color: yellow' if idx==lowest_idx else '' for idx in s.index]

# %%
print('Regional Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, RMSE
# <style  type="text/css" >
#     #T_0a41e65a_5532_11ea_88c6_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_0a41e65a_5532_11ea_88c6_00505683952erow1_col4 {
#             background-color:  yellow;
#         }    #T_0a41e65a_5532_11ea_88c6_00505683952erow2_col4 {
#             background-color:  yellow;
#         }    #T_0a41e65a_5532_11ea_88c6_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_0a41e65a_5532_11ea_88c6_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_0a41e65a_5532_11ea_88c6_00505683952erow5_col5 {
#             background-color:  yellow;
#         }    #T_0a41e65a_5532_11ea_88c6_00505683952erow6_col1 {
#             background-color:  yellow;
#         }    #T_0a41e65a_5532_11ea_88c6_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_0a41e65a_5532_11ea_88c6_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_0a41e65a_5532_11ea_88c6_00505683952erow9_col6 {
#             background-color:  yellow;
#         }</style><table id="T_0a41e65a_5532_11ea_88c6_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a41e65a_5532_11ea_88c6_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow0_col0" class="data row0 col0" >24.0</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow0_col1" class="data row0 col1" >24.1</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow0_col2" class="data row0 col2" >27.2</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow0_col3" class="data row0 col3" >30.6</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow0_col4" class="data row0 col4" >33.8</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow0_col5" class="data row0 col5" >33.8</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow0_col6" class="data row0 col6" >23.5</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_0a41e65a_5532_11ea_88c6_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow1_col0" class="data row1 col0" >80.5</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow1_col1" class="data row1 col1" >80.6</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow1_col2" class="data row1 col2" >80.8</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow1_col3" class="data row1 col3" >80.5</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow1_col4" class="data row1 col4" >78.1</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow1_col5" class="data row1 col5" >78.4</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow1_col6" class="data row1 col6" >80.9</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_0a41e65a_5532_11ea_88c6_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow2_col0" class="data row2 col0" >99.8</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow2_col1" class="data row2 col1" >100.6</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow2_col2" class="data row2 col2" >107.9</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow2_col3" class="data row2 col3" >96.6</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow2_col4" class="data row2 col4" >95.6</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow2_col5" class="data row2 col5" >97.7</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow2_col6" class="data row2 col6" >114.1</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_0a41e65a_5532_11ea_88c6_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow3_col0" class="data row3 col0" >82.5</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow3_col1" class="data row3 col1" >82.5</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow3_col2" class="data row3 col2" >89.2</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow3_col3" class="data row3 col3" >75.6</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow3_col4" class="data row3 col4" >72.4</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow3_col5" class="data row3 col5" >73.3</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow3_col6" class="data row3 col6" >82.8</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_0a41e65a_5532_11ea_88c6_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow4_col0" class="data row4 col0" >75.5</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow4_col1" class="data row4 col1" >75.6</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952erow4_col2" class="data row4 col2" >76.1</td>
#                         <td id="T_0a41e65a_5532_11ea_88c6_00505683952er
00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_36afd0e4_5532_11ea_88c6_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_36afd0e4_5532_11ea_88c6_00505683952erow5_col0" class="data row5 col0" >38%</td>
#                         <td id="T_36afd0e4_5532_11ea_88c6_00505683952erow5_col1" class="data row5 col1" >38%</td>
#                         <td id="T_36afd0e4_5532_11ea_88c6_00505683952erow5_col2" class="data row5 col2" >40%</td>
#                         <td id="T_36afd0e4_5532_11ea_88c6_00505683952erow5_col3" class="data row5 col3" >36%</td>
#                         <td id="T_36afd0e4_5532_11ea_88c6_00505683952erow5_col4" class="data row5 col4" >36%</td>
#                         <td id="T_36afd0e4_5532_11ea_88c6_00505683952erow5_col5" class="data row5 col5" >36%</td>

# %%
print('Global vs. Regional Models, ΔRMSE')
regional_data, global_data, counts = compare_models(rmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔRMSE
# <style  type="text/css" >
#     #T_3bbc3794_5532_11ea_88c6_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 80.6%, transparent 80.6%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 80.3%, transparent 80.3%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 80.2%, transparent 80.2%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 87.1%, transparent 87.1%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.3%, transparent 62.3%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.6%, transparent 60.6%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 71.4%, transparent 71.4%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.8%, orange 47.8%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.0%, orange 47.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.3%, transparent 58.3%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.5%, orange 40.5%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.4%, orange 43.4%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.8%, orange 47.8%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.9%, orange 40.9%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 4.6%, orange 4.6%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.0%, orange 47.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.3%, orange 36.3%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 4.1%, orange 4.1%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.0%, orange 47.0%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.9%, orange 46.9%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 24.3%, orange 24.3%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 78.2%, transparent 78.2%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 98.2%, transparent 98.2%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 86.5%, transparent 86.5%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.9%, orange 16.9%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.2%, orange 43.2%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.8%, orange 42.8%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.3%, orange 38.3%, orange 50.0%, transparent 50.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 65.5%, transparent 65.5%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 77.6%, transparent 77.6%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 88.0%, transparent 88.0%);
#         }    #T_3bbc3794_5532_11ea_88c6_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 57.7%, transparent 57.7%);
#         }    #T_3bbc3794_5532

# %%
print('Global vs. Regional Models, ΔRMSE%')
regional_data, global_data, counts = compare_models(nrmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.2, vmax=0.2))
# Out:
# Global vs. Regional Models, ΔRMSE%
# <style  type="text/css" >
#     #T_40d08096_5532_11ea_88c6_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.5%, transparent 62.5%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.5%, transparent 62.5%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.2%, transparent 62.2%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 65.2%, transparent 65.2%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.0%, transparent 55.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.2%, transparent 54.2%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.7%, transparent 58.7%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.2%, transparent 52.2%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, orange 48.5%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.7%, orange 39.7%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.7%, orange 38.7%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.5%, orange 37.5%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.0%, orange 47.0%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.7%, orange 39.7%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.5%, orange 16.5%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.5%, orange 44.5%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.0%, transparent 56.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.2%, transparent 60.2%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.0%, transparent 58.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.0%, orange 43.0%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.0%, orange 48.0%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.7%, orange 46.7%, orange 50.0%, transparent 50.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.7%, transparent 54.7%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.0%, transparent 58.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.0%, transparent 61.0%);
#         }    #T_40d08096_5532_11ea_88c6_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gr

# %%
print('Global vs. Regional Models, ΔMAE')
regional_data, global_data, counts = compare_models(mae)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔMAE
# <style  type="text/css" >
#     #T_45e040c6_5532_11ea_88c6_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 83.8%, transparent 83.8%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 84.8%, transparent 84.8%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.3%, transparent 55.3%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 71.6%, transparent 71.6%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 69.1%, transparent 69.1%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 76.6%, transparent 76.6%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 70.4%, transparent 70.4%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.9%, orange 45.9%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, orange 45.0%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.5%, transparent 60.5%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.7%, orange 46.7%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, orange 46.6%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.6%, orange 45.6%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, orange 45.0%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 18.8%, orange 18.8%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.8%, orange 16.8%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.5%, orange 27.5%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.2%, orange 33.2%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, orange 25.4%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.1%, orange 2.1%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.3%, orange 38.3%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.2%, orange 38.2%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.5%, orange 36.5%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.5%, transparent 62.5%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 68.3%, transparent 68.3%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.6%, orange 48.6%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 22.5%, orange 22.5%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 20.8%, orange 20.8%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.2%, orange 19.2%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.8%, orange 12.8%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.9%, orange 37.9%, orange 50.0%, transparent 50.0%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.8%, transparent 61.8%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 76.6%, transparent 76.6%);
#         }    #T_45e040c6_5532_11ea_88c6_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33

# %%
print('Global vs. Regional Models, Δbias%')
regional_data, global_data, counts = compare_models(rel_bias)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.4, vmax=0.4))
# Out:
# Global vs. Regional Models, Δbias%
# <style  type="text/css" >
#     #T_4aeceda8_5532_11ea_88c6_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.1%, orange 39.1%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.5%, orange 38.5%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.1%, orange 38.1%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, orange 41.9%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.1%, orange 45.1%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.5%, orange 41.5%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.9%, transparent 52.9%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.0%, transparent 53.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.1%, transparent 52.1%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.7%, transparent 54.7%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.4%, transparent 53.4%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.7%, transparent 51.7%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.6%, transparent 54.6%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.0%, orange 40.0%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.9%, orange 39.9%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.2%, orange 44.2%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.7%, orange 36.7%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.5%, orange 41.5%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.7%, orange 43.7%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.7%, orange 39.7%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.9%, orange 45.9%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.9%, orange 45.9%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.4%, orange 38.4%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.2%, orange 40.2%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.4%, orange 43.4%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.5%, orange 44.5%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.5%, transparent 51.5%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.2%, orange 47.2%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.4%, orange 47.4%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.0%, orange 47.0%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.1%, orange 46.1%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.7%, transparent 52.7%);
#         }    #T_4aeceda8_5532_11ea_88c6_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             backgr

# %%
METRIC = 'growing_stock_tpa'

MODELS = {'ElasticNet': best_lms,
          'LASSO': best_lassos,
          'LASSO{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

pickle.dump(x_scaler, 
            open('../models/{}/sklearn/x_scaler.pkl'.format(METRIC), 'wb'))
pickle.dump(transformer, 
            open('../models/{}/sklearn/y_scaler.pkl'.format(METRIC), 'wb'))

for i in range(len(ecoregion_names)):
    for key in MODELS.keys():
        fname = ecoregion_names[i] + '_{}.pkl'.format(key)
        path_to_file = '../models/{}/sklearn/{}'.format(METRIC, fname)
        pickle.dump(MODELS[key][i], 
                    open(path_to_file, 'wb'))
        
        if key == 'LASSO{}'.format(MAX_FEATURES):
            sfm_name = ecoregion_names[i] + '_LASSO{}_featureselect.pkl'.format(MAX_FEATURES)
            path_to_file = '../models/{}/sklearn/{}'.format(METRIC, sfm_name)
            pickle.dump(sfms[i], 
                        open(path_to_file, 'wb'))
