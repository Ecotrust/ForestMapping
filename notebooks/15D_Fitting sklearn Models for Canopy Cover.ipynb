# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
# data prep and model-tuning
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, QuantileTransformer
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV

# types of models we'll fit
from sklearn.linear_model import ElasticNetCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR

from scipy.stats import shapiro

import pickle
from copy import deepcopy

# %% [markdown]
# ## Our Data

# %%
DATA = '../data/processed/training_data_annual.csv'
df = pd.read_csv(DATA)
df = df.dropna()
print('{:,d} samples'.format(len(df)))
print('Columns:', df.columns.values)
# Out:
# 3,529 samples
# Columns: ['uuid' 'lidar_year' 'lat' 'lon' 'orig_id' 'source' 'meas_yr' 'ecoregion3'
#  'agency' 'plot_size_ac' 'num_returns' 'strat0_return-proportion'
#  'strat1_return-proportion' 'strat2_return-proportion'
#  'strat3_return-proportion' 'strat4_return-proportion'
#  'strat5_return-proportion' 'skewness' 'kurtosis'
#  'strat0_intensity-median' 'strat1_intensity-median'
#  'strat2_intensity-median' 'strat3_intensity-median'
#  'strat4_intensity-median' 'strat5_intensity-median'
#  'height_05-percentile' 'height_25-percentile' 'height_50-percentile'
#  'height_75-percentile' 'height_95_percentile' 'height_max' 'cover'
#  'lidar_acq' 'potential_volume' 'stddev_height' 'surface_area_ratio'
#  'surface_volume' 'surface_volume_ratio' 'aspect' 'elevation'
#  'overall_curvature' 'plan_curvature' 'profile_curvature' 'slope'
#  'solar_radiation_index' 'mat' 'mwmt' 'mcmt' 'td' 'map' 'msp' 'ahm' 'shm'
#  'dd_0' 'dd5' 'dd_18' 'dd18' 'nffd' 'bffp' 'effp' 'ffp' 'pas' 'emt' 'ext'
#  'eref' 'cmd' 'rh' 'dormancy' 'evi_amplitude' 'evi_area' 'evi_minimum'
#  'greenup' 'maturity' 'midgreendown' 'midgreenup' 'numcycles' 'peak'
#  'green' 'blue' 'red' 'nir' 'endvi' 'ndvi' 'savi' 'swir1' 'swir2'
#  'wetness' 'greenness' 'brightness' 'landsat_year' 'clim_year'
#  'distance_to_water_m' 'bulk_dens' 'soil_depth' 'pct_clay_surf'
#  'pct_rock_surf' 'pct_sand_surf' 'pot_veg_type' 'tpa' 'ba' 'sdi' 'ccf'
#  'qmd' 'tcuft' 'topht' 'number_of_strata' 'total_cover' 'structure_class'
#  'canopy_baseheight' 'canopy_bulkdensity' 'aboveground_biomass'
#  'aboveground_carbon' 'gs_tpa' 'AF' 'AS' 'BM' 'BO' 'CH' 'CW' 'DF' 'DG'
#  'ES' 'GC' 'GF' 'IC' 'JP' 'KP' 'LO' 'LP' 'MA' 'MC' 'MH' 'NF' 'OH' 'OS'
#  'OT' 'PC' 'PL' 'PP' 'PY' 'RA' 'RC' 'RF' 'SF' 'SH' 'SP' 'SS' 'TO' 'WA'
#  'WB' 'WF' 'WH' 'WI' 'WJ' 'WL' 'WO' 'WP' 'YC' 'TRUE_FIR' 'OTHER_HARDWOOD'
#  'MAPLE' 'OAK' 'DOUGLAS_FIR' 'SPRUCE' 'CEDAR' 'PONDEROSA_PINE'
#  'OTHER_SOFTWOOD' 'LODGEPOLE_PINE' 'HEMLOCK' 'RED_ALDER' 'TANOAK'
#  'JUNIPER' 'LARCH' 'fvs_year' 'year_diff' 'returns_per_m2']

# %% [markdown]
# ## Filter out some of the training data
# We can exclude some of the training data based on how far separated the inventory data (interpolated using FVS simulations) is from the year the lidar was collected. Similarly, we can screen out training examples that had relatively low density of lidar returns.

# %%
df['year_diff'] = abs(df['fvs_year'] - df['lidar_year']).astype(int)

# %%
len(df.loc[df['year_diff'] >= 5])
# Out:
# 224

# %%
df = df.loc[df['year_diff'] < 5]

# %%
len(df.loc[df['returns_per_m2'] < 4.0])
# Out:
# 93

# %%
df = df.loc[df['returns_per_m2'] >= 4.0]

# %%
lidar_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['topht'].values.reshape(-1, 1))

lidar_height_transformed = lidar_height_transformer.transform(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformed = fvs_height_transformer.transform(df['topht'].values.reshape(-1, 1))

diff_height_transformed = abs(lidar_height_transformed - fvs_height_transformed)


fig, axs = plt.subplots(1,2, figsize=(15,5))

# select outliers
OUTLIER_THRESH = 3.05
outliers = diff_height_transformed > OUTLIER_THRESH
outliers = np.logical_or(outliers, (df['height_95_percentile'] > 275/3.28084).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 60/3.28084) & (df['topht'] > 105)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 10/3.28084) & (df['topht'] > 40)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])/df['topht']) > 1.0).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])) > 100).values.reshape(-1, 1))

axs[0].hist(diff_height_transformed, bins=20)
axs[0].axvline(OUTLIER_THRESH, color='k')
axs[0].set_title('Differences between transformed lidar and fvs canopy height')

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[~outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[~outliers],
            s=1, label='Inliers (n={:,d})'.format((~outliers).sum()))

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[outliers],
            s=5, label='Outliers (n={:,d})'.format(outliers.sum()))

axs[1].set_xlabel('Lidar Canopy Height, ft')
axs[1].set_ylabel('FVS Canopy Height, ft')
axs[1].plot([0,400],[0,400], color='k', lw=2, label='1:1')
axs[1].set_xlim(-10, 400)
axs[1].set_ylim(-10, 400)
axs[1].set_aspect('equal')
axs[1].legend();

# %%
# filter out the height outliers
df = df[~outliers]

# %% [markdown]
# ## Inspect how many samples we have for different years, regions, etc.

# %%
df.groupby(by=['lidar_year'])[['uuid']].count().rename({'uuid':'count'}, axis=1)
# Out:
#             count
# lidar_year
# 2008          686
# 2009           12
# 2010            2
# 2011           76
# 2012          527
# 2013          199
# 2014          298
# 2015          475
# 2016          478
# 2017          165
# 2018           25

# %%
pd.pivot_table(df, 
               values='uuid', 
               aggfunc='count', 
               index=['meas_yr'], 
               columns=['lidar_year'], 
               fill_value=0)
# Out:
# lidar_year  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# meas_yr
# 2010         395     0     0     0     2     0     2     6     0     0     0
# 2011         291     0     0     0     1     0     2     1     0     0     0
# 2013           0    12     0    33   345    45     3     6    13    25     2
# 2014           0     0     2    26   124    39    28    38    83    34     0
# 2015           0     0     0    17    16    12    15   122    95    24     2
# 2016           0     0     0     0    39    73    39   214    63    32    21
# 2017           0     0     0     0     0    30   163    47    78    40     0
# 2018           0     0     0     0     0     0    46    41   146    10     0

# %%
ecoreg_counts = df.groupby(by=['ecoregion3'])[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
ecoreg_counts
# Out:
#                                                     uuid  lidar_acq  \
# ecoregion3
# blue_mountains                                        29          2
# cascades                                             480         21
# coast_range                                         1399         18
# columbia_plateau                                       4          3
# eastern_cascades_slopes_and_foothills                124          9
# klamath_mountains_california_high_north_coast_r...   190          6
# north_cascades                                       339         18
# northern_rockies                                      68          4
# puget_lowland                                        106         13
# willamette_valley                                     41          2
#
#                                                     lidar_year  plot_size_ac
# ecoregion3
# blue_mountains                                               2             1
# cascades                                                     9             3
# coast_range                                                  9             2
# columbia_plateau                                             3             1
# eastern_cascades_slopes_and_foothills                        5             2
# klamath_mountains_california_high_north_coast_r...           5             2
# north_cascades                                               6             2
# northern_rockies                                             3             1
# puget_lowland                                                7             1
# willamette_valley                                            2             2

# %%
df[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
# Out:
# uuid            2780
# lidar_acq         67
# lidar_year        11
# plot_size_ac       3
# dtype: int64

# %% [markdown]
# ## Available features
# First, we'll use one-hot encoding for categorical features

# %%
# convert agency, ecoregion, and lidar acquisition into one-hot encoded set of variables
df = pd.get_dummies(df, prefix='agency', columns=['agency'])
# df = pd.get_dummies(df, prefix='eco', columns=['ecoregion3'])
# df = pd.get_dummies(df, prefix='acq', columns=['lidar_acq'])

# %% [markdown]
# The different types of predictor variables we can use to predict a forest attribute, including climate, lidar-derived, soil, and satellite imagery.

# %%
CLIM_COLS = ['mat', 'mwmt', 'mcmt', 'td', 'map', 'msp', 'ahm', 'shm', 
             'dd_0', 'dd5', 'dd_18', 'dd18', 'nffd', 'bffp', 'effp', 
             'ffp', 'pas', 'emt', 'ext', 'eref', 'cmd', 'rh']

LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
       'strat1_return-proportion', 'strat2_return-proportion',
       'strat3_return-proportion', 'strat4_return-proportion',
       'strat5_return-proportion', 'strat0_intensity-median',
       'strat1_intensity-median', 'strat2_intensity-median',
       'strat3_intensity-median', 'strat4_intensity-median',
       'strat5_intensity-median', 'height_05-percentile',
       'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
       'height_95_percentile', 'height_max', 'cover', 'potential_volume',
       'stddev_height', 'surface_area_ratio', 'surface_volume',
       'surface_volume_ratio', 'aspect', 'elevation', 'overall_curvature',
       'plan_curvature', 'profile_curvature', 'slope', 'solar_radiation_index', 
              'kurtosis', 'skewnewss']

USE_LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
                  'strat1_return-proportion', 'strat2_return-proportion',
                  'strat3_return-proportion', 'strat4_return-proportion',
                  'strat5_return-proportion', 'height_05-percentile',
                  'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
                  'height_95_percentile', 'cover', 'potential_volume',
                  'stddev_height', 'surface_volume',
                  'aspect', 'elevation', 'slope', 'solar_radiation_index',
                  'kurtosis', 'skewness']

SOIL_COLS = ['bulk_dens', 'soil_depth', 'pct_clay_surf', 'pct_rock_surf', 'pct_sand_surf']

LANDSAT_COLS = ['green', 'blue', 'red', 'nir', 'endvi', 'ndvi', 'savi',
                'swir1', 'swir2', 'wetness', 'greenness', 'brightness']

AGENCY_COLS = ['agency_BLM', 'agency_USFS', 'agency_WADNR']

# ECOREGIONS = [col for col in df.columns if col.startswith('eco_')]

# %% [markdown]
# ## Selecting initial features and targets
# This is the first step in determining what features we want to use, and what we want to predict. Later, we can still apply some procedures to choose a subset of these features to make simpler models.

# %%
X_COLS = USE_LIDAR_COLS + ['ecoregion3'] 
Y_COLS = ['total_cover']

# %%
USE_REGIONS = ['blue_mountains', 'coast_range', 'north_cascades', 'cascades',
               'klamath_mountains_california_high_north_coast_range', 
               'eastern_cascades_slopes_and_foothills', 'northern_rockies',
               'puget_lowland', 'willamette_valley']
display(df.groupby('ecoregion3')[Y_COLS].mean().round(0).astype(int).loc[USE_REGIONS])
display(df[Y_COLS].mean().round(0).astype(int))
# Out:
#                                                     total_cover
# ecoregion3
# blue_mountains                                               25
# coast_range                                                  69
# north_cascades                                               62
# cascades                                                     64
# klamath_mountains_california_high_north_coast_r...           58
# eastern_cascades_slopes_and_foothills                        48
# northern_rockies                                             43
# puget_lowland                                                68
# willamette_valley                                            65
# total_cover    64
# dtype: int64

# %% [markdown]
# ## Split the data into training and testing sets
# Since some plot_ids have multiple observations, we want all observations for each plot_id to fall entirely in train_set or entirely the training or testing sets because these samples are definitely not independent.

# %%
# a dataframe with unique plot ids
splits = pd.DataFrame(pd.unique(df['uuid']), columns=['uuid']).set_index('uuid')

# randomly assign each plot-id to train(0) or test(1) sets
np.random.seed(127)
splits['train0_test1'] = np.random.choice(2,
                                          size=len(splits),
                                          p=[0.8,0.2])

# add set assignments to the dataframe
df['train0_test1'] = splits.loc[df['uuid']]['train0_test1'].values

# %%
train_plots = df.loc[df['train0_test1'] == 0]
test_plots = df.loc[df['train0_test1'] == 1]
len(train_plots), len(test_plots)
# Out:
# (2769, 704)

# %%
x_train, x_test = train_plots[X_COLS], test_plots[X_COLS]
y_train, y_test = train_plots[Y_COLS], test_plots[Y_COLS]

# %% [markdown]
# ## Standardize features
# Scale all predictive features to have 0 mean and unit variance (subtracting mean, dividing by standard deviation).

# %%
x_scaler = StandardScaler()
x_scaler.fit(df[X_COLS].drop(['ecoregion3'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Consider a few transformations for the target variable

# %%
fig, axs = plt.subplots(1,6, figsize=(15,2.5))

quantile = QuantileTransformer(output_distribution='normal', random_state=127)
box_cox = PowerTransformer(method='box-cox')
yeo_johnson = PowerTransformer(method='yeo-johnson')

VALS = [y_train.values,
        np.log1p(y_train.values),
        np.sqrt(y_train.values),
        quantile.fit_transform(y_train.values),
        box_cox.fit_transform(y_train.values + 1e-9),
        yeo_johnson.fit_transform(y_train.values)]

TITLES = ['Raw', 'Log', 'SQRT', 'Quantile', 'Box-Cox', 'Yeo-Johnson']
SHAPIRO_ps = [shapiro(vals)[-1] for vals in VALS]

for i, vals in enumerate(VALS):
    axs.ravel()[i].hist(vals, bins=20)
    axs.ravel()[i].set_title(TITLES[i])
    
plt.show();

# %%
# identify the closest to normally-distributed
TITLES[np.array(SHAPIRO_ps).argmax()]
# Out:
# 'Quantile'

# %%
# choose your transformer here
transformer = quantile

# %%
transformer.fit(df[Y_COLS])
y_train.loc[:,Y_COLS], y_test.loc[:,Y_COLS] = transformer.transform(y_train), transformer.transform(y_test)
# Out:
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Split datasets by ecoregion
# We want to explore model transferability between regions, so we'll train models independently on subsets of the data within a single ecoregion, as well as a model that is trained on all available ecoregions.

# %%
ecoregions = [reg for reg in pd.unique(df.ecoregion3) if ecoreg_counts.loc[reg]['uuid'] > 20]

eco_train_idx = [x_train.loc[x_train.ecoregion3 == eco].index.values for eco in ecoregions]
eco_test_idx = [x_test.loc[x_test.ecoregion3 == eco].index.values for eco in ecoregions]

eco_xtrain_dfs = [x_train.loc[x_train.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytrain_dfs = [y_train.loc[idx].values.ravel() for idx in eco_train_idx]
eco_xtest_dfs = [x_test.loc[x_test.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytest_dfs = [y_test.loc[idx].values.ravel() for idx in eco_test_idx]

# append a "global" model that contains data from all ecoregions
ecoregions.append('all')
ecoregion_names = ['_'.join(x.split('_')[0:2]) for x in ecoregions]
eco_xtrain_dfs.append(x_train.drop(['ecoregion3'], axis=1))
eco_ytrain_dfs.append(y_train.values.ravel())
eco_xtest_dfs.append(x_test.drop(['ecoregion3'], axis=1))
eco_ytest_dfs.append(y_test.values.ravel())

# %% [markdown]
# ## Scoring
# We'll use Root Mean Square Error to evaluate model performance.

# %%
def rmse(pred, obs):
    # use our transformer to calculate RMSE on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return np.sqrt((np.square(obs-pred)).mean())

# %%
def nrmse(pred, obs):
    # use our transformer to calculate percent RMSE on the original data scale
    this_rmse = rmse(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return this_rmse/obs.mean()

# %%
def mae(pred, obs):
    # use our transformer to calculate mean absolute error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean()

# %%
def mape(pred, obs):
    # use our transformer to calculate mean average percent error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean() / obs.mean()

# %%
def bias(pred, obs):
    # use our transformer to calculate mean bias on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return (pred - obs).mean()

# %%
def rel_bias(pred, obs):
    # use our transformer to calculate mean relative bias on the original data scale
    this_bias = bias(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1))  
    
    return this_bias/obs.mean()

# %% [markdown]
# This helper function will calculate RMSE scores for each regionally-trained model and the global model on each ecoregion.

# %%
def get_score_df(models, metric=rmse, feature_selectors=None):
    regional_scores = []
    global_scores = []
    counts = []
    
    for i, mod in enumerate(models):
        X_test = x_scaler.transform(eco_xtest_dfs[i])
        if feature_selectors:
            X_test = feature_selectors[i].transform(X_test)
        y_test = eco_ytest_dfs[i]
        reg_score = metric(mod.predict(X_test), y_test)
        regional_scores.append(reg_score.round(3))
        
        if feature_selectors:
            X_test = x_scaler.transform(eco_xtest_dfs[i])
            X_test = feature_selectors[-1].transform(X_test)
        glob_score = metric(models[-1].predict(X_test), y_test)
        global_scores.append(glob_score.round(3))
        count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
        counts.append(count)
        
    data = list(zip(regional_scores, global_scores, counts))
    res_df = pd.DataFrame(data=data,
                          columns=['regional_model', 'global_model', 'n'],
                          index=ecoregion_names)
    
    return res_df

# %% [markdown]
# ## Fit some models
# For each type of model, we'll employ cross-validation to tune model hyperparameters, generating a tuned model for each ecoregion as well as a tuned model using all training data. We'll work our way through:
#
# #### ElasticNet Regression
# Linear model that employs a mix of L1 and L2 regularization to penalize model complexity
#
# #### LASSO Regression
# Linear model that employs L1 regularization to penalize model complexity. We'll also work with a feature-selection process to fit models capped to an explicitly-predefined number of features.
#
# #### K-Nearest Neighbor Regression
#
# #### Random Forest Regression
#
# #### Gradient Boosting Trees Regression
#
# #### Support Vector Machine Regression

# %% [markdown]
# ## ElasticNet (Linear Model)

# %%
best_lms = []

for i in range(len(ecoregions)):
    lm = ElasticNetCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    lm.fit(X, y)
    best_lms.append(lm)

# %%
elastic_res = get_score_df(best_lms)
elastic_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              8.133         9.598   104
# coast_range                14.571        15.199  1580
# north_cascades             15.045        13.753   443
# cascades                   15.114        15.129   613
# klamath_mountains          14.724        15.009   275
# eastern_cascades           18.741        14.800   203
# northern_rockies           10.955        11.276    83
# puget_lowland              10.185         9.404   122
# willamette_valley           9.874         9.930    41
# all                        14.623        14.623  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lms])
count_nonzero = [(~np.isclose(coef, 0, atol=1e-3)).sum() for coef in coefs]
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.054
# north_cascades                                                 --
# cascades                                                    0.022
# klamath_mountains_california_high_north_coast_r...         -0.068
# eastern_cascades_slopes_and_foothills                       0.031
# northern_rockies                                               --
# puget_lowland                                               0.152
# willamette_valley                                              --
# all                                                         0.032
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                       -0.132
# coast_range                                                          -0.039
# north_cascades                                                       -0.307
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.248
# eastern_cascades_slopes_and_foothills                                -0.117
# northern_rockies                                                     -0.116
# puget_lowland                                                        -0.039
# willamette_valley                                                     -0.05
# all                                                                   -0.19
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           -0.08
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                -0.089
# northern_rockies                                                     -0.033
# puget_lowland                                                        -0.092
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.098
# north_cascades                                                           --
# cascades                                                              0.258
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                 0.208
# northern_rockies                                                      0.077
# puget_lowland                                                         0.032
# willamette_valley                                                    -0.098
# all                                                                   0.063
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                             0.1
# north_cascades                                                           --
# cascades                                                              0.275
# klamath_mountains_california_high_north_coast_r...                    0.109
# eastern_cascades_slopes_and_foothills                                 0.152
# northern_rockies                                                      0.231
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                    0.08
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.026
# north_cascades                                                           --
# cascades                                                              0.133
# klamath_mountains_california_high_north_coast_r...                    -0.06
# eastern_cascades_slopes_and_foothills                                 0.025
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.134
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.148
# north_cascades                                                       --
# cascades                                                          0.026
# klamath_mountains_california_high_north_coast_r...                -0.07
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                     0.037
# willamette_valley                                                    --
# all                                                               0.111
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                      -0.017
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                             0.018
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                 0.032
# all                                                                  --
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                       --  ...
# coast_range                                                      -0.285  ...
# north_cascades                                                       --  ...
# cascades                                                             --  ...
# klamath_mountains_california_high_north_coast_r...               -0.107  ...
# eastern_cascades_slopes_and_foothills                             0.165  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                     0.111  ...
# willamette_valley                                                    --  ...
# all                                                                  --  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                      0.191               --
# coast_range                                         0.241               --
# north_cascades                                      0.242               --
# cascades                                               --            0.273
# klamath_mountains_california_high_north_coast_r...  0.389               --
# eastern_cascades_slopes_and_foothills               0.316             0.18
# northern_rockies                                     0.31               --
# puget_lowland                                       0.261               --
# willamette_valley                                      --               --
# all                                                 0.255               --
#
#                                                    stddev_height  \
# blue_mountains                                                --
# coast_range                                               -0.132
# north_cascades                                                --
# cascades                                                  -0.184
# klamath_mountains_california_high_north_coast_r...          -0.2
# eastern_cascades_slopes_and_foothills                     -0.139
# northern_rockies                                          -0.009
# puget_lowland                                             -0.024
# willamette_valley                                             --
# all                                                       -0.097
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --     --
# coast_range                                                 0.321  0.044
# north_cascades                                                 --     --
# cascades                                                    0.147     --
# klamath_mountains_california_high_north_coast_r...         -0.017     --
# eastern_cascades_slopes_and_foothills                       0.121 -0.069
# northern_rockies                                               -- -0.011
# puget_lowland                                                  -- -0.044
# willamette_valley                                           0.011     --
# all                                                         0.097     --
#
#                                                    elevation  slope  \
# blue_mountains                                            --     --
# coast_range                                            0.049  0.029
# north_cascades                                            --     --
# cascades                                                0.02 -0.127
# klamath_mountains_california_high_north_coast_r...    -0.014 -0.104
# eastern_cascades_slopes_and_foothills                 -0.017 -0.062
# northern_rockies                                          --     --
# puget_lowland                                             --     --
# willamette_valley                                         --     --
# all                                                   -0.026     --
#
#                                                    solar_radiation_index  \
# blue_mountains                                                        --
# coast_range                                                        0.108
# north_cascades                                                        --
# cascades                                                           -0.08
# klamath_mountains_california_high_north_coast_r...                    --
# eastern_cascades_slopes_and_foothills                             -0.075
# northern_rockies                                                      --
# puget_lowland                                                         --
# willamette_valley                                                     --
# all                                                                 0.03
#
#                                                    kurtosis skewness
# blue_mountains                                           --   -0.169
# coast_range                                          -0.375    -0.05
# north_cascades                                           --   -0.117
# cascades                                             -0.155   -0.219
# klamath_mountains_california_high_north_coast_r...       --       --
# eastern_cascades_slopes_and_foothills                    --    0.386
# northern_rockies                                         --       --
# puget_lowland                                            --   -0.227
# willamette_valley                                        --       --
# all                                                      --   -0.141
#
# [10 rows x 22 columns]

# %% [markdown]
# ## LASSO (Linear Model)
# Starting with implicit feature selection via L1 regularization of coefficients.

# %%
best_lassos = []

for i in range(len(ecoregions)):
    lasso = LassoCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000, n_alphas=1000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    lasso.fit(X, y)
    best_lassos.append(lasso)

# %%
lasso_res = get_score_df(best_lassos)
lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              7.951         9.572   104
# coast_range                14.576        15.266  1580
# north_cascades             15.078        13.721   443
# cascades                   15.095        15.179   613
# klamath_mountains          14.818        14.895   275
# eastern_cascades           13.854        14.744   203
# northern_rockies           10.616        11.171    83
# puget_lowland               9.762         9.473   122
# willamette_valley           9.823         9.806    41
# all                        14.642        14.642  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lassos])
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.054
# north_cascades                                                 --
# cascades                                                     0.02
# klamath_mountains_california_high_north_coast_r...         -0.068
# eastern_cascades_slopes_and_foothills                          --
# northern_rockies                                               --
# puget_lowland                                               0.148
# willamette_valley                                              --
# all                                                         0.033
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                       -0.393
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.236
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   -0.18
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.125
# coast_range                                                          -0.067
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                        -0.075
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        0.026
# coast_range                                                           0.099
# north_cascades                                                           --
# cascades                                                              0.261
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.064
# puget_lowland                                                         0.005
# willamette_valley                                                    -0.087
# all                                                                   0.065
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.101
# north_cascades                                                           --
# cascades                                                              0.278
# klamath_mountains_california_high_north_coast_r...                    0.103
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.219
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.079
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.027
# north_cascades                                                           --
# cascades                                                              0.134
# klamath_mountains_california_high_north_coast_r...                   -0.062
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.137
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.148
# north_cascades                                                       --
# cascades                                                          0.023
# klamath_mountains_california_high_north_coast_r...               -0.053
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                     0.016
# willamette_valley                                                    --
# all                                                               0.112
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                      -0.017
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                 0.028
# all                                                                  --
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                       --  ...
# coast_range                                                      -0.289  ...
# north_cascades                                                       --  ...
# cascades                                                             --  ...
# klamath_mountains_california_high_north_coast_r...               -0.128  ...
# eastern_cascades_slopes_and_foothills                                --  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                     0.048  ...
# willamette_valley                                                    --  ...
# all                                                                  --  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                      0.377               --
# coast_range                                         0.285               --
# north_cascades                                      0.163               --
# cascades                                               --            0.301
# klamath_mountains_california_high_north_coast_r...  0.407               --
# eastern_cascades_slopes_and_foothills               0.545               --
# northern_rockies                                    0.456               --
# puget_lowland                                       0.342               --
# willamette_valley                                      --               --
# all                                                  0.27               --
#
#                                                    stddev_height  \
# blue_mountains                                                --
# coast_range                                               -0.132
# north_cascades                                                --
# cascades                                                  -0.197
# klamath_mountains_california_high_north_coast_r...        -0.208
# eastern_cascades_slopes_and_foothills                         --
# northern_rockies                                              --
# puget_lowland                                             -0.016
# willamette_valley                                             --
# all                                                       -0.101
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --  0.012
# coast_range                                                 0.324  0.044
# north_cascades                                                 --     --
# cascades                                                    0.133     --
# klamath_mountains_california_high_north_coast_r...             --     --
# eastern_cascades_slopes_and_foothills                          -- -0.011
# northern_rockies                                               -- -0.001
# puget_lowland                                                  -- -0.032
# willamette_valley                                              --     --
# all                                                         0.099     --
#
#                                                    elevation  slope  \
# blue_mountains                                            --  0.053
# coast_range                                            0.049  0.029
# north_cascades                                            --     --
# cascades                                               0.018 -0.129
# klamath_mountains_california_high_north_coast_r...     -0.01 -0.104
# eastern_cascades_slopes_and_foothills                     --     --
# northern_rockies                                          --     --
# puget_lowland                                             --     --
# willamette_valley                                         --     --
# all                                                   -0.027     --
#
#                                                    solar_radiation_index  \
# blue_mountains                                                     0.015
# coast_range                                                        0.108
# north_cascades                                                        --
# cascades                                                           -0.08
# klamath_mountains_california_high_north_coast_r...                    --
# eastern_cascades_slopes_and_foothills                                 --
# northern_rockies                                                      --
# puget_lowland                                                         --
# willamette_valley                                                     --
# all                                                                0.032
#
#                                                    kurtosis skewness
# blue_mountains                                           --   -0.176
# coast_range                                          -0.379   -0.047
# north_cascades                                           --   -0.106
# cascades                                             -0.158   -0.218
# klamath_mountains_california_high_north_coast_r...       --       --
# eastern_cascades_slopes_and_foothills                    --       --
# northern_rockies                                         --       --
# puget_lowland                                            --   -0.252
# willamette_valley                                        --       --
# all                                                      --   -0.141
#
# [10 rows x 22 columns]

# %% [markdown]
# Now we'll explicitly define the maximum number of features to use for fitting a linear model. We'll trim features by iteratively increasing a threshold for coefficients using LASSO regression

# %%
MAX_FEATURES = 5
sfms = [] # transformers that filter X features
trimmed_lassos = [] # re-fit lasso regressions on the subset of the features

for i, lasso in enumerate(best_lassos):
    lasso = deepcopy(lasso)
    sfm = SelectFromModel(lasso, threshold=0.001)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    Y = (eco_ytrain_dfs[i].ravel())
    sfm.fit(X, Y)
    n_features = sfm.transform(X).shape[1]

    # Reset the threshold till the number of features equals two.
    # Note that the attribute can be set directly instead of repeatedly
    # fitting the metatransformer.
    while n_features > MAX_FEATURES:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    
    sfms.append(sfm)
    try:
        trimmed_lassos.append(lasso.fit(sfm.transform(X), Y))
    except ValueError:
        print(ecoregion_names[i])
        raise

# %%
coefs = []
for i in range(len(ecoregions)):
    cols = np.zeros(eco_xtest_dfs[i].columns.shape)
    cols[sfms[i].get_support()] = trimmed_lassos[i].coef_
    coefs.append(cols)
    
coefs = np.array(coefs)

coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                    --
# north_cascades                                                 --
# cascades                                                       --
# klamath_mountains_california_high_north_coast_r...             --
# eastern_cascades_slopes_and_foothills                          --
# northern_rockies                                               --
# puget_lowland                                                 0.2
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                       -0.393
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.198
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                  -0.157
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                        -0.099
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                              0.213
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.088
# puget_lowland                                                            --
# willamette_valley                                                    -0.111
# all                                                                      --
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                              0.284
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.273
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.163
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                               0.108
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                  0.07
# all                                                                  --
#
#                                                    height_50-percentile  \
# blue_mountains                                                       --
# coast_range                                                      -0.323
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...               -0.298
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                     0.057
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_95_percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                 0.35
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                     cover potential_volume  \
# blue_mountains                                      0.362               --
# coast_range                                         0.552               --
# north_cascades                                      0.163               --
# cascades                                               --            0.428
# klamath_mountains_california_high_north_coast_r...  0.508               --
# eastern_cascades_slopes_and_foothills               0.605               --
# northern_rockies                                    0.431               --
# puget_lowland                                       0.301               --
# willamette_valley                                      --               --
# all                                                 0.416               --
#
#                                                    stddev_height  \
# blue_mountains                                                --
# coast_range                                                   --
# north_cascades                                                --
# cascades                                                  -0.239
# klamath_mountains_california_high_north_coast_r...          -0.3
# eastern_cascades_slopes_and_foothills                         --
# northern_rockies                                              --
# puget_lowland                                                 --
# willamette_valley                                             --
# all                                                        -0.13
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --     --
# coast_range                                                 0.249     --
# north_cascades                                                 --     --
# cascades                                                       --     --
# klamath_mountains_california_high_north_coast_r...             --     --
# eastern_cascades_slopes_and_foothills                          -- -0.082
# northern_rockies                                               --  -0.02
# puget_lowland                                                  --     --
# willamette_valley                                              --     --
# all                                                            --     --
#
#                                                    kurtosis skewness
# blue_mountains                                           --   -0.162
# coast_range                                          -0.315       --
# north_cascades                                           --   -0.106
# cascades                                                 --    -0.33
# klamath_mountains_california_high_north_coast_r...       --       --
# eastern_cascades_slopes_and_foothills                    --       --
# northern_rockies                                         --       --
# puget_lowland                                            --   -0.366
# willamette_valley                                        --       --
# all                                                      --   -0.146

# %%
trimmed_lasso_res = get_score_df(trimmed_lassos, feature_selectors=sfms)
trimmed_lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              7.998         9.787   104
# coast_range                14.920        15.737  1580
# north_cascades             15.078        13.665   443
# cascades                   14.866        15.383   613
# klamath_mountains          15.661        15.015   275
# eastern_cascades           14.830        14.339   203
# northern_rockies           10.992        11.260    83
# puget_lowland              10.077        10.059   122
# willamette_valley          10.120         9.469    41
# all                        14.870        14.870  3473

# %% [markdown]
# ## K-Nearest Neighbors Regression

# %%
# Set the parameters by cross-validation
knn_params = {'n_neighbors': [1,2,3,4,5,10,20],
              'weights': ['uniform', 'distance'],
              'metric': ['minkowski', 'manhattan']}


knn_gs = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=knn_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_knns = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    knn_gs.fit(X, y)
    best_fit = knn_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_knns.append(best_fit)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    1.9s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.8s finished

# %%
knn_res = get_score_df(best_knns)
knn_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              9.057         9.092   104
# coast_range                14.571        14.838  1580
# north_cascades             13.692        13.123   443
# cascades                   14.913        14.109   613
# klamath_mountains          15.610        14.584   275
# eastern_cascades           14.416        14.204   203
# northern_rockies           13.319        12.061    83
# puget_lowland              13.482        11.005   122
# willamette_valley          17.493         9.753    41
# all                        14.125        14.125  3473

# %% [markdown]
# ## Random Forest Regression

# %%
# Set the parameters by cross-validation
rf_params = {'n_estimators': [100, 500, 1000, 5000],
             'max_features': ['sqrt'],
             'max_depth': [3, 5, 10, 25, 50],
             'min_samples_leaf': [1,2,4],
             'bootstrap': [True]}


rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=rf_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_rfs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    rf_gs.fit(X, y)
    best_fit = rf_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_rfs.append(best_fit)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    8.9s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   18.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   18.2s remaining:    9.8s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   47.5s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   22.7s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   11.7s remaining:    6.3s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   25.8s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   13.1s remaining:    7.0s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   24.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   11.9s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.9s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   11.1s remaining:    6.0s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.1s remaining:    5.4s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   22.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.8s remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   19.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  1.6min finished

# %%
rf_res = get_score_df(best_rfs)
rf_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              7.974         8.323   104
# coast_range                14.391        14.781  1580
# north_cascades             13.314        13.430   443
# cascades                   14.493        14.671   613
# klamath_mountains          14.850        14.796   275
# eastern_cascades           13.893        13.739   203
# northern_rockies           12.045        12.650    83
# puget_lowland               9.579        10.889   122
# willamette_valley          11.648        10.288    41
# all                        14.207        14.207  3473

# %%
### Employing feature selection to try and improve random forest regression

# %%
importances = best_rfs[-1].feature_importances_
indices = np.argsort(importances)[::-1]
features = eco_xtrain_dfs[-1].columns[indices]

# Print the feature ranking
print("Feature ranking:")

for f in range(eco_xtrain_dfs[-1].shape[1]):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. cover (0.135201)
# 2. strat0_return-proportion (0.128568)
# 3. height_25-percentile (0.092972)
# 4. height_50-percentile (0.089749)
# 5. surface_volume (0.061587)
# 6. skewness (0.057512)
# 7. height_75-percentile (0.050166)
# 8. stddev_height (0.046051)
# 9. strat1_return-proportion (0.040094)
# 10. kurtosis (0.034609)
# 11. height_05-percentile (0.034565)
# 12. elevation (0.032096)
# 13. height_95_percentile (0.031226)
# 14. potential_volume (0.029568)
# 15. strat3_return-proportion (0.022647)
# 16. strat2_return-proportion (0.020516)
# 17. returns_per_m2 (0.020486)
# 18. slope (0.018559)
# 19. solar_radiation_index (0.016640)
# 20. aspect (0.016283)
# 21. strat4_return-proportion (0.012013)
# 22. strat5_return-proportion (0.008895)

# %% [markdown]
# ## Gradient Boosting Trees Regression

# %%
# Set the parameters by cross-validation
gb_params = {'n_estimators': [100, 500, 1000, 5000],
             'learning_rate': [0.01, 0.1],
             'max_depth': [2, 3, 4, 5, 10],
             'max_features': ['sqrt'] 
            }

gb_gs = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=gb_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_gbs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    gb_gs.fit(X, y)
    best_fit = gb_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_gbs.append(best_fit)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    4.5s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.6s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   13.9s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   16.3s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.9s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   12.4s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.5s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.1s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.6s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.3s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.1s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.6s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.4s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.3s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.0s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   40.5s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   41.9s finished

# %%
gb_res = get_score_df(best_gbs)
gb_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              8.367         8.204   104
# coast_range                14.673        14.796  1580
# north_cascades             14.206        13.259   443
# cascades                   15.927        14.324   613
# klamath_mountains          15.119        14.892   275
# eastern_cascades           14.956        13.961   203
# northern_rockies           11.461        11.333    83
# puget_lowland              11.749        10.712   122
# willamette_valley          11.930         9.755    41
# all                        14.110        14.110  3473

# %%
### Employing feature selection to try and improve gradient boosting regression

# %% [markdown]
# ## Support Vector Machines Regression

# %%
# Set the parameters by cross-validation
svm_params = {'kernel': ['linear', 'rbf'],
              'gamma': ['scale', 'auto'],
              'C': [0.1,1,10,100,1000]
              }

svm_gs = GridSearchCV(estimator=SVR(), param_grid=svm_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_svms = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    svm_gs.fit(X, y)
    best_fit = svm_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_svms.append(best_fit)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    2.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   51.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   17.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    8.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   10.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   17.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   12.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.0s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    1.2s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  3.5min finished

# %%
svm_res = get_score_df(best_svms)
svm_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              7.978         7.898   104
# coast_range                14.526        14.823  1580
# north_cascades             13.698        13.078   443
# cascades                   15.304        14.349   613
# klamath_mountains          15.447        14.603   275
# eastern_cascades           21.191        13.993   203
# northern_rockies            8.660        10.014    83
# puget_lowland              11.318        11.355   122
# willamette_valley           9.730         8.317    41
# all                        14.038        14.038  3473

# %%
### Employing feature selection to try and improve support vector regression

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

def scatter_graphs(model_dict):
    names = MODELS.keys()
    EXTEND_PCT = 0.10
    
    fig, axs = plt.subplots(len(ecoregion_names), len(names), 
                            sharex=True, sharey=True,
                            figsize=(11,15)
                           )
    
    all_obs = transformer.inverse_transform(eco_ytest_dfs[-1].reshape(-1,1))
    obs_min = all_obs.min()
    obs_max = all_obs.max()
    rng = obs_max - obs_min
        
    for i, ecoreg in enumerate(ecoregion_names):
        observed = transformer.inverse_transform(eco_ytest_dfs[i].reshape(-1,1))
        
        for j, name in enumerate(names):
            axs[0,j].set_title(name)
            axs[i,0].set_ylabel('\n'.join(ecoreg.split('_')).upper())
            axs[i,j].set_xlim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_ylim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_aspect('equal')
            
            if name == 'LASSO_{}'.format(MAX_FEATURES):
                predicted = MODELS[name][-1].predict(sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i])))
            else:
                predicted = MODELS[name][-1].predict(x_scaler.transform(eco_xtest_dfs[i]))
            
            predicted = transformer.inverse_transform(predicted.reshape(-1,1))
            axs[i,j].scatter(observed, predicted, s=0.5)
            axs[i,j].plot((obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng), 
                          (obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng),
                         color='k', lw=0.5)
            
    plt.tight_layout(pad=0.5)

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

scatter_graphs(MODELS)

# %% [markdown]
# ## View scores for regional and global models

# %%
MODEL_NAMES = ['ElasticNet', 'LASSO', 'LASSO_{}'.format(MAX_FEATURES), 'KNN', 'RF', 'GB', 'SVM']
BEST_MODELS = [best_lms, best_lassos, trimmed_lassos, best_knns, best_rfs, best_gbs, best_svms]

def compare_models(metric):
    score_dfs = []
    for name, best_models in list(zip(MODEL_NAMES, BEST_MODELS)):
        if name == 'LASSO_{}'.format(MAX_FEATURES):
            score_df = get_score_df(best_models, metric, sfms) 
            score_dfs.append(score_df)
        else:
            score_df = get_score_df(best_models, metric) 
            score_dfs.append(score_df)
        
    counts = np.array(score_dfs[-1]['n'].values)
    regional_data = np.array([df['regional_model'].values for df in score_dfs])
    global_data = np.array([df['global_model'].values for df in score_dfs])
    
    return regional_data, global_data, counts

# %%
def highlight_best(s):
    '''
    highlight the closest value to zero in a Series yellow.
    '''
    lowest_idx = abs(s).idxmin()
    return ['background-color: yellow' if idx==lowest_idx else '' for idx in s.index]

# %%
print('Regional Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, RMSE
# <style  type="text/css" >
#     #T_b594b0e0_552e_11ea_84b7_00505683952erow0_col1 {
#             background-color:  yellow;
#         }    #T_b594b0e0_552e_11ea_84b7_00505683952erow1_col4 {
#             background-color:  yellow;
#         }    #T
td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow2_col5" class="data row2 col5" >10.2</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow2_col6" class="data row2 col6" >10.0</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_c0d3298c_552e_11ea_84b7_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow3_col0" class="data row3 col0" >12.0</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow3_col1" class="data row3 col1" >12.1</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow3_col2" class="data row3 col2" >12.2</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow3_col3" class="data row3 col3" >11.1</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow3_col4" class="data row3 col4" >11.6</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow3_col5" class="data row3 col5" >11.4</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow3_col6" class="data row3 col6" >11.2</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_c0d3298c_552e_11ea_84b7_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow4_col0" class="data row4 col0" >12.7</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow4_col1" class="data row4 col1" >12.6</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow4_col2" class="data row4 col2" >12.6</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow4_col3" class="data row4 col3" >12.5</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow4_col4" class="data row4 col4" >12.6</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow4_col5" class="data row4 col5" >12.7</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow4_col6" class="data row4 col6" >12.0</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_c0d3298c_552e_11ea_84b7_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow5_col0" class="data row5 col0" >11.4</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow5_col1" class="data row5 col1" >11.3</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow5_col2" class="data row5 col2" >10.8</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow5_col3" class="data row5 col3" >10.6</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow5_col4" class="data row5 col4" >10.6</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow5_col5" class="data row5 col5" >10.6</td>
#                         <td id="T_c0d3298c_552e_11ea_84b7_00505683952erow5_col6" cla

# %%
print('Global Models, MAPE')
regional_data, global_data, counts = compare_models(mape)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:.0%}", subset=global_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, MAPE
# <style  type="text/css" >
#     #T_c238769c_552e_11ea_84b7_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow3_col3 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow7_col0 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow7_col1 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow8_col6 {
#             background-color:  yellow;
#         }    #T_c238769c_552e_11ea_84b7_00505683952erow9_col6 {
#             background-color:  yellow;
#         }</style><table id="T_c238769c_552e_11ea_84b7_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c238769c_552e_11ea_84b7_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow0_col0" class="data row0 col0" >28%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow0_col1" class="data row0 col1" >28%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow0_col2" class="data row0 col2" >28%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow0_col3" class="data row0 col3" >25%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow0_col4" class="data row0 col4" >24%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow0_col5" class="data row0 col5" >24%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow0_col6" class="data row0 col6" >23%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_c238769c_552e_11ea_84b7_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow1_col0" class="data row1 col0" >16%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow1_col1" class="data row1 col1" >16%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow1_col2" class="data row1 col2" >17%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow1_col3" class="data row1 col3" >16%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow1_col4" class="data row1 col4" >16%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow1_col5" class="data row1 col5" >16%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow1_col6" class="data row1 col6" >16%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_c238769c_552e_11ea_84b7_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow2_col0" class="data row2 col0" >18%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow2_col1" class="data row2 col1" >18%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow2_col2" class="data row2 col2" >18%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow2_col3" class="data row2 col3" >16%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow2_col4" class="data row2 col4" >17%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow2_col5" class="data row2 col5" >17%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow2_col6" class="data row2 col6" >16%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_c238769c_552e_11ea_84b7_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow3_col0" class="data row3 col0" >19%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow3_col1" class="data row3 col1" >19%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow3_col2" class="data row3 col2" >19%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow3_col3" class="data row3 col3" >18%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow3_col4" class="data row3 col4" >18%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow3_col5" class="data row3 col5" >18%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow3_col6" class="data row3 col6" >18%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_c238769c_552e_11ea_84b7_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow4_col0" class="data row4 col0" >23%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow4_col1" class="data row4 col1" >22%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow4_col2" class="data row4 col2" >22%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow4_col3" class="data row4 col3" >22%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow4_col4" class="data row4 col4" >22%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow4_col5" class="data row4 col5" >22%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow4_col6" class="data row4 col6" >21%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_c238769c_552e_11ea_84b7_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow5_col0" class="data row5 col0" >26%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow5_col1" class="data row5 col1" >26%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow5_col2" class="data row5 col2" >25%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow5_col3" class="data row5 col3" >24%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow5_col4" class="data row5 col4" >24%</td>
#                         <td id="T_c238769c_552e_11ea_84b7_00505683952erow5_col5" class="data row5 col5" >25%</td>

# %%
print('Global vs. Regional Models, ΔRMSE')
regional_data, global_data, counts = compare_models(rmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔRMSE
# <style  type="text/css" >
#     #T_c50e2416_552e_11ea_84b7_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 59.2%, transparent 59.2%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.1%, transparent 60.1%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.2%, transparent 61.2%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.2%, transparent 50.2%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.2%, transparent 52.2%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.0%, orange 49.0%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.9%, transparent 53.9%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.3%, transparent 54.3%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.1%, transparent 55.1%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.7%, transparent 51.7%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.4%, transparent 52.4%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.8%, transparent 50.8%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.9%, transparent 51.9%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, orange 41.9%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.5%, orange 41.5%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.2%, orange 41.2%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.4%, orange 46.4%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.7%, transparent 50.7%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.1%, orange 44.1%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.1%, orange 46.1%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.2%, transparent 53.2%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, orange 45.0%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.1%, transparent 51.1%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.0%, orange 40.0%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.0%, orange 44.0%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.8%, transparent 51.8%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.0%, orange 46.0%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.6%, orange 43.6%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.6%, orange 48.6%, orange 50.0%, transparent 50.0%);
#         }    #T_c50e2416_552e_11ea_84b7_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transp

# %%
print('Global vs. Regional Models, ΔRMSE%')
regional_data, global_data, counts = compare_models(nrmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.2, vmax=0.2))
# Out:
# Global vs. Regional Models, ΔRMSE%
# <style  type="text/css" >
#     #T_c6778f22_552e_11ea_84b7_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.0%, transparent 62.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 63.5%, transparent 63.5%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 65.0%, transparent 65.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.0%, transparent 53.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, orange 48.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.2%, transparent 52.2%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.5%, transparent 52.5%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.7%, transparent 52.7%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.7%, transparent 50.7%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.5%, transparent 51.5%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.0%, transparent 51.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, orange 44.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.5%, orange 44.5%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.2%, orange 44.2%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.0%, orange 46.0%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.5%, orange 47.5%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.0%, transparent 52.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.7%, orange 46.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.7%, transparent 50.7%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.7%, orange 43.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.2%, orange 46.2%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.2%, transparent 51.2%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.2%, orange 47.2%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.5%, orange 45.5%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.0%, orange 49.0%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.2%, orange 46.2%, orange 50.0%, transparent 50.0%);
#         }    #T_c6778f22_552e_11ea_84b7_0050568395

# %%
print('Global vs. Regional Models, ΔMAE')
regional_data, global_data, counts = compare_models(mae)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔMAE
# <style  type="text/css" >
#     #T_c7da0692_552e_11ea_84b7_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.5%, transparent 61.5%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.4%, transparent 60.4%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.4%, transparent 62.4%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.2%, transparent 53.2%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.1%, transparent 53.1%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, orange 49.9%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.3%, transparent 51.3%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.4%, transparent 51.4%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.8%, transparent 51.8%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.8%, transparent 50.8%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.2%, transparent 51.2%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.3%, orange 49.3%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.5%, transparent 51.5%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.5%, orange 43.5%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.6%, orange 43.6%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.2%, orange 42.2%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.1%, orange 45.1%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.2%, orange 48.2%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.6%, orange 44.6%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.7%, orange 45.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, orange 45.0%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.4%, orange 49.4%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, orange 43.3%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.4%, orange 45.4%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.2%, transparent 56.2%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.0%, transparent 55.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.6%, transparent 51.6%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, orange 44.9%, orange 50.0%, transparent 50.0%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.9%, transparent 51.9%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.8%, transparent 51.8%);
#         }    #T_c7da0692_552e_11ea_84b7_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transp

# %%
print('Global vs. Regional Models, Δbias%')
regional_data, global_data, counts = compare_models(rel_bias)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.4, vmax=0.4))
# Out:
# Global vs. Regional Models, Δbias%
# <style  type="text/css" >
#     #T_c9427474_552e_11ea_84b7_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 68.2%, transparent 68.2%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 65.9%, transparent 65.9%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 68.5%, transparent 68.5%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 59.5%, transparent 59.5%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.6%, transparent 60.6%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 57.9%, transparent 57.9%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.1%, transparent 58.1%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.9%, orange 47.9%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.5%, orange 47.5%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, orange 48.5%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.4%, orange 48.4%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.1%, orange 44.1%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.4%, orange 44.4%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.4%, orange 44.4%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.6%, orange 44.6%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.7%, orange 46.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.1%, orange 49.1%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.4%, orange 46.4%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.2%, transparent 50.2%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.4%, orange 46.4%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.6%, orange 48.6%, orange 50.0%, transparent 50.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.4%, transparent 51.4%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.0%, transparent 56.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.7%, transparent 55.7%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.4%, transparent 54.4%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.0%, transparent 52.0%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.7%, transparent 52.7%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.7%, transparent 52.7%);
#         }    #T_c9427474_552e_11ea_84b7_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(9

# %%
METRIC = 'canopy_cover'

MODELS = {'ElasticNet': best_lms,
          'LASSO': best_lassos,
          'LASSO{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

pickle.dump(x_scaler, 
            open('../models/{}/sklearn/x_scaler.pkl'.format(METRIC), 'wb'))
pickle.dump(transformer, 
            open('../models/{}/sklearn/y_scaler.pkl'.format(METRIC), 'wb'))

for i in range(len(ecoregion_names)):
    for key in MODELS.keys():
        fname = ecoregion_names[i] + '_{}.pkl'.format(key)
        path_to_file = '../models/{}/sklearn/{}'.format(METRIC, fname)
        pickle.dump(MODELS[key][i], 
                    open(path_to_file, 'wb'))
        
        if key == 'LASSO{}'.format(MAX_FEATURES):
            sfm_name = ecoregion_names[i] + '_LASSO{}_featureselect.pkl'.format(MAX_FEATURES)
            path_to_file = '../models/{}/sklearn/{}'.format(METRIC, sfm_name)
            pickle.dump(sfms[i], 
                        open(path_to_file, 'wb'))
