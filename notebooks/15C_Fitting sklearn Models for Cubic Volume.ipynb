# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
# data prep and model-tuning
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, QuantileTransformer
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV

# types of models we'll fit
from sklearn.linear_model import ElasticNetCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR

from scipy.stats import shapiro

import pickle
from copy import deepcopy

# %% [markdown]
# ## Our Data

# %%
DATA = '../data/processed/training_data_annual.csv'
df = pd.read_csv(DATA)
df = df.dropna()
print('{:,d} samples'.format(len(df)))
print('Columns:', df.columns.values)
# Out:
# 3,529 samples
# Columns: ['uuid' 'lidar_year' 'lat' 'lon' 'orig_id' 'source' 'meas_yr' 'ecoregion3'
#  'agency' 'plot_size_ac' 'num_returns' 'strat0_return-proportion'
#  'strat1_return-proportion' 'strat2_return-proportion'
#  'strat3_return-proportion' 'strat4_return-proportion'
#  'strat5_return-proportion' 'skewness' 'kurtosis'
#  'strat0_intensity-median' 'strat1_intensity-median'
#  'strat2_intensity-median' 'strat3_intensity-median'
#  'strat4_intensity-median' 'strat5_intensity-median'
#  'height_05-percentile' 'height_25-percentile' 'height_50-percentile'
#  'height_75-percentile' 'height_95_percentile' 'height_max' 'cover'
#  'lidar_acq' 'potential_volume' 'stddev_height' 'surface_area_ratio'
#  'surface_volume' 'surface_volume_ratio' 'aspect' 'elevation'
#  'overall_curvature' 'plan_curvature' 'profile_curvature' 'slope'
#  'solar_radiation_index' 'mat' 'mwmt' 'mcmt' 'td' 'map' 'msp' 'ahm' 'shm'
#  'dd_0' 'dd5' 'dd_18' 'dd18' 'nffd' 'bffp' 'effp' 'ffp' 'pas' 'emt' 'ext'
#  'eref' 'cmd' 'rh' 'dormancy' 'evi_amplitude' 'evi_area' 'evi_minimum'
#  'greenup' 'maturity' 'midgreendown' 'midgreenup' 'numcycles' 'peak'
#  'green' 'blue' 'red' 'nir' 'endvi' 'ndvi' 'savi' 'swir1' 'swir2'
#  'wetness' 'greenness' 'brightness' 'landsat_year' 'clim_year'
#  'distance_to_water_m' 'bulk_dens' 'soil_depth' 'pct_clay_surf'
#  'pct_rock_surf' 'pct_sand_surf' 'pot_veg_type' 'tpa' 'ba' 'sdi' 'ccf'
#  'qmd' 'tcuft' 'topht' 'number_of_strata' 'total_cover' 'structure_class'
#  'canopy_baseheight' 'canopy_bulkdensity' 'aboveground_biomass'
#  'aboveground_carbon' 'gs_tpa' 'AF' 'AS' 'BM' 'BO' 'CH' 'CW' 'DF' 'DG'
#  'ES' 'GC' 'GF' 'IC' 'JP' 'KP' 'LO' 'LP' 'MA' 'MC' 'MH' 'NF' 'OH' 'OS'
#  'OT' 'PC' 'PL' 'PP' 'PY' 'RA' 'RC' 'RF' 'SF' 'SH' 'SP' 'SS' 'TO' 'WA'
#  'WB' 'WF' 'WH' 'WI' 'WJ' 'WL' 'WO' 'WP' 'YC' 'TRUE_FIR' 'OTHER_HARDWOOD'
#  'MAPLE' 'OAK' 'DOUGLAS_FIR' 'SPRUCE' 'CEDAR' 'PONDEROSA_PINE'
#  'OTHER_SOFTWOOD' 'LODGEPOLE_PINE' 'HEMLOCK' 'RED_ALDER' 'TANOAK'
#  'JUNIPER' 'LARCH' 'fvs_year' 'year_diff' 'returns_per_m2']

# %% [markdown]
# ## Filter out some of the training data
# We can exclude some of the training data based on how far separated the inventory data (interpolated using FVS simulations) is from the year the lidar was collected. Similarly, we can screen out training examples that had relatively low density of lidar returns.

# %%
df['year_diff'] = abs(df['fvs_year'] - df['lidar_year']).astype(int)

# %%
len(df.loc[df['year_diff'] >= 5])
# Out:
# 224

# %%
df = df.loc[df['year_diff'] < 5]

# %%
len(df.loc[df['returns_per_m2'] < 4.0])
# Out:
# 93

# %%
df = df.loc[df['returns_per_m2'] >= 4.0]

# %%
lidar_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['topht'].values.reshape(-1, 1))

lidar_height_transformed = lidar_height_transformer.transform(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformed = fvs_height_transformer.transform(df['topht'].values.reshape(-1, 1))

diff_height_transformed = abs(lidar_height_transformed - fvs_height_transformed)


fig, axs = plt.subplots(1,2, figsize=(15,5))

# select outliers
OUTLIER_THRESH = 3.05
outliers = diff_height_transformed > OUTLIER_THRESH
outliers = np.logical_or(outliers, (df['height_95_percentile'] > 275/3.28084).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 60/3.28084) & (df['topht'] > 105)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 10/3.28084) & (df['topht'] > 40)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])/df['topht']) > 1.0).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])) > 100).values.reshape(-1, 1))

axs[0].hist(diff_height_transformed, bins=20)
axs[0].axvline(OUTLIER_THRESH, color='k')
axs[0].set_title('Differences between transformed lidar and fvs canopy height')

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[~outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[~outliers],
            s=1, label='Inliers (n={:,d})'.format((~outliers).sum()))

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[outliers],
            s=5, label='Outliers (n={:,d})'.format(outliers.sum()))

axs[1].set_xlabel('Lidar Canopy Height, ft')
axs[1].set_ylabel('FVS Canopy Height, ft')
axs[1].plot([0,400],[0,400], color='k', lw=2, label='1:1')
axs[1].set_xlim(-10, 400)
axs[1].set_ylim(-10, 400)
axs[1].set_aspect('equal')
axs[1].legend();

# %%
# filter out the height outliers
df = df[~outliers]

# %% [markdown]
# ## Inspect how many samples we have for different years, regions, etc.

# %%
df.groupby(by=['lidar_year'])[['uuid']].count().rename({'uuid':'count'}, axis=1)
# Out:
#             count
# lidar_year
# 2008          686
# 2009           12
# 2010            2
# 2011           76
# 2012          527
# 2013          199
# 2014          298
# 2015          475
# 2016          478
# 2017          165
# 2018           25

# %%
pd.pivot_table(df, 
               values='uuid', 
               aggfunc='count', 
               index=['meas_yr'], 
               columns=['lidar_year'], 
               fill_value=0)
# Out:
# lidar_year  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# meas_yr
# 2010         395     0     0     0     2     0     2     6     0     0     0
# 2011         291     0     0     0     1     0     2     1     0     0     0
# 2013           0    12     0    33   345    45     3     6    13    25     2
# 2014           0     0     2    26   124    39    28    38    83    34     0
# 2015           0     0     0    17    16    12    15   122    95    24     2
# 2016           0     0     0     0    39    73    39   214    63    32    21
# 2017           0     0     0     0     0    30   163    47    78    40     0
# 2018           0     0     0     0     0     0    46    41   146    10     0

# %%
ecoreg_counts = df.groupby(by=['ecoregion3'])[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
ecoreg_counts
# Out:
#                                                     uuid  lidar_acq  \
# ecoregion3
# blue_mountains                                        29          2
# cascades                                             480         21
# coast_range                                         1399         18
# columbia_plateau                                       4          3
# eastern_cascades_slopes_and_foothills                124          9
# klamath_mountains_california_high_north_coast_r...   190          6
# north_cascades                                       339         18
# northern_rockies                                      68          4
# puget_lowland                                        106         13
# willamette_valley                                     41          2
#
#                                                     lidar_year  plot_size_ac
# ecoregion3
# blue_mountains                                               2             1
# cascades                                                     9             3
# coast_range                                                  9             2
# columbia_plateau                                             3             1
# eastern_cascades_slopes_and_foothills                        5             2
# klamath_mountains_california_high_north_coast_r...           5             2
# north_cascades                                               6             2
# northern_rockies                                             3             1
# puget_lowland                                                7             1
# willamette_valley                                            2             2

# %%
df[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
# Out:
# uuid            2780
# lidar_acq         67
# lidar_year        11
# plot_size_ac       3
# dtype: int64

# %% [markdown]
# ## Available features
# First, we'll use one-hot encoding for categorical features

# %%
# convert agency, ecoregion, and lidar acquisition into one-hot encoded set of variables
df = pd.get_dummies(df, prefix='agency', columns=['agency'])
# df = pd.get_dummies(df, prefix='eco', columns=['ecoregion3'])
# df = pd.get_dummies(df, prefix='acq', columns=['lidar_acq'])

# %%
# convert tcuft into hundreds of cubic feet per acre (CCF/ac)
df['ccf_ac'] = df['tcuft'] / 100

# %% [markdown]
# The different types of predictor variables we can use to predict a forest attribute, including climate, lidar-derived, soil, and satellite imagery.

# %%
CLIM_COLS = ['mat', 'mwmt', 'mcmt', 'td', 'map', 'msp', 'ahm', 'shm', 
             'dd_0', 'dd5', 'dd_18', 'dd18', 'nffd', 'bffp', 'effp', 
             'ffp', 'pas', 'emt', 'ext', 'eref', 'cmd', 'rh']

LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
       'strat1_return-proportion', 'strat2_return-proportion',
       'strat3_return-proportion', 'strat4_return-proportion',
       'strat5_return-proportion', 'strat0_intensity-median',
       'strat1_intensity-median', 'strat2_intensity-median',
       'strat3_intensity-median', 'strat4_intensity-median',
       'strat5_intensity-median', 'height_05-percentile',
       'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
       'height_95_percentile', 'height_max', 'cover', 'potential_volume',
       'stddev_height', 'surface_area_ratio', 'surface_volume',
       'surface_volume_ratio', 'aspect', 'elevation', 'overall_curvature',
       'plan_curvature', 'profile_curvature', 'slope', 'solar_radiation_index', 
              'kurtosis', 'skewnewss']

USE_LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
                  'strat1_return-proportion', 'strat2_return-proportion',
                  'strat3_return-proportion', 'strat4_return-proportion',
                  'strat5_return-proportion', 'height_05-percentile',
                  'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
                  'height_95_percentile', 'cover', 'potential_volume',
                  'stddev_height', 'surface_volume',
                  'aspect', 'elevation', 'slope', 'solar_radiation_index',
                  'kurtosis', 'skewness']

SOIL_COLS = ['bulk_dens', 'soil_depth', 'pct_clay_surf', 'pct_rock_surf', 'pct_sand_surf']

LANDSAT_COLS = ['green', 'blue', 'red', 'nir', 'endvi', 'ndvi', 'savi',
                'swir1', 'swir2', 'wetness', 'greenness', 'brightness']

AGENCY_COLS = ['agency_BLM', 'agency_USFS', 'agency_WADNR']

# ECOREGIONS = [col for col in df.columns if col.startswith('eco_')]

# %% [markdown]
# ## Selecting initial features and targets
# This is the first step in determining what features we want to use, and what we want to predict. Later, we can still apply some procedures to choose a subset of these features to make simpler models.

# %%
X_COLS = USE_LIDAR_COLS + ['ecoregion3'] 
Y_COLS = ['ccf_ac']

# %%
USE_REGIONS = ['blue_mountains', 'coast_range', 'north_cascades', 'cascades',
               'klamath_mountains_california_high_north_coast_range', 
               'eastern_cascades_slopes_and_foothills', 'northern_rockies',
               'puget_lowland', 'willamette_valley']
display(df.groupby('ecoregion3')[Y_COLS].mean().round(1).loc[USE_REGIONS])
display(df[Y_COLS].mean().round(1))
# Out:
#                                                     ccf_ac
# ecoregion3
# blue_mountains                                        14.7
# coast_range                                           95.4
# north_cascades                                        57.0
# cascades                                              75.8
# klamath_mountains_california_high_north_coast_r...    74.5
# eastern_cascades_slopes_and_foothills                 43.0
# northern_rockies                                      27.3
# puget_lowland                                         63.6
# willamette_valley                                     95.2
# ccf_ac    79.5
# dtype: float64

# %% [markdown]
# ## Split the data into training and testing sets
# Since some plot_ids have multiple observations, we want all observations for each plot_id to fall entirely in train_set or entirely the training or testing sets because these samples are definitely not independent.

# %%
# a dataframe with unique plot ids
splits = pd.DataFrame(pd.unique(df['uuid']), columns=['uuid']).set_index('uuid')

# randomly assign each plot-id to train(0) or test(1) sets
np.random.seed(127)
splits['train0_test1'] = np.random.choice(2,
                                          size=len(splits),
                                          p=[0.8,0.2])

# add set assignments to the dataframe
df['train0_test1'] = splits.loc[df['uuid']]['train0_test1'].values

# %%
train_plots = df.loc[df['train0_test1'] == 0]
test_plots = df.loc[df['train0_test1'] == 1]
len(train_plots), len(test_plots)
# Out:
# (2769, 704)

# %%
x_train, x_test = train_plots[X_COLS], test_plots[X_COLS]
y_train, y_test = train_plots[Y_COLS], test_plots[Y_COLS]

# %% [markdown]
# ## Standardize features
# Scale all predictive features to have 0 mean and unit variance (subtracting mean, dividing by standard deviation).

# %%
x_scaler = StandardScaler()
x_scaler.fit(df[X_COLS].drop(['ecoregion3'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Consider a few transformations for the target variable

# %%
fig, axs = plt.subplots(1,6, figsize=(15,2.5))

quantile = QuantileTransformer(output_distribution='normal', random_state=127)
box_cox = PowerTransformer(method='box-cox')
yeo_johnson = PowerTransformer(method='yeo-johnson')

VALS = [y_train.values,
        np.log1p(y_train.values),
        np.sqrt(y_train.values),
        quantile.fit_transform(y_train.values),
        box_cox.fit_transform(y_train.values + 1e-9),
        yeo_johnson.fit_transform(y_train.values)]

TITLES = ['Raw', 'Log', 'SQRT', 'Quantile', 'Box-Cox', 'Yeo-Johnson']
SHAPIRO_ps = [shapiro(vals)[-1] for vals in VALS]

for i, vals in enumerate(VALS):
    axs.ravel()[i].hist(vals, bins=20)
    axs.ravel()[i].set_title(TITLES[i])
    
plt.show();

# %%
# identify the closest to normally-distributed
TITLES[np.array(SHAPIRO_ps).argmax()]
# Out:
# 'Box-Cox'

# %%
# choose your transformer here
transformer = quantile

# %%
transformer.fit(df[Y_COLS])
y_train.loc[:,Y_COLS], y_test.loc[:,Y_COLS] = transformer.transform(y_train), transformer.transform(y_test)
# Out:
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Split datasets by ecoregion
# We want to explore model transferability between regions, so we'll train models independently on subsets of the data within a single ecoregion, as well as a model that is trained on all available ecoregions.

# %%
ecoregions = [reg for reg in pd.unique(df.ecoregion3) if ecoreg_counts.loc[reg]['uuid'] > 20]

eco_train_idx = [x_train.loc[x_train.ecoregion3 == eco].index.values for eco in ecoregions]
eco_test_idx = [x_test.loc[x_test.ecoregion3 == eco].index.values for eco in ecoregions]

eco_xtrain_dfs = [x_train.loc[x_train.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytrain_dfs = [y_train.loc[idx].values.ravel() for idx in eco_train_idx]
eco_xtest_dfs = [x_test.loc[x_test.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytest_dfs = [y_test.loc[idx].values.ravel() for idx in eco_test_idx]

# append a "global" model that contains data from all ecoregions
ecoregions.append('all')
ecoregion_names = ['_'.join(x.split('_')[0:2]) for x in ecoregions]
eco_xtrain_dfs.append(x_train.drop(['ecoregion3'], axis=1))
eco_ytrain_dfs.append(y_train.values.ravel())
eco_xtest_dfs.append(x_test.drop(['ecoregion3'], axis=1))
eco_ytest_dfs.append(y_test.values.ravel())

# %% [markdown]
# ## Scoring
# We'll use Root Mean Square Error to evaluate model performance.

# %%
def rmse(pred, obs):
    # use our transformer to calculate RMSE on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return np.sqrt((np.square(obs-pred)).mean())

# %%
def nrmse(pred, obs):
    # use our transformer to calculate percent RMSE on the original data scale
    this_rmse = rmse(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return this_rmse/obs.mean()

# %%
def mae(pred, obs):
    # use our transformer to calculate mean absolute error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean()

# %%
def mape(pred, obs):
    # use our transformer to calculate mean average percent error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean() / obs.mean()

# %%
def bias(pred, obs):
    # use our transformer to calculate mean bias on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return (pred - obs).mean()

# %%
def rel_bias(pred, obs):
    # use our transformer to calculate mean relative bias on the original data scale
    this_bias = bias(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1))  
    
    return this_bias/obs.mean()

# %% [markdown]
# This helper function will calculate RMSE scores for each regionally-trained model and the global model on each ecoregion.

# %%
def get_score_df(models, metric=rmse, feature_selectors=None):
    regional_scores = []
    global_scores = []
    counts = []
    
    for i, mod in enumerate(models):
        X_test = x_scaler.transform(eco_xtest_dfs[i])
        if feature_selectors:
            X_test = feature_selectors[i].transform(X_test)
        y_test = eco_ytest_dfs[i]
        reg_score = metric(mod.predict(X_test), y_test)
        regional_scores.append(reg_score.round(3))
        
        if feature_selectors:
            X_test = x_scaler.transform(eco_xtest_dfs[i])
            X_test = feature_selectors[-1].transform(X_test)
        glob_score = metric(models[-1].predict(X_test), y_test)
        global_scores.append(glob_score.round(3))
        count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
        counts.append(count)
        
    data = list(zip(regional_scores, global_scores, counts))
    res_df = pd.DataFrame(data=data,
                          columns=['regional_model', 'global_model', 'n'],
                          index=ecoregion_names)
    
    return res_df

# %% [markdown]
# ## Fit some models
# For each type of model, we'll employ cross-validation to tune model hyperparameters, generating a tuned model for each ecoregion as well as a tuned model using all training data. We'll work our way through:
#
# #### ElasticNet Regression
# Linear model that employs a mix of L1 and L2 regularization to penalize model complexity
#
# #### LASSO Regression
# Linear model that employs L1 regularization to penalize model complexity. We'll also work with a feature-selection process to fit models capped to an explicitly-predefined number of features.
#
# #### K-Nearest Neighbor Regression
#
# #### Random Forest Regression
#
# #### Gradient Boosting Trees Regression
#
# #### Support Vector Machine Regression

# %% [markdown]
# ## ElasticNet (Linear Model)

# %%
best_lms = []

for i in range(len(ecoregions)):
    lm = ElasticNetCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    lm.fit(X, y)
    best_lms.append(lm)

# %%
elastic_res = get_score_df(best_lms)
elastic_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              6.460         7.717   104
# coast_range                52.661        51.336  1580
# north_cascades             31.857        34.660   443
# cascades                   28.199        28.001   613
# klamath_mountains          31.930        28.886   275
# eastern_cascades           14.449        15.285   203
# northern_rockies           11.995         6.465    83
# puget_lowland              20.098        19.320   122
# willamette_valley          34.425        43.278    41
# all                        39.920        39.920  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lms])
count_nonzero = [(~np.isclose(coef, 0, atol=1e-3)).sum() for coef in coefs]
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.029
# north_cascades                                             -0.016
# cascades                                                     0.01
# klamath_mountains_california_high_north_coast_r...             --
# eastern_cascades_slopes_and_foothills                       0.002
# northern_rockies                                            0.087
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                       -0.042
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                -0.044
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.069
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.027
# coast_range                                                          -0.023
# north_cascades                                                           --
# cascades                                                             -0.012
# klamath_mountains_california_high_north_coast_r...                    -0.05
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                     -0.011
# puget_lowland                                                          -0.1
# willamette_valley                                                        --
# all                                                                   -0.01
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                              0.049
# klamath_mountains_california_high_north_coast_r...                   -0.077
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.121
# puget_lowland                                                            --
# willamette_valley                                                    -0.019
# all                                                                  -0.002
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.004
# coast_range                                                           0.025
# north_cascades                                                           --
# cascades                                                              0.076
# klamath_mountains_california_high_north_coast_r...                    0.041
# eastern_cascades_slopes_and_foothills                                 0.059
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.119
# coast_range                                                           0.047
# north_cascades                                                        0.046
# cascades                                                              0.065
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                         0.035
# willamette_valley                                                     0.003
# all                                                                   0.022
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.111
# north_cascades                                                           --
# cascades                                                              0.011
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     0.076
# all                                                                   0.001
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.029
# north_cascades                                                       --
# cascades                                                         -0.016
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                        0.02
# north_cascades                                                    0.057
# cascades                                                          0.065
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                 0.079
# all                                                               0.047
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                       --  ...
# coast_range                                                      -0.047  ...
# north_cascades                                                    0.014  ...
# cascades                                                          0.012  ...
# klamath_mountains_california_high_north_coast_r...                0.051  ...
# eastern_cascades_slopes_and_foothills                              0.24  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                        --  ...
# willamette_valley                                                 0.012  ...
# all                                                                  --  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                      0.146               --
# coast_range                                         0.097              0.1
# north_cascades                                      0.152            0.156
# cascades                                               --            0.045
# klamath_mountains_california_high_north_coast_r...  0.138               --
# eastern_cascades_slopes_and_foothills               0.049            0.102
# northern_rockies                                    0.018               --
# puget_lowland                                       0.054               --
# willamette_valley                                      --            0.089
# all                                                 0.125             0.05
#
#                                                    stddev_height  \
# blue_mountains                                             0.024
# coast_range                                               -0.055
# north_cascades                                                --
# cascades                                                   0.041
# klamath_mountains_california_high_north_coast_r...            --
# eastern_cascades_slopes_and_foothills                      0.014
# northern_rockies                                          -0.122
# puget_lowland                                                 --
# willamette_valley                                             --
# all                                                           --
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --  0.005
# coast_range                                                 0.127  0.013
# north_cascades                                                 --     --
# cascades                                                    0.196 -0.015
# klamath_mountains_california_high_north_coast_r...             --     --
# eastern_cascades_slopes_and_foothills                          -- -0.022
# northern_rockies                                            0.131     --
# puget_lowland                                               0.187     --
# willamette_valley                                           0.101     --
# all                                                         0.138     --
#
#                                                    elevation  slope  \
# blue_mountains                                            --     --
# coast_range                                              0.1 -0.035
# north_cascades                                         0.042     --
# cascades                                               0.204 -0.051
# klamath_mountains_california_high_north_coast_r...     0.004 -0.008
# eastern_cascades_slopes_and_foothills                  0.057 -0.103
# northern_rockies                                       0.008     --
# puget_lowland                                             --     --
# willamette_valley                                         --     --
# all                                                    0.099 -0.008
#
#                                                    solar_radiation_index  \
# blue_mountains                                                        --
# coast_range                                                        0.063
# north_cascades                                                        --
# cascades                                                           0.014
# klamath_mountains_california_high_north_coast_r...                 0.041
# eastern_cascades_slopes_and_foothills                             -0.018
# northern_rockies                                                      --
# puget_lowland                                                         --
# willamette_valley                                                     --
# all                                                                0.034
#
#                                                    kurtosis skewness
# blue_mountains                                           --    -0.22
# coast_range                                          -0.147   -0.255
# north_cascades                                           --   -0.148
# cascades                                             -0.134   -0.201
# klamath_mountains_california_high_north_coast_r...       --   -0.057
# eastern_cascades_slopes_and_foothills                    --   -0.057
# northern_rockies                                         --   -0.187
# puget_lowland                                            --   -0.256
# willamette_valley                                        --       --
# all                                                   0.008   -0.215
#
# [10 rows x 22 columns]

# %% [markdown]
# ## LASSO (Linear Model)
# Starting with implicit feature selection via L1 regularization of coefficients.

# %%
best_lassos = []

for i in range(len(ecoregions)):
    lasso = LassoCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000, n_alphas=1000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    lasso.fit(X, y)
    best_lassos.append(lasso)

# %%
lasso_res = get_score_df(best_lassos)
lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              6.540         8.354   104
# coast_range                52.667        51.400  1580
# north_cascades             35.026        34.690   443
# cascades                   28.182        27.969   613
# klamath_mountains          31.700        28.788   275
# eastern_cascades           14.372        14.972   203
# northern_rockies           12.192         6.781    83
# puget_lowland              19.385        19.174   122
# willamette_valley          31.085        40.319    41
# all                        39.921        39.921  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lassos])
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.028
# north_cascades                                             -0.028
# cascades                                                     0.01
# klamath_mountains_california_high_north_coast_r...         -0.006
# eastern_cascades_slopes_and_foothills                       0.003
# northern_rockies                                            0.083
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                       -0.103
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                -0.032
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.046
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.016
# coast_range                                                          -0.023
# north_cascades                                                           --
# cascades                                                             -0.013
# klamath_mountains_california_high_north_coast_r...                   -0.031
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                     -0.007
# puget_lowland                                                        -0.057
# willamette_valley                                                        --
# all                                                                  -0.005
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                              0.044
# klamath_mountains_california_high_north_coast_r...                   -0.078
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.135
# puget_lowland                                                            --
# willamette_valley                                                    -0.008
# all                                                                  -0.001
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.003
# coast_range                                                           0.022
# north_cascades                                                         0.02
# cascades                                                              0.069
# klamath_mountains_california_high_north_coast_r...                    0.055
# eastern_cascades_slopes_and_foothills                                 0.063
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.117
# coast_range                                                           0.044
# north_cascades                                                        0.029
# cascades                                                              0.057
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                         0.008
# willamette_valley                                                        --
# all                                                                   0.018
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.103
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     0.033
# all                                                                      --
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.029
# north_cascades                                                       --
# cascades                                                         -0.015
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                               0.002
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                       0.019
# north_cascades                                                    0.089
# cascades                                                          0.059
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                 0.099
# all                                                               0.037
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                       --  ...
# coast_range                                                      -0.035  ...
# north_cascades                                                       --  ...
# cascades                                                             --  ...
# klamath_mountains_california_high_north_coast_r...                0.015  ...
# eastern_cascades_slopes_and_foothills                              0.27  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                        --  ...
# willamette_valley                                                    --  ...
# all                                                                  --  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                       0.14               --
# coast_range                                         0.095            0.097
# north_cascades                                      0.033            0.038
# cascades                                               --            0.028
# klamath_mountains_california_high_north_coast_r...  0.152               --
# eastern_cascades_slopes_and_foothills               0.056            0.033
# northern_rockies                                    0.005               --
# puget_lowland                                          --               --
# willamette_valley                                      --               --
# all                                                 0.115               --
#
#                                                    stddev_height  \
# blue_mountains                                                --
# coast_range                                               -0.054
# north_cascades                                                --
# cascades                                                    0.04
# klamath_mountains_california_high_north_coast_r...        -0.063
# eastern_cascades_slopes_and_foothills                      0.017
# northern_rockies                                          -0.135
# puget_lowland                                                 --
# willamette_valley                                             --
# all                                                           --
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --  0.002
# coast_range                                                 0.127  0.013
# north_cascades                                                 --     --
# cascades                                                     0.21 -0.015
# klamath_mountains_california_high_north_coast_r...             --     --
# eastern_cascades_slopes_and_foothills                          -- -0.024
# northern_rockies                                            0.111     --
# puget_lowland                                               0.165     --
# willamette_valley                                           0.081     --
# all                                                         0.172     --
#
#                                                    elevation  slope  \
# blue_mountains                                            --     --
# coast_range                                            0.099 -0.034
# north_cascades                                         0.129     --
# cascades                                               0.205  -0.05
# klamath_mountains_california_high_north_coast_r...     0.043 -0.049
# eastern_cascades_slopes_and_foothills                  0.061 -0.104
# northern_rockies                                       0.009     --
# puget_lowland                                             --     --
# willamette_valley                                         --     --
# all                                                     0.11 -0.016
#
#                                                    solar_radiation_index  \
# blue_mountains                                                        --
# coast_range                                                        0.063
# north_cascades                                                        --
# cascades                                                           0.013
# klamath_mountains_california_high_north_coast_r...                 0.046
# eastern_cascades_slopes_and_foothills                             -0.018
# northern_rockies                                                      --
# puget_lowland                                                         --
# willamette_valley                                                     --
# all                                                                0.037
#
#                                                    kurtosis skewness
# blue_mountains                                           --   -0.231
# coast_range                                          -0.137   -0.262
# north_cascades                                        0.072   -0.274
# cascades                                             -0.105    -0.22
# klamath_mountains_california_high_north_coast_r...       --   -0.075
# eastern_cascades_slopes_and_foothills                    --   -0.068
# northern_rockies                                         --    -0.18
# puget_lowland                                            --   -0.372
# willamette_valley                                        --       --
# all                                                   0.045   -0.271
#
# [10 rows x 22 columns]

# %% [markdown]
# Now we'll explicitly define the maximum number of features to use for fitting a linear model. We'll trim features by iteratively increasing a threshold for coefficients using LASSO regression

# %%
MAX_FEATURES = 5
sfms = [] # transformers that filter X features
trimmed_lassos = [] # re-fit lasso regressions on the subset of the features

for i, lasso in enumerate(best_lassos):
    lasso = deepcopy(lasso)
    sfm = SelectFromModel(lasso, threshold=0.001)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    Y = (eco_ytrain_dfs[i].ravel())
    sfm.fit(X, Y)
    n_features = sfm.transform(X).shape[1]

    # Reset the threshold till the number of features equals two.
    # Note that the attribute can be set directly instead of repeatedly
    # fitting the metatransformer.
    while n_features > MAX_FEATURES:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    
    sfms.append(sfm)
    try:
        trimmed_lassos.append(lasso.fit(sfm.transform(X), Y))
    except ValueError:
        print(ecoregion_names[i])
        raise

# %%
coefs = []
for i in range(len(ecoregions)):
    cols = np.zeros(eco_xtest_dfs[i].columns.shape)
    cols[sfms[i].get_support()] = trimmed_lassos[i].coef_
    coefs.append(cols)
    
coefs = np.array(coefs)

coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                       -0.178
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.073
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.077
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                        -0.086
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.133
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.149
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.167
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                         0.012
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                    0.125
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                 0.109
# all                                                                  --
#
#                                                    height_50-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                             0.354
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_75-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                          0.044
# klamath_mountains_california_high_north_coast_r...                0.134
# eastern_cascades_slopes_and_foothills                             0.035
# northern_rockies                                                  0.593
# puget_lowland                                                        --
# willamette_valley                                                 0.425
# all                                                                  --
#
#                                                    height_95_percentile  \
# blue_mountains                                                    0.397
# coast_range                                                       0.524
# north_cascades                                                    0.767
# cascades                                                          0.552
# klamath_mountains_california_high_north_coast_r...                0.486
# eastern_cascades_slopes_and_foothills                             0.595
# northern_rockies                                                  0.587
# puget_lowland                                                     0.776
# willamette_valley                                                 0.293
# all                                                               0.514
#
#                                                     cover stddev_height  \
# blue_mountains                                      0.143            --
# coast_range                                            --            --
# north_cascades                                         --            --
# cascades                                               --            --
# klamath_mountains_california_high_north_coast_r...  0.258            --
# eastern_cascades_slopes_and_foothills                  --            --
# northern_rockies                                       --        -0.277
# puget_lowland                                          --            --
# willamette_valley                                      --            --
# all                                                 0.139            --
#
#                                                    surface_volume elevation  \
# blue_mountains                                                 --        --
# coast_range                                                  0.25        --
# north_cascades                                                 --     0.098
# cascades                                                    0.217     0.231
# klamath_mountains_california_high_north_coast_r...             --        --
# eastern_cascades_slopes_and_foothills                          --        --
# northern_rockies                                               --        --
# puget_lowland                                                  --        --
# willamette_valley                                           0.121        --
# all                                                         0.253     0.111
#
#                                                     slope skewness
# blue_mountains                                         --   -0.233
# coast_range                                            --   -0.388
# north_cascades                                         --   -0.147
# cascades                                               --   -0.343
# klamath_mountains_california_high_north_coast_r...     --   -0.118
# eastern_cascades_slopes_and_foothills              -0.111    -0.25
# northern_rockies                                       --   -0.178
# puget_lowland                                          --   -0.593
# willamette_valley                                      --       --
# all                                                    --   -0.223

# %%
trimmed_lasso_res = get_score_df(trimmed_lassos, feature_selectors=sfms)
trimmed_lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              6.426         8.154   104
# coast_range                51.326        50.733  1580
# north_cascades             37.080        36.186   443
# cascades                   28.562        28.452   613
# klamath_mountains          33.537        30.188   275
# eastern_cascades           14.704        14.605   203
# northern_rockies           10.100         7.398    83
# puget_lowland              20.027        20.336   122
# willamette_valley          28.493        45.558    41
# all                        39.931        39.931  3473

# %% [markdown]
# ## K-Nearest Neighbors Regression

# %%
# Set the parameters by cross-validation
knn_params = {'n_neighbors': [1,2,3,4,5,10,20],
              'weights': ['uniform', 'distance'],
              'metric': ['minkowski', 'manhattan']}


knn_gs = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=knn_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_knns = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    knn_gs.fit(X, y)
    best_fit = knn_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_knns.append(best_fit)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    1.9s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    2.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.7s finished

# %%
knn_res = get_score_df(best_knns)
knn_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              6.789         8.845   104
# coast_range                56.830        55.533  1580
# north_cascades             25.171        30.250   443
# cascades                   30.103        29.466   613
# klamath_mountains          32.007        25.982   275
# eastern_cascades           15.839        15.817   203
# northern_rockies           17.581        10.425    83
# puget_lowland              24.859        21.916   122
# willamette_valley          67.514        61.646    41
# all                        42.167        42.167  3473

# %% [markdown]
# ## Random Forest Regression

# %%
# Set the parameters by cross-validation
rf_params = {'n_estimators': [100, 500, 1000, 5000],
             'max_features': ['sqrt'],
             'max_depth': [3, 5, 10, 25, 50],
             'min_samples_leaf': [1,2,4],
             'bootstrap': [True]}


rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=rf_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_rfs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    rf_gs.fit(X, y)
    best_fit = rf_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_rfs.append(best_fit)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    8.8s remaining:    4.7s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   17.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   39.0s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.8s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   12.5s remaining:    6.7s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   28.0s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   11.0s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   25.9s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.2s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   25.0s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    8.1s remaining:    4.4s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   20.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   11.6s remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.4s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   20.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  1.4min finished

# %%
rf_res = get_score_df(best_rfs)
rf_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              6.420         8.339   104
# coast_range                54.247        53.293  1580
# north_cascades             26.856        27.631   443
# cascades                   28.955        28.278   613
# klamath_mountains          28.939        27.469   275
# eastern_cascades           15.511        15.743   203
# northern_rockies           17.907         6.541    83
# puget_lowland              18.975        19.974   122
# willamette_valley          63.807        53.746    41
# all                        40.386        40.386  3473

# %%
### Employing feature selection to try and improve random forest regression

# %%
importances = best_rfs[-1].feature_importances_
indices = np.argsort(importances)[::-1]
features = eco_xtrain_dfs[-1].columns[indices]

# Print the feature ranking
print("Feature ranking:")

for f in range(eco_xtrain_dfs[-1].shape[1]):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. height_75-percentile (0.157081)
# 2. surface_volume (0.133228)
# 3. height_95_percentile (0.118333)
# 4. height_50-percentile (0.101110)
# 5. potential_volume (0.098815)
# 6. strat5_return-proportion (0.078788)
# 7. strat4_return-proportion (0.041316)
# 8. cover (0.037021)
# 9. skewness (0.033726)
# 10. height_25-percentile (0.033642)
# 11. strat3_return-proportion (0.029329)
# 12. strat0_return-proportion (0.024716)
# 13. stddev_height (0.018036)
# 14. kurtosis (0.017706)
# 15. strat2_return-proportion (0.017472)
# 16. strat1_return-proportion (0.012502)
# 17. elevation (0.012010)
# 18. solar_radiation_index (0.008142)
# 19. slope (0.007711)
# 20. aspect (0.007346)
# 21. returns_per_m2 (0.007342)
# 22. height_05-percentile (0.004626)

# %% [markdown]
# ## Gradient Boosting Trees Regression

# %%
# Set the parameters by cross-validation
gb_params = {'n_estimators': [100, 500, 1000, 5000],
             'learning_rate': [0.01, 0.1],
             'max_depth': [2, 3, 4, 5, 10],
             'max_features': ['sqrt'] 
            }

gb_gs = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=gb_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_gbs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    gb_gs.fit(X, y)
    best_fit = gb_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_gbs.append(best_fit)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    4.5s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.6s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   14.3s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   16.6s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.9s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.4s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   12.9s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.2s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.9s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.5s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.9s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.7s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.4s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.1s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.1s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.3s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   38.3s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   40.5s finished

# %%
gb_res = get_score_df(best_gbs)
gb_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              7.212         9.174   104
# coast_range                54.729        53.710  1580
# north_cascades             27.434        26.031   443
# cascades                   28.612        27.539   613
# klamath_mountains          28.647        25.848   275
# eastern_cascades           14.876        16.047   203
# northern_rockies           21.171         5.817    83
# puget_lowland              21.029        20.425   122
# willamette_valley          64.557        49.372    41
# all                        40.274        40.274  3473

# %%
### Employing feature selection to try and improve gradient boosting regression

# %% [markdown]
# ## Support Vector Machines Regression

# %%
# Set the parameters by cross-validation
svm_params = {'kernel': ['linear', 'rbf'],
              'gamma': ['scale', 'auto'],
              'C': [0.1,1,10,100,1000]
              }

svm_gs = GridSearchCV(estimator=SVR(), param_grid=svm_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_svms = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    svm_gs.fit(X, y)
    best_fit = svm_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_svms.append(best_fit)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.3s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.5min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   19.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   37.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   44.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    7.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    6.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    6.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    1.5s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  5.7min finished

# %%
svm_res = get_score_df(best_svms)
svm_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              5.820         9.804   104
# coast_range                52.075        56.215  1580
# north_cascades             30.669        29.935   443
# cascades                   27.514        29.517   613
# klamath_mountains          29.896        27.541   275
# eastern_cascades           14.264        15.259   203
# northern_rockies            6.943         6.362    83
# puget_lowland              21.882        22.674   122
# willamette_valley          40.339        55.384    41
# all                        42.544        42.544  3473

# %%
### Employing feature selection to try and improve support vector regression

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

def scatter_graphs(model_dict):
    names = MODELS.keys()
    EXTEND_PCT = 0.10
    
    fig, axs = plt.subplots(len(ecoregion_names), len(names), 
                            sharex=True, sharey=True,
                            figsize=(11,15)
                           )
    
    all_obs = transformer.inverse_transform(eco_ytest_dfs[-1].reshape(-1,1))
    obs_min = all_obs.min()
    obs_max = all_obs.max()
    rng = obs_max - obs_min
        
    for i, ecoreg in enumerate(ecoregion_names):
        observed = transformer.inverse_transform(eco_ytest_dfs[i].reshape(-1,1))
        
        for j, name in enumerate(names):
            axs[0,j].set_title(name)
            axs[i,0].set_ylabel('\n'.join(ecoreg.split('_')).upper())
            axs[i,j].set_xlim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_ylim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_aspect('equal')
            
            if name == 'LASSO_{}'.format(MAX_FEATURES):
                predicted = MODELS[name][-1].predict(sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i])))
            else:
                predicted = MODELS[name][-1].predict(x_scaler.transform(eco_xtest_dfs[i]))
            
            predicted = transformer.inverse_transform(predicted.reshape(-1,1))
            axs[i,j].scatter(observed, predicted, s=0.5)
            axs[i,j].plot((obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng), 
                          (obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng),
                         color='k', lw=0.5)
            
    plt.tight_layout(pad=0.5)

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

scatter_graphs(MODELS)

# %% [markdown]
# ## View scores for regional and global models

# %%
MODEL_NAMES = ['ElasticNet', 'LASSO', 'LASSO_{}'.format(MAX_FEATURES), 'KNN', 'RF', 'GB', 'SVM']
BEST_MODELS = [best_lms, best_lassos, trimmed_lassos, best_knns, best_rfs, best_gbs, best_svms]

def compare_models(metric):
    score_dfs = []
    for name, best_models in list(zip(MODEL_NAMES, BEST_MODELS)):
        if name == 'LASSO_{}'.format(MAX_FEATURES):
            score_df = get_score_df(best_models, metric, sfms) 
            score_dfs.append(score_df)
        else:
            score_df = get_score_df(best_models, metric) 
            score_dfs.append(score_df)
        
    counts = np.array(score_dfs[-1]['n'].values)
    regional_data = np.array([df['regional_model'].values for df in score_dfs])
    global_data = np.array([df['global_model'].values for df in score_dfs])
    
    return regional_data, global_data, counts

# %%
def highlight_best(s):
    '''
    highlight the closest value to zero in a Series yellow.
    '''
    lowest_idx = abs(s).idxmin()
    return ['background-color: yellow' if idx==lowest_idx else '' for idx in s.index]

# %%
print('Regional Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, RMSE
# <style  type="text/css" >
#     #T_573f230c_551c_11ea_a752_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_573f230c_551c_11ea_a752_00505683952erow1_col2 {
#             background-color:  yellow;
#         }    #T_573f230c_551c_11ea_a752_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_573f230c_551c_11ea_a752_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_573f230c_551c_11ea_a752_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_573f230c_551c_11ea_a752_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_573f230c_551c_11ea_a752_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_573f230c_551c_11ea_a752_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_573f230c_551c_11ea_a752_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_573f230c_551c_11ea_a752_00505683952erow9_col0 {
#             background-color:  yellow;
#         }</style><table id="T_573f230c_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_573f230c_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >6.5</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >6.5</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >6.4</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >6.8</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >6.4</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >7.2</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >5.8</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_573f230c_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >52.7</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >52.7</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >51.3</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >56.8</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >54.2</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >54.7</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >52.1</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_573f230c_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >31.9</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >35.0</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >37.1</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >25.2</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >26.9</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >27.4</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >30.7</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_573f230c_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >28.2</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >28.2</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >28.6</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >30.1</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >29.0</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >28.6</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >27.5</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_573f230c_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >31.9</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >31.7</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >33.5</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >32.0</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >28.9</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >28.6</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >29.9</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_573f230c_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >14.4</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >14.4</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >14.7</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >15.8</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow5_col4" class="data row5 col4" >15.5</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow5_col5" class="data row5 col5" >14.9</td>
#                         <td id="T_573f230c_551c_11ea_a752_00505683952erow5_col6" cla

# %%
print('Regional Models, RMSE%')
regional_data, global_data, counts = compare_models(nrmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:.0%}", subset=regional_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, RMSE%
# <style  type="text/css" >
#     #T_594cfa0c_551c_11ea_a752_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow1_col2 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow9_col0 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow9_col1 {
#             background-color:  yellow;
#         }    #T_594cfa0c_551c_11ea_a752_00505683952erow9_col2 {
#             background-color:  yellow;
#         }</style><table id="T_594cfa0c_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_594cfa0c_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >45%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >46%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >45%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >48%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >45%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >51%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >41%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_594cfa0c_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >50%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >50%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >49%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >54%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >52%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >52%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >50%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_594cfa0c_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >54%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >59%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >63%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >43%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >45%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >46%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >52%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_594cfa0c_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >37%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >37%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >37%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >39%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >38%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >37%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >36%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_594cfa0c_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >42%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >42%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >44%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >42%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >38%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >38%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >39%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_594cfa0c_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >40%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >40%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >41%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >44%</td>
#                         <td id="T_594cfa0c_551c_11ea_a752_00505683952erow5_col4" class="data row5 col4" >43%</td>
#                         <t

# %%
print('Regional Models, Bias')
regional_data, global_data, counts = compare_models(bias)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .apply(highlight_best, axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, Bias
# <style  type="text/css" >
#     #T_5b3a7f42_551c_11ea_a752_00505683952erow0_col4 {
#             background-color:  yellow;
#         }    #T_5b3a7f42_551c_11ea_a752_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_5b3a7f42_551c_11ea_a752_00505683952erow2_col1 {
#             background-color:  yellow;
#         }    #T_5b3a7f42_551c_11ea_a752_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_5b3a7f42_551c_11ea_a752_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_5b3a7f42_551c_11ea_a752_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_5b3a7f42_551c_11ea_a752_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_5b3a7f42_551c_11ea_a752_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_5b3a7f42_551c_11ea_a752_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_5b3a7f42_551c_11ea_a752_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_5b3a7f42_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5b3a7f42_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >0.7</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >0.7</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >0.7</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >0.6</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >0.5</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >0.8</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >0.5</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_5b3a7f42_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >-11.5</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >-11.5</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >-12.0</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >-11.8</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >-11.3</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >-12.6</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >-11.0</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_5b3a7f42_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >-4.8</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >-1.0</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >-1.9</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >-4.7</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >-3.6</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >-4.5</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >-5.4</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_5b3a7f42_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >-6.5</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >-6.5</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >-6.5</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >-7.0</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >-7.4</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >-7.2</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >-6.2</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_5b3a7f42_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >-1.4</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >0.5</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >0.6</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >-5.3</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >-3.4</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >-3.7</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >0.3</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_5b3a7f42_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >-1.0</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >-0.9</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >0.4</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >-1.3</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow5_col4" class="data row5 col4" >-2.6</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow5_col5" class="data row5 col5" >-1.7</td>
#                         <td id="T_5b3a7f42_551c_11ea_a752_00505683952erow5_col6"

# %%
print('Regional Models, MAE')
regional_data, global_data, counts = compare_models(mae)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, MAE
# <style  type="text/css" >
#     #T_5d2cde12_551c_11ea_a752_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_5d2cde12_551c_11ea_a752_00505683952erow1_col2 {
#             background-color:  yellow;
#         }    #T_5d2cde12_551c_11ea_a752_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_5d2cde12_551c_11ea_a752_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_5d2cde12_551c_11ea_a752_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_5d2cde12_551c_11ea_a752_00505683952erow5_col5 {
#             background-color:  yellow;
#         }    #T_5d2cde12_551c_11ea_a752_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_5d2cde12_551c_11ea_a752_00505683952erow7_col1 {
#             background-color:  yellow;
#         }    #T_5d2cde12_551c_11ea_a752_00505683952erow8_col1 {
#             background-color:  yellow;
#         }    #T_5d2cde12_551c_11ea_a752_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_5d2cde12_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d2cde12_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >4.4</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >4.5</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >4.5</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >4.8</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >4.4</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >4.6</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >3.6</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_5d2cde12_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >30.7</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >30.6</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >30.3</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >32.8</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >31.2</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >31.6</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >30.3</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_5d2cde12_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >20.3</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >20.0</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >20.6</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >17.9</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >17.9</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >18.3</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >18.5</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_5d2cde12_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >19.2</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >19.2</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >19.4</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >19.4</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >19.1</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >19.0</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >19.0</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_5d2cde12_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >20.9</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >20.8</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >21.4</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >19.8</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >18.8</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >18.5</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >19.5</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_5d2cde12_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >8.9</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >8.8</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >9.1</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >10.1</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow5_col4" class="data row5 col4" >9.7</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow5_col5" class="data row5 col5" >8.6</td>
#                         <td id="T_5d2cde12_551c_11ea_a752_00505683952erow5_col6" class="d

# %%
print('Regional Models, MAPE')
regional_data, global_data, counts = compare_models(mape)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:.0%}", subset=regional_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, MAPE
# <style  type="text/css" >
#     #T_5f1d8d34_551c_11ea_a752_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow1_col2 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow2_col4 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow5_col5 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow7_col1 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow8_col1 {
#             background-color:  yellow;
#         }    #T_5f1d8d34_551c_11ea_a752_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_5f1d8d34_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f1d8d34_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >31%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >32%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >32%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >34%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >31%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >32%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_5f1d8d34_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >29%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >29%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >29%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >31%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >30%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >30%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >29%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_5f1d8d34_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >34%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >34%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >35%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >30%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >30%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >31%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >31%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_5f1d8d34_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_5f1d8d34_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >27%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >27%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >28%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >26%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >24%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >26%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_5f1d8d34_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >24%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >25%</td>
#                         <td id="T_5f1d8d34_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >28%</td>
#                         <td id="T_5f1

# %%
print('Global Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=global_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, RMSE
# <style  type="text/css" >
#     #T_611ca2c8_551c_11ea_a752_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_611ca2c8_551c_11ea_a752_00505683952erow1_col2 {
#             background-color:  yellow;
#         }    #T_611ca2c8_551c_11ea_a752_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_611ca2c8_551c_11ea_a752_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_611ca2c8_551c_11ea_a752_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_611ca2c8_551c_11ea_a752_00505683952erow5_col2 {
#             background-color:  yellow;
#         }    #T_611ca2c8_551c_11ea_a752_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_611ca2c8_551c_11ea_a752_00505683952erow7_col1 {
#             background-color:  yellow;
#         }    #T_611ca2c8_551c_11ea_a752_00505683952erow8_col1 {
#             background-color:  yellow;
#         }    #T_611ca2c8_551c_11ea_a752_00505683952erow9_col0 {
#             background-color:  yellow;
#         }</style><table id="T_611ca2c8_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_611ca2c8_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >7.7</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >8.4</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >8.2</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >8.8</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >8.3</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >9.2</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >9.8</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_611ca2c8_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >51.3</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >51.4</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >50.7</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >55.5</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >53.3</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >53.7</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >56.2</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_611ca2c8_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >34.7</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >34.7</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >36.2</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >30.2</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >27.6</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >26.0</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >29.9</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_611ca2c8_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >28.0</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >28.0</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >28.5</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >29.5</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >28.3</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >27.5</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >29.5</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_611ca2c8_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >28.9</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >28.8</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >30.2</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >26.0</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >27.5</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >25.8</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >27.5</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_611ca2c8_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >15.3</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >15.0</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >14.6</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >15.8</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow5_col4" class="data row5 col4" >15.7</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow5_col5" class="data row5 col5" >16.0</td>
#                         <td id="T_611ca2c8_551c_11ea_a752_00505683952erow5_col6" cla

# %%
print('Global Models, RMSE%')
regional_data, global_data, counts = compare_models(nrmse)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:.0%}", subset=global_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, RMSE%
# <style  type="text/css" >
#     #T_6315b9f2_551c_11ea_a752_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow1_col2 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow5_col2 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow7_col1 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow8_col1 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow9_col0 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow9_col1 {
#             background-color:  yellow;
#         }    #T_6315b9f2_551c_11ea_a752_00505683952erow9_col2 {
#             background-color:  yellow;
#         }</style><table id="T_6315b9f2_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6315b9f2_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >54%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >59%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >57%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >62%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >58%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >64%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >69%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_6315b9f2_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >49%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >49%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >48%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >53%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >51%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >51%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >53%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_6315b9f2_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >59%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >59%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >61%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >51%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >47%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >44%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >51%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_6315b9f2_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >36%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >36%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >37%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >38%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >37%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >36%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >38%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_6315b9f2_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >38%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >38%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >40%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >34%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >36%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >34%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >36%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_6315b9f2_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >42%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >41%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >40%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >44%</td>
#                         <td id="T_6315b9f2_551c_11ea_a752_00505683952erow5_col4" class="data row5 col4" >44%</td>
#                         <t

# %%
print('Global Models, Bias')
regional_data, global_data, counts = compare_models(bias)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=global_scores.columns[:-1])
 .apply(highlight_best, axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, Bias
# <style  type="text/css" >
#     #T_650bb612_551c_11ea_a752_00505683952erow0_col4 {
#             background-color:  yellow;
#         }    #T_650bb612_551c_11ea_a752_00505683952erow1_col4 {
#             background-color:  yellow;
#         }    #T_650bb612_551c_11ea_a752_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_650bb612_551c_11ea_a752_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_650bb612_551c_11ea_a752_00505683952erow4_col0 {
#             background-color:  yellow;
#         }    #T_650bb612_551c_11ea_a752_00505683952erow5_col5 {
#             background-color:  yellow;
#         }    #T_650bb612_551c_11ea_a752_00505683952erow6_col4 {
#             background-color:  yellow;
#         }    #T_650bb612_551c_11ea_a752_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_650bb612_551c_11ea_a752_00505683952erow8_col1 {
#             background-color:  yellow;
#         }    #T_650bb612_551c_11ea_a752_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_650bb612_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_650bb612_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >1.5</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >2.0</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >1.6</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >0.9</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >0.7</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >1.6</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >2.4</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_650bb612_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >-11.9</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >-11.8</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >-11.5</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >-11.3</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >-10.2</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >-10.8</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >-12.7</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_650bb612_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >-5.6</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >-4.9</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >-6.9</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >-4.6</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >-4.3</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >-4.1</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >-6.9</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_650bb612_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >-7.2</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >-6.4</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >-7.1</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >-7.7</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >-8.0</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >-6.0</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >-5.4</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_650bb612_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >-0.4</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >0.4</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >1.6</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >-6.0</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >-3.3</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >-2.0</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >-3.8</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_650bb612_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >-2.7</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >-2.1</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >-2.5</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >-0.4</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow5_col4" class="data row5 col4" >-1.9</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow5_col5" class="data row5 col5" >-0.3</td>
#                         <td id="T_650bb612_551c_11ea_a752_00505683952erow5_col6

# %%
print('Global Models, MAE')
regional_data, global_data, counts = compare_models(mae)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=global_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, MAE
# <style  type="text/css" >
#     #T_670b17fa_551c_11ea_a752_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_670b17fa_551c_11ea_a752_00505683952erow1_col1 {
#             background-color:  yellow;
#         }    #T_670b17fa_551c_11ea_a752_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_670b17fa_551c_11ea_a752_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_670b17fa_551c_11ea_a752_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_670b17fa_551c_11ea_a752_00505683952erow5_col1 {
#             background-color:  yellow;
#         }    #T_670b17fa_551c_11ea_a752_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_670b17fa_551c_11ea_a752_00505683952erow7_col1 {
#             background-color:  yellow;
#         }    #T_670b17fa_551c_11ea_a752_00505683952erow8_col1 {
#             background-color:  yellow;
#         }    #T_670b17fa_551c_11ea_a752_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_670b17fa_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_670b17fa_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >5.2</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >5.5</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >5.5</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >5.8</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >5.8</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >6.3</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >6.0</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_670b17fa_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >30.1</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >30.0</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >30.2</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >32.1</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >30.7</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >30.9</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >32.0</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_670b17fa_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >20.9</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >20.6</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >21.7</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >20.6</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >18.5</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >17.2</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >18.4</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_670b17fa_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >19.5</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >19.4</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >19.6</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >20.8</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >19.3</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >19.0</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >19.1</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_670b17fa_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >19.3</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >19.1</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >19.8</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >16.9</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >17.7</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >16.4</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >18.2</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_670b17fa_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >8.8</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >8.6</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >8.7</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >10.0</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow5_col4" class="data row5 col4" >9.6</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow5_col5" class="data row5 col5" >9.9</td>
#                         <td id="T_670b17fa_551c_11ea_a752_00505683952erow5_col6" class="d

# %%
print('Global Models, MAPE')
regional_data, global_data, counts = compare_models(mape)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:.0%}", subset=global_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, MAPE
# <style  type="text/css" >
#     #T_68fd85c0_551c_11ea_a752_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow1_col1 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow5_col1 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow7_col1 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow8_col1 {
#             background-color:  yellow;
#         }    #T_68fd85c0_551c_11ea_a752_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_68fd85c0_551c_11ea_a752_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68fd85c0_551c_11ea_a752_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow0_col0" class="data row0 col0" >37%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow0_col1" class="data row0 col1" >39%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow0_col2" class="data row0 col2" >38%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow0_col3" class="data row0 col3" >41%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow0_col4" class="data row0 col4" >41%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow0_col5" class="data row0 col5" >44%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow0_col6" class="data row0 col6" >42%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_68fd85c0_551c_11ea_a752_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow1_col0" class="data row1 col0" >29%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow1_col1" class="data row1 col1" >28%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow1_col2" class="data row1 col2" >29%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow1_col3" class="data row1 col3" >30%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow1_col4" class="data row1 col4" >29%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow1_col5" class="data row1 col5" >29%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow1_col6" class="data row1 col6" >30%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_68fd85c0_551c_11ea_a752_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow2_col0" class="data row2 col0" >35%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow2_col1" class="data row2 col1" >35%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow2_col2" class="data row2 col2" >37%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow2_col3" class="data row2 col3" >35%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow2_col4" class="data row2 col4" >31%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow2_col5" class="data row2 col5" >29%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow2_col6" class="data row2 col6" >31%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_68fd85c0_551c_11ea_a752_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow3_col0" class="data row3 col0" >25%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow3_col1" class="data row3 col1" >25%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow3_col2" class="data row3 col2" >26%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow3_col3" class="data row3 col3" >27%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow3_col4" class="data row3 col4" >25%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow3_col5" class="data row3 col5" >25%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow3_col6" class="data row3 col6" >25%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_68fd85c0_551c_11ea_a752_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow4_col0" class="data row4 col0" >25%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow4_col1" class="data row4 col1" >25%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow4_col2" class="data row4 col2" >26%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow4_col3" class="data row4 col3" >22%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow4_col4" class="data row4 col4" >23%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow4_col5" class="data row4 col5" >22%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow4_col6" class="data row4 col6" >24%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_68fd85c0_551c_11ea_a752_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow5_col0" class="data row5 col0" >24%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow5_col1" class="data row5 col1" >24%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow5_col2" class="data row5 col2" >24%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow5_col3" class="data row5 col3" >28%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow5_col4" class="data row5 col4" >26%</td>
#                         <td id="T_68fd85c0_551c_11ea_a752_00505683952erow5_col5" class="data row5 col5" >27%</td>

# %%
print('Global vs. Regional Models, ΔRMSE')
regional_data, global_data, counts = compare_models(rmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔRMSE
# <style  type="text/css" >
#     #T_6cdef0fc_551c_11ea_a752_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 57.9%, transparent 57.9%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.3%, transparent 61.3%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.8%, transparent 60.8%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.8%, transparent 62.8%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.0%, transparent 62.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.3%, transparent 62.3%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 74.9%, transparent 74.9%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.7%, orange 41.7%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.1%, orange 42.1%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.3%, orange 46.3%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, orange 41.9%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.0%, orange 44.0%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.6%, orange 43.6%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 75.9%, transparent 75.9%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 67.5%, transparent 67.5%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.9%, orange 47.9%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.4%, orange 44.4%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 81.7%, transparent 81.7%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.8%, transparent 54.8%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.2%, orange 41.2%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.4%, orange 45.4%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.8%, orange 48.8%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, orange 48.7%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.3%, orange 49.3%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.0%, orange 46.0%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.8%, orange 45.8%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, orange 43.3%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 62.5%, transparent 62.5%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.0%, orange 31.0%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.8%, orange 31.8%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 29.1%, orange 29.1%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.3%, orange 12.3%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.8%, orange 40.8%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.5%, orange 32.5%, orange 50.0%, transparent 50.0%);
#         }    #T_6cdef0fc_551c_11ea_a752_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  l

# %%
print('Global vs. Regional Models, ΔRMSE%')
regional_data, global_data, counts = compare_models(nrmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.2, vmax=0.2))
# Out:
# Global vs. Regional Models, ΔRMSE%
# <style  type="text/css" >
#     #T_6ed5d54c_551c_11ea_a752_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 72.0%, transparent 72.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 82.0%, transparent 82.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 80.5%, transparent 80.5%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 86.0%, transparent 86.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 83.7%, transparent 83.7%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 84.2%, transparent 84.2%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 100.0%, transparent 100.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.0%, orange 47.0%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.0%, orange 47.0%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, orange 48.5%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.0%, orange 47.0%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.5%, orange 47.5%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 59.7%, transparent 59.7%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.7%, transparent 61.7%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, orange 48.7%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.2%, orange 46.2%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 71.5%, transparent 71.5%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.2%, transparent 53.2%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.0%, orange 44.0%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.7%, orange 46.7%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.5%, orange 46.5%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.5%, transparent 56.5%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.0%, orange 40.0%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.5%, orange 40.5%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.0%, orange 39.0%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.2%, orange 30.2%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.2%, orange 45.2%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.7%, orange 40.7%, orange 50.0%, transparent 50.0%);
#         }    #T_6ed5d54c_551c_11ea_a752_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:

# %%
print('Global vs. Regional Models, ΔMAE')
regional_data, global_data, counts = compare_models(mae)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔMAE
# <style  type="text/css" >
#     #T_70c6cd84_551c_11ea_a752_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.9%, transparent 54.9%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.5%, transparent 56.5%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.8%, transparent 55.8%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.1%, transparent 56.1%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.8%, transparent 58.8%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.1%, transparent 61.1%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 65.0%, transparent 65.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.2%, orange 46.2%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.2%, orange 46.2%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, orange 49.9%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.9%, orange 45.9%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.2%, orange 47.2%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.9%, orange 45.9%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 60.8%, transparent 60.8%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.4%, transparent 53.4%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.5%, transparent 53.5%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 57.0%, transparent 57.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 66.7%, transparent 66.7%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.3%, transparent 53.3%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.4%, orange 43.4%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.4%, orange 49.4%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.5%, transparent 51.5%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.8%, transparent 50.8%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.5%, transparent 51.5%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 59.0%, transparent 59.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.0%, transparent 51.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.2%, transparent 50.2%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.8%, orange 39.8%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.5%, orange 39.5%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.0%, orange 40.0%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.8%, orange 31.8%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.0%, orange 43.0%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.9%, orange 36.9%, orange 50.0%, transparent 50.0%);
#         }    #T_70c6cd84_551c_11ea_a752_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparen

# %%
print('Global vs. Regional Models, Δbias%')
regional_data, global_data, counts = compare_models(rel_bias)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.4, vmax=0.4))
# Out:
# Global vs. Regional Models, Δbias%
# <style  type="text/css" >
#     #T_72c76256_551c_11ea_a752_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.7%, transparent 56.7%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 61.9%, transparent 61.9%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 57.7%, transparent 57.7%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.7%, transparent 52.7%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.0%, transparent 52.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.4%, transparent 56.4%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 66.4%, transparent 66.4%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.6%, transparent 50.6%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.4%, transparent 51.4%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.2%, transparent 52.2%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.0%, orange 48.0%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, orange 48.5%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.9%, orange 41.9%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.5%, orange 39.5%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, orange 48.5%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.9%, transparent 50.9%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.7%, orange 46.7%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.9%, orange 48.9%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.9%, orange 48.9%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.9%, orange 48.9%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.9%, orange 48.9%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.9%, transparent 51.9%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.2%, transparent 51.2%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.7%, transparent 51.7%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, orange 49.9%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.5%, transparent 51.5%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, orange 48.7%, orange 50.0%, transparent 50.0%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.2%, transparent 50.2%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.9%, transparent 52.9%);
#         }    #T_72c76256_551c_11ea_a752_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparen

# %%
METRIC = 'cubic_volume'

MODELS = {'ElasticNet': best_lms,
          'LASSO': best_lassos,
          'LASSO{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

pickle.dump(x_scaler, 
            open('../models/{}/sklearn/x_scaler.pkl'.format(METRIC), 'wb'))
pickle.dump(transformer, 
            open('../models/{}/sklearn/y_scaler.pkl'.format(METRIC), 'wb'))

for i in range(len(ecoregion_names)):
    for key in MODELS.keys():
        fname = ecoregion_names[i] + '_{}.pkl'.format(key)
        path_to_file = '../models/{}/sklearn/{}'.format(METRIC, fname)
        pickle.dump(MODELS[key][i], 
                    open(path_to_file, 'wb'))
        
        if key == 'LASSO{}'.format(MAX_FEATURES):
            sfm_name = ecoregion_names[i] + '_LASSO{}_featureselect.pkl'.format(MAX_FEATURES)
            path_to_file = '../models/{}/sklearn/{}'.format(METRIC, sfm_name)
            pickle.dump(sfms[i], 
                        open(path_to_file, 'wb'))
