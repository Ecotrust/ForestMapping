# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
# data prep and model-tuning
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, QuantileTransformer
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV

# types of models we'll fit
from sklearn.linear_model import ElasticNetCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR

import pickle
from copy import deepcopy

# %% [markdown]
# ## Our Data

# %%
DATA = '../data/processed/training_data_annual.csv'
df = pd.read_csv(DATA)
df = df.dropna()
print('{:,d} samples'.format(len(df)))
print('Columns:', df.columns.values)
# Out:
# 4,721 samples
# Columns: ['uuid' 'lidar_year' 'lat' 'lon' 'orig_id' 'source' 'meas_yr' 'ecoregion3'
#  'agency' 'plot_size_ac' 'num_returns' 'strat0_return-proportion'
#  'strat1_return-proportion' 'strat2_return-proportion'
#  'strat3_return-proportion' 'strat4_return-proportion'
#  'strat5_return-proportion' 'strat0_intensity-median'
#  'strat1_intensity-median' 'strat2_intensity-median'
#  'strat3_intensity-median' 'strat4_intensity-median'
#  'strat5_intensity-median' 'height_05-percentile' 'height_25-percentile'
#  'height_50-percentile' 'height_75-percentile' 'height_95_percentile'
#  'height_max' 'cover' 'lidar_acq' 'potential_volume' 'stddev_height'
#  'surface_area_ratio' 'surface_volume' 'surface_volume_ratio' 'aspect'
#  'elevation' 'overall_curvature' 'plan_curvature' 'profile_curvature'
#  'slope' 'solar_radiation_index' 'mat' 'mwmt' 'mcmt' 'td' 'map' 'msp'
#  'ahm' 'shm' 'dd_0' 'dd5' 'dd_18' 'dd18' 'nffd' 'bffp' 'effp' 'ffp' 'pas'
#  'emt' 'ext' 'eref' 'cmd' 'rh' 'green' 'blue' 'red' 'nir' 'endvi' 'ndvi'
#  'savi' 'swir1' 'swir2' 'wetness' 'greenness' 'brightness' 'landsat_year'
#  'clim_year' 'distance_to_water_m' 'bulk_dens' 'soil_depth'
#  'pct_clay_surf' 'pct_rock_surf' 'pct_sand_surf' 'pot_veg_type' 'tpa' 'ba'
#  'sdi' 'ccf' 'qmd' 'tcuft' 'topht' 'number_of_strata' 'total_cover'
#  'structure_class' 'canopy_baseheight' 'canopy_bulkdensity'
#  'aboveground_biomass' 'aboveground_carbon' 'gs_tpa' 'AF' 'AS' 'BM' 'BO'
#  'CH' 'CW' 'DF' 'DG' 'ES' 'GC' 'GF' 'IC' 'JP' 'KP' 'LO' 'LP' 'MA' 'MC'
#  'MH' 'NF' 'OH' 'OS' 'OT' 'PC' 'PL' 'PP' 'PY' 'RA' 'RC' 'RF' 'SF' 'SH'
#  'SP' 'SS' 'TO' 'WA' 'WB' 'WF' 'WH' 'WI' 'WJ' 'WL' 'WO' 'WP' 'YC'
#  'TRUE_FIR' 'OTHER_HARDWOOD' 'MAPLE' 'OAK' 'DOUGLAS_FIR' 'SPRUCE' 'CEDAR'
#  'PONDEROSA_PINE' 'OTHER_SOFTWOOD' 'LODGEPOLE_PINE' 'HEMLOCK' 'RED_ALDER'
#  'TANOAK' 'JUNIPER' 'LARCH' 'fvs_year' 'year_diff' 'returns_per_m2']

# %% [markdown]
# ## Filter out some of the training data
# We can exclude some of the training data based on how far separated the inventory data (interpolated using FVS simulations) is from the year the lidar was collected. Similarly, we can screen out training examples that had relatively low density of lidar returns.

# %%
df['year_diff'] = abs(df['fvs_year'] - df['lidar_year']).astype(int)
df = df.loc[df['year_diff'] < 10]
df = df.loc[df['returns_per_m2'] >= 4.0]

# %% [markdown]
# ## Inspect how many samples we have for different years, regions, etc.

# %%
df.groupby(by=['lidar_year'])[['uuid']].count().rename({'uuid':'count'}, axis=1)
# Out:
#             count
# lidar_year
# 2006          191
# 2008          857
# 2009          113
# 2010           21
# 2011          161
# 2012          720
# 2013          269
# 2014          368
# 2015          680
# 2016          604
# 2017          191
# 2018           35

# %%
pd.pivot_table(df, 
               values='uuid', 
               aggfunc='count', 
               index=['meas_yr'], 
               columns=['lidar_year'], 
               fill_value=0)
# Out:
# lidar_year  2006  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# meas_yr
# 2010           0   475     0     0     0     4     0     2     7     0     0
# 2011           0   377     0     0     0     1     0     2     3     0     0
# 2013         168     0    18     0    37   466    54     6    11    14    28
# 2014           5     0    60     2    28   132    45    50    44    99    40
# 2015          18     4     5     0    55    18    13    16   217   114    25
# 2016           0     1    18    15    26    45    90    59   284    77    36
# 2017           0     0     9     2    12    44    43   182    58   104    51
# 2018           0     0     3     2     3    10    24    51    56   196    11
#
# lidar_year  2018
# meas_yr
# 2010           0
# 2011           0
# 2013           2
# 2014           1
# 2015           6
# 2016          26
# 2017           0
# 2018           0

# %%
ecoreg_counts = df.groupby(by=['ecoregion3'])[['uuid']].count()
ecoreg_counts
# Out:
#                                                     uuid
# ecoregion3
# blue_mountains                                       108
# cascades                                             747
# coast_range                                         1809
# columbia_plateau                                      14
# eastern_cascades_slopes_and_foothills                409
# klamath_mountains_california_high_north_coast_r...   323
# north_cascades                                       505
# northern_rockies                                     103
# puget_lowland                                        149
# willamette_valley                                     43

# %% [markdown]
# ## Available features
# First, we'll use one-hot encoding for categorical features

# %%
# convert agency, ecoregion, and lidar acquisition into one-hot encoded set of variables
df = pd.get_dummies(df, prefix='agency', columns=['agency'])
# df = pd.get_dummies(df, prefix='eco', columns=['ecoregion3'])
# df = pd.get_dummies(df, prefix='acq', columns=['lidar_acq'])

# %% [markdown]
# The different types of predictor variables we can use to predict a forest attribute, including climate, lidar-derived, soil, and satellite imagery.

# %%
CLIM_COLS = ['mat', 'mwmt', 'mcmt', 'td', 'map', 'msp', 'ahm', 'shm', 
             'dd_0', 'dd5', 'dd_18', 'dd18', 'nffd', 'bffp', 'effp', 
             'ffp', 'pas', 'emt', 'ext', 'eref', 'cmd', 'rh']
LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
       'strat1_return-proportion', 'strat2_return-proportion',
       'strat3_return-proportion', 'strat4_return-proportion',
       'strat5_return-proportion', 'strat0_intensity-median',
       'strat1_intensity-median', 'strat2_intensity-median',
       'strat3_intensity-median', 'strat4_intensity-median',
       'strat5_intensity-median', 'height_05-percentile',
       'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
       'height_95_percentile', 'height_max', 'cover', 'potential_volume',
       'stddev_height', 'surface_area_ratio', 'surface_volume',
       'surface_volume_ratio', 'aspect', 'elevation', 'overall_curvature',
       'plan_curvature', 'profile_curvature', 'slope', 'solar_radiation_index']

SOIL_COLS = ['bulk_dens', 'soil_depth', 'pct_clay_surf', 'pct_rock_surf', 'pct_sand_surf']

LANDSAT_COLS = ['green', 'blue', 'red', 'nir', 'endvi', 'ndvi', 'savi',
                'swir1', 'swir2', 'wetness', 'greenness', 'brightness']

AGENCY_COLS = ['agency_BLM', 'agency_USFS', 'agency_WADNR']

# ECOREGIONS = [col for col in df.columns if col.startswith('eco_')]

# %% [markdown]
# ## Selecting initial features and targets
# This is the first step in determining what features we want to use, and what we want to predict. Later, we can still apply some procedures to choose a subset of these features to make simpler models.

# %%
X_COLS = LIDAR_COLS + ['plot_size_ac', 'ecoregion3'] + LANDSAT_COLS + CLIM_COLS
Y_COLS = ['total_cover']

# %% [markdown]
# ## Split the data into training and testing sets
# Since some plot_ids have multiple observations, we want all observations for each plot_id to fall entirely in train_set or entirely the training or testing sets because these samples are definitely not independent.

# %%
# a dataframe with unique plot ids
splits = pd.DataFrame(pd.unique(df['uuid']), columns=['uuid']).set_index('uuid')

# randomly assign each plot-id to train(0) or test(1) sets
np.random.seed(127)
splits['train0_test1'] = np.random.choice(2,
                                          size=len(splits),
                                          p=[0.8,0.2])

# add set assignments to the dataframe
df['train0_test1'] = splits.loc[df['uuid']]['train0_test1'].values

# %%
train_plots = df.loc[df['train0_test1'] == 0]
test_plots = df.loc[df['train0_test1'] == 1]
len(train_plots), len(test_plots)
# Out:
# (3355, 855)

# %%
x_train, x_test = train_plots[X_COLS].reset_index(drop=True), test_plots[X_COLS].reset_index(drop=True)
y_train, y_test = train_plots[Y_COLS].reset_index(drop=True), test_plots[Y_COLS].reset_index(drop=True)

# %% [markdown]
# ## Standardize features
# Scale all predictive features to have 0 mean and unit variance (subtracting mean, dividing by standard deviation).

# %%
x_scaler = StandardScaler()
x_scaler.fit(df[X_COLS].drop(['ecoregion3'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Consider a few transformations for the target variable

# %%
fig, axs = plt.subplots(1,5, figsize=(12,2.5))
axs.ravel()[0].hist(y_train.values, bins=20)
axs.ravel()[1].hist(np.log(y_train.values+1), bins=20)
axs.ravel()[2].hist(np.sqrt(y_train.values), bins=20)
quantile_transformer = QuantileTransformer(output_distribution='normal', random_state=127)
axs.ravel()[3].hist(quantile_transformer.fit_transform(y_train.values), bins=20)
power_transformer = PowerTransformer(method='box-cox')
axs.ravel()[4].hist(power_transformer.fit_transform(y_train.values + 1e-9), bins=20)

TITLES = ['Raw', 'Log', 'SQRT', 'Quantile', 'Box-Cox']
for i, title in enumerate(TITLES):
    axs.ravel()[i].set_title(title)
plt.show();

# %%
# choose your transformer here
transformer = quantile_transformer

# %%
transformer.fit(df[Y_COLS])
y_train, y_test = transformer.transform(y_train), transformer.transform(y_test)

# %% [markdown]
# ## Split datasets by ecoregion
# We want to explore model transferability between regions, so we'll train models independently on subsets of the data within a single ecoregion, as well as a model that is trained on all available ecoregions.

# %%
ecoregions = [reg for reg in pd.unique(df.ecoregion3) if ecoreg_counts.loc[reg]['uuid'] > 20]

eco_train_idx = [x_train.loc[x_train.ecoregion3 == eco].index.values for eco in ecoregions]
eco_test_idx = [x_test.loc[x_test.ecoregion3 == eco].index.values for eco in ecoregions]

eco_xtrain_dfs = [x_train.loc[x_train.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytrain_dfs = [y_train[idx].ravel() for idx in eco_train_idx]
eco_xtest_dfs = [x_test.loc[x_test.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytest_dfs = [y_test[idx].ravel() for idx in eco_test_idx]

# append a "global" model that contains data from all ecoregions
ecoregions.append('all')
ecoregion_names = ['_'.join(x.split('_')[0:2]) for x in ecoregions]
eco_xtrain_dfs.append(x_train.drop(['ecoregion3'], axis=1))
eco_ytrain_dfs.append(y_train.ravel())
eco_xtest_dfs.append(x_test.drop(['ecoregion3'], axis=1))
eco_ytest_dfs.append(y_test.ravel())

# %% [markdown]
# ## Scoring
# We'll use Root Mean Square Error to evaluate model performance.

# %%
def rmse(pred, obs):
    # use our transformer to calculate RMSE on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return np.sqrt(mean_squared_error(obs, pred))

# %%
def nrmse(pred, obs):
    # use our transformer to calculate percent RMSE on the original data scale
    this_rmse = rmse(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return this_rmse/obs.mean()

# %%
def mae(pred, obs):
    # use our transformer to calculate mean absolute error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return abs(pred - obs).mean()

# %%
def mape(pred, obs):
    # use our transformer to calculate mean average percent error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return abs(pred - obs).mean() / obs.mean()

# %%
def bias(pred, obs):
    # use our transformer to calculate mean bias on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return (pred - obs).mean()

# %% [markdown]
# This helper function will calculate RMSE scores for each regionally-trained model and the global model on each ecoregion.

# %%
def get_score_df(models, metric=rmse, feature_selectors=None):
    regional_scores = []
    global_scores = []
    counts = []
    
    for i, mod in enumerate(models):
        X_test = x_scaler.transform(eco_xtest_dfs[i])
        if feature_selectors:
            X_test = feature_selectors[i].transform(X_test)
        y_test = eco_ytest_dfs[i].reshape(-1, 1)
        reg_score = metric(mod.predict(X_test), y_test)
        regional_scores.append(reg_score.round(3))
        
        if feature_selectors:
            X_test = x_scaler.transform(eco_xtest_dfs[i])
            X_test = feature_selectors[-1].transform(X_test)
        glob_score = metric(models[-1].predict(X_test), y_test)
        global_scores.append(glob_score.round(3))
        count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
        counts.append(count)
        
    data = list(zip(regional_scores, global_scores, counts))
    res_df = pd.DataFrame(data=data,
                          columns=['regional_model', 'global_model', 'n'],
                          index=ecoregion_names)
    
    return res_df

# %% [markdown]
# ## Fit some models
# For each type of model, we'll employ cross-validation to tune model hyperparameters, generating a tuned model for each ecoregion as well as a tuned model using all training data. We'll work our way through:
#
# #### ElasticNet Regression
# Linear model that employs a mix of L1 and L2 regularization to penalize model complexity
#
# #### LASSO Regression
# Linear model that employs L1 regularization to penalize model complexity. We'll also work with a feature-selection process to fit models capped to an explicitly-predefined number of features.
#
# #### K-Nearest Neighbor Regression
#
# #### Random Forest Regression
#
# #### Gradient Boosting Trees Regression
#
# #### Support Vector Machine Regression

# %% [markdown]
# ## ElasticNet (Linear Model)

# %%
best_lms = []

for i in range(len(ecoregions)):
    lm = ElasticNetCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    lm.fit(X, y)
    best_lms.append(lm)

# %%
elastic_res = get_score_df(best_lms, rmse)
elastic_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              6.900         9.919   108
# coast_range                16.720        16.862  1646
# eastern_cascades           14.085        13.893   403
# north_cascades             18.753        16.159   490
# cascades                   15.231        15.451   728
# klamath_mountains          17.086        20.255   321
# northern_rockies           17.519        19.360   103
# puget_lowland              20.005        22.105   147
# willamette_valley           3.448        12.798    43
# all                        16.731        16.731  3355

# %%
coefs = np.array([lm.coef_ for lm in best_lms])
count_nonzero = [(~np.isclose(coef, 0, atol=1e-3)).sum() for coef in coefs]
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                              0.047
# coast_range                                                 0.077
# eastern_cascades_slopes_and_foothills                          --
# north_cascades                                              0.078
# cascades                                                    0.035
# klamath_mountains_california_high_north_coast_r...             --
# northern_rockies                                               --
# puget_lowland                                               0.046
# willamette_valley                                              --
# all                                                         0.054
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                       -0.074
# coast_range                                                          -0.008
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                       -0.049
# cascades                                                             -0.305
# klamath_mountains_california_high_north_coast_r...                   -0.273
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.117
# all                                                                  -0.057
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.131
# coast_range                                                          -0.134
# eastern_cascades_slopes_and_foothills                                -0.048
# north_cascades                                                       -0.207
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                     -0.261
# puget_lowland                                                        -0.323
# willamette_valley                                                        --
# all                                                                  -0.114
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        0.062
# coast_range                                                            0.04
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     -0.04
# all                                                                      --
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                         0.15
# coast_range                                                           0.085
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                              0.008
# klamath_mountains_california_high_north_coast_r...                    0.072
# northern_rockies                                                         --
# puget_lowland                                                         0.009
# willamette_valley                                                        --
# all                                                                   0.096
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                         0.12
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                        0.116
# cascades                                                              0.019
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                         0.056
# willamette_valley                                                        --
# all                                                                   0.044
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                 0.092
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                      0.011
# puget_lowland                                                            --
# willamette_valley                                                     0.096
# all                                                                   0.156
#
#                                                    strat0_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                          --
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                  -0.02
#
#                                                    strat1_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                         -0.029
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                          --
# cascades                                                            -0.119
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat2_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                         -0.018
# eastern_cascades_slopes_and_foothills                               -0.003
# north_cascades                                                      -0.351
# cascades                                                            -0.101
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.149
#
#                                                     ...    dd5   dd18   nffd  \
# blue_mountains                                      ...     --     --     --
# coast_range                                         ...  -0.07 -0.022     --
# eastern_cascades_slopes_and_foothills               ...     --     --     --
# north_cascades                                      ...     -- -0.004     --
# cascades                                            ...     --     --     --
# klamath_mountains_california_high_north_coast_r...  ...     --     --     --
# northern_rockies                                    ...     --     --     --
# puget_lowland                                       ...     --     --     --
# willamette_valley                                   ...     --     --     --
# all                                                 ... -0.149     -- -0.133
#
#                                                      bffp    pas    emt  \
# blue_mountains                                      0.056     --     --
# coast_range                                            --     --     --
# eastern_cascades_slopes_and_foothills                  --     --     --
# north_cascades                                         --  0.133     --
# cascades                                               --   0.01     --
# klamath_mountains_california_high_north_coast_r...     --     --     --
# northern_rockies                                       --     --     --
# puget_lowland                                          --     --     --
# willamette_valley                                      --     --     --
# all                                                -0.137  0.052  0.065
#
#                                                       ext   eref    cmd     rh
# blue_mountains                                      0.009     -- -0.058     --
# coast_range                                        -0.079     --     --  0.065
# eastern_cascades_slopes_and_foothills                  --     --     --     --
# north_cascades                                         --     --     --     --
# cascades                                               --     --     -- -0.051
# klamath_mountains_california_high_north_coast_r...     --     --     --   0.09
# northern_rockies                                       --     --     --     --
# puget_lowland                                          --     -- -0.042     --
# willamette_valley                                      --     --     --     --
# all                                                    -- -0.021   0.14     --
#
# [10 rows x 63 columns]

# %% [markdown]
# ## LASSO (Linear Model)
# Starting with implicit feature selection via L1 regularization of coefficients.

# %%
best_lassos = []

for i in range(len(ecoregions)):
    lasso = LassoCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000, n_alphas=1000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    lasso.fit(X, y)
    best_lassos.append(lasso)

# %%
lasso_res = get_score_df(best_lassos)
lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              6.893         9.951   108
# coast_range                16.705        16.856  1646
# eastern_cascades           14.154        13.888   403
# north_cascades             18.933        16.165   490
# cascades                   15.223        15.431   728
# klamath_mountains          16.995        20.246   321
# northern_rockies           17.327        19.320   103
# puget_lowland              20.261        22.113   147
# willamette_valley           4.318        12.881    43
# all                        16.726        16.726  3355

# %%
coefs = np.array([lm.coef_ for lm in best_lassos])
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                              0.055
# coast_range                                                 0.081
# eastern_cascades_slopes_and_foothills                          --
# north_cascades                                              0.082
# cascades                                                    0.031
# klamath_mountains_california_high_north_coast_r...             --
# northern_rockies                                               --
# puget_lowland                                               0.035
# willamette_valley                                              --
# all                                                         0.055
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                             -0.284
# klamath_mountains_california_high_north_coast_r...                   -0.311
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.042
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.096
# coast_range                                                          -0.122
# eastern_cascades_slopes_and_foothills                                -0.047
# north_cascades                                                       -0.179
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                     -0.291
# puget_lowland                                                        -0.433
# willamette_valley                                                        --
# all                                                                  -0.078
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        0.053
# coast_range                                                           0.039
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.003
# all                                                                      --
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.152
# coast_range                                                           0.083
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                     0.06
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.096
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.124
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                        0.123
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                         0.023
# willamette_valley                                                        --
# all                                                                   0.043
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                 0.124
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     0.078
# all                                                                   0.157
#
#                                                    strat0_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                          --
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.018
#
#                                                    strat1_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                         -0.018
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                          --
# cascades                                                            -0.125
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat2_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                         -0.018
# eastern_cascades_slopes_and_foothills                               -0.002
# north_cascades                                                      -0.374
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.151
#
#                                                     ...   dd_0    dd5  nffd  \
# blue_mountains                                      ...     --     --    --
# coast_range                                         ...     -- -0.068    --
# eastern_cascades_slopes_and_foothills               ...     --     --    --
# north_cascades                                      ...     --     --    --
# cascades                                            ...     --     --    --
# klamath_mountains_california_high_north_coast_r...  ...     --     --    --
# northern_rockies                                    ...     --     --    --
# puget_lowland                                       ...     --     --    --
# willamette_valley                                   ...     --     --    --
# all                                                 ... -0.005 -0.176 -0.14
#
#                                                      bffp    pas    emt  \
# blue_mountains                                      0.076     --     --
# coast_range                                            --     --     --
# eastern_cascades_slopes_and_foothills                  --     --     --
# north_cascades                                         --  0.138     --
# cascades                                               --     --     --
# klamath_mountains_california_high_north_coast_r...     --     --     --
# northern_rockies                                       --     --     --
# puget_lowland                                          --     --     --
# willamette_valley                                      --     --     --
# all                                                -0.157  0.053  0.061
#
#                                                       ext  eref    cmd     rh
# blue_mountains                                      0.003    --  -0.05     --
# coast_range                                        -0.104    --     --  0.045
# eastern_cascades_slopes_and_foothills                  --    --     --     --
# north_cascades                                         --    --     --     --
# cascades                                               --    --     --     --
# klamath_mountains_california_high_north_coast_r...     --    --     --  0.075
# northern_rockies                                       --    --     --     --
# puget_lowland                                          --    -- -0.068     --
# willamette_valley                                      --    --     --     --
# all                                                    -- -0.01  0.143     --
#
# [10 rows x 60 columns]

# %% [markdown]
# Now we'll explicitly define the maximum number of features to use for fitting a linear model. We'll trim features by iteratively increasing a threshold for coefficients using LASSO regression

# %%
MAX_FEATURES = 5
sfms = [] # transformers that filter X features
trimmed_lassos = [] # re-fit lasso regressions on the subset of the features

for i, lasso in enumerate(best_lassos):
    lasso = deepcopy(lasso)
    sfm = SelectFromModel(lasso, threshold=0.001)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    Y = (eco_ytrain_dfs[i].ravel())
    sfm.fit(X, Y)
    n_features = sfm.transform(X).shape[1]

    # Reset the threshold till the number of features equals two.
    # Note that the attribute can be set directly instead of repeatedly
    # fitting the metatransformer.
    while n_features > MAX_FEATURES:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    
    sfms.append(sfm)
    try:
        trimmed_lassos.append(lasso.fit(sfm.transform(X), Y))
    except ValueError:
        print(ecoregion_names[i])
        raise
    
trimmed_regional_scores = []
trimmed_global_scores = []
counts = []

for i, lasso in enumerate(trimmed_lassos):
    X_reg = sfms[i].transform(x_scaler.transform(eco_xtest_dfs[i]))
    X_glob = sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i]))
    observed = eco_ytest_dfs[i]
    
    reg_score = rmse(lasso.predict(X_reg), observed)
    glob_score = rmse(trimmed_lassos[-1].predict(X_glob), observed)
    
    trimmed_regional_scores.append(reg_score.round(3))
    trimmed_global_scores.append(glob_score.round(3))
    
    count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
    counts.append(count)
    

trimmed_lasso_res = pd.DataFrame(data=list(zip(trimmed_regional_scores, trimmed_global_scores, counts)),
                      columns=['regional_model', 'global_model', 'n'],
                      index=ecoregion_names)
trimmed_lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              5.778        11.243   108
# coast_range                17.867        17.990  1646
# eastern_cascades           14.808        15.186   403
# north_cascades             19.560        17.156   490
# cascades                   15.734        15.619   728
# klamath_mountains          16.890        20.296   321
# northern_rockies           18.090        21.258   103
# puget_lowland              20.735        24.383   147
# willamette_valley           3.667        16.695    43
# all                        17.728        17.728  3355

# %%
coefs = []
for i in range(len(ecoregions)):
    cols = np.zeros(eco_xtest_dfs[i].columns.shape)
    cols[sfms[i].get_support()] = trimmed_lassos[i].coef_
    coefs.append(cols)
    
coefs = np.array(coefs)

coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                             -0.312
# klamath_mountains_california_high_north_coast_r...                   -0.321
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.292
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                -0.063
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                     -0.297
# puget_lowland                                                        -0.573
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.108
# all                                                                      --
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.101
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                    0.097
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.072
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                 0.201
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     0.139
# all                                                                      --
#
#                                                    strat2_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.451
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat3_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                          --
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                       -0.209
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat4_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                       0.288
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat5_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                          --
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                        0.155
# willamette_valley                                                       --
# all                                                                     --
#
#                                                     ...   blue    nir   ndvi  \
# blue_mountains                                      ...     --     --     --
# coast_range                                         ...     --    0.2     --
# eastern_cascades_slopes_and_foothills               ...     --     --     --
# north_cascades                                      ...     --     --  0.443
# cascades                                            ...  0.184     --     --
# klamath_mountains_california_high_north_coast_r...  ...     --     --     --
# northern_rockies                                    ...     --     --     --
# puget_lowland                                       ...     --  0.155     --
# willamette_valley                                   ...     --     --     --
# all                                                 ...     --     --     --
#
#                                                     swir2 wetness greenness  \
# blue_mountains                                         --      --        --
# coast_range                                        -0.443      --        --
# eastern_cascades_slopes_and_foothills              -0.308      --        --
# north_cascades                                         --      --        --
# cascades                                           -0.606      --        --
# klamath_mountains_california_high_north_coast_r...     --      --      0.27
# northern_rockies                                       --   0.363        --
# puget_lowland                                          --   0.237        --
# willamette_valley                                      --      --        --
# all                                                -0.209      --        --
#
#                                                      mwmt    shm    dd5     rh
# blue_mountains                                         --     --     --     --
# coast_range                                            -- -0.102     --     --
# eastern_cascades_slopes_and_foothills                  --     --     --     --
# north_cascades                                         --     --     --     --
# cascades                                           -0.173     --     --     --
# klamath_mountains_california_high_north_coast_r...     --     --     --  0.128
# northern_rockies                                       --     --     --     --
# puget_lowland                                          --     --     --     --
# willamette_valley                                      --     --     --     --
# all                                                    --     -- -0.156     --
#
# [10 rows x 28 columns]

# %% [markdown]
# ## K-Nearest Neighbors Regression

# %%
# Set the parameters by cross-validation
knn_params = {'n_neighbors': [1,2,3,4,5,10,20],
              'weights': ['uniform', 'distance'],
              'metric': ['minkowski', 'manhattan']}


knn_gs = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=knn_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_knns = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    knn_gs.fit(X, y)
    best_fit = knn_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_knns.append(best_fit)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    2.4s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    2.6s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.2s remaining:    0.5s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.5s finished
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    1.6s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    1.9s finished

# %%
knn_res = get_score_df(best_knns)
knn_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              8.189         8.545   108
# coast_range                18.053        17.831  1646
# eastern_cascades           12.901        15.334   403
# north_cascades             13.791        13.397   490
# cascades                   16.045        14.993   728
# klamath_mountains          15.727        15.679   321
# northern_rockies           19.025        19.693   103
# puget_lowland              25.914        21.277   147
# willamette_valley           9.499         7.108    43
# all                        16.505        16.505  3355

# %% [markdown]
# ## Random Forest Regression

# %%
# Set the parameters by cross-validation
rf_params = {'n_estimators': [100, 500, 1000, 5000],
             'max_features': ['sqrt'],
             'max_depth': [3, 5, 10, 25, 50],
             'min_samples_leaf': [1,2,4],
             'bootstrap': [True, False]}


rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=rf_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_rfs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    rf_gs.fit(X, y)
    best_fit = rf_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_rfs.append(best_fit)

# %%
rf_res = get_score_df(best_rfs)
rf_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              5.555         7.978   108
# coast_range                16.330        16.186  1646
# eastern_cascades           13.401        13.477   403
# north_cascades             17.105        13.007   490
# cascades                   14.470        14.206   728
# klamath_mountains          16.418        16.721   321
# northern_rockies           19.224        19.961   103
# puget_lowland              21.029        19.940   147
# willamette_valley           5.528        14.064    43
# all                        15.445        15.445  3355

# %%
### Employing feature selection to try and improve random forest regression

# %%
importances = best_rfs[-1].feature_importances_
indices = np.argsort(importances)[::-1]
features = eco_xtrain_dfs[-1].columns[indices]

# Print the feature ranking
print("Feature ranking:")

for f in range(eco_xtrain_dfs[-1].shape[1]):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. cover (0.081651)
# 2. surface_volume (0.058247)
# 3. height_50-percentile (0.053634)
# 4. height_25-percentile (0.049168)
# 5. height_75-percentile (0.035962)
# 6. swir2 (0.035341)
# 7. strat0_return-proportion (0.035037)
# 8. swir1 (0.031662)
# 9. strat1_return-proportion (0.027151)
# 10. surface_area_ratio (0.026554)
# 11. ndvi (0.025281)
# 12. stddev_height (0.023760)
# 13. savi (0.021414)
# 14. wetness (0.021076)
# 15. potential_volume (0.017902)
# 16. red (0.014759)
# 17. height_05-percentile (0.013596)
# 18. endvi (0.013535)
# 19. cmd (0.012756)
# 20. strat2_intensity-median (0.012376)
# 21. map (0.012206)
# 22. ahm (0.012196)
# 23. strat0_intensity-median (0.011918)
# 24. strat1_intensity-median (0.011734)
# 25. greenness (0.011583)
# 26. height_95_percentile (0.011582)
# 27. nir (0.010777)
# 28. overall_curvature (0.010119)
# 29. ext (0.010059)
# 30. strat3_return-proportion (0.009950)
# 31. rh (0.009869)
# 32. eref (0.009393)
# 33. elevation (0.009390)
# 34. profile_curvature (0.009359)
# 35. strat2_return-proportion (0.009162)
# 36. green (0.009048)
# 37. brightness (0.009042)
# 38. strat3_intensity-median (0.008942)
# 39. plan_curvature (0.008922)
# 40. shm (0.008894)
# 41. slope (0.008458)
# 42. emt (0.008435)
# 43. dd18 (0.008357)
# 44. height_max (0.008334)
# 45. nffd (0.008105)
# 46. td (0.008101)
# 47. ffp (0.007968)
# 48. mwmt (0.007958)
# 49. msp (0.007954)
# 50. blue (0.007698)
# 51. bffp (0.007668)
# 52. mcmt (0.007567)
# 53. aspect (0.007518)
# 54. pas (0.007370)
# 55. strat4_intensity-median (0.007345)
# 56. returns_per_m2 (0.007310)
# 57. dd_0 (0.007304)
# 58. dd5 (0.007294)
# 59. solar_radiation_index (0.007006)
# 60. strat4_return-proportion (0.006767)
# 61. dd_18 (0.006607)
# 62. strat5_intensity-median (0.006395)
# 63. strat5_return-proportion (0.005979)
# 64. effp (0.005675)
# 65. mat (0.004580)
# 66. plot_size_ac (0.001240)
# 67. surface_volume_ratio (0.000000)

# %% [markdown]
# ## Gradient Boosting Trees Regression

# %%
# Set the parameters by cross-validation
gb_params = {'n_estimators': [100, 500, 1000, 5000],
             'learning_rate': [0.01, 0.1],
             'max_depth': [2, 3, 4, 5, 10],
             'max_features': ['sqrt'] 
            }

gb_gs = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=gb_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_gbs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    gb_gs.fit(X, y)
    best_fit = gb_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_gbs.append(best_fit)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    6.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   18.4s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    3.4s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    4.0s remaining:    4.4s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.5s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    7.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.4s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.5s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.8s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.8s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    3.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.4s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   44.2s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   46.7s finished

# %%
gb_res = get_score_df(best_gbs)
gb_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              5.642         8.345   108
# coast_range                16.178        15.892  1646
# eastern_cascades           13.164        13.408   403
# north_cascades             15.290        13.060   490
# cascades                   13.243        13.894   728
# klamath_mountains          16.628        16.804   321
# northern_rockies           20.327        19.331   103
# puget_lowland              19.972        19.147   147
# willamette_valley           7.807        13.794    43
# all                        15.206        15.206  3355

# %%
### Employing feature selection to try and improve gradient boosting regression

# %% [markdown]
# ## Support Vector Machines Regression

# %%
# Set the parameters by cross-validation
svm_params = {'kernel': ['linear', 'rbf'],
              'gamma': ['scale', 'auto'],
              'C': [0.1,1,10,100,1000]
              }

svm_gs = GridSearchCV(estimator=SVR(), param_grid=svm_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_svms = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    svm_gs.fit(X, y)
    best_fit = svm_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_svms.append(best_fit)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    3.0s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    6.7s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    1.0s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  8.6min finished
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    2.7s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  2.9min finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.2s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  3.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  4.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  7.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    3.1s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    8.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  2.0min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    4.9s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 32.6min finished

# %%
svm_res = get_score_df(best_svms)
svm_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              7.294         6.749   108
# coast_range                15.595        15.784  1646
# eastern_cascades           13.420        13.323   403
# north_cascades             17.962        12.627   490
# cascades                   15.185        13.310   728
# klamath_mountains          16.429        17.408   321
# northern_rockies           16.711        17.049   103
# puget_lowland              23.001        20.378   147
# willamette_valley           6.566        15.445    43
# all                        15.073        15.073  3355

# %%
### Employing feature selection to try and improve support vector regression

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

def scatter_graphs(model_dict):
    names = MODELS.keys()
    EXTEND_PCT = 0.10
    
    fig, axs = plt.subplots(len(ecoregion_names), len(names), 
                            sharex=True, sharey=True,
                            figsize=(12,15)
                           )
    
    all_obs = transformer.inverse_transform(eco_ytest_dfs[-1].reshape(-1,1))
    obs_min = all_obs.min()
    obs_max = all_obs.max()
    rng = obs_max - obs_min
        
    for i, ecoreg in enumerate(ecoregion_names):
        observed = transformer.inverse_transform(eco_ytest_dfs[i].reshape(-1,1))
        
        for j, name in enumerate(names):
            axs[0,j].set_title(name)
            axs[i,0].set_ylabel(ecoreg)
            axs[i,j].set_xlim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_ylim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_aspect('equal')
            
            if name == 'LASSO_{}'.format(MAX_FEATURES):
                predicted = MODELS[name][-1].predict(sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i])))
            else:
                predicted = MODELS[name][-1].predict(x_scaler.transform(eco_xtest_dfs[i]))
            
            predicted = transformer.inverse_transform(predicted.reshape(-1,1))
            axs[i,j].scatter(observed, predicted, s=0.5)
            axs[i,j].plot((obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng), 
                          (obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng),
                         color='k', lw=0.5)
            
    plt.tight_layout(pad=0.001)

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

scatter_graphs(MODELS)

# %% [markdown]
# ## View scores for regional and global models

# %%
MODEL_NAMES = ['ElasticNet', 'LASSO', 'LASSO_{}'.format(MAX_FEATURES), 'KNN', 'RF', 'GB', 'SVM']
BEST_MODELS = [best_lms, best_lassos, trimmed_lassos, best_knns, best_rfs, best_gbs, best_svms]
    
def compare_models(metric):
    score_dfs = []

    for name, best_models in list(zip(MODEL_NAMES, BEST_MODELS)):
        if name == 'LASSO_{}'.format(MAX_FEATURES):
            score_df = get_score_df(best_models, metric, sfms) 
            score_dfs.append(score_df)
        else:
            score_df = get_score_df(best_models, metric) 
            score_dfs.append(score_df)
        
    counts = np.array(score_dfs[-1]['n'].values)
    regional_data = np.array([df['regional_model'].values for df in score_dfs])
    global_data = np.array([df['global_model'].values for df in score_dfs])
    
    return regional_data, global_data, counts

# %%
def highlight_best(s):
    '''
    highlight the closest value to zero in a Series yellow.
    '''
    lowest_idx = abs(s).idxmin()
    return ['background-color: yellow' if idx==lowest_idx else '' for idx in s.index]

# %%
print('Regional Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
regional_rmse = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_rmse
 .style
 .highlight_min(color='yellow', axis=1))
# Out:
# Regional Models, RMSE
# <style  type="text/css" >
#     #T_f80c2cf6_4d44_11ea_99b1_00505683952erow0_col4 {
#             background-color:  yellow;
#         }    #T_f80c2cf6_4d44_11ea_99b1_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_f80c2cf6_4d44_11ea_99b1_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_f80c2cf6_4d44_11ea_99b1_00505683952erow3_col3 {
#             background-color:  yellow;
#         }    #T_f80c2cf6_4d44_11ea_99b1_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_f80c2cf6_4d44_11ea_99b1_00505683952erow5_col3 {
#             background-color:  yellow;
#         }    #T_f80c2cf6_4d44_11ea_99b1_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_f80c2cf6_4d44_11ea_99b1_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_f80c2cf6_4d44_11ea_99b1_00505683952erow8_col0 {
#             background-color:  yellow;
#         }    #T_f80c2cf6_4d44_11ea_99b1_00505683952erow9_col6 {
#             background-color:  yellow;
#         }</style><table id="T_f80c2cf6_4d44_11ea_99b1_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f80c2cf6_4d44_11ea_99b1_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow0_col0" class="data row0 col0" >6.9</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow0_col1" class="data row0 col1" >6.893</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow0_col2" class="data row0 col2" >5.778</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow0_col3" class="data row0 col3" >8.189</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow0_col4" class="data row0 col4" >5.555</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow0_col5" class="data row0 col5" >5.642</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow0_col6" class="data row0 col6" >7.294</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_f80c2cf6_4d44_11ea_99b1_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow1_col0" class="data row1 col0" >16.72</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow1_col1" class="data row1 col1" >16.705</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow1_col2" class="data row1 col2" >17.867</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952erow1_col3" class="data row1 col3" >18.053</td>
#                         <td id="T_f80c2cf6_4d44_11ea_99b1_00505683952er
</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow0_col6" class="data row0 col6" >28%</td>
#             </tr>
#             <tr>
#                         <th id="T_0a20c4ec_4d45_11ea_99b1_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow1_col0" class="data row1 col0" >26%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow1_col1" class="data row1 col1" >26%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow1_col2" class="data row1 col2" >27%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow1_col3" class="data row1 col3" >27%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow1_col4" class="data row1 col4" >25%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow1_col5" class="data row1 col5" >24%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow1_col6" class="data row1 col6" >24%</td>
#             </tr>
#             <tr>
#                         <th id="T_0a20c4ec_4d45_11ea_99b1_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow2_col0" class="data row2 col0" >34%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow2_col1" class="data row2 col1" >34%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow2_col2" class="data row2 col2" >38%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow2_col3" class="data row2 col3" >38%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow2_col4" class="data row2 col4" >34%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow2_col5" class="data row2 col5" >33%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow2_col6" class="data row2 col6" >33%</td>
#             </tr>
#             <tr>
#                         <th id="T_0a20c4ec_4d45_11ea_99b1_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow3_col0" class="data row3 col0" >28%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow3_col1" class="data row3 col1" >28%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow3_col2" class="data row3 col2" >30%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow3_col3" class="data row3 col3" >23%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow3_col4" class="data row3 col4" >23%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow3_col5" class="data row3 col5" >23%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow3_col6" class="data row3 col6" >22%</td>
#             </tr>
#             <tr>
#                         <th id="T_0a20c4ec_4d45_11ea_99b1_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow4_col0" class="data row4 col0" >24%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow4_col1" class="data row4 col1" >24%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow4_col2" class="data row4 col2" >25%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow4_col3" class="data row4 col3" >24%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow4_col4" class="data row4 col4" >23%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow4_col5" class="data row4 col5" >22%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow4_col6" class="data row4 col6" >21%</td>
#             </tr>
#             <tr>
#                         <th id="T_0a20c4ec_4d45_11ea_99b1_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow5_col0" class="data row5 col0" >36%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow5_col1" class="data row5 col1" >36%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow5_col2" class="data row5 col2" >36%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow5_col3" class="data row5 col3" >28%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow5_col4" class="data row5 col4" >29%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow5_col5" class="data row5 col5" >30%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow5_col6" class="data row5 col6" >31%</td>
#             </tr>
#             <tr>
#                         <th id="T_0a20c4ec_4d45_11ea_99b1_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow6_col0" class="data row6 col0" >48%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow6_col1" class="data row6 col1" >48%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1_00505683952erow6_col2" class="data row6 col2" >52%</td>
#                         <td id="T_0a20c4ec_4d45_11ea_99b1

# %%
print('Global Models, Bias')
regional_data, global_data, counts = compare_models(bias)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores
 .style
 .apply(highlight_best, axis=1))
# Out:
# Global Models, Bias
# <style  type="text/css" >
#     #T_0d37cee6_4d45_11ea_99b1_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_0d37cee6_4d45_11ea_99b1_00505683952erow1_col2 {
#             background-color:  yellow;
#         }    #T_0d37cee6_4d45_11ea_99b1_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_0d37cee6_4d45_11ea_99b1_00505683952erow3_col3 {
#             background-color:  yellow;
#         }    #T_0d37cee6_4d45_11ea_99b1_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_0d37cee6_4d45_11ea_99b1_00505683952erow5_col4 {
#             background-color:  yellow;
#         }    #T_0d37cee6_4d45_11ea_99b1_00505683952erow6_col2 {
#             background-color:  yellow;
#         }    #T_0d37cee6_4d45_11ea_99b1_00505683952erow7_col2 {
#             background-color:  yellow;
#         }    #T_0d37cee6_4d45_11ea_99b1_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T
</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow0_col5" class="data row0 col5" >28%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow0_col6" class="data row0 col6" >23%</td>
#             </tr>
#             <tr>
#                         <th id="T_13499cc4_4d45_11ea_99b1_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow1_col0" class="data row1 col0" >19%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow1_col1" class="data row1 col1" >19%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow1_col2" class="data row1 col2" >20%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow1_col3" class="data row1 col3" >20%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow1_col4" class="data row1 col4" >18%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow1_col5" class="data row1 col5" >17%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow1_col6" class="data row1 col6" >17%</td>
#             </tr>
#             <tr>
#                         <th id="T_13499cc4_4d45_11ea_99b1_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow2_col0" class="data row2 col0" >28%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow2_col1" class="data row2 col1" >28%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow2_col2" class="data row2 col2" >30%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow2_col3" class="data row2 col3" >28%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow2_col4" class="data row2 col4" >26%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow2_col5" class="data row2 col5" >26%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow2_col6" class="data row2 col6" >26%</td>
#             </tr>
#             <tr>
#                         <th id="T_13499cc4_4d45_11ea_99b1_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow3_col0" class="data row3 col0" >20%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow3_col1" class="data row3 col1" >20%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow3_col2" class="data row3 col2" >22%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow3_col3" class="data row3 col3" >18%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow3_col4" class="data row3 col4" >18%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow3_col5" class="data row3 col5" >18%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow3_col6" class="data row3 col6" >16%</td>
#             </tr>
#             <tr>
#                         <th id="T_13499cc4_4d45_11ea_99b1_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow4_col0" class="data row4 col0" >18%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow4_col1" class="data row4 col1" >18%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow4_col2" class="data row4 col2" >18%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow4_col3" class="data row4 col3" >18%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow4_col4" class="data row4 col4" >16%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow4_col5" class="data row4 col5" >16%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow4_col6" class="data row4 col6" >15%</td>
#             </tr>
#             <tr>
#                         <th id="T_13499cc4_4d45_11ea_99b1_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow5_col0" class="data row5 col0" >24%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow5_col1" class="data row5 col1" >25%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow5_col2" class="data row5 col2" >27%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow5_col3" class="data row5 col3" >20%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow5_col4" class="data row5 col4" >21%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow5_col5" class="data row5 col5" >21%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow5_col6" class="data row5 col6" >21%</td>
#             </tr>
#             <tr>
#                         <th id="T_13499cc4_4d45_11ea_99b1_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow6_col0" class="data row6 col0" >38%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_00505683952erow6_col1" class="data row6 col1" >37%</td>
#                         <td id="T_13499cc4_4d45_11ea_99b1_0050568395

# %%
METRIC = 'canopy_cover'

MODELS = {'ElasticNet': best_lms,
          'LASSO': best_lassos,
          'LASSO{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

pickle.dump(x_scaler, 
            open('../models/{}/sklearn/x_scaler.pkl'.format(METRIC), 'wb'))
pickle.dump(transformer, 
            open('../models/{}/sklearn/y_scaler.pkl'.format(METRIC), 'wb'))

for i in range(len(ecoregion_names)):
    for key in MODELS.keys():
        fname = ecoregion_names[i] + '_{}.pkl'.format(key)
        path_to_file = '../models/{}/sklearn/{}'.format(METRIC, fname)
        pickle.dump(MODELS[key][i], 
                    open(path_to_file, 'wb'))
        
        if key == 'LASSO{}'.format(MAX_FEATURES):
            sfm_name = ecoregion_names[i] + '_LASSO{}_featureselect.pkl'.format(MAX_FEATURES)
            path_to_file = '../models/{}/sklearn/{}'.format(METRIC, sfm_name)
            pickle.dump(sfms[i], 
                        open(path_to_file, 'wb'))
