# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
# data prep and model-tuning
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, QuantileTransformer
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV

# types of models we'll fit
from sklearn.linear_model import ElasticNetCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR

import pickle
from copy import deepcopy

# %% [markdown]
# ## Our Data

# %%
DATA = '../data/processed/training_data_annual.csv'
df = pd.read_csv(DATA)
df = df.dropna()
print('{:,d} samples'.format(len(df)))
print('Columns:', df.columns.values)
# Out:
# 4,721 samples
# Columns: ['uuid' 'lidar_year' 'lat' 'lon' 'orig_id' 'source' 'meas_yr' 'ecoregion3'
#  'agency' 'plot_size_ac' 'num_returns' 'strat0_return-proportion'
#  'strat1_return-proportion' 'strat2_return-proportion'
#  'strat3_return-proportion' 'strat4_return-proportion'
#  'strat5_return-proportion' 'strat0_intensity-median'
#  'strat1_intensity-median' 'strat2_intensity-median'
#  'strat3_intensity-median' 'strat4_intensity-median'
#  'strat5_intensity-median' 'height_05-percentile' 'height_25-percentile'
#  'height_50-percentile' 'height_75-percentile' 'height_95_percentile'
#  'height_max' 'cover' 'lidar_acq' 'potential_volume' 'stddev_height'
#  'surface_area_ratio' 'surface_volume' 'surface_volume_ratio' 'aspect'
#  'elevation' 'overall_curvature' 'plan_curvature' 'profile_curvature'
#  'slope' 'solar_radiation_index' 'mat' 'mwmt' 'mcmt' 'td' 'map' 'msp'
#  'ahm' 'shm' 'dd_0' 'dd5' 'dd_18' 'dd18' 'nffd' 'bffp' 'effp' 'ffp' 'pas'
#  'emt' 'ext' 'eref' 'cmd' 'rh' 'green' 'blue' 'red' 'nir' 'endvi' 'ndvi'
#  'savi' 'swir1' 'swir2' 'wetness' 'greenness' 'brightness' 'landsat_year'
#  'clim_year' 'distance_to_water_m' 'bulk_dens' 'soil_depth'
#  'pct_clay_surf' 'pct_rock_surf' 'pct_sand_surf' 'pot_veg_type' 'tpa' 'ba'
#  'sdi' 'ccf' 'qmd' 'tcuft' 'topht' 'number_of_strata' 'total_cover'
#  'structure_class' 'canopy_baseheight' 'canopy_bulkdensity'
#  'aboveground_biomass' 'aboveground_carbon' 'gs_tpa' 'AF' 'AS' 'BM' 'BO'
#  'CH' 'CW' 'DF' 'DG' 'ES' 'GC' 'GF' 'IC' 'JP' 'KP' 'LO' 'LP' 'MA' 'MC'
#  'MH' 'NF' 'OH' 'OS' 'OT' 'PC' 'PL' 'PP' 'PY' 'RA' 'RC' 'RF' 'SF' 'SH'
#  'SP' 'SS' 'TO' 'WA' 'WB' 'WF' 'WH' 'WI' 'WJ' 'WL' 'WO' 'WP' 'YC'
#  'TRUE_FIR' 'OTHER_HARDWOOD' 'MAPLE' 'OAK' 'DOUGLAS_FIR' 'SPRUCE' 'CEDAR'
#  'PONDEROSA_PINE' 'OTHER_SOFTWOOD' 'LODGEPOLE_PINE' 'HEMLOCK' 'RED_ALDER'
#  'TANOAK' 'JUNIPER' 'LARCH' 'fvs_year' 'year_diff' 'returns_per_m2']

# %% [markdown]
# ## Filter out some of the training data
# We can exclude some of the training data based on how far separated the inventory data (interpolated using FVS simulations) is from the year the lidar was collected. Similarly, we can screen out training examples that had relatively low density of lidar returns.

# %%
df['year_diff'] = abs(df['fvs_year'] - df['lidar_year']).astype(int)
df = df.loc[df['year_diff'] < 10]
df = df.loc[df['returns_per_m2'] >= 4.0]

# %% [markdown]
# ## Inspect how many samples we have for different years, regions, etc.

# %%
df.groupby(by=['lidar_year'])[['uuid']].count().rename({'uuid':'count'}, axis=1)
# Out:
#             count
# lidar_year
# 2006          191
# 2008          857
# 2009          113
# 2010           21
# 2011          161
# 2012          720
# 2013          269
# 2014          368
# 2015          680
# 2016          604
# 2017          191
# 2018           35

# %%
pd.pivot_table(df, 
               values='uuid', 
               aggfunc='count', 
               index=['meas_yr'], 
               columns=['lidar_year'], 
               fill_value=0)
# Out:
# lidar_year  2006  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# meas_yr
# 2010           0   475     0     0     0     4     0     2     7     0     0
# 2011           0   377     0     0     0     1     0     2     3     0     0
# 2013         168     0    18     0    37   466    54     6    11    14    28
# 2014           5     0    60     2    28   132    45    50    44    99    40
# 2015          18     4     5     0    55    18    13    16   217   114    25
# 2016           0     1    18    15    26    45    90    59   284    77    36
# 2017           0     0     9     2    12    44    43   182    58   104    51
# 2018           0     0     3     2     3    10    24    51    56   196    11
#
# lidar_year  2018
# meas_yr
# 2010           0
# 2011           0
# 2013           2
# 2014           1
# 2015           6
# 2016          26
# 2017           0
# 2018           0

# %%
ecoreg_counts = df.groupby(by=['ecoregion3'])[['uuid']].count()
ecoreg_counts
# Out:
#                                                     uuid
# ecoregion3
# blue_mountains                                       108
# cascades                                             747
# coast_range                                         1809
# columbia_plateau                                      14
# eastern_cascades_slopes_and_foothills                409
# klamath_mountains_california_high_north_coast_r...   323
# north_cascades                                       505
# northern_rockies                                     103
# puget_lowland                                        149
# willamette_valley                                     43

# %% [markdown]
# ## Available features
# First, we'll use one-hot encoding for categorical features

# %%
# convert agency, ecoregion, and lidar acquisition into one-hot encoded set of variables
df = pd.get_dummies(df, prefix='agency', columns=['agency'])
# df = pd.get_dummies(df, prefix='eco', columns=['ecoregion3'])
# df = pd.get_dummies(df, prefix='acq', columns=['lidar_acq'])

# %% [markdown]
# The different types of predictor variables we can use to predict a forest attribute, including climate, lidar-derived, soil, and satellite imagery.

# %%
CLIM_COLS = ['mat', 'mwmt', 'mcmt', 'td', 'map', 'msp', 'ahm', 'shm', 
             'dd_0', 'dd5', 'dd_18', 'dd18', 'nffd', 'bffp', 'effp', 
             'ffp', 'pas', 'emt', 'ext', 'eref', 'cmd', 'rh']
LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
       'strat1_return-proportion', 'strat2_return-proportion',
       'strat3_return-proportion', 'strat4_return-proportion',
       'strat5_return-proportion', 'strat0_intensity-median',
       'strat1_intensity-median', 'strat2_intensity-median',
       'strat3_intensity-median', 'strat4_intensity-median',
       'strat5_intensity-median', 'height_05-percentile',
       'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
       'height_95_percentile', 'height_max', 'cover', 'potential_volume',
       'stddev_height', 'surface_area_ratio', 'surface_volume',
       'surface_volume_ratio', 'aspect', 'elevation', 'overall_curvature',
       'plan_curvature', 'profile_curvature', 'slope', 'solar_radiation_index']

SOIL_COLS = ['bulk_dens', 'soil_depth', 'pct_clay_surf', 'pct_rock_surf', 'pct_sand_surf']

LANDSAT_COLS = ['green', 'blue', 'red', 'nir', 'endvi', 'ndvi', 'savi',
                'swir1', 'swir2', 'wetness', 'greenness', 'brightness']

AGENCY_COLS = ['agency_BLM', 'agency_USFS', 'agency_WADNR']

# ECOREGIONS = [col for col in df.columns if col.startswith('eco_')]

# %% [markdown]
# ## Selecting initial features and targets
# This is the first step in determining what features we want to use, and what we want to predict. Later, we can still apply some procedures to choose a subset of these features to make simpler models.

# %%
X_COLS = LIDAR_COLS + ['plot_size_ac', 'ecoregion3'] + LANDSAT_COLS + CLIM_COLS
Y_COLS = ['qmd']

# %% [markdown]
# ## Split the data into training and testing sets
# Since some plot_ids have multiple observations, we want all observations for each plot_id to fall entirely in train_set or entirely the training or testing sets because these samples are definitely not independent.

# %%
# a dataframe with unique plot ids
splits = pd.DataFrame(pd.unique(df['uuid']), columns=['uuid']).set_index('uuid')

# randomly assign each plot-id to train(0) or test(1) sets
np.random.seed(127)
splits['train0_test1'] = np.random.choice(2,
                                          size=len(splits),
                                          p=[0.8,0.2])

# add set assignments to the dataframe
df['train0_test1'] = splits.loc[df['uuid']]['train0_test1'].values

# %%
train_plots = df.loc[df['train0_test1'] == 0]
test_plots = df.loc[df['train0_test1'] == 1]
len(train_plots), len(test_plots)
# Out:
# (3355, 855)

# %%
x_train, x_test = train_plots[X_COLS].reset_index(drop=True), test_plots[X_COLS].reset_index(drop=True)
y_train, y_test = train_plots[Y_COLS].reset_index(drop=True), test_plots[Y_COLS].reset_index(drop=True)

# %% [markdown]
# ## Standardize features
# Scale all predictive features to have 0 mean and unit variance (subtracting mean, dividing by standard deviation).

# %%
x_scaler = StandardScaler()
x_scaler.fit(df[X_COLS].drop(['ecoregion3'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Consider a few transformations for the target variable

# %%
fig, axs = plt.subplots(1,5, figsize=(12,2.5))
axs.ravel()[0].hist(y_train.values, bins=20)
axs.ravel()[1].hist(np.log(y_train.values+1), bins=20)
axs.ravel()[2].hist(np.sqrt(y_train.values), bins=20)
quantile_transformer = QuantileTransformer(output_distribution='normal', random_state=127)
axs.ravel()[3].hist(quantile_transformer.fit_transform(y_train.values), bins=20)
power_transformer = PowerTransformer(method='box-cox')
axs.ravel()[4].hist(power_transformer.fit_transform(y_train.values + 1e-9), bins=20)

TITLES = ['Raw', 'Log', 'SQRT', 'Quantile', 'Box-Cox']
for i, title in enumerate(TITLES):
    axs.ravel()[i].set_title(title)
plt.show();

# %%
# choose your transformer here
transformer = FunctionTransformer(np.sqrt, np.square, validate=False)

# %%
transformer.fit(df[Y_COLS])
y_train, y_test = transformer.transform(y_train), transformer.transform(y_test)

# %% [markdown]
# ## Split datasets by ecoregion
# We want to explore model transferability between regions, so we'll train models independently on subsets of the data within a single ecoregion, as well as a model that is trained on all available ecoregions.

# %%
ecoregions = [reg for reg in pd.unique(df.ecoregion3) if ecoreg_counts.loc[reg]['uuid'] > 20]

eco_train_idx = [x_train.loc[x_train.ecoregion3 == eco].index.values for eco in ecoregions]
eco_test_idx = [x_test.loc[x_test.ecoregion3 == eco].index.values for eco in ecoregions]

eco_xtrain_dfs = [x_train.loc[x_train.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytrain_dfs = [y_train.loc[idx].values.ravel() for idx in eco_train_idx]
eco_xtest_dfs = [x_test.loc[x_test.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytest_dfs = [y_test.loc[idx].values.ravel() for idx in eco_test_idx]

# append a "global" model that contains data from all ecoregions
ecoregions.append('all')
ecoregion_names = ['_'.join(x.split('_')[0:2]) for x in ecoregions]
eco_xtrain_dfs.append(x_train.drop(['ecoregion3'], axis=1))
eco_ytrain_dfs.append(y_train.values.ravel())
eco_xtest_dfs.append(x_test.drop(['ecoregion3'], axis=1))
eco_ytest_dfs.append(y_test.values.ravel())

# %% [markdown]
# ## Scoring
# We'll use Root Mean Square Error to evaluate model performance.

# %%
def rmse(pred, obs):
    # use our transformer to calculate RMSE on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return np.sqrt(mean_squared_error(obs, pred))

# %%
def nrmse(pred, obs):
    # use our transformer to calculate percent RMSE on the original data scale
    this_rmse = rmse(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return this_rmse/obs.mean()

# %%
def mae(pred, obs):
    # use our transformer to calculate mean absolute error on the original data scale
    pred = transformer.inverse_transform(pred)
    obs = transformer.inverse_transform(obs)
    
    return abs(pred - obs).mean()

# %%
def mape(pred, obs):
    # use our transformer to calculate mean average percent error on the original data scale
    pred = transformer.inverse_transform(pred)
    obs = transformer.inverse_transform(obs)
    
    return abs(pred - obs).mean() / obs.mean()

# %%
def bias(pred, obs):
    # use our transformer to calculate mean bias on the original data scale
    pred = transformer.inverse_transform(pred)
    obs = transformer.inverse_transform(obs)
    
    return (pred - obs).mean()

# %% [markdown]
# This helper function will calculate RMSE scores for each regionally-trained model and the global model on each ecoregion.

# %%
def get_score_df(models, metric=rmse, feature_selectors=None):
    regional_scores = []
    global_scores = []
    counts = []
    
    for i, mod in enumerate(models):
        X_test = x_scaler.transform(eco_xtest_dfs[i])
        if feature_selectors:
            X_test = feature_selectors[i].transform(X_test)
        y_test = eco_ytest_dfs[i]
        reg_score = metric(mod.predict(X_test), y_test)
        regional_scores.append(reg_score.round(3))
        
        if feature_selectors:
            X_test = x_scaler.transform(eco_xtest_dfs[i])
            X_test = feature_selectors[-1].transform(X_test)
        glob_score = metric(models[-1].predict(X_test), y_test)
        global_scores.append(glob_score.round(3))
        count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
        counts.append(count)
        
    data = list(zip(regional_scores, global_scores, counts))
    res_df = pd.DataFrame(data=data,
                          columns=['regional_model', 'global_model', 'n'],
                          index=ecoregion_names)
    
    return res_df

# %% [markdown]
# ## Fit some models
# For each type of model, we'll employ cross-validation to tune model hyperparameters, generating a tuned model for each ecoregion as well as a tuned model using all training data. We'll work our way through:
#
# #### ElasticNet Regression
# Linear model that employs a mix of L1 and L2 regularization to penalize model complexity
#
# #### LASSO Regression
# Linear model that employs L1 regularization to penalize model complexity. We'll also work with a feature-selection process to fit models capped to an explicitly-predefined number of features.
#
# #### K-Nearest Neighbor Regression
#
# #### Random Forest Regression
#
# #### Gradient Boosting Trees Regression
#
# #### Support Vector Machine Regression

# %% [markdown]
# ## ElasticNet (Linear Model)

# %%
best_lms = []

for i in range(len(ecoregions)):
    lm = ElasticNetCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    lm.fit(X, y)
    best_lms.append(lm)

# %%
elastic_res = get_score_df(best_lms)
elastic_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              2.521         5.221   108
# coast_range                 5.542         5.808  1646
# eastern_cascades            4.710         5.383   403
# north_cascades              4.226         4.374   490
# cascades                    5.387         5.437   728
# klamath_mountains           6.548         7.072   321
# northern_rockies            7.971         8.457   103
# puget_lowland               5.205         5.259   147
# willamette_valley           3.342         3.975    43
# all                         5.700         5.700  3355

# %%
coefs = np.array([lm.coef_ for lm in best_lms])
count_nonzero = [(~np.isclose(coef, 0, atol=1e-3)).sum() for coef in coefs]
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                  0.02
# eastern_cascades_slopes_and_foothills                          --
# north_cascades                                              0.026
# cascades                                                    0.006
# klamath_mountains_california_high_north_coast_r...          0.075
# northern_rockies                                               --
# puget_lowland                                              -0.018
# willamette_valley                                              --
# all                                                         0.008
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                 0.078
# north_cascades                                                           --
# cascades                                                             -0.068
# klamath_mountains_california_high_north_coast_r...                    0.323
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     0.172
# all                                                                   0.046
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                          -0.047
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                       -0.057
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.177
# northern_rockies                                                     -0.105
# puget_lowland                                                        -0.188
# willamette_valley                                                        --
# all                                                                  -0.055
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                       -0.173
# coast_range                                                          -0.066
# eastern_cascades_slopes_and_foothills                                -0.154
# north_cascades                                                       -0.032
# cascades                                                             -0.025
# klamath_mountains_california_high_north_coast_r...                   -0.029
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                  -0.032
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                         0.01
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                -0.136
# north_cascades                                                        0.018
# cascades                                                             -0.089
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.018
# all                                                                   0.008
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.215
# coast_range                                                           0.098
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                        0.109
# cascades                                                              0.032
# klamath_mountains_california_high_north_coast_r...                    0.167
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.012
# all                                                                    0.17
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.062
# eastern_cascades_slopes_and_foothills                                 0.139
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.216
#
#                                                    strat0_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.123
# cascades                                                             0.063
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.008
#
#                                                    strat1_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                0.015
# north_cascades                                                          --
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat2_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                         -0.038
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.064
# cascades                                                            -0.112
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.092
#
#                                                     ...   dd18   nffd   bffp  \
# blue_mountains                                      ...     --     -- -0.023
# coast_range                                         ...  0.082     -- -0.023
# eastern_cascades_slopes_and_foothills               ...     --     --  0.175
# north_cascades                                      ...     --     --     --
# cascades                                            ...     -- -0.391     --
# klamath_mountains_california_high_north_coast_r...  ...     --     --     --
# northern_rockies                                    ...     --     --     --
# puget_lowland                                       ...     --     --  0.102
# willamette_valley                                   ...     --     --     --
# all                                                 ...     -- -0.297 -0.064
#
#                                                      effp    ffp    pas  \
# blue_mountains                                         --     --     --
# coast_range                                            --     --     --
# eastern_cascades_slopes_and_foothills                  -- -0.028 -0.057
# north_cascades                                         --     --     --
# cascades                                            0.229     -- -0.057
# klamath_mountains_california_high_north_coast_r...     --     --     --
# northern_rockies                                       --     --     --
# puget_lowland                                          -- -0.011     --
# willamette_valley                                      --     --     --
# all                                                    --     --     --
#
#                                                       emt    ext   eref     rh
# blue_mountains                                         --     --     --  0.022
# coast_range                                            --     --     --     --
# eastern_cascades_slopes_and_foothills                  --     --     --     --
# north_cascades                                         --     --     -- -0.089
# cascades                                               --     --     --     --
# klamath_mountains_california_high_north_coast_r...     --     --     --     --
# northern_rockies                                       --     --     --     --
# puget_lowland                                          --     --     --     --
# willamette_valley                                      --     --     --     --
# all                                                -0.037 -0.016 -0.107 -0.026
#
# [10 rows x 62 columns]

# %% [markdown]
# ## LASSO (Linear Model)
# Starting with implicit feature selection via L1 regularization of coefficients.

# %%
best_lassos = []

for i in range(len(ecoregions)):
    lasso = LassoCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000, n_alphas=1000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    lasso.fit(X, y)
    best_lassos.append(lasso)

# %%
coefs = np.array([lm.coef_ for lm in best_lassos])
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.019
# eastern_cascades_slopes_and_foothills                          --
# north_cascades                                              0.008
# cascades                                                    0.006
# klamath_mountains_california_high_north_coast_r...          0.063
# northern_rockies                                               --
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                         0.008
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                 0.094
# north_cascades                                                           --
# cascades                                                             -0.057
# klamath_mountains_california_high_north_coast_r...                    0.377
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     0.215
# all                                                                   0.041
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           -0.04
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                       -0.065
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.158
# northern_rockies                                                     -0.085
# puget_lowland                                                        -0.194
# willamette_valley                                                        --
# all                                                                  -0.057
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                       -0.137
# coast_range                                                          -0.059
# eastern_cascades_slopes_and_foothills                                -0.149
# north_cascades                                                           --
# cascades                                                             -0.021
# klamath_mountains_california_high_north_coast_r...                   -0.011
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                  -0.034
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                -0.137
# north_cascades                                                           --
# cascades                                                             -0.086
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.004
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.235
# coast_range                                                           0.097
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                        0.096
# cascades                                                               0.03
# klamath_mountains_california_high_north_coast_r...                    0.187
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.009
# all                                                                   0.167
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.056
# eastern_cascades_slopes_and_foothills                                 0.094
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.206
#
#                                                    strat0_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.107
# cascades                                                             0.064
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.008
#
#                                                    strat1_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                0.018
# north_cascades                                                          --
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat2_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                         -0.011
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.047
# cascades                                                            -0.108
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                 -0.093
#
#                                                     ...   dd_0   dd18   nffd  \
# blue_mountains                                      ...     --     --     --
# coast_range                                         ...     --  0.092     --
# eastern_cascades_slopes_and_foothills               ...     --     --     --
# north_cascades                                      ...     --     --     --
# cascades                                            ...     --     -- -0.447
# klamath_mountains_california_high_north_coast_r...  ...     --     --     --
# northern_rockies                                    ...     --     --     --
# puget_lowland                                       ...     --     --     --
# willamette_valley                                   ...     --     --     --
# all                                                 ...  0.121     -- -0.323
#
#                                                      bffp   effp    pas  \
# blue_mountains                                         --     --     --
# coast_range                                            --     --     --
# eastern_cascades_slopes_and_foothills               0.182     -- -0.051
# north_cascades                                         --     --     --
# cascades                                               --  0.271 -0.064
# klamath_mountains_california_high_north_coast_r...     --     --     --
# northern_rockies                                       --     --     --
# puget_lowland                                          --     --     --
# willamette_valley                                      --     --     --
# all                                                -0.056     --     --
#
#                                                       emt    ext   eref     rh
# blue_mountains                                         --     --     --  0.003
# coast_range                                            --     --     --     --
# eastern_cascades_slopes_and_foothills                  --     --     --     --
# north_cascades                                         --     --     -- -0.039
# cascades                                               --     --     --     --
# klamath_mountains_california_high_north_coast_r...     --     --     --     --
# northern_rockies                                       --     --     --     --
# puget_lowland                                          --     --     --     --
# willamette_valley                                      --     --     --     --
# all                                                -0.044 -0.007 -0.091     --
#
# [10 rows x 57 columns]

# %% [markdown]
# Now we'll explicitly define the maximum number of features to use for fitting a linear model. We'll trim features by iteratively increasing a threshold for coefficients using LASSO regression

# %%
MAX_FEATURES = 5
sfms = [] # transformers that filter X features
trimmed_lassos = [] # re-fit lasso regressions on the subset of the features

for i, lasso in enumerate(best_lassos):
    lasso = deepcopy(lasso)
    sfm = SelectFromModel(lasso, threshold=0.001)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    Y = (eco_ytrain_dfs[i].ravel())
    sfm.fit(X, Y)
    n_features = sfm.transform(X).shape[1]

    # Reset the threshold till the number of features equals two.
    # Note that the attribute can be set directly instead of repeatedly
    # fitting the metatransformer.
    while n_features > MAX_FEATURES:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    
    sfms.append(sfm)
    try:
        trimmed_lassos.append(lasso.fit(sfm.transform(X), Y))
    except ValueError:
        print(ecoregion_names[i])
        raise

# %%
coefs = []
for i in range(len(ecoregions)):
    cols = np.zeros(eco_xtest_dfs[i].columns.shape)
    cols[sfms[i].get_support()] = trimmed_lassos[i].coef_
    coefs.append(cols)
    
coefs = np.array(coefs)

coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                     0.35
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     0.252
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                     -0.118
# puget_lowland                                                        -0.216
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                -0.169
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                -0.315
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.386
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                        0.218
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat0_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.139
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat3_intensity-median  \
# blue_mountains                                                       0.371
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                          --
# cascades                                                                --
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    height_75-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# eastern_cascades_slopes_and_foothills                                --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# northern_rockies                                                  0.092
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_95_percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# eastern_cascades_slopes_and_foothills                             1.104
# north_cascades                                                    0.607
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# northern_rockies                                                   0.42
# puget_lowland                                                     0.126
# willamette_valley                                                    --
# all                                                               1.196
#
#                                                    height_max  ...  \
# blue_mountains                                             --  ...
# coast_range                                                --  ...
# eastern_cascades_slopes_and_foothills                  -0.734  ...
# north_cascades                                             --  ...
# cascades                                                   --  ...
# klamath_mountains_california_high_north_coast_r...         --  ...
# northern_rockies                                           --  ...
# puget_lowland                                              --  ...
# willamette_valley                                          --  ...
# all                                                    -0.917  ...
#
#                                                    profile_curvature  slope  \
# blue_mountains                                                    --     --
# coast_range                                                       --     --
# eastern_cascades_slopes_and_foothills                             --     --
# north_cascades                                                    --     --
# cascades                                                          --     --
# klamath_mountains_california_high_north_coast_r...                --     --
# northern_rockies                                                  --     --
# puget_lowland                                                     --  0.193
# willamette_valley                                              0.074     --
# all                                                               --     --
#
#                                                    plot_size_ac  swir2   mcmt  \
# blue_mountains                                               --  0.277     --
# coast_range                                                  -- -0.252     --
# eastern_cascades_slopes_and_foothills                        --     --     --
# north_cascades                                               --     --     --
# cascades                                                     -- -0.414     --
# klamath_mountains_california_high_north_coast_r...        0.511     --     --
# northern_rockies                                             --     --     --
# puget_lowland                                                --     --     --
# willamette_valley                                         0.217     --     --
# all                                                          --     --  0.239
#
#                                                       msp    ahm   shm   nffd  \
# blue_mountains                                         --     --    --     --
# coast_range                                            --     -- -0.25     --
# eastern_cascades_slopes_and_foothills                  --     --    --     --
# north_cascades                                      0.142     --    --     --
# cascades                                               --  0.304    --  -0.06
# klamath_mountains_california_high_north_coast_r...     --     --    --     --
# northern_rockies                                       --     --    --     --
# puget_lowland                                          --     --    --     --
# willamette_valley                                      --     --    --     --
# all                                                    --     --    -- -0.189
#
#                                                      bffp
# blue_mountains                                         --
# coast_range                                            --
# eastern_cascades_slopes_and_foothills               0.126
# north_cascades                                         --
# cascades                                               --
# klamath_mountains_california_high_north_coast_r...     --
# northern_rockies                                       --
# puget_lowland                                          --
# willamette_valley                                      --
# all                                                    --
#
# [10 rows x 24 columns]

# %% [markdown]
# ## K-Nearest Neighbors Regression

# %%
# Set the parameters by cross-validation
knn_params = {'n_neighbors': [1,2,3,4,5,10,20],
              'weights': ['uniform', 'distance'],
              'metric': ['minkowski', 'manhattan']}


knn_gs = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=knn_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_knns = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    knn_gs.fit(X, y)
    best_fit = knn_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_knns.append(best_fit)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    5.6s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    6.0s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.3s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.9s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.3s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.3s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.3s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.2s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.6s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    3.5s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    4.5s finished

# %% [markdown]
# ## Random Forest Regression

# %%
# Set the parameters by cross-validation
rf_params = {'n_estimators': [100, 500, 1000, 5000],
             'max_features': ['sqrt'],
             'max_depth': [3, 5, 10, 25, 50],
             'min_samples_leaf': [1,2,4],
             'bootstrap': [True, False]}


rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=rf_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_rfs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    rf_gs.fit(X, y)
    best_fit = rf_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_rfs.append(best_fit)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   59.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   26.2s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  3.1min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.6min finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   28.9s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  2.3min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   32.1s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  3.0min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:   28.8s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.6min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.3min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.3min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.1min finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:  1.9min
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed: 14.0min finished

# %%
### Employing feature selection to try and improve random forest regression

# %%
importances = best_rfs[-1].feature_importances_
indices = np.argsort(importances)[::-1]
features = eco_xtrain_dfs[-1].columns[indices]

# Print the feature ranking
print("Feature ranking:")

for f in range(eco_xtrain_dfs[-1].shape[1]):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. potential_volume (0.098055)
# 2. surface_volume (0.077039)
# 3. height_75-percentile (0.056334)
# 4. stddev_height (0.050717)
# 5. height_50-percentile (0.042563)
# 6. surface_area_ratio (0.037487)
# 7. strat5_return-proportion (0.035852)
# 8. height_95_percentile (0.035340)
# 9. strat1_return-proportion (0.021355)
# 10. strat3_return-proportion (0.021226)
# 11. strat2_return-proportion (0.020697)
# 12. height_max (0.020615)
# 13. cover (0.019756)
# 14. strat4_return-proportion (0.018815)
# 15. height_25-percentile (0.015809)
# 16. swir2 (0.014463)
# 17. strat4_intensity-median (0.012676)
# 18. strat5_intensity-median (0.011520)
# 19. emt (0.010503)
# 20. swir1 (0.010443)
# 21. wetness (0.010147)
# 22. cmd (0.010058)
# 23. strat0_return-proportion (0.009922)
# 24. nir (0.009838)
# 25. elevation (0.009643)
# 26. map (0.009626)
# 27. greenness (0.009597)
# 28. strat2_intensity-median (0.009571)
# 29. brightness (0.009536)
# 30. savi (0.009514)
# 31. ndvi (0.009366)
# 32. strat3_intensity-median (0.009285)
# 33. shm (0.009204)
# 34. green (0.009175)
# 35. plot_size_ac (0.008878)
# 36. red (0.008876)
# 37. ffp (0.008640)
# 38. mcmt (0.008580)
# 39. slope (0.008518)
# 40. strat0_intensity-median (0.008453)
# 41. msp (0.008277)
# 42. ahm (0.008230)
# 43. td (0.008183)
# 44. effp (0.007977)
# 45. strat1_intensity-median (0.007963)
# 46. bffp (0.007668)
# 47. eref (0.007652)
# 48. nffd (0.007651)
# 49. endvi (0.007584)
# 50. solar_radiation_index (0.007557)
# 51. dd5 (0.007434)
# 52. dd_18 (0.007277)
# 53. ext (0.007269)
# 54. rh (0.007240)
# 55. blue (0.007238)
# 56. aspect (0.006967)
# 57. returns_per_m2 (0.006878)
# 58. dd_0 (0.006847)
# 59. overall_curvature (0.006830)
# 60. plan_curvature (0.006638)
# 61. dd18 (0.006535)
# 62. profile_curvature (0.006460)
# 63. pas (0.006347)
# 64. mat (0.005629)
# 65. mwmt (0.005492)
# 66. height_05-percentile (0.002485)
# 67. surface_volume_ratio (0.000003)

# %% [markdown]
# ## Gradient Boosting Trees Regression

# %%
# Set the parameters by cross-validation
gb_params = {'n_estimators': [100, 500, 1000, 5000],
             'learning_rate': [0.01, 0.1],
             'max_depth': [2, 3, 4, 5, 10],
             'max_features': ['sqrt'] 
            }

gb_gs = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=gb_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_gbs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    gb_gs.fit(X, y)
    best_fit = gb_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_gbs.append(best_fit)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.6s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    4.3s remaining:    4.7s
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   11.8s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   12.0s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.7s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.9s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    3.5s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.7s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    4.6s remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.2s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.6s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.8s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.9s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.7s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.9s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.6s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   39.8s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   40.3s finished

# %%
### Employing feature selection to try and improve gradient boosting regression

# %% [markdown]
# ## Support Vector Machines Regression

# %%
# Set the parameters by cross-validation
svm_params = {'kernel': ['linear', 'rbf'],
              'gamma': ['scale', 'auto'],
              'C': [0.1,1,10,100,1000]
              }

svm_gs = GridSearchCV(estimator=SVR(), param_grid=svm_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_svms = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    svm_gs.fit(X, y)
    best_fit = svm_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_svms.append(best_fit)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   28.6s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.9s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  8.4min finished
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    2.6s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  2.4min finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  4.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.2s remaining:    0.2s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  5.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    1.8s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.7min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.8min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    4.5s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 30.3min finished

# %%
### Employing feature selection to try and improve support vector regression

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

def scatter_graphs(model_dict):
    names = MODELS.keys()
    EXTEND_PCT = 0.10
    
    fig, axs = plt.subplots(len(ecoregion_names), len(names), 
                            sharex=True, sharey=True,
                            figsize=(12,15)
                           )
    
    all_obs = transformer.inverse_transform(eco_ytest_dfs[-1])
    obs_min = all_obs.min()
    obs_max = all_obs.max()
    rng = obs_max - obs_min
        
    for i, ecoreg in enumerate(ecoregion_names):
        observed = transformer.inverse_transform(eco_ytest_dfs[i])
        
        for j, name in enumerate(names):
            axs[0,j].set_title(name)
            axs[i,0].set_ylabel(ecoreg)
            axs[i,j].set_xlim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_ylim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_aspect('equal')
            
            if name == 'LASSO_{}'.format(MAX_FEATURES):
                predicted = MODELS[name][-1].predict(sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i])))
            else:
                predicted = MODELS[name][-1].predict(x_scaler.transform(eco_xtest_dfs[i]))
            
            predicted = transformer.inverse_transform(predicted)
            axs[i,j].scatter(observed, predicted, s=0.5)
            axs[i,j].plot((obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng), 
                          (obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng),
                         color='k', lw=0.5)
            
    plt.tight_layout(pad=0.001)

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

scatter_graphs(MODELS)

# %% [markdown]
# ## View scores for regional and global models

# %%
MODEL_NAMES = ['ElasticNet', 'LASSO', 'LASSO_{}'.format(MAX_FEATURES), 'KNN', 'RF', 'GB', 'SVM']
BEST_MODELS = [best_lms, best_lassos, trimmed_lassos, best_knns, best_rfs, best_gbs, best_svms]

def compare_models(metric):
    score_dfs = []
    for name, best_models in list(zip(MODEL_NAMES, BEST_MODELS)):
        if name == 'LASSO_{}'.format(MAX_FEATURES):
            score_df = get_score_df(best_models, metric, sfms) 
            score_dfs.append(score_df)
        else:
            score_df = get_score_df(best_models, metric) 
            score_dfs.append(score_df)
        
    counts = np.array(score_dfs[-1]['n'].values)
    regional_data = np.array([df['regional_model'].values for df in score_dfs])
    global_data = np.array([df['global_model'].values for df in score_dfs])
    
    return regional_data, global_data, counts

# %%
def highlight_best(s):
    '''
    highlight the closest value to zero in a Series yellow.
    '''
    lowest_idx = abs(s).idxmin()
    return ['background-color: yellow' if idx==lowest_idx else '' for idx in s.index]

# %%
print('Regional Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
regional_rmse = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_rmse
 .style
 .highlight_min(color='yellow', axis=1))
# Out:
# Regional Models, RMSE
# <style  type="text/css" >
#     #T_9322d836_4d3e_11ea_841f_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_9322d836_4d3e_11ea_841f_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_9322d836_4d3e_11ea_841f_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_9322d836_4d3e_11ea_841f_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_9322d836_4d3e_11ea_841f_00505683952erow4_col1 {
#             background-color:  yellow;
#         }    #T_9322d836_4d3e_11ea_841f_00505683952erow5_col5 {
#             background-color:  yellow;
#         }    #T_9322d836_4d3e_11ea_841f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_9322d836_4d3e_11ea_841f_00505683952erow7_col0 {
#             background-color:  yellow;
#         }    #T_9322d836_4d3e_11ea_841f_00505683952erow8_col5 {
#             background-color:  yellow;
#         }    #T_9322d836_4d3e_11ea_841f_00505683952erow9_col6 {
#             background-color:  yellow;
#         }</style><table id="T_9322d836_4d3e_11ea_841f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9322d836_4d3e_11ea_841f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_9322d836_4d3e_11ea_841f_00505683952erow0_col0" class="data row0 col0" >2.521</td>
#                         <td id="T_9322d836_4d3e_11ea_841f_00505683952erow0_col1" class="data row0 col1" >2.625</td>
#                         <td id="T_9322d836_4d3e_11ea_841f_00505683952erow0_col2" class="data row0 col2" >2.808</td>
#                         <td id="T_9322d836_4d3e_11ea_841f_00505683952erow0_col3" class="data row0 col3" >3.386</td>
#                         <td id="T_9322d836_4d3e_11ea_841f_00505683952er
</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow1_col1" class="data row1 col1" >39%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow1_col2" class="data row1 col2" >40%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow1_col3" class="data row1 col3" >40%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow1_col4" class="data row1 col4" >39%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow1_col5" class="data row1 col5" >39%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow1_col6" class="data row1 col6" >38%</td>
#             </tr>
#             <tr>
#                         <th id="T_95ec3ada_4d3e_11ea_841f_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow2_col0" class="data row2 col0" >41%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow2_col1" class="data row2 col1" >42%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow2_col2" class="data row2 col2" >45%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow2_col3" class="data row2 col3" >46%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow2_col4" class="data row2 col4" >41%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow2_col5" class="data row2 col5" >40%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow2_col6" class="data row2 col6" >45%</td>
#             </tr>
#             <tr>
#                         <th id="T_95ec3ada_4d3e_11ea_841f_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow3_col0" class="data row3 col0" >38%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow3_col1" class="data row3 col1" >37%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow3_col2" class="data row3 col2" >37%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow3_col3" class="data row3 col3" >38%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow3_col4" class="data row3 col4" >36%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow3_col5" class="data row3 col5" >37%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow3_col6" class="data row3 col6" >41%</td>
#             </tr>
#             <tr>
#                         <th id="T_95ec3ada_4d3e_11ea_841f_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow4_col0" class="data row4 col0" >39%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow4_col1" class="data row4 col1" >39%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow4_col2" class="data row4 col2" >41%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow4_col3" class="data row4 col3" >44%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow4_col4" class="data row4 col4" >41%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow4_col5" class="data row4 col5" >40%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow4_col6" class="data row4 col6" >39%</td>
#             </tr>
#             <tr>
#                         <th id="T_95ec3ada_4d3e_11ea_841f_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow5_col0" class="data row5 col0" >67%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow5_col1" class="data row5 col1" >67%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow5_col2" class="data row5 col2" >71%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow5_col3" class="data row5 col3" >67%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow5_col4" class="data row5 col4" >62%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow5_col5" class="data row5 col5" >59%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow5_col6" class="data row5 col6" >67%</td>
#             </tr>
#             <tr>
#                         <th id="T_95ec3ada_4d3e_11ea_841f_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow6_col0" class="data row6 col0" >62%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow6_col1" class="data row6 col1" >63%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f_00505683952erow6_col2" class="data row6 col2" >59%</td>
#                         <td id="T_95ec3ada_4d3e_11ea_841f

# %%
print('Regional Models, Bias')
regional_data, global_data, counts = compare_models(bias)
regional_rmse = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_rmse
 .style
 .apply(highlight_best, axis=1))
# Out:
# Regional Models, Bias
# <style  type="text/css" >
#     #T_af669d0c_4d3e_11ea_841f_00505683952erow0_col0 {
#             background-color:  yellow;
#         }    #T_af669d0c_4d3e_11ea_841f_00505683952erow1_col3 {
#             background-color:  yellow;
#         }    #T_af669d0c_4d3e_11ea_841f_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_af669d0c_4d3e_11ea_841f_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_af669d0c_4d3e_11ea_841f_00505683952erow4_col3 {
#             background-color:  yellow;
#         }    #T_af669d0c_4d3e_11ea_841f_00505683952erow5_col0 {
#             background-color:  yellow;
#         }    #T_af669d0c_4d3e_11ea_841f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_af669d0c_4d3e_11ea_841f_00505683952erow7_col6 {
#             background-color:  yellow;
#         }    #T_af669d0c_4d3e_11ea_841f_00505683952erow8_col0 {
#             background-color:  yellow;
#         }    #T_af669d0c_4d3e_11ea_841f_00505683952erow9_col3 {
#             background-color:  yellow;
#         }</style><table id="T_af669d0c_4d3e_11ea_841f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_af669d0c_4d3e_11ea_841f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_af669d0c_4d3e_11ea_841f_00505683952er
td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow0_col3" class="data row0 col3" >3.371</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow0_col4" class="data row0 col4" >4.028</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow0_col5" class="data row0 col5" >3.971</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow0_col6" class="data row0 col6" >3.042</td>
#             </tr>
#             <tr>
#                         <th id="T_b7734cfc_4d3e_11ea_841f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow1_col0" class="data row1 col0" >5.808</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow1_col1" class="data row1 col1" >5.801</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow1_col2" class="data row1 col2" >6.537</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow1_col3" class="data row1 col3" >5.657</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow1_col4" class="data row1 col4" >5.484</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow1_col5" class="data row1 col5" >5.505</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow1_col6" class="data row1 col6" >5.375</td>
#             </tr>
#             <tr>
#                         <th id="T_b7734cfc_4d3e_11ea_841f_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow2_col0" class="data row2 col0" >5.383</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow2_col1" class="data row2 col1" >5.372</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow2_col2" class="data row2 col2" >4.548</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow2_col3" class="data row2 col3" >5.19</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow2_col4" class="data row2 col4" >4.691</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow2_col5" class="data row2 col5" >4.668</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow2_col6" class="data row2 col6" >5.181</td>
#             </tr>
#             <tr>
#                         <th id="T_b7734cfc_4d3e_11ea_841f_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow3_col0" class="data row3 col0" >4.374</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow3_col1" class="data row3 col1" >4.359</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow3_col2" class="data row3 col2" >4.257</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow3_col3" class="data row3 col3" >4.199</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow3_col4" class="data row3 col4" >4.081</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow3_col5" class="data row3 col5" >4.161</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow3_col6" class="data row3 col6" >4.083</td>
#             </tr>
#             <tr>
#                         <th id="T_b7734cfc_4d3e_11ea_841f_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow4_col0" class="data row4 col0" >5.437</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow4_col1" class="data row4 col1" >5.437</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow4_col2" class="data row4 col2" >6.278</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow4_col3" class="data row4 col3" >6.184</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow4_col4" class="data row4 col4" >5.408</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow4_col5" class="data row4 col5" >5.275</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow4_col6" class="data row4 col6" >5.322</td>
#             </tr>
#             <tr>
#                         <th id="T_b7734cfc_4d3e_11ea_841f_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow5_col0" class="data row5 col0" >7.072</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow5_col1" class="data row5 col1" >7.077</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow5_col2" class="data row5 col2" >7.716</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow5_col3" class="data row5 col3" >5.859</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow5_col4" class="data row5 col4" >6.08</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow5_col5" class="data row5 col5" >6.088</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow5_col6" class="data row5 col6" >6.538</td>
#             </tr>
#             <tr>
#                         <th id="T_b7734cfc_4d3e_11ea_841f_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow6_col0" class="data row6 col0" >8.457</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow6_col1" class="data row6 col1" >8.451</td>
#                         <td id="T_b7734cfc_4d3e_11ea_841f_00505683952erow6_col2" class

# %%
print('Global Models, RMSE%')
regional_data, global_data, counts = compare_models(nrmse)
global_rmse = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_rmse[global_rmse.columns[:-1]]
 .style
 .format("{:.0%}")
 .highlight_min(color='yellow', axis=1))
# Out:
# Global Models, RMSE%
# <style  type="text/css" >
#     #T_ba219c4c_4d3e_11ea_841f_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_ba219c4c_4d3e_11ea_841f_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_ba219c4c_4d3e_11ea_841f_00505683952erow2_col2 {
#             background-color:  yellow;
#         }    #T_ba219c4c_4d3e_11ea_841f_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_ba219c4c_4d3e_11ea_841f_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_ba219c4c_4d3e_11ea_841f_00505683952erow5_col3 {
#             background-color:  yellow;
#         }    #T_ba219c4c_4d3e_11ea_841f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_ba219c4c_4d3e_11ea_841f_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_ba219c4c_4d3e_11ea_841f_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_ba219c4c_4d3e_11ea_841f_00505683952erow9_col6 {
#             background-color:  yellow;
#         }</style><table id="T_ba219c4c_4d3e_11ea_841f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba219c4c_4d3e_11ea_841f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow0_col0" class="data row0 col0" >38%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow0_col1" class="data row0 col1" >38%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow0_col2" class="data row0 col2" >44%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow0_col3" class="data row0 col3" >24%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow0_col4" class="data row0 col4" >29%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow0_col5" class="data row0 col5" >29%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow0_col6" class="data row0 col6" >22%</td>
#             </tr>
#             <tr>
#                         <th id="T_ba219c4c_4d3e_11ea_841f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow1_col0" class="data row1 col0" >41%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow1_col1" class="data row1 col1" >41%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow1_col2" class="data row1 col2" >46%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow1_col3" class="data row1 col3" >40%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow1_col4" class="data row1 col4" >39%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow1_col5" class="data row1 col5" >39%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow1_col6" class="data row1 col6" >38%</td>
#             </tr>
#             <tr>
#                         <th id="T_ba219c4c_4d3e_11ea_841f_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow2_col0" class="data row2 col0" >47%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow2_col1" class="data row2 col1" >47%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow2_col2" class="data row2 col2" >40%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow2_col3" class="data row2 col3" >45%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow2_col4" class="data row2 col4" >41%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow2_col5" class="data row2 col5" >41%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow2_col6" class="data row2 col6" >45%</td>
#             </tr>
#             <tr>
#                         <th id="T_ba219c4c_4d3e_11ea_841f_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow3_col0" class="data row3 col0" >39%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow3_col1" class="data row3 col1" >39%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow3_col2" class="data row3 col2" >38%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow3_col3" class="data row3 col3" >38%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow3_col4" class="data row3 col4" >36%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow3_col5" class="data row3 col5" >37%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow3_col6" class="data row3 col6" >37%</td>
#             </tr>
#             <tr>
#                         <th id="T_ba219c4c_4d3e_11ea_841f_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow4_col0" class="data row4 col0" >39%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow4_col1" class="data row4 col1" >39%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow4_col2" class="data row4 col2" >45%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow4_col3" class="data row4 col3" >44%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow4_col4" class="data row4 col4" >39%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow4_col5" class="data row4 col5" >38%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow4_col6" class="data row4 col6" >38%</td>
#             </tr>
#             <tr>
#                         <th id="T_ba219c4c_4d3e_11ea_841f_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow5_col0" class="data row5 col0" >72%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow5_col1" class="data row5 col1" >72%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow5_col2" class="data row5 col2" >79%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow5_col3" class="data row5 col3" >60%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow5_col4" class="data row5 col4" >62%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow5_col5" class="data row5 col5" >62%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow5_col6" class="data row5 col6" >67%</td>
#             </tr>
#             <tr>
#                         <th id="T_ba219c4c_4d3e_11ea_841f_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow6_col0" class="data row6 col0" >66%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow6_col1" class="data row6 col1" >66%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f_00505683952erow6_col2" class="data row6 col2" >57%</td>
#                         <td id="T_ba219c4c_4d3e_11ea_841f

# %%
print('Global Models, Bias')
regional_data, global_data, counts = compare_models(bias)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores
 .style
 .apply(highlight_best, axis=1))
# Out:
# Global Models, Bias
# <style  type="text/css" >
#     #T_bcc4ef1c_4d3e_11ea_841f_00505683952erow0_col3 {
#             background-color:  yellow;
#         }    #T_bcc4ef1c_4d3e_11ea_841f_00505683952erow1_col3 {
#             background-color:  yellow;
#         }    #T_bcc4ef1c_4d3e_11ea_841f_00505683952erow2_col2 {
#             background-color:  yellow;
#         }    #T_bcc4ef1c_4d3e_11ea_841f_00505683952erow3_col1 {
#             background-color:  yellow;
#         }    #T_bcc4ef1c_4d3e_11ea_841f_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_bcc4ef1c_4d3e_11ea_841f_00505683952erow5_col5 {
#             background-color:  yellow;
#         }    #T_bcc4ef1c_4d3e_11ea_841f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T
</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow0_col3" class="data row0 col3" >19%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow0_col4" class="data row0 col4" >23%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow0_col5" class="data row0 col5" >20%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow0_col6" class="data row0 col6" >16%</td>
#             </tr>
#             <tr>
#                         <th id="T_c229d0a8_4d3e_11ea_841f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow1_col0" class="data row1 col0" >29%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow1_col1" class="data row1 col1" >29%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow1_col2" class="data row1 col2" >35%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow1_col3" class="data row1 col3" >27%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow1_col4" class="data row1 col4" >26%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow1_col5" class="data row1 col5" >26%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow1_col6" class="data row1 col6" >26%</td>
#             </tr>
#             <tr>
#                         <th id="T_c229d0a8_4d3e_11ea_841f_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow2_col0" class="data row2 col0" >32%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow2_col1" class="data row2 col1" >32%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow2_col2" class="data row2 col2" >28%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow2_col3" class="data row2 col3" >32%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow2_col4" class="data row2 col4" >29%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow2_col5" class="data row2 col5" >29%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow2_col6" class="data row2 col6" >30%</td>
#             </tr>
#             <tr>
#                         <th id="T_c229d0a8_4d3e_11ea_841f_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow3_col0" class="data row3 col0" >28%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow3_col1" class="data row3 col1" >28%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow3_col2" class="data row3 col2" >30%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow3_col3" class="data row3 col3" >26%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow3_col4" class="data row3 col4" >24%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow3_col5" class="data row3 col5" >25%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow3_col6" class="data row3 col6" >27%</td>
#             </tr>
#             <tr>
#                         <th id="T_c229d0a8_4d3e_11ea_841f_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow4_col0" class="data row4 col0" >26%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow4_col1" class="data row4 col1" >26%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow4_col2" class="data row4 col2" >30%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow4_col3" class="data row4 col3" >29%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow4_col4" class="data row4 col4" >24%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow4_col5" class="data row4 col5" >24%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow4_col6" class="data row4 col6" >23%</td>
#             </tr>
#             <tr>
#                         <th id="T_c229d0a8_4d3e_11ea_841f_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow5_col0" class="data row5 col0" >53%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow5_col1" class="data row5 col1" >53%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow5_col2" class="data row5 col2" >61%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow5_col3" class="data row5 col3" >46%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow5_col4" class="data row5 col4" >44%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow5_col5" class="data row5 col5" >42%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow5_col6" class="data row5 col6" >44%</td>
#             </tr>
#             <tr>
#                         <th id="T_c229d0a8_4d3e_11ea_841f_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow6_col0" class="data row6 col0" >45%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_00505683952erow6_col1" class="data row6 col1" >45%</td>
#                         <td id="T_c229d0a8_4d3e_11ea_841f_0050568395

# %%
print('Global Models, Mean Bias')
regional_data, global_data, counts = compare_models(bias)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores
 .style.apply(highlight_best, axis=1))
# Out:
# Global Models, Mean Bias
# <style  type="text/css" >
#     #T_c77c123c_4d3e_11ea_841f_00505683952erow0_col3 {
#             background-color:  yellow;
#         }    #T_c77c123c_4d3e_11ea_841f_00505683952erow1_col3 {
#             background-color:  yellow;
#         }    #T_c77c123c_4d3e_11ea_841f_00505683952erow2_col2 {
#             background-color:  yellow;
#         }    #T_c77c123c_4d3e_11ea_841f_00505683952erow3_col1 {
#             background-color:  yellow;
#         }    #T_c77c123c_4d3e_11ea_841f_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_c77c123c_4d3e_11ea_841f_00505683952erow5_col5 {
#             background-color:  yellow;
#         }    #T_c77c123c_4d3e_11ea_841f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_c77c123c_4d3e_11ea_841f_00505683952erow7_col2 {
#             background-color:  yellow;
#         }    #T_c77c123c_4d3e_11ea_841f_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_c77c123c_4d3e_11ea_841f_00505683952erow9_col3 {
#             background-color:  yellow;
#         }</style><table id="T_c77c123c_4d3e_11ea_841f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c77c123c_4d3e_11ea_841f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow0_col0" class="data row0 col0" >-3.17</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow0_col1" class="data row0 col1" >-3.226</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow0_col2" class="data row0 col2" >-5.188</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow0_col3" class="data row0 col3" >-1.329</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow0_col4" class="data row0 col4" >-2.516</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow0_col5" class="data row0 col5" >-2.216</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow0_col6" class="data row0 col6" >-1.403</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_c77c123c_4d3e_11ea_841f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow1_col0" class="data row1 col0" >-1.31</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow1_col1" class="data row1 col1" >-1.314</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow1_col2" class="data row1 col2" >-1.707</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow1_col3" class="data row1 col3" >-0.63</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow1_col4" class="data row1 col4" >-0.973</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow1_col5" class="data row1 col5" >-0.869</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow1_col6" class="data row1 col6" >-0.91</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow1_col7" class="data row1 col7" >1646</td>
#             </tr>
#             <tr>
#                         <th id="T_c77c123c_4d3e_11ea_841f_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow2_col0" class="data row2 col0" >-1.782</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow2_col1" class="data row2 col1" >-1.774</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow2_col2" class="data row2 col2" >-0.934</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow2_col3" class="data row2 col3" >-1.837</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow2_col4" class="data row2 col4" >-1.746</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow2_col5" class="data row2 col5" >-1.774</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow2_col6" class="data row2 col6" >-1.597</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_c77c123c_4d3e_11ea_841f_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow3_col0" class="data row3 col0" >0.042</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow3_col1" class="data row3 col1" >0.028</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow3_col2" class="data row3 col2" >-0.382</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow3_col3" class="data row3 col3" >-0.198</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow3_col4" class="data row3 col4" >-0.349</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow3_col5" class="data row3 col5" >-0.322</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow3_col6" class="data row3 col6" >-0.201</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_c77c123c_4d3e_11ea_841f_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow4_col0" class="data row4 col0" >-1.278</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow4_col1" class="data row4 col1" >-1.265</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow4_col2" class="data row4 col2" >-1.49</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow4_col3" class="data row4 col3" >-1.213</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow4_col4" class="data row4 col4" >-1.731</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow4_col5" class="data row4 col5" >-1.599</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow4_col6" class="data row4 col6" >-0.92</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_c77c123c_4d3e_11ea_841f_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow5_col0" class="data row5 col0" >1.529</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow5_col1" class="data row5 col1" >1.558</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow5_col2" class="data row5 col2" >3.025</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow5_col3" class="data row5 col3" >0.191</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952erow5_col4" class="data row5 col4" >0.419</td>
#                         <td id="T_c77c123c_4d3e_11ea_841f_00505683952er

# %%
METRIC = 'qmd'

MODELS = {'ElasticNet': best_lms,
          'LASSO': best_lassos,
          'LASSO{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

pickle.dump(x_scaler, 
            open('../models/{}/sklearn/x_scaler.pkl'.format(METRIC), 'wb'))
pickle.dump(transformer, 
            open('../models/{}/sklearn/y_scaler.pkl'.format(METRIC), 'wb'))

for i in range(len(ecoregion_names)):
    for key in MODELS.keys():
        fname = ecoregion_names[i] + '_{}.pkl'.format(key)
        path_to_file = '../models/{}/sklearn/{}'.format(METRIC, fname)
        pickle.dump(MODELS[key][i], 
                    open(path_to_file, 'wb'))
        
        if key == 'LASSO{}'.format(MAX_FEATURES):
            sfm_name = ecoregion_names[i] + '_LASSO{}_featureselect.pkl'.format(MAX_FEATURES)
            path_to_file = '../models/{}/sklearn/{}'.format(METRIC, sfm_name)
            pickle.dump(sfms[i], 
                        open(path_to_file, 'wb'))
