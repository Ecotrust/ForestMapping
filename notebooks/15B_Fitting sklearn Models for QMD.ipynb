# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
# data prep and model-tuning
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, QuantileTransformer
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV

# types of models we'll fit
from sklearn.linear_model import ElasticNetCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR

from scipy.stats import shapiro

import pickle
from copy import deepcopy

# %% [markdown]
# ## Our Data

# %%
DATA = '../data/processed/training_data_annual.csv'
df = pd.read_csv(DATA)
df = df.dropna()
print('{:,d} samples'.format(len(df)))
print('Columns:', df.columns.values)
# Out:
# 4,721 samples
# Columns: ['uuid' 'lidar_year' 'lat' 'lon' 'orig_id' 'source' 'meas_yr' 'ecoregion3'
#  'agency' 'plot_size_ac' 'num_returns' 'strat0_return-proportion'
#  'strat1_return-proportion' 'strat2_return-proportion'
#  'strat3_return-proportion' 'strat4_return-proportion'
#  'strat5_return-proportion' 'skewness' 'kurtosis'
#  'strat0_intensity-median' 'strat1_intensity-median'
#  'strat2_intensity-median' 'strat3_intensity-median'
#  'strat4_intensity-median' 'strat5_intensity-median'
#  'height_05-percentile' 'height_25-percentile' 'height_50-percentile'
#  'height_75-percentile' 'height_95_percentile' 'height_max' 'cover'
#  'lidar_acq' 'potential_volume' 'stddev_height' 'surface_area_ratio'
#  'surface_volume' 'surface_volume_ratio' 'aspect' 'elevation'
#  'overall_curvature' 'plan_curvature' 'profile_curvature' 'slope'
#  'solar_radiation_index' 'mat' 'mwmt' 'mcmt' 'td' 'map' 'msp' 'ahm' 'shm'
#  'dd_0' 'dd5' 'dd_18' 'dd18' 'nffd' 'bffp' 'effp' 'ffp' 'pas' 'emt' 'ext'
#  'eref' 'cmd' 'rh' 'green' 'blue' 'red' 'nir' 'endvi' 'ndvi' 'savi'
#  'swir1' 'swir2' 'wetness' 'greenness' 'brightness' 'landsat_year'
#  'clim_year' 'distance_to_water_m' 'bulk_dens' 'soil_depth'
#  'pct_clay_surf' 'pct_rock_surf' 'pct_sand_surf' 'pot_veg_type' 'tpa' 'ba'
#  'sdi' 'ccf' 'qmd' 'tcuft' 'topht' 'number_of_strata' 'total_cover'
#  'structure_class' 'canopy_baseheight' 'canopy_bulkdensity'
#  'aboveground_biomass' 'aboveground_carbon' 'gs_tpa' 'AF' 'AS' 'BM' 'BO'
#  'CH' 'CW' 'DF' 'DG' 'ES' 'GC' 'GF' 'IC' 'JP' 'KP' 'LO' 'LP' 'MA' 'MC'
#  'MH' 'NF' 'OH' 'OS' 'OT' 'PC' 'PL' 'PP' 'PY' 'RA' 'RC' 'RF' 'SF' 'SH'
#  'SP' 'SS' 'TO' 'WA' 'WB' 'WF' 'WH' 'WI' 'WJ' 'WL' 'WO' 'WP' 'YC'
#  'TRUE_FIR' 'OTHER_HARDWOOD' 'MAPLE' 'OAK' 'DOUGLAS_FIR' 'SPRUCE' 'CEDAR'
#  'PONDEROSA_PINE' 'OTHER_SOFTWOOD' 'LODGEPOLE_PINE' 'HEMLOCK' 'RED_ALDER'
#  'TANOAK' 'JUNIPER' 'LARCH' 'fvs_year' 'year_diff' 'returns_per_m2']

# %% [markdown]
# ## Filter out some of the training data
# We can exclude some of the training data based on how far separated the inventory data (interpolated using FVS simulations) is from the year the lidar was collected. Similarly, we can screen out training examples that had relatively low density of lidar returns.

# %%
df['year_diff'] = abs(df['fvs_year'] - df['lidar_year']).astype(int)

# %%
len(df.loc[df['year_diff'] >= 5])
# Out:
# 829

# %%
df = df.loc[df['year_diff'] < 5]

# %%
len(df.loc[df['returns_per_m2'] < 4.0])
# Out:
# 103

# %%
df = df.loc[df['returns_per_m2'] >= 4.0]

# %%
lidar_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformer = QuantileTransformer(output_distribution='normal').fit(df['topht'].values.reshape(-1, 1))

lidar_height_transformed = lidar_height_transformer.transform(df['height_95_percentile'].values.reshape(-1, 1))
fvs_height_transformed = fvs_height_transformer.transform(df['topht'].values.reshape(-1, 1))

diff_height_transformed = abs(lidar_height_transformed - fvs_height_transformed)


fig, axs = plt.subplots(1,2, figsize=(15,5))

# select outliers
OUTLIER_THRESH = 3.05
outliers = diff_height_transformed > OUTLIER_THRESH
outliers = np.logical_or(outliers, (df['height_95_percentile'] > 275/3.28084).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 60/3.28084) & (df['topht'] > 105)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((df['height_95_percentile'] < 10/3.28084) & (df['topht'] > 40)).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])/df['topht']) > 1.0).values.reshape(-1, 1))
outliers = np.logical_or(outliers, ((abs(df['height_95_percentile']*3.28084 - df['topht'])) > 100).values.reshape(-1, 1))

axs[0].hist(diff_height_transformed, bins=20)
axs[0].axvline(OUTLIER_THRESH, color='k')
axs[0].set_title('Differences between transformed lidar and fvs canopy height')

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[~outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[~outliers],
            s=1, label='Inliers (n={:,d})'.format((~outliers).sum()))

axs[1].scatter(df['height_95_percentile'].values.reshape(-1, 1)[outliers]*3.28084, 
            df['topht'].values.reshape(-1, 1)[outliers],
            s=5, label='Outliers (n={:,d})'.format(outliers.sum()))

axs[1].set_xlabel('Lidar Canopy Height, ft')
axs[1].set_ylabel('FVS Canopy Height, ft')
axs[1].plot([0,400],[0,400], color='k', lw=2, label='1:1')
axs[1].set_xlim(-10, 400)
axs[1].set_ylim(-10, 400)
axs[1].set_aspect('equal')
axs[1].legend();

# %%
# filter out the height outliers
df = df[~outliers]

# %% [markdown]
# ## Inspect how many samples we have for different years, regions, etc.

# %%
df.groupby(by=['lidar_year'])[['uuid']].count().rename({'uuid':'count'}, axis=1)
# Out:
#             count
# lidar_year
# 2008          747
# 2009           18
# 2010            2
# 2011          120
# 2012          613
# 2013          232
# 2014          342
# 2015          646
# 2016          543
# 2017          177
# 2018           33

# %%
pd.pivot_table(df, 
               values='uuid', 
               aggfunc='count', 
               index=['meas_yr'], 
               columns=['lidar_year'], 
               fill_value=0)
# Out:
# lidar_year  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# meas_yr
# 2010         419     0     0     0     3     0     2     7     0     0     0
# 2011         328     0     0     0     1     0     2     2     0     0     0
# 2013           0    18     0    37   421    49     3    10    13    26     2
# 2014           0     0     2    29   130    43    47    41    86    36     0
# 2015           0     0     0    54    16    12    16   202   105    24     5
# 2016           0     0     0     0    42    86    48   275    67    35    26
# 2017           0     0     0     0     0    42   177    54    93    46     0
# 2018           0     0     0     0     0     0    47    55   179    10     0

# %%
ecoreg_counts = df.groupby(by=['ecoregion3'])[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
ecoreg_counts
# Out:
#                                                     uuid  lidar_acq  \
# ecoregion3
# blue_mountains                                       104          2
# cascades                                             579         21
# coast_range                                         1511         18
# columbia_plateau                                       8          4
# eastern_cascades_slopes_and_foothills                202         11
# klamath_mountains_california_high_north_coast_r...   253          7
# north_cascades                                       405         18
# northern_rockies                                      71          4
# puget_lowland                                        110         14
# willamette_valley                                     41          2
#
#                                                     lidar_year  plot_size_ac
# ecoregion3
# blue_mountains                                               2             1
# cascades                                                     9             3
# coast_range                                                  9             2
# columbia_plateau                                             4             1
# eastern_cascades_slopes_and_foothills                        6             2
# klamath_mountains_california_high_north_coast_r...           5             2
# north_cascades                                               6             2
# northern_rockies                                             3             1
# puget_lowland                                                7             1
# willamette_valley                                            2             2

# %%
df[['uuid', 'lidar_acq', 'lidar_year', 'plot_size_ac']].nunique()
# Out:
# uuid            3284
# lidar_acq         70
# lidar_year        11
# plot_size_ac       3
# dtype: int64

# %% [markdown]
# ## Available features
# First, we'll use one-hot encoding for categorical features

# %%
# convert agency, ecoregion, and lidar acquisition into one-hot encoded set of variables
df = pd.get_dummies(df, prefix='agency', columns=['agency'])
# df = pd.get_dummies(df, prefix='eco', columns=['ecoregion3'])
# df = pd.get_dummies(df, prefix='acq', columns=['lidar_acq'])

# %% [markdown]
# The different types of predictor variables we can use to predict a forest attribute, including climate, lidar-derived, soil, and satellite imagery.

# %%
CLIM_COLS = ['mat', 'mwmt', 'mcmt', 'td', 'map', 'msp', 'ahm', 'shm', 
             'dd_0', 'dd5', 'dd_18', 'dd18', 'nffd', 'bffp', 'effp', 
             'ffp', 'pas', 'emt', 'ext', 'eref', 'cmd', 'rh']

LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
       'strat1_return-proportion', 'strat2_return-proportion',
       'strat3_return-proportion', 'strat4_return-proportion',
       'strat5_return-proportion', 'strat0_intensity-median',
       'strat1_intensity-median', 'strat2_intensity-median',
       'strat3_intensity-median', 'strat4_intensity-median',
       'strat5_intensity-median', 'height_05-percentile',
       'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
       'height_95_percentile', 'height_max', 'cover', 'potential_volume',
       'stddev_height', 'surface_area_ratio', 'surface_volume',
       'surface_volume_ratio', 'aspect', 'elevation', 'overall_curvature',
       'plan_curvature', 'profile_curvature', 'slope', 'solar_radiation_index', 
              'kurtosis', 'skewnewss']

USE_LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
                  'strat1_return-proportion', 'strat2_return-proportion',
                  'strat3_return-proportion', 'strat4_return-proportion',
                  'strat5_return-proportion', 'height_05-percentile',
                  'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
                  'height_95_percentile', 'cover', 'potential_volume',
                  'stddev_height', 'surface_volume',
                  'aspect', 'elevation', 'slope', 'solar_radiation_index',
                  'kurtosis', 'skewness']

SOIL_COLS = ['bulk_dens', 'soil_depth', 'pct_clay_surf', 'pct_rock_surf', 'pct_sand_surf']

LANDSAT_COLS = ['green', 'blue', 'red', 'nir', 'endvi', 'ndvi', 'savi',
                'swir1', 'swir2', 'wetness', 'greenness', 'brightness']

AGENCY_COLS = ['agency_BLM', 'agency_USFS', 'agency_WADNR']

# ECOREGIONS = [col for col in df.columns if col.startswith('eco_')]

# %% [markdown]
# ## Selecting initial features and targets
# This is the first step in determining what features we want to use, and what we want to predict. Later, we can still apply some procedures to choose a subset of these features to make simpler models.

# %%
X_COLS = USE_LIDAR_COLS + ['ecoregion3'] 
Y_COLS = ['qmd']

# %% [markdown]
# ## Split the data into training and testing sets
# Since some plot_ids have multiple observations, we want all observations for each plot_id to fall entirely in train_set or entirely the training or testing sets because these samples are definitely not independent.

# %%
# a dataframe with unique plot ids
splits = pd.DataFrame(pd.unique(df['uuid']), columns=['uuid']).set_index('uuid')

# randomly assign each plot-id to train(0) or test(1) sets
np.random.seed(127)
splits['train0_test1'] = np.random.choice(2,
                                          size=len(splits),
                                          p=[0.8,0.2])

# add set assignments to the dataframe
df['train0_test1'] = splits.loc[df['uuid']]['train0_test1'].values

# %%
train_plots = df.loc[df['train0_test1'] == 0]
test_plots = df.loc[df['train0_test1'] == 1]
len(train_plots), len(test_plots)
# Out:
# (2769, 704)

# %%
x_train, x_test = train_plots[X_COLS], test_plots[X_COLS]
y_train, y_test = train_plots[Y_COLS], test_plots[Y_COLS]

# %% [markdown]
# ## Standardize features
# Scale all predictive features to have 0 mean and unit variance (subtracting mean, dividing by standard deviation).

# %%
x_scaler = StandardScaler()
x_scaler.fit(df[X_COLS].drop(['ecoregion3'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Consider a few transformations for the target variable

# %%
fig, axs = plt.subplots(1,6, figsize=(15,2.5))

quantile = QuantileTransformer(output_distribution='normal', random_state=127)
box_cox = PowerTransformer(method='box-cox')
yeo_johnson = PowerTransformer(method='yeo-johnson')

VALS = [y_train.values,
        np.log1p(y_train.values),
        np.sqrt(y_train.values),
        quantile.fit_transform(y_train.values),
        box_cox.fit_transform(y_train.values + 1e-9),
        yeo_johnson.fit_transform(y_train.values)]

TITLES = ['Raw', 'Log', 'SQRT', 'Quantile', 'Box-Cox', 'Yeo-Johnson']
SHAPIRO_ps = [shapiro(vals)[-1] for vals in VALS]

for i, vals in enumerate(VALS):
    axs.ravel()[i].hist(vals, bins=20)
    axs.ravel()[i].set_title(TITLES[i])
    
plt.show();

# %%
# identify the closest to normally-distributed
TITLES[np.array(SHAPIRO_ps).argmax()]
# Out:
# 'Yeo-Johnson'

# %%
# choose your transformer here
transformer = quantile

# %%
transformer.fit(df[Y_COLS])
y_train.loc[:,Y_COLS], y_test.loc[:,Y_COLS] = transformer.transform(y_train), transformer.transform(y_test)
# Out:
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Split datasets by ecoregion
# We want to explore model transferability between regions, so we'll train models independently on subsets of the data within a single ecoregion, as well as a model that is trained on all available ecoregions.

# %%
ecoregions = [reg for reg in pd.unique(df.ecoregion3) if ecoreg_counts.loc[reg]['uuid'] > 20]

eco_train_idx = [x_train.loc[x_train.ecoregion3 == eco].index.values for eco in ecoregions]
eco_test_idx = [x_test.loc[x_test.ecoregion3 == eco].index.values for eco in ecoregions]

eco_xtrain_dfs = [x_train.loc[x_train.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytrain_dfs = [y_train.loc[idx].values.ravel() for idx in eco_train_idx]
eco_xtest_dfs = [x_test.loc[x_test.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytest_dfs = [y_test.loc[idx].values.ravel() for idx in eco_test_idx]

# append a "global" model that contains data from all ecoregions
ecoregions.append('all')
ecoregion_names = ['_'.join(x.split('_')[0:2]) for x in ecoregions]
eco_xtrain_dfs.append(x_train.drop(['ecoregion3'], axis=1))
eco_ytrain_dfs.append(y_train.values.ravel())
eco_xtest_dfs.append(x_test.drop(['ecoregion3'], axis=1))
eco_ytest_dfs.append(y_test.values.ravel())

# %% [markdown]
# ## Scoring
# We'll use Root Mean Square Error to evaluate model performance.

# %%
def rmse(pred, obs):
    # use our transformer to calculate RMSE on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return np.sqrt((np.square(obs-pred)).mean())

# %%
def nrmse(pred, obs):
    # use our transformer to calculate percent RMSE on the original data scale
    this_rmse = rmse(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return this_rmse/obs.mean()

# %%
def mae(pred, obs):
    # use our transformer to calculate mean absolute error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean()

# %%
def mape(pred, obs):
    # use our transformer to calculate mean average percent error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return abs(pred - obs).mean() / obs.mean()

# %%
def bias(pred, obs):
    # use our transformer to calculate mean bias on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1))
    obs = transformer.inverse_transform(obs.reshape(-1,1))
    
    return (pred - obs).mean()

# %%
def rel_bias(pred, obs):
    # use our transformer to calculate mean relative bias on the original data scale
    this_bias = bias(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1))  
    
    return this_bias/obs.mean()

# %% [markdown]
# This helper function will calculate RMSE scores for each regionally-trained model and the global model on each ecoregion.

# %%
def get_score_df(models, metric=rmse, feature_selectors=None):
    regional_scores = []
    global_scores = []
    counts = []
    
    for i, mod in enumerate(models):
        X_test = x_scaler.transform(eco_xtest_dfs[i])
        if feature_selectors:
            X_test = feature_selectors[i].transform(X_test)
        y_test = eco_ytest_dfs[i]
        reg_score = metric(mod.predict(X_test), y_test)
        regional_scores.append(reg_score.round(3))
        
        if feature_selectors:
            X_test = x_scaler.transform(eco_xtest_dfs[i])
            X_test = feature_selectors[-1].transform(X_test)
        glob_score = metric(models[-1].predict(X_test), y_test)
        global_scores.append(glob_score.round(3))
        count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
        counts.append(count)
        
    data = list(zip(regional_scores, global_scores, counts))
    res_df = pd.DataFrame(data=data,
                          columns=['regional_model', 'global_model', 'n'],
                          index=ecoregion_names)
    
    return res_df

# %% [markdown]
# ## Fit some models
# For each type of model, we'll employ cross-validation to tune model hyperparameters, generating a tuned model for each ecoregion as well as a tuned model using all training data. We'll work our way through:
#
# #### ElasticNet Regression
# Linear model that employs a mix of L1 and L2 regularization to penalize model complexity
#
# #### LASSO Regression
# Linear model that employs L1 regularization to penalize model complexity. We'll also work with a feature-selection process to fit models capped to an explicitly-predefined number of features.
#
# #### K-Nearest Neighbor Regression
#
# #### Random Forest Regression
#
# #### Gradient Boosting Trees Regression
#
# #### Support Vector Machine Regression

# %% [markdown]
# ## ElasticNet (Linear Model)

# %%
best_lms = []

for i in range(len(ecoregions)):
    lm = ElasticNetCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    lm.fit(X, y)
    best_lms.append(lm)

# %%
elastic_res = get_score_df(best_lms)
elastic_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              2.219         2.321   104
# coast_range                 5.555         5.585  1580
# north_cascades              3.705         3.463   443
# cascades                    3.893         3.691   613
# klamath_mountains           6.319         7.228   275
# eastern_cascades            3.662         3.849   203
# northern_rockies            2.591         2.805    83
# puget_lowland               3.497         2.662   122
# willamette_valley           5.111         6.928    41
# all                         4.999         4.999  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lms])
count_nonzero = [(~np.isclose(coef, 0, atol=1e-3)).sum() for coef in coefs]
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.101
# north_cascades                                                 --
# cascades                                                    0.063
# klamath_mountains_california_high_north_coast_r...          0.134
# eastern_cascades_slopes_and_foothills                       0.005
# northern_rockies                                           -0.068
# puget_lowland                                              -0.154
# willamette_valley                                              --
# all                                                         0.026
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                        0.191
# coast_range                                                           0.076
# north_cascades                                                           --
# cascades                                                              0.038
# klamath_mountains_california_high_north_coast_r...                    0.345
# eastern_cascades_slopes_and_foothills                                 0.195
# northern_rockies                                                      0.116
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.181
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.015
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                              0.032
# klamath_mountains_california_high_north_coast_r...                   -0.147
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                        -0.016
# willamette_valley                                                        --
# all                                                                  -0.056
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                        -0.34
# coast_range                                                           -0.01
# north_cascades                                                       -0.105
# cascades                                                             -0.062
# klamath_mountains_california_high_north_coast_r...                   -0.137
# eastern_cascades_slopes_and_foothills                                -0.192
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                  -0.117
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.062
# north_cascades                                                           --
# cascades                                                             -0.042
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                 0.072
# northern_rockies                                                         --
# puget_lowland                                                         0.063
# willamette_valley                                                    -0.063
# all                                                                  -0.003
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                         0.13
# coast_range                                                           0.173
# north_cascades                                                        0.012
# cascades                                                               0.01
# klamath_mountains_california_high_north_coast_r...                     0.08
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.053
# puget_lowland                                                         0.096
# willamette_valley                                                        --
# all                                                                   0.054
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.162
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     0.153
# all                                                                   0.053
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                      -0.059
# north_cascades                                                       --
# cascades                                                         -0.034
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                              -0.034
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                      -0.052
# north_cascades                                                       --
# cascades                                                          0.172
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                       --  ...
# coast_range                                                       0.024  ...
# north_cascades                                                       --  ...
# cascades                                                           0.05  ...
# klamath_mountains_california_high_north_coast_r...                0.127  ...
# eastern_cascades_slopes_and_foothills                                --  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                        --  ...
# willamette_valley                                                    --  ...
# all                                                               0.005  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                         --            0.017
# coast_range                                        -0.115               --
# north_cascades                                         --            0.014
# cascades                                           -0.217           -0.443
# klamath_mountains_california_high_north_coast_r...     --               --
# eastern_cascades_slopes_and_foothills              -0.145               --
# northern_rockies                                   -0.127            0.046
# puget_lowland                                          --               --
# willamette_valley                                      --            0.219
# all                                                    --            0.003
#
#                                                    stddev_height  \
# blue_mountains                                              0.04
# coast_range                                                0.171
# north_cascades                                             0.139
# cascades                                                    0.32
# klamath_mountains_california_high_north_coast_r...         0.209
# eastern_cascades_slopes_and_foothills                      0.076
# northern_rockies                                           0.505
# puget_lowland                                              0.113
# willamette_valley                                          0.168
# all                                                        0.153
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --  0.041
# coast_range                                                    -- -0.001
# north_cascades                                                 -- -0.004
# cascades                                                       -- -0.022
# klamath_mountains_california_high_north_coast_r...          0.036     --
# eastern_cascades_slopes_and_foothills                          --  0.035
# northern_rockies                                           -0.294  0.048
# puget_lowland                                               0.154  0.047
# willamette_valley                                              --  0.004
# all                                                            --     --
#
#                                                    elevation  slope  \
# blue_mountains                                            --     --
# coast_range                                            -0.11  -0.02
# north_cascades                                            --     --
# cascades                                               0.016  0.051
# klamath_mountains_california_high_north_coast_r...        --     --
# eastern_cascades_slopes_and_foothills                  0.068 -0.027
# northern_rockies                                          --  0.035
# puget_lowland                                             --  0.067
# willamette_valley                                         --     --
# all                                                    0.006     --
#
#                                                    solar_radiation_index  \
# blue_mountains                                                        --
# coast_range                                                       -0.053
# north_cascades                                                        --
# cascades                                                           0.058
# klamath_mountains_california_high_north_coast_r...                    --
# eastern_cascades_slopes_and_foothills                              0.023
# northern_rockies                                                   0.064
# puget_lowland                                                     -0.031
# willamette_valley                                                     --
# all                                                                   --
#
#                                                    kurtosis skewness
# blue_mountains                                           --   -0.251
# coast_range                                           0.002   -0.386
# north_cascades                                           --   -0.152
# cascades                                             -0.017   -0.415
# klamath_mountains_california_high_north_coast_r...       --   -0.108
# eastern_cascades_slopes_and_foothills                    --   -0.497
# northern_rockies                                         --   -0.477
# puget_lowland                                            --       --
# willamette_valley                                        --       --
# all                                                      --   -0.249
#
# [10 rows x 22 columns]

# %% [markdown]
# ## LASSO (Linear Model)
# Starting with implicit feature selection via L1 regularization of coefficients.

# %%
best_lassos = []

for i in range(len(ecoregions)):
    lasso = LassoCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000, n_alphas=1000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    lasso.fit(X, y)
    best_lassos.append(lasso)

# %%
lasso_res = get_score_df(best_lassos)
lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              2.193         2.232   104
# coast_range                 5.551         5.541  1580
# north_cascades              3.817         3.458   443
# cascades                    3.909         3.745   613
# klamath_mountains           6.278         7.181   275
# eastern_cascades            3.642         3.706   203
# northern_rockies            2.581         2.738    83
# puget_lowland               3.490         2.625   122
# willamette_valley           5.183         6.460    41
# all                         4.960         4.960  3473

# %%
coefs = np.array([lm.coef_ for lm in best_lassos])
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.101
# north_cascades                                                 --
# cascades                                                    0.065
# klamath_mountains_california_high_north_coast_r...          0.141
# eastern_cascades_slopes_and_foothills                          --
# northern_rockies                                           -0.051
# puget_lowland                                              -0.143
# willamette_valley                                              --
# all                                                         0.034
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                        0.184
# coast_range                                                           0.069
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                    0.381
# eastern_cascades_slopes_and_foothills                                 0.221
# northern_rockies                                                      0.097
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.304
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                              0.019
# klamath_mountains_california_high_north_coast_r...                   -0.143
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                  -0.024
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                       -0.379
# coast_range                                                          -0.006
# north_cascades                                                       -0.086
# cascades                                                             -0.059
# klamath_mountains_california_high_north_coast_r...                   -0.122
# eastern_cascades_slopes_and_foothills                                -0.189
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                  -0.069
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.065
# north_cascades                                                           --
# cascades                                                             -0.042
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                 0.051
# northern_rockies                                                         --
# puget_lowland                                                         0.078
# willamette_valley                                                    -0.056
# all                                                                      --
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.085
# coast_range                                                           0.175
# north_cascades                                                           --
# cascades                                                              0.011
# klamath_mountains_california_high_north_coast_r...                    0.087
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                      0.007
# puget_lowland                                                         0.088
# willamette_valley                                                        --
# all                                                                    0.07
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.165
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                      0.15
# all                                                                   0.018
#
#                                                    height_05-percentile  \
# blue_mountains                                                       --
# coast_range                                                      -0.059
# north_cascades                                                       --
# cascades                                                         -0.035
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                              -0.047
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                      -0.054
# north_cascades                                                       --
# cascades                                                          0.176
# klamath_mountains_california_high_north_coast_r...                   --
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_50-percentile  ...  \
# blue_mountains                                                       --  ...
# coast_range                                                       0.019  ...
# north_cascades                                                       --  ...
# cascades                                                          0.053  ...
# klamath_mountains_california_high_north_coast_r...                0.165  ...
# eastern_cascades_slopes_and_foothills                                --  ...
# northern_rockies                                                     --  ...
# puget_lowland                                                        --  ...
# willamette_valley                                                    --  ...
# all                                                                0.02  ...
#
#                                                     cover potential_volume  \
# blue_mountains                                         --               --
# coast_range                                        -0.129               --
# north_cascades                                         --               --
# cascades                                           -0.265           -0.478
# klamath_mountains_california_high_north_coast_r...     --               --
# eastern_cascades_slopes_and_foothills              -0.103               --
# northern_rockies                                   -0.134               --
# puget_lowland                                          --               --
# willamette_valley                                      --            0.332
# all                                                    --               --
#
#                                                    stddev_height  \
# blue_mountains                                                --
# coast_range                                                0.168
# north_cascades                                             0.091
# cascades                                                   0.327
# klamath_mountains_california_high_north_coast_r...         0.208
# eastern_cascades_slopes_and_foothills                       0.06
# northern_rockies                                           0.559
# puget_lowland                                              0.011
# willamette_valley                                          0.154
# all                                                        0.125
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --  0.037
# coast_range                                                    -- -0.001
# north_cascades                                                 -- -0.011
# cascades                                                       -- -0.022
# klamath_mountains_california_high_north_coast_r...             --     --
# eastern_cascades_slopes_and_foothills                          --  0.033
# northern_rockies                                           -0.301  0.043
# puget_lowland                                                  --  0.055
# willamette_valley                                              --     --
# all                                                            -- -0.002
#
#                                                    elevation  slope  \
# blue_mountains                                            --     --
# coast_range                                            -0.11  -0.02
# north_cascades                                            --     --
# cascades                                               0.017  0.051
# klamath_mountains_california_high_north_coast_r...        --     --
# eastern_cascades_slopes_and_foothills                  0.062 -0.025
# northern_rockies                                          --  0.013
# puget_lowland                                             --  0.062
# willamette_valley                                         --     --
# all                                                    0.015 -0.011
#
#                                                    solar_radiation_index  \
# blue_mountains                                                        --
# coast_range                                                       -0.053
# north_cascades                                                        --
# cascades                                                           0.058
# klamath_mountains_california_high_north_coast_r...                    --
# eastern_cascades_slopes_and_foothills                              0.017
# northern_rockies                                                   0.059
# puget_lowland                                                     -0.022
# willamette_valley                                                     --
# all                                                               -0.008
#
#                                                    kurtosis skewness
# blue_mountains                                           --   -0.277
# coast_range                                           0.013   -0.395
# north_cascades                                       -0.007   -0.129
# cascades                                             -0.003   -0.425
# klamath_mountains_california_high_north_coast_r...       --   -0.122
# eastern_cascades_slopes_and_foothills                    --   -0.494
# northern_rockies                                         --   -0.471
# puget_lowland                                            --       --
# willamette_valley                                        --       --
# all                                                   0.061    -0.37
#
# [10 rows x 22 columns]

# %% [markdown]
# Now we'll explicitly define the maximum number of features to use for fitting a linear model. We'll trim features by iteratively increasing a threshold for coefficients using LASSO regression

# %%
MAX_FEATURES = 5
sfms = [] # transformers that filter X features
trimmed_lassos = [] # re-fit lasso regressions on the subset of the features

for i, lasso in enumerate(best_lassos):
    lasso = deepcopy(lasso)
    sfm = SelectFromModel(lasso, threshold=0.001)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    Y = (eco_ytrain_dfs[i].ravel())
    sfm.fit(X, Y)
    n_features = sfm.transform(X).shape[1]

    # Reset the threshold till the number of features equals two.
    # Note that the attribute can be set directly instead of repeatedly
    # fitting the metatransformer.
    while n_features > MAX_FEATURES:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    
    sfms.append(sfm)
    try:
        trimmed_lassos.append(lasso.fit(sfm.transform(X), Y))
    except ValueError:
        print(ecoregion_names[i])
        raise

# %%
coefs = []
for i in range(len(ecoregions)):
    cols = np.zeros(eco_xtest_dfs[i].columns.shape)
    cols[sfms[i].get_support()] = trimmed_lassos[i].coef_
    coefs.append(cols)
    
coefs = np.array(coefs)

coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                    --
# north_cascades                                                 --
# cascades                                                       --
# klamath_mountains_california_high_north_coast_r...             --
# eastern_cascades_slopes_and_foothills                          --
# northern_rockies                                               --
# puget_lowland                                              -0.198
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                        0.373
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                    0.537
# eastern_cascades_slopes_and_foothills                                 0.203
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.302
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.145
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                       -0.329
# coast_range                                                              --
# north_cascades                                                       -0.106
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                -0.151
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                         0.122
# willamette_valley                                                    -0.109
# all                                                                      --
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.234
# coast_range                                                           0.159
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                         0.104
# willamette_valley                                                        --
# all                                                                   0.109
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.121
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# eastern_cascades_slopes_and_foothills                                    --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                     0.161
# all                                                                      --
#
#                                                    height_50-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                0.402
# eastern_cascades_slopes_and_foothills                                --
# northern_rockies                                                     --
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_95_percentile  \
# blue_mountains                                                    0.391
# coast_range                                                        0.34
# north_cascades                                                      0.6
# cascades                                                          0.725
# klamath_mountains_california_high_north_coast_r...                0.329
# eastern_cascades_slopes_and_foothills                             0.594
# northern_rockies                                                  0.438
# puget_lowland                                                      0.92
# willamette_valley                                                 0.038
# all                                                               0.617
#
#                                                     cover potential_volume  \
# blue_mountains                                         --               --
# coast_range                                            --               --
# north_cascades                                         --               --
# cascades                                           -0.329               --
# klamath_mountains_california_high_north_coast_r...     --               --
# eastern_cascades_slopes_and_foothills              -0.184               --
# northern_rockies                                   -0.217               --
# puget_lowland                                          --               --
# willamette_valley                                      --            0.308
# all                                                    --               --
#
#                                                    stddev_height  \
# blue_mountains                                                --
# coast_range                                                 0.27
# north_cascades                                             0.114
# cascades                                                   0.113
# klamath_mountains_california_high_north_coast_r...          0.13
# eastern_cascades_slopes_and_foothills                         --
# northern_rockies                                           0.594
# puget_lowland                                                 --
# willamette_valley                                          0.231
# all                                                        0.104
#
#                                                    surface_volume aspect  \
# blue_mountains                                                 --     --
# coast_range                                                    --     --
# north_cascades                                                 -- -0.033
# cascades                                                       --     --
# klamath_mountains_california_high_north_coast_r...             --     --
# eastern_cascades_slopes_and_foothills                          --     --
# northern_rockies                                           -0.541     --
# puget_lowland                                                  --     --
# willamette_valley                                              --     --
# all                                                            --     --
#
#                                                     slope skewness
# blue_mountains                                         --   -0.415
# coast_range                                            --   -0.331
# north_cascades                                         --   -0.145
# cascades                                               --   -0.462
# klamath_mountains_california_high_north_coast_r...     --       --
# eastern_cascades_slopes_and_foothills                  --    -0.59
# northern_rockies                                       --   -0.499
# puget_lowland                                       0.067       --
# willamette_valley                                      --       --
# all                                                    --   -0.301

# %%
trimmed_lasso_res = get_score_df(trimmed_lassos, feature_selectors=sfms)
trimmed_lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              2.139         2.389   104
# coast_range                 5.591         5.533  1580
# north_cascades              3.845         3.591   443
# cascades                    3.961         3.851   613
# klamath_mountains           6.383         7.240   275
# eastern_cascades            3.591         3.938   203
# northern_rockies            2.604         2.934    83
# puget_lowland               3.629         2.564   122
# willamette_valley           4.734         6.606    41
# all                         5.001         5.001  3473

# %% [markdown]
# ## K-Nearest Neighbors Regression

# %%
# Set the parameters by cross-validation
knn_params = {'n_neighbors': [1,2,3,4,5,10,20],
              'weights': ['uniform', 'distance'],
              'metric': ['minkowski', 'manhattan']}


knn_gs = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=knn_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_knns = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    knn_gs.fit(X, y)
    best_fit = knn_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_knns.append(best_fit)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    2.1s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    2.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.6s finished

# %%
knn_res = get_score_df(best_knns)
knn_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              2.640         1.804   104
# coast_range                 5.716         5.706  1580
# north_cascades              3.661         3.359   443
# cascades                    3.801         3.567   613
# klamath_mountains           6.552         6.499   275
# eastern_cascades            4.305         3.680   203
# northern_rockies            3.128         2.883    83
# puget_lowland               5.614         3.367   122
# willamette_valley           6.973         8.691    41
# all                         4.962         4.962  3473

# %% [markdown]
# ## Random Forest Regression

# %%
# Set the parameters by cross-validation
rf_params = {'n_estimators': [100, 500, 1000, 5000],
             'max_features': ['sqrt'],
             'max_depth': [3, 5, 10, 25, 50],
             'min_samples_leaf': [1,2,4],
             'bootstrap': [True]}


rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=rf_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_rfs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    rf_gs.fit(X, y)
    best_fit = rf_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_rfs.append(best_fit)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    9.0s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   18.3s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   17.8s remaining:    9.6s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   46.2s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   22.1s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   12.2s remaining:    6.6s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   26.3s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.2s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.4s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:    9.0s remaining:    4.9s
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   22.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   10.4s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   22.8s finished
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   11.1s remaining:    6.0s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   21.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done 117 out of 180 | elapsed:   11.4s remaining:    6.1s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   20.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  1.5min finished

# %%
rf_res = get_score_df(best_rfs)
rf_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              2.609         1.855   104
# coast_range                 5.413         5.354  1580
# north_cascades              3.265         3.520   443
# cascades                    3.613         3.351   613
# klamath_mountains           6.496         6.606   275
# eastern_cascades            4.090         3.705   203
# northern_rockies            3.376         2.787    83
# puget_lowland               3.374         2.737   122
# willamette_valley           6.035         6.806    41
# all                         4.743         4.743  3473

# %%
### Employing feature selection to try and improve random forest regression

# %%
importances = best_rfs[-1].feature_importances_
indices = np.argsort(importances)[::-1]
features = eco_xtrain_dfs[-1].columns[indices]

# Print the feature ranking
print("Feature ranking:")

for f in range(eco_xtrain_dfs[-1].shape[1]):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. height_95_percentile (0.121752)
# 2. height_75-percentile (0.108327)
# 3. potential_volume (0.085249)
# 4. strat5_return-proportion (0.073452)
# 5. height_50-percentile (0.067663)
# 6. strat4_return-proportion (0.059793)
# 7. strat2_return-proportion (0.057410)
# 8. stddev_height (0.052142)
# 9. surface_volume (0.051711)
# 10. strat3_return-proportion (0.048279)
# 11. strat0_return-proportion (0.032964)
# 12. cover (0.030096)
# 13. skewness (0.029730)
# 14. strat1_return-proportion (0.029303)
# 15. elevation (0.026377)
# 16. kurtosis (0.024571)
# 17. height_25-percentile (0.022009)
# 18. solar_radiation_index (0.018671)
# 19. returns_per_m2 (0.018371)
# 20. slope (0.017808)
# 21. aspect (0.016626)
# 22. height_05-percentile (0.007697)

# %% [markdown]
# ## Gradient Boosting Trees Regression

# %%
# Set the parameters by cross-validation
gb_params = {'n_estimators': [100, 500, 1000, 5000],
             'learning_rate': [0.01, 0.1],
             'max_depth': [2, 3, 4, 5, 10],
             'max_features': ['sqrt'] 
            }

gb_gs = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=gb_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_gbs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    gb_gs.fit(X, y)
    best_fit = gb_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_gbs.append(best_fit)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    4.9s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.0s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   13.5s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   16.7s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    3.9s remaining:    4.3s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.8s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   13.3s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    3.0s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.8s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.6s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.3s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.1s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:    4.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.2s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.5s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.1s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.5s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   39.8s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   40.4s finished

# %%
gb_res = get_score_df(best_gbs)
gb_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              2.671         1.744   104
# coast_range                 5.358         5.436  1580
# north_cascades              3.544         3.518   443
# cascades                    3.743         3.465   613
# klamath_mountains           6.682         6.714   275
# eastern_cascades            4.195         3.689   203
# northern_rockies            3.796         2.742    83
# puget_lowland               3.869         2.722   122
# willamette_valley           5.743         6.558    41
# all                         4.808         4.808  3473

# %%
### Employing feature selection to try and improve gradient boosting regression

# %% [markdown]
# ## Support Vector Machines Regression

# %%
# Set the parameters by cross-validation
svm_params = {'kernel': ['linear', 'rbf'],
              'gamma': ['scale', 'auto'],
              'C': [0.1,1,10,100,1000]
              }

svm_gs = GridSearchCV(estimator=SVR(), param_grid=svm_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_svms = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    svm_gs.fit(X, y)
    best_fit = svm_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_svms.append(best_fit)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.3s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  1.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   17.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   25.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    7.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    6.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    9.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   19.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    1.3s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  4.0min finished

# %%
svm_res = get_score_df(best_svms)
svm_res
# Out:
#                    regional_model  global_model     n
# blue_mountains              2.390         1.673   104
# coast_range                 5.510         5.558  1580
# north_cascades              3.684         3.583   443
# cascades                    3.950         3.592   613
# klamath_mountains           6.135         7.248   275
# eastern_cascades            4.267         3.489   203
# northern_rockies            2.720         2.342    83
# puget_lowland               4.147         3.268   122
# willamette_valley           5.339         6.302    41
# all                         4.941         4.941  3473

# %%
### Employing feature selection to try and improve support vector regression

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

def scatter_graphs(model_dict):
    names = MODELS.keys()
    EXTEND_PCT = 0.10
    
    fig, axs = plt.subplots(len(ecoregion_names), len(names), 
                            sharex=True, sharey=True,
                            figsize=(11,15)
                           )
    
    all_obs = transformer.inverse_transform(eco_ytest_dfs[-1].reshape(-1,1))
    obs_min = all_obs.min()
    obs_max = all_obs.max()
    rng = obs_max - obs_min
        
    for i, ecoreg in enumerate(ecoregion_names):
        observed = transformer.inverse_transform(eco_ytest_dfs[i].reshape(-1,1))
        
        for j, name in enumerate(names):
            axs[0,j].set_title(name)
            axs[i,0].set_ylabel('\n'.join(ecoreg.split('_')).upper())
            axs[i,j].set_xlim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_ylim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_aspect('equal')
            
            if name == 'LASSO_{}'.format(MAX_FEATURES):
                predicted = MODELS[name][-1].predict(sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i])))
            else:
                predicted = MODELS[name][-1].predict(x_scaler.transform(eco_xtest_dfs[i]))
            
            predicted = transformer.inverse_transform(predicted.reshape(-1,1))
            axs[i,j].scatter(observed, predicted, s=0.5)
            axs[i,j].plot((obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng), 
                          (obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng),
                         color='k', lw=0.5)
            
    plt.tight_layout(pad=0.5)

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

scatter_graphs(MODELS)

# %% [markdown]
# ## View scores for regional and global models

# %%
MODEL_NAMES = ['ElasticNet', 'LASSO', 'LASSO_{}'.format(MAX_FEATURES), 'KNN', 'RF', 'GB', 'SVM']
BEST_MODELS = [best_lms, best_lassos, trimmed_lassos, best_knns, best_rfs, best_gbs, best_svms]

def compare_models(metric):
    score_dfs = []
    for name, best_models in list(zip(MODEL_NAMES, BEST_MODELS)):
        if name == 'LASSO_{}'.format(MAX_FEATURES):
            score_df = get_score_df(best_models, metric, sfms) 
            score_dfs.append(score_df)
        else:
            score_df = get_score_df(best_models, metric) 
            score_dfs.append(score_df)
        
    counts = np.array(score_dfs[-1]['n'].values)
    regional_data = np.array([df['regional_model'].values for df in score_dfs])
    global_data = np.array([df['global_model'].values for df in score_dfs])
    
    return regional_data, global_data, counts

# %%
def highlight_best(s):
    '''
    highlight the closest value to zero in a Series yellow.
    '''
    lowest_idx = abs(s).idxmin()
    return ['background-color: yellow' if idx==lowest_idx else '' for idx in s.index]

# %%
print('Regional Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, RMSE
# <style  type="text/css" >
#     #T_873d5280_5509_11ea_869f_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_873d5280_5509_11ea_869f_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_873d5280_5509_11ea_869f_00505683952erow2_col4 {
#             background-color:  yellow;
#         }    #T_873d5280_5509_11ea_869f_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_873d5280_5509_11ea_869f_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_873d5280_5509_11ea_869f_00505683952erow5_col2 {
#             background-color:  yellow;
#         }    #T_873d5280_5509_11ea_869f_00505683952erow6_col1 {
#             background-color:  yellow;
#         }    #T_873d5280_5509_11ea_869f_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_873d5280_5509_11ea_869f_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_873d5280_5509_11ea_869f_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_873d5280_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_873d5280_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >2.2</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >2.2</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >2.1</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >2.6</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >2.6</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >2.7</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >2.4</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_873d5280_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >5.6</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >5.6</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >5.6</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >5.7</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >5.4</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >5.4</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >5.5</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_873d5280_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >3.7</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >3.8</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >3.8</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >3.7</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >3.3</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >3.5</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >3.7</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_873d5280_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >3.9</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >3.9</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >4.0</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >3.8</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >3.6</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >3.7</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >4.0</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_873d5280_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >6.3</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >6.3</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >6.4</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >6.6</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >6.5</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >6.7</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >6.1</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_873d5280_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >3.7</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >3.6</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >3.6</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >4.3</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >4.1</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >4.2</td>
#                         <td id="T_873d5280_5509_11ea_869f_00505683952erow5_col6" class="data row5 col6" >4.3</td>

# %%
print('Regional Models, RMSE%')
regional_data, global_data, counts = compare_models(nrmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:.0%}", subset=regional_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, RMSE%
# <style  type="text/css" >
#     #T_8945a384_5509_11ea_869f_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_8945a384_5509_11ea_869f_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_8945a384_5509_11ea_869f_00505683952erow2_col4 {
#             background-color:  yellow;
#         }    #T_8945a384_5509_11ea_869f_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_8945a384_5509_11ea_869f_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_8945a384_5509_11ea_869f_00505683952erow5_col2 {
#             background-color:  yellow;
#         }    #T_8945a384_5509_11ea_869f_00505683952erow6_col1 {
#             background-color:  yellow;
#         }    #T_8945a384_5509_11ea_869f_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_8945a384_5509_11ea_869f_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_8945a384_5509_11ea_869f_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_8945a384_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8945a384_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >21%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >21%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >20%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >25%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >25%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >26%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >23%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_8945a384_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >36%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >36%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >36%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >37%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >35%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >35%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >36%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_8945a384_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >30%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >31%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >32%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >30%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >27%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >29%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >30%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_8945a384_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >31%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >31%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >32%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >30%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >29%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >30%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >31%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_8945a384_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >58%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >58%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >59%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >60%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >60%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >62%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >57%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_8945a384_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >32%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >32%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >31%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >37%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >35%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >36%</td>
#                         <td id="T_8945a384_5509_11ea_869f_00505683952erow5_col6" class="data row5 col6" >37%</td>

# %%
print('Regional Models, Bias')
regional_data, global_data, counts = compare_models(bias)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .apply(highlight_best, axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, Bias
# <style  type="text/css" >
#     #T_8b44f7a2_5509_11ea_869f_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_8b44f7a2_5509_11ea_869f_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_8b44f7a2_5509_11ea_869f_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_8b44f7a2_5509_11ea_869f_00505683952erow3_col1 {
#             background-color:  yellow;
#         }    #T_8b44f7a2_5509_11ea_869f_00505683952erow4_col2 {
#             background-color:  yellow;
#         }    #T_8b44f7a2_5509_11ea_869f_00505683952erow5_col5 {
#             background-color:  yellow;
#         }    #T_8b44f7a2_5509_11ea_869f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_8b44f7a2_5509_11ea_869f_00505683952erow7_col2 {
#             background-color:  yellow;
#         }    #T_8b44f7a2_5509_11ea_869f_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_8b44f7a2_5509_11ea_869f_00505683952erow9_col6 {
#             background-color:  yellow;
#         }</style><table id="T_8b44f7a2_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b44f7a2_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >1.4</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >1.4</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >1.1</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >1.9</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >1.6</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >1.8</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >1.5</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_8b44f7a2_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >-1.2</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >-1.2</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >-1.2</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >-1.1</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >-1.0</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >-1.0</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >-0.9</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_8b44f7a2_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >-0.9</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >-0.7</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >-0.7</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >-0.8</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >-0.7</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >-0.6</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >-0.9</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_8b44f7a2_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >-0.0</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >-0.0</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >-0.0</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >-0.2</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >-0.3</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >-0.2</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >0.4</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_8b44f7a2_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >-0.7</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >-0.7</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >-0.3</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >-1.1</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >-0.6</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >-0.7</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >-1.1</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_8b44f7a2_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >-0.4</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >-0.3</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >-0.2</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >0.3</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >-0.2</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >-0.1</td>
#                         <td id="T_8b44f7a2_5509_11ea_869f_00505683952erow5_col6" class

# %%
print('Regional Models, MAE')
regional_data, global_data, counts = compare_models(mae)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=regional_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, MAE
# <style  type="text/css" >
#     #T_8d4a89b8_5509_11ea_869f_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_8d4a89b8_5509_11ea_869f_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_8d4a89b8_5509_11ea_869f_00505683952erow2_col4 {
#             background-color:  yellow;
#         }    #T_8d4a89b8_5509_11ea_869f_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_8d4a89b8_5509_11ea_869f_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_8d4a89b8_5509_11ea_869f_00505683952erow5_col0 {
#             background-color:  yellow;
#         }    #T_8d4a89b8_5509_11ea_869f_00505683952erow6_col0 {
#             background-color:  yellow;
#         }    #T_8d4a89b8_5509_11ea_869f_00505683952erow7_col0 {
#             background-color:  yellow;
#         }    #T_8d4a89b8_5509_11ea_869f_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_8d4a89b8_5509_11ea_869f_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_8d4a89b8_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d4a89b8_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >1.9</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >1.9</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >1.9</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >2.3</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >2.4</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >2.4</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >2.0</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_8d4a89b8_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >3.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >3.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >3.9</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >4.0</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >3.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >3.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >3.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_8d4a89b8_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >2.9</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >2.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >2.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >2.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >2.5</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >2.7</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >2.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_8d4a89b8_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >2.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >2.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >2.9</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >2.7</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >2.7</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >2.6</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >2.8</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_8d4a89b8_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >4.5</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >4.4</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >4.6</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >4.6</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >4.5</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >4.5</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >4.2</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_8d4a89b8_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >2.6</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >2.6</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >2.7</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >3.2</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >2.9</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >2.9</td>
#                         <td id="T_8d4a89b8_5509_11ea_869f_00505683952erow5_col6" class="data row5 col6" >3.2</td>

# %%
print('Regional Models, MAPE')
regional_data, global_data, counts = compare_models(mape)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(regional_scores
 .style
 .format("{:.0%}", subset=regional_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, MAPE
# <style  type="text/css" >
#     #T_8f4bc844_5509_11ea_869f_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow1_col4 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow2_col4 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow5_col0 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow6_col0 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow7_col0 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow8_col2 {
#             background-color:  yellow;
#         }    #T_8f4bc844_5509_11ea_869f_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_8f4bc844_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8f4bc844_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >19%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >18%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >18%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >22%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >19%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_8f4bc844_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >25%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >25%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >25%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >26%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >25%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >25%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >25%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_8f4bc844_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >24%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >21%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >22%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_8f4bc844_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >22%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >22%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >21%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >21%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >22%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_8f4bc844_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >41%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >41%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >42%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >43%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >41%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >41%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >39%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_8f4bc844_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >22%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >23%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >28%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >25%</td>
#                         <td id="T_8f4bc844_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >25%</td>

# %%
print('Global Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=global_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, RMSE
# <style  type="text/css" >
#     #T_914ab4e8_5509_11ea_869f_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_914ab4e8_5509_11ea_869f_00505683952erow1_col4 {
#             background-color:  yellow;
#         }    #T_914ab4e8_5509_11ea_869f_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_914ab4e8_5509_11ea_869f_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_914ab4e8_5509_11ea_869f_00505683952erow4_col3 {
#             background-color:  yellow;
#         }    #T_914ab4e8_5509_11ea_869f_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_914ab4e8_5509_11ea_869f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_914ab4e8_5509_11ea_869f_00505683952erow7_col2 {
#             background-color:  yellow;
#         }    #T_914ab4e8_5509_11ea_869f_00505683952erow8_col6 {
#             background-color:  yellow;
#         }    #T_914ab4e8_5509_11ea_869f_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_914ab4e8_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_914ab4e8_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >2.3</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >2.2</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >2.4</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >1.8</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >1.9</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >1.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >1.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_914ab4e8_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >5.6</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >5.5</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >5.5</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >5.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >5.4</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >5.4</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >5.6</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_914ab4e8_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >3.5</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >3.5</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >3.6</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >3.4</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >3.5</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >3.5</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >3.6</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_914ab4e8_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >3.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >3.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >3.9</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >3.6</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >3.4</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >3.5</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >3.6</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_914ab4e8_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >7.2</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >7.2</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >7.2</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >6.5</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >6.6</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >6.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >7.2</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_914ab4e8_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >3.8</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >3.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >3.9</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >3.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >3.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >3.7</td>
#                         <td id="T_914ab4e8_5509_11ea_869f_00505683952erow5_col6" class="data row5 col6" >3.5</td>

# %%
print('Global Models, RMSE%')
regional_data, global_data, counts = compare_models(nrmse)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:.0%}", subset=global_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, RMSE%
# <style  type="text/css" >
#     #T_935f64ea_5509_11ea_869f_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_935f64ea_5509_11ea_869f_00505683952erow1_col4 {
#             background-color:  yellow;
#         }    #T_935f64ea_5509_11ea_869f_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_935f64ea_5509_11ea_869f_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_935f64ea_5509_11ea_869f_00505683952erow4_col3 {
#             background-color:  yellow;
#         }    #T_935f64ea_5509_11ea_869f_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_935f64ea_5509_11ea_869f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_935f64ea_5509_11ea_869f_00505683952erow7_col2 {
#             background-color:  yellow;
#         }    #T_935f64ea_5509_11ea_869f_00505683952erow8_col6 {
#             background-color:  yellow;
#         }    #T_935f64ea_5509_11ea_869f_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_935f64ea_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_935f64ea_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >22%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >21%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >23%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >17%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >18%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >17%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >16%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_935f64ea_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >36%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >36%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >36%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >37%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >35%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >35%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >36%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_935f64ea_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >28%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >28%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >29%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >28%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >29%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >29%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >29%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_935f64ea_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >29%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >30%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >31%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >28%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >27%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >28%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >29%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_935f64ea_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >67%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >66%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >67%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >60%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >61%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >62%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >67%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_935f64ea_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >33%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >32%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >34%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >32%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >32%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >32%</td>
#                         <td id="T_935f64ea_5509_11ea_869f_00505683952erow5_col6" class="data row5 col6" >30%</td>

# %%
print('Global Models, Bias')
regional_data, global_data, counts = compare_models(bias)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=global_scores.columns[:-1])
 .apply(highlight_best, axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, Bias
# <style  type="text/css" >
#     #T_95669d8a_5509_11ea_869f_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_95669d8a_5509_11ea_869f_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_95669d8a_5509_11ea_869f_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_95669d8a_5509_11ea_869f_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_95669d8a_5509_11ea_869f_00505683952erow4_col3 {
#             background-color:  yellow;
#         }    #T_95669d8a_5509_11ea_869f_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_95669d8a_5509_11ea_869f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_95669d8a_5509_11ea_869f_00505683952erow7_col2 {
#             background-color:  yellow;
#         }    #T_95669d8a_5509_11ea_869f_00505683952erow8_col6 {
#             background-color:  yellow;
#         }    #T_95669d8a_5509_11ea_869f_00505683952erow9_col6 {
#             background-color:  yellow;
#         }</style><table id="T_95669d8a_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95669d8a_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >-1.6</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >-1.4</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >-1.5</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >0.6</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >-0.4</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >-0.5</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >0.2</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_95669d8a_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >-1.2</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >-1.2</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >-1.2</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >-1.2</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >-1.0</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >-1.0</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >-0.7</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_95669d8a_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >-0.5</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >-0.4</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >-0.5</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >0.1</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >-0.1</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >-0.2</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >-0.0</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_95669d8a_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >-0.4</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >-0.3</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >-0.5</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >-0.5</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >-0.5</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >-0.4</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >0.0</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_95669d8a_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >2.4</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >2.5</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >2.7</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >1.6</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >1.8</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >1.8</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >2.4</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_95669d8a_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >-1.1</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >-0.9</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >-1.1</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >-0.8</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >-1.2</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >-1.1</td>
#                         <td id="T_95669d8a_5509_11ea_869f_00505683952erow5_col6" class="

# %%
print('Global Models, MAE')
regional_data, global_data, counts = compare_models(mae)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:,.0f}", subset=['n'])
 .format("{:,.1f}", subset=global_scores.columns[:-1])
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, MAE
# <style  type="text/css" >
#     #T_976a9da2_5509_11ea_869f_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_976a9da2_5509_11ea_869f_00505683952erow1_col4 {
#             background-color:  yellow;
#         }    #T_976a9da2_5509_11ea_869f_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_976a9da2_5509_11ea_869f_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_976a9da2_5509_11ea_869f_00505683952erow4_col4 {
#             background-color:  yellow;
#         }    #T_976a9da2_5509_11ea_869f_00505683952erow5_col4 {
#             background-color:  yellow;
#         }    #T_976a9da2_5509_11ea_869f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_976a9da2_5509_11ea_869f_00505683952erow7_col2 {
#             background-color:  yellow;
#         }    #T_976a9da2_5509_11ea_869f_00505683952erow8_col6 {
#             background-color:  yellow;
#         }    #T_976a9da2_5509_11ea_869f_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_976a9da2_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_976a9da2_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >1.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >1.6</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >1.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >1.5</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >1.5</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >1.4</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >1.3</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_976a9da2_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >3.8</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >3.8</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >3.8</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >3.9</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >3.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >3.8</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >3.9</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_976a9da2_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >2.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >2.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >2.8</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >2.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >2.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >2.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >2.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_976a9da2_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >2.8</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >2.9</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >2.9</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >2.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >2.5</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >2.6</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >2.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_976a9da2_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >5.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >5.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >5.9</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >5.1</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >5.0</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >5.1</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >5.2</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_976a9da2_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >2.8</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >2.7</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >2.8</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >2.4</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >2.4</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >2.5</td>
#                         <td id="T_976a9da2_5509_11ea_869f_00505683952erow5_col6" class="data row5 col6" >2.5</td>

# %%
print('Global Models, MAPE')
regional_data, global_data, counts = compare_models(mape)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(global_scores
 .style
 .format("{:.0%}", subset=global_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, MAPE
# <style  type="text/css" >
#     #T_996e57ba_5509_11ea_869f_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow1_col4 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow2_col3 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow2_col5 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow4_col4 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow5_col4 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow7_col2 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow8_col6 {
#             background-color:  yellow;
#         }    #T_996e57ba_5509_11ea_869f_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_996e57ba_5509_11ea_869f_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_996e57ba_5509_11ea_869f_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow0_col0" class="data row0 col0" >16%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow0_col1" class="data row0 col1" >15%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow0_col2" class="data row0 col2" >17%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow0_col3" class="data row0 col3" >15%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow0_col4" class="data row0 col4" >14%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow0_col5" class="data row0 col5" >13%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow0_col6" class="data row0 col6" >13%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow0_col7" class="data row0 col7" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_996e57ba_5509_11ea_869f_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow1_col0" class="data row1 col0" >25%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow1_col1" class="data row1 col1" >25%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow1_col2" class="data row1 col2" >25%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow1_col3" class="data row1 col3" >26%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow1_col4" class="data row1 col4" >24%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow1_col5" class="data row1 col5" >25%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow1_col6" class="data row1 col6" >25%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow1_col7" class="data row1 col7" >1,580</td>
#             </tr>
#             <tr>
#                         <th id="T_996e57ba_5509_11ea_869f_00505683952elevel0_row2" class="row_heading level0 row2" >north_cascades</th>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow2_col0" class="data row2 col0" >22%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow2_col1" class="data row2 col1" >22%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow2_col2" class="data row2 col2" >23%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow2_col3" class="data row2 col3" >22%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow2_col4" class="data row2 col4" >22%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow2_col5" class="data row2 col5" >22%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow2_col6" class="data row2 col6" >22%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow2_col7" class="data row2 col7" >443</td>
#             </tr>
#             <tr>
#                         <th id="T_996e57ba_5509_11ea_869f_00505683952elevel0_row3" class="row_heading level0 row3" >cascades</th>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow3_col0" class="data row3 col0" >22%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow3_col1" class="data row3 col1" >23%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow3_col2" class="data row3 col2" >23%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow3_col3" class="data row3 col3" >21%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow3_col4" class="data row3 col4" >20%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow3_col5" class="data row3 col5" >21%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow3_col6" class="data row3 col6" >21%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow3_col7" class="data row3 col7" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_996e57ba_5509_11ea_869f_00505683952elevel0_row4" class="row_heading level0 row4" >klamath_mountains</th>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow4_col0" class="data row4 col0" >53%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow4_col1" class="data row4 col1" >52%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow4_col2" class="data row4 col2" >55%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow4_col3" class="data row4 col3" >47%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow4_col4" class="data row4 col4" >46%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow4_col5" class="data row4 col5" >47%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow4_col6" class="data row4 col6" >48%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow4_col7" class="data row4 col7" >275</td>
#             </tr>
#             <tr>
#                         <th id="T_996e57ba_5509_11ea_869f_00505683952elevel0_row5" class="row_heading level0 row5" >eastern_cascades</th>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow5_col0" class="data row5 col0" >24%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow5_col1" class="data row5 col1" >24%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow5_col2" class="data row5 col2" >24%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow5_col3" class="data row5 col3" >21%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow5_col4" class="data row5 col4" >21%</td>
#                         <td id="T_996e57ba_5509_11ea_869f_00505683952erow5_col5" class="data row5 col5" >22%</td>

# %%
print('Global vs. Regional Models, ΔRMSE')
regional_data, global_data, counts = compare_models(rmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔRMSE
# <style  type="text/css" >
#     #T_9d7197be_5509_11ea_869f_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.6%, transparent 50.6%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.2%, transparent 50.2%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.6%, transparent 51.6%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.8%, orange 44.8%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.3%, orange 45.3%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.2%, orange 44.2%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.5%, orange 45.5%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.2%, transparent 50.2%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, orange 49.9%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, orange 49.6%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, orange 49.9%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, orange 49.6%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.3%, transparent 50.3%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, orange 48.5%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.8%, orange 47.8%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.4%, orange 48.4%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.1%, orange 48.1%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.6%, transparent 51.6%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.8%, orange 49.8%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.4%, orange 49.4%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, orange 48.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.0%, orange 49.0%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.3%, orange 49.3%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, orange 48.5%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.4%, orange 48.4%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.3%, orange 48.3%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.8%, orange 47.8%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.7%, transparent 55.7%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.6%, transparent 55.6%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.4%, transparent 55.4%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.7%, transparent 50.7%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.2%, transparent 50.2%);
#         }    #T_9d7197be_5509_11ea_869f_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  l

# %%
print('Global vs. Regional Models, ΔRMSE%')
regional_data, global_data, counts = compare_models(nrmse)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.2, vmax=0.2))
# Out:
# Global vs. Regional Models, ΔRMSE%
# <style  type="text/css" >
#     #T_9f85f0e0_5509_11ea_869f_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.2%, transparent 52.2%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.0%, transparent 51.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.0%, transparent 56.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.0%, orange 30.0%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.0%, orange 32.0%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.7%, orange 27.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.7%, orange 32.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.5%, transparent 50.5%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.0%, orange 49.0%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.2%, transparent 51.2%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.7%, transparent 50.7%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, orange 45.0%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.7%, orange 42.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, orange 44.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.7%, orange 43.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 55.2%, transparent 55.2%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.0%, orange 46.0%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.7%, orange 46.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.7%, orange 47.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.5%, orange 45.5%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, orange 44.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.2%, orange 44.2%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.0%, orange 43.0%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 71.0%, transparent 71.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 70.7%, transparent 70.7%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 69.7%, transparent 69.7%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, orange 48.7%, orange 50.0%, transparent 50.0%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.5%, transparent 52.5%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.7%, transparent 50.7%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 75.7%, transparent 75.7%);
#         }    #T_9f85f0e0_5509_11ea_869f_00505683952erow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  lin

# %%
print('Global vs. Regional Models, ΔMAE')
regional_data, global_data, counts = compare_models(mae)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1f}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-8, vmax=8))
# Out:
# Global vs. Regional Models, ΔMAE
# <style  type="text/css" >
#     #T_a191ee16_5509_11ea_869f_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.4%, orange 48.4%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.0%, orange 48.0%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.1%, orange 49.1%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, orange 44.9%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.3%, orange 44.3%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.5%, orange 43.5%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.6%, orange 45.6%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.8%, orange 49.8%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.5%, orange 49.5%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.4%, transparent 50.4%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.8%, orange 48.8%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.3%, orange 49.3%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.8%, orange 48.8%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.0%, transparent 51.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.8%, orange 49.8%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.4%, orange 49.4%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.8%, orange 49.8%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.8%, orange 49.8%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, orange 49.2%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.0%, orange 49.0%, orange 50.0%, transparent 50.0%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.1%, transparent 58.1%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 57.7%, transparent 57.7%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.2%, transparent 58.2%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 52.7%, transparent 52.7%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.1%, transparent 53.1%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.6%, transparent 53.6%);
#         }    #T_a191ee16_5509_11ea_869f_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linea

# %%
print('Global vs. Regional Models, Δbias%')
regional_data, global_data, counts = compare_models(rel_bias)
diff_scores = pd.DataFrame(data=np.vstack((global_data - regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregion_names)
(diff_scores.iloc[:-1]
 .style
 .format("{:,.1%}", subset=diff_scores.columns[:-1])
 .format("{:,.0f}", subset=['n'])
 .bar(subset=diff_scores.columns[:-1], color=['orange', 'blue'], align='mid', vmin=-0.4, vmax=0.4))
# Out:
# Global vs. Regional Models, Δbias%
# <style  type="text/css" >
#     #T_a39699b4_5509_11ea_869f_00505683952erow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 13.7%, orange 13.7%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 17.2%, orange 17.2%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 18.1%, orange 18.1%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.2%, orange 34.2%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 24.9%, orange 24.9%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 23.2%, orange 23.2%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 34.6%, orange 34.6%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.4%, orange 49.4%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, orange 49.6%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.6%, transparent 50.6%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.1%, orange 49.1%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 50.1%, transparent 50.1%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.7%, orange 49.7%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.0%, transparent 51.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 54.0%, transparent 54.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.9%, transparent 53.9%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 51.9%, transparent 51.9%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 59.2%, transparent 59.2%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 56.0%, transparent 56.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 53.5%, transparent 53.5%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 58.4%, transparent 58.4%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, orange 46.6%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.5%, orange 47.5%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, orange 44.9%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.2%, orange 47.2%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.4%, orange 48.4%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.1%, orange 48.1%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.6%, orange 46.6%, orange 50.0%, transparent 50.0%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 86.4%, transparent 86.4%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 87.4%, transparent 87.4%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 84.4%, transparent 84.4%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 81.4%, transparent 81.4%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 77.2%, transparent 77.2%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, blue 50.0%, blue 78.6%, transparent 78.6%);
#         }    #T_a39699b4_5509_11ea_869f_00505683952erow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(9

# %%
METRIC = 'qmd'

MODELS = {'ElasticNet': best_lms,
          'LASSO': best_lassos,
          'LASSO{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

pickle.dump(x_scaler, 
            open('../models/{}/sklearn/x_scaler.pkl'.format(METRIC), 'wb'))
pickle.dump(transformer, 
            open('../models/{}/sklearn/y_scaler.pkl'.format(METRIC), 'wb'))

for i in range(len(ecoregion_names)):
    for key in MODELS.keys():
        fname = ecoregion_names[i] + '_{}.pkl'.format(key)
        path_to_file = '../models/{}/sklearn/{}'.format(METRIC, fname)
        pickle.dump(MODELS[key][i], 
                    open(path_to_file, 'wb'))
        
        if key == 'LASSO{}'.format(MAX_FEATURES):
            sfm_name = ecoregion_names[i] + '_LASSO{}_featureselect.pkl'.format(MAX_FEATURES)
            path_to_file = '../models/{}/sklearn/{}'.format(METRIC, sfm_name)
            pickle.dump(sfms[i], 
                        open(path_to_file, 'wb'))
