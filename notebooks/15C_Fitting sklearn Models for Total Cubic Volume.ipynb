# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style('darkgrid')
# %matplotlib inline

# %%
# data prep and model-tuning
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import FunctionTransformer, PowerTransformer, QuantileTransformer
from scipy.stats import shapiro
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import GridSearchCV

# types of models we'll fit
from sklearn.linear_model import ElasticNetCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR

import pickle
from copy import deepcopy

# %% [markdown]
# ## Our Data

# %%
DATA = '../data/processed/training_data_annual.csv'
df = pd.read_csv(DATA)
df = df.dropna()
print('{:,d} samples'.format(len(df)))
print('Columns:', df.columns.values)
# Out:
# 4,721 samples
# Columns: ['uuid' 'lidar_year' 'lat' 'lon' 'orig_id' 'source' 'meas_yr' 'ecoregion3'
#  'agency' 'plot_size_ac' 'num_returns' 'strat0_return-proportion'
#  'strat1_return-proportion' 'strat2_return-proportion'
#  'strat3_return-proportion' 'strat4_return-proportion'
#  'strat5_return-proportion' 'strat0_intensity-median'
#  'strat1_intensity-median' 'strat2_intensity-median'
#  'strat3_intensity-median' 'strat4_intensity-median'
#  'strat5_intensity-median' 'height_05-percentile' 'height_25-percentile'
#  'height_50-percentile' 'height_75-percentile' 'height_95_percentile'
#  'height_max' 'cover' 'lidar_acq' 'potential_volume' 'stddev_height'
#  'surface_area_ratio' 'surface_volume' 'surface_volume_ratio' 'aspect'
#  'elevation' 'overall_curvature' 'plan_curvature' 'profile_curvature'
#  'slope' 'solar_radiation_index' 'mat' 'mwmt' 'mcmt' 'td' 'map' 'msp'
#  'ahm' 'shm' 'dd_0' 'dd5' 'dd_18' 'dd18' 'nffd' 'bffp' 'effp' 'ffp' 'pas'
#  'emt' 'ext' 'eref' 'cmd' 'rh' 'green' 'blue' 'red' 'nir' 'endvi' 'ndvi'
#  'savi' 'swir1' 'swir2' 'wetness' 'greenness' 'brightness' 'landsat_year'
#  'clim_year' 'distance_to_water_m' 'bulk_dens' 'soil_depth'
#  'pct_clay_surf' 'pct_rock_surf' 'pct_sand_surf' 'pot_veg_type' 'tpa' 'ba'
#  'sdi' 'ccf' 'qmd' 'tcuft' 'topht' 'number_of_strata' 'total_cover'
#  'structure_class' 'canopy_baseheight' 'canopy_bulkdensity'
#  'aboveground_biomass' 'aboveground_carbon' 'gs_tpa' 'AF' 'AS' 'BM' 'BO'
#  'CH' 'CW' 'DF' 'DG' 'ES' 'GC' 'GF' 'IC' 'JP' 'KP' 'LO' 'LP' 'MA' 'MC'
#  'MH' 'NF' 'OH' 'OS' 'OT' 'PC' 'PL' 'PP' 'PY' 'RA' 'RC' 'RF' 'SF' 'SH'
#  'SP' 'SS' 'TO' 'WA' 'WB' 'WF' 'WH' 'WI' 'WJ' 'WL' 'WO' 'WP' 'YC'
#  'TRUE_FIR' 'OTHER_HARDWOOD' 'MAPLE' 'OAK' 'DOUGLAS_FIR' 'SPRUCE' 'CEDAR'
#  'PONDEROSA_PINE' 'OTHER_SOFTWOOD' 'LODGEPOLE_PINE' 'HEMLOCK' 'RED_ALDER'
#  'TANOAK' 'JUNIPER' 'LARCH' 'fvs_year' 'year_diff' 'returns_per_m2']

# %% [markdown]
# ## Filter out some of the training data
# We can exclude some of the training data based on how far separated the inventory data (interpolated using FVS simulations) is from the year the lidar was collected. Similarly, we can screen out training examples that had relatively low density of lidar returns.

# %%
df['year_diff'] = abs(df['fvs_year'] - df['lidar_year']).astype(int)
df = df.loc[df['year_diff'] < 10]
df = df.loc[df['returns_per_m2'] >= 4.0]

# %% [markdown]
# ## Inspect how many samples we have for different years, regions, etc.

# %%
df.groupby(by=['lidar_year'])[['uuid']].count().rename({'uuid':'count'}, axis=1)
# Out:
#             count
# lidar_year
# 2006          191
# 2008          857
# 2009          113
# 2010           21
# 2011          161
# 2012          720
# 2013          269
# 2014          368
# 2015          680
# 2016          604
# 2017          191
# 2018           35

# %%
pd.pivot_table(df, 
               values='uuid', 
               aggfunc='count', 
               index=['meas_yr'], 
               columns=['lidar_year'], 
               fill_value=0)
# Out:
# lidar_year  2006  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# meas_yr
# 2010           0   475     0     0     0     4     0     2     7     0     0
# 2011           0   377     0     0     0     1     0     2     3     0     0
# 2013         168     0    18     0    37   466    54     6    11    14    28
# 2014           5     0    60     2    28   132    45    50    44    99    40
# 2015          18     4     5     0    55    18    13    16   217   114    25
# 2016           0     1    18    15    26    45    90    59   284    77    36
# 2017           0     0     9     2    12    44    43   182    58   104    51
# 2018           0     0     3     2     3    10    24    51    56   196    11
#
# lidar_year  2018
# meas_yr
# 2010           0
# 2011           0
# 2013           2
# 2014           1
# 2015           6
# 2016          26
# 2017           0
# 2018           0

# %%
ecoreg_counts = df.groupby(by=['ecoregion3'])[['uuid']].count()
ecoreg_counts
# Out:
#                                                     uuid
# ecoregion3
# blue_mountains                                       108
# cascades                                             747
# coast_range                                         1809
# columbia_plateau                                      14
# eastern_cascades_slopes_and_foothills                409
# klamath_mountains_california_high_north_coast_r...   323
# north_cascades                                       505
# northern_rockies                                     103
# puget_lowland                                        149
# willamette_valley                                     43

# %% [markdown]
# ## Available features
# First, we'll use one-hot encoding for categorical features

# %%
# convert agency, ecoregion, and lidar acquisition into one-hot encoded set of variables
df = pd.get_dummies(df, prefix='agency', columns=['agency'])
# df = pd.get_dummies(df, prefix='eco', columns=['ecoregion3'])
# df = pd.get_dummies(df, prefix='acq', columns=['lidar_acq'])

# %% [markdown]
# The different types of predictor variables we can use to predict a forest attribute, including climate, lidar-derived, soil, and satellite imagery.

# %%
CLIM_COLS = ['mat', 'mwmt', 'mcmt', 'td', 'map', 'msp', 'ahm', 'shm', 
             'dd_0', 'dd5', 'dd_18', 'dd18', 'nffd', 'bffp', 'effp', 
             'ffp', 'pas', 'emt', 'ext', 'eref', 'cmd', 'rh']
LIDAR_COLS = ['returns_per_m2', 'strat0_return-proportion',
       'strat1_return-proportion', 'strat2_return-proportion',
       'strat3_return-proportion', 'strat4_return-proportion',
       'strat5_return-proportion', 'strat0_intensity-median',
       'strat1_intensity-median', 'strat2_intensity-median',
       'strat3_intensity-median', 'strat4_intensity-median',
       'strat5_intensity-median', 'height_05-percentile',
       'height_25-percentile', 'height_50-percentile', 'height_75-percentile',
       'height_95_percentile', 'height_max', 'cover', 'potential_volume',
       'stddev_height', 'surface_area_ratio', 'surface_volume',
       'surface_volume_ratio', 'aspect', 'elevation', 'overall_curvature',
       'plan_curvature', 'profile_curvature', 'slope', 'solar_radiation_index']

SOIL_COLS = ['bulk_dens', 'soil_depth', 'pct_clay_surf', 'pct_rock_surf', 'pct_sand_surf']

LANDSAT_COLS = ['green', 'blue', 'red', 'nir', 'endvi', 'ndvi', 'savi',
                'swir1', 'swir2', 'wetness', 'greenness', 'brightness']

AGENCY_COLS = ['agency_BLM', 'agency_USFS', 'agency_WADNR']

# ECOREGIONS = [col for col in df.columns if col.startswith('eco_')]

# %% [markdown]
# ## Selecting initial features and targets
# This is the first step in determining what features we want to use, and what we want to predict. Later, we can still apply some procedures to choose a subset of these features to make simpler models.

# %%
X_COLS = LIDAR_COLS + ['plot_size_ac', 'ecoregion3'] + LANDSAT_COLS + CLIM_COLS
Y_COLS = ['tcuft']

# %% [markdown]
# ## Split the data into training and testing sets
# Since some plot_ids have multiple observations, we want all observations for each plot_id to fall entirely in train_set or entirely the training or testing sets because these samples are definitely not independent.

# %%
# a dataframe with unique plot ids
splits = pd.DataFrame(pd.unique(df['uuid']), columns=['uuid']).set_index('uuid')

# randomly assign each plot-id to train(0) or test(1) sets
np.random.seed(127)
splits['train0_test1'] = np.random.choice(2,
                                          size=len(splits),
                                          p=[0.8,0.2])

# add set assignments to the dataframe
df['train0_test1'] = splits.loc[df['uuid']]['train0_test1'].values

# %%
train_plots = df.loc[df['train0_test1'] == 0]
test_plots = df.loc[df['train0_test1'] == 1]
len(train_plots), len(test_plots)
# Out:
# (3355, 855)

# %%
x_train, x_test = train_plots[X_COLS].reset_index(drop=True), test_plots[X_COLS].reset_index(drop=True)
y_train, y_test = train_plots[Y_COLS].reset_index(drop=True), test_plots[Y_COLS].reset_index(drop=True)

# %% [markdown]
# ## Standardize features
# Scale all predictive features to have 0 mean and unit variance (subtracting mean, dividing by standard deviation).

# %%
x_scaler = StandardScaler()
x_scaler.fit(df[X_COLS].drop(['ecoregion3'], axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ## Consider a few transformations for the target variable

# %%
fig, axs = plt.subplots(1,6, figsize=(15,2.5))
axs.ravel()[0].hist(y_train.values, bins=20)

qtrans = QuantileTransformer(output_distribution='normal', random_state=127)
box_cox = PowerTransformer(method='box-cox')
yeo_johnson = PowerTransformer(method='yeo-johnson')

VALS = [y_train.values,
        np.log1p(y_train.values),
        np.sqrt(y_train.values),
        qtrans.fit_transform(y_train.values),
        box_cox.fit_transform(y_train.values + 1e-9),
        yeo_johnson.fit_transform(y_train.values)]

TITLES = ['Raw', 'Log', 'SQRT', 'Quantile', 'Box-Cox', 'Yeo-Johnson']
SHAPIRO_ps = [shapiro(vals)[-1] for vals in VALS]

for i, vals in enumerate(VALS):
    axs.ravel()[i].hist(vals, bins=20)
    axs.ravel()[i].set_title(TITLES[i])
    
plt.show();

# %%
# identify the closest to normally-distributed
TITLES[np.array(SHAPIRO_ps).argmax()]
# Out:
# 'Yeo-Johnson'

# %%
# choose your transformer here
transformer = yeo_johnson

# %%
transformer.fit(df[Y_COLS])
y_train, y_test = transformer.transform(y_train), transformer.transform(y_test)

# %% [markdown]
# ## Split datasets by ecoregion
# We want to explore model transferability between regions, so we'll train models independently on subsets of the data within a single ecoregion, as well as a model that is trained on all available ecoregions.

# %%
ecoregions = [reg for reg in pd.unique(df.ecoregion3) if ecoreg_counts.loc[reg]['uuid'] > 20]

eco_train_idx = [x_train.loc[x_train.ecoregion3 == eco].index.values for eco in ecoregions]
eco_test_idx = [x_test.loc[x_test.ecoregion3 == eco].index.values for eco in ecoregions]

eco_xtrain_dfs = [x_train.loc[x_train.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytrain_dfs = [y_train[idx].ravel() for idx in eco_train_idx]
eco_xtest_dfs = [x_test.loc[x_test.ecoregion3 == eco].drop(['ecoregion3'], axis=1) for eco in ecoregions]
eco_ytest_dfs = [y_test[idx].ravel() for idx in eco_test_idx]

# append a "global" model that contains data from all ecoregions
ecoregions.append('all')
ecoregion_names = ['_'.join(x.split('_')[0:2]) for x in ecoregions]
eco_xtrain_dfs.append(x_train.drop(['ecoregion3'], axis=1))
eco_ytrain_dfs.append(y_train.ravel())
eco_xtest_dfs.append(x_test.drop(['ecoregion3'], axis=1))
eco_ytest_dfs.append(y_test.ravel())

# %% [markdown]
# ## Scoring
# We'll use Root Mean Square Error to evaluate model performance.

# %%
def rmse(pred, obs):
    # use our transformer to calculate RMSE on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return np.sqrt((np.square(obs-pred)).mean())

# %%
def nrmse(pred, obs):
    # use our transformer to calculate percent RMSE on the original data scale
    this_rmse = rmse(pred,obs)
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return this_rmse/obs.mean()

# %%
def mae(pred, obs):
    # use our transformer to calculate mean absolute error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return abs(pred - obs).mean()

# %%
def mape(pred, obs):
    # use our transformer to calculate mean average percent error on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return abs(pred - obs).mean() / obs.mean()

# %%
def bias(pred, obs):
    # use our transformer to calculate mean bias on the original data scale
    pred = transformer.inverse_transform(pred.reshape(-1,1)).ravel()
    obs = transformer.inverse_transform(obs.reshape(-1,1)).ravel()
    
    return (pred - obs).mean()

# %% [markdown]
# This helper function will calculate RMSE scores for each regionally-trained model and the global model on each ecoregion.

# %%
def get_score_df(models, metric=rmse, feature_selectors=None):
    regional_scores = []
    global_scores = []
    counts = []
    
    for i, mod in enumerate(models):
        X_test = x_scaler.transform(eco_xtest_dfs[i])
        if feature_selectors:
            X_test = feature_selectors[i].transform(X_test)
        y_test = eco_ytest_dfs[i].reshape(-1, 1)
        reg_score = metric(mod.predict(X_test), y_test)
        regional_scores.append(reg_score.round(3))
        
        if feature_selectors:
            X_test = x_scaler.transform(eco_xtest_dfs[i])
            X_test = feature_selectors[-1].transform(X_test)
        glob_score = metric(models[-1].predict(X_test), y_test)
        global_scores.append(glob_score.round(3))
        count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
        counts.append(count)
        
    data = list(zip(regional_scores, global_scores, counts))
    res_df = pd.DataFrame(data=data,
                          columns=['regional_model', 'global_model', 'n'],
                          index=ecoregion_names)
    
    return res_df

# %% [markdown]
# ## Fit some models
# For each type of model, we'll employ cross-validation to tune model hyperparameters, generating a tuned model for each ecoregion as well as a tuned model using all training data. We'll work our way through:
#
# #### ElasticNet Regression
# Linear model that employs a mix of L1 and L2 regularization to penalize model complexity
#
# #### LASSO Regression
# Linear model that employs L1 regularization to penalize model complexity. We'll also work with a feature-selection process to fit models capped to an explicitly-predefined number of features.
#
# #### K-Nearest Neighbor Regression
#
# #### Random Forest Regression
#
# #### Gradient Boosting Trees Regression
#
# #### Support Vector Machine Regression

# %% [markdown]
# ## ElasticNet (Linear Model)

# %%
best_lms = []

for i in range(len(ecoregions)):
    lm = ElasticNetCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    lm.fit(X, y)
    best_lms.append(lm)

# %%
elastic_res = get_score_df(best_lms, rmse)
elastic_res
# Out:
#                    regional_model  global_model     n
# blue_mountains            535.833       573.525   108
# coast_range              3686.180      4092.861  1646
# eastern_cascades         2439.214      2111.460   403
# north_cascades           2556.893      3005.840   490
# cascades                 3557.109      4016.386   728
# klamath_mountains        3832.941      4070.865   321
# northern_rockies         1943.508      2153.059   103
# puget_lowland            2931.743      3610.768   147
# willamette_valley        1524.698      2651.926    43
# all                      3701.680      3701.680  3355

# %%
coefs = np.array([lm.coef_ for lm in best_lms])
count_nonzero = [(~np.isclose(coef, 0, atol=1e-3)).sum() for coef in coefs]
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.001
# eastern_cascades_slopes_and_foothills                          --
# north_cascades                                              0.015
# cascades                                                   -0.003
# klamath_mountains_california_high_north_coast_r...          0.007
# northern_rockies                                               --
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                       -0.064
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                             -0.094
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                       -0.029
# coast_range                                                          -0.078
# eastern_cascades_slopes_and_foothills                                -0.036
# north_cascades                                                       -0.122
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.059
# northern_rockies                                                     -0.157
# puget_lowland                                                        -0.196
# willamette_valley                                                        --
# all                                                                  -0.019
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                          -0.003
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                       -0.043
# cascades                                                              0.007
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.095
# all                                                                    0.05
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.084
# coast_range                                                           0.042
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                    0.171
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.033
# all                                                                   0.121
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.122
# coast_range                                                           0.069
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                        0.136
# cascades                                                              0.068
# klamath_mountains_california_high_north_coast_r...                    0.114
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.199
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                            0.11
# eastern_cascades_slopes_and_foothills                                 0.059
# north_cascades                                                           --
# cascades                                                              0.068
# klamath_mountains_california_high_north_coast_r...                    0.427
# northern_rockies                                                       0.08
# puget_lowland                                                            --
# willamette_valley                                                     0.209
# all                                                                   0.399
#
#                                                    strat0_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.047
# cascades                                                             0.073
# klamath_mountains_california_high_north_coast_r...                  -0.146
# northern_rockies                                                        --
# puget_lowland                                                       -0.008
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat1_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.023
# cascades                                                            -0.096
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat2_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                         -0.035
# eastern_cascades_slopes_and_foothills                               -0.029
# north_cascades                                                      -0.025
# cascades                                                            -0.014
# klamath_mountains_california_high_north_coast_r...                  -0.047
# northern_rockies                                                        --
# puget_lowland                                                       -0.015
# willamette_valley                                                       --
# all                                                                 -0.059
#
#                                                     ...   nffd   bffp   effp  \
# blue_mountains                                      ...     --     --     --
# coast_range                                         ...     --     --     --
# eastern_cascades_slopes_and_foothills               ...     --     --     --
# north_cascades                                      ...     --     --     --
# cascades                                            ... -0.321     --  0.151
# klamath_mountains_california_high_north_coast_r...  ...     --  0.084     --
# northern_rockies                                    ...     --     --     --
# puget_lowland                                       ...     --     --     --
# willamette_valley                                   ...     --     --     --
# all                                                 ... -0.027     --  0.102
#
#                                                       ffp    pas    emt  \
# blue_mountains                                         --     --     --
# coast_range                                            --     --  0.005
# eastern_cascades_slopes_and_foothills              -0.021     --     --
# north_cascades                                         --  0.081     --
# cascades                                               -- -0.051 -0.214
# klamath_mountains_california_high_north_coast_r...     --     --     --
# northern_rockies                                       --     --     --
# puget_lowland                                          --     --     --
# willamette_valley                                      --     --     --
# all                                                    -- -0.033     --
#
#                                                       ext   eref    cmd     rh
# blue_mountains                                         --     -- -0.002     --
# coast_range                                            --     --     --  0.071
# eastern_cascades_slopes_and_foothills                  --     --     --     --
# north_cascades                                         --     --     --     --
# cascades                                               --   0.06     --  0.088
# klamath_mountains_california_high_north_coast_r... -0.081     --     --  0.013
# northern_rockies                                       --     --     --     --
# puget_lowland                                          --     --     --     --
# willamette_valley                                      --     --     --     --
# all                                                -0.122  0.316  0.117   0.16
#
# [10 rows x 65 columns]

# %% [markdown]
# ## LASSO (Linear Model)
# Starting with implicit feature selection via L1 regularization of coefficients.

# %%
best_lassos = []

for i in range(len(ecoregions)):
    lasso = LassoCV(cv=3, random_state=127, n_jobs=-1, max_iter=1000000, n_alphas=1000)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    lasso.fit(X, y)
    best_lassos.append(lasso)

# %%
lasso_res = get_score_df(best_lassos)
lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains            541.698       578.094   108
# coast_range              3676.925      4090.919  1646
# eastern_cascades         2465.652      2100.431   403
# north_cascades           2557.669      3004.255   490
# cascades                 3565.300      4025.752   728
# klamath_mountains        3795.338      4074.996   321
# northern_rockies         1938.723      2156.156   103
# puget_lowland            3034.416      3602.892   147
# willamette_valley        1578.843      2646.214    43
# all                      3701.580      3701.580  3355

# %%
coefs = np.array([lm.coef_ for lm in best_lassos])
coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    returns_per_m2  \
# blue_mountains                                                 --
# coast_range                                                 0.001
# eastern_cascades_slopes_and_foothills                          --
# north_cascades                                              0.015
# cascades                                                   -0.003
# klamath_mountains_california_high_north_coast_r...             --
# northern_rockies                                               --
# puget_lowland                                                  --
# willamette_valley                                              --
# all                                                            --
#
#                                                    strat0_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                             -0.094
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                          -0.076
# eastern_cascades_slopes_and_foothills                                -0.035
# north_cascades                                                       -0.126
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.061
# northern_rockies                                                     -0.161
# puget_lowland                                                        -0.217
# willamette_valley                                                        --
# all                                                                  -0.019
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                       -0.044
# cascades                                                              0.006
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.062
# all                                                                   0.053
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                        0.059
# coast_range                                                           0.045
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                    0.185
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.015
# all                                                                   0.125
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.139
# coast_range                                                           0.072
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                        0.143
# cascades                                                              0.066
# klamath_mountains_california_high_north_coast_r...                    0.131
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                   0.203
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.115
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                              0.066
# klamath_mountains_california_high_north_coast_r...                    0.502
# northern_rockies                                                      0.051
# puget_lowland                                                            --
# willamette_valley                                                      0.22
# all                                                                   0.409
#
#                                                    strat0_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.047
# cascades                                                             0.072
# klamath_mountains_california_high_north_coast_r...                   -0.17
# northern_rockies                                                        --
# puget_lowland                                                       -0.005
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat1_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                             --
# eastern_cascades_slopes_and_foothills                                   --
# north_cascades                                                      -0.018
# cascades                                                            -0.096
# klamath_mountains_california_high_north_coast_r...                      --
# northern_rockies                                                        --
# puget_lowland                                                           --
# willamette_valley                                                       --
# all                                                                     --
#
#                                                    strat2_intensity-median  \
# blue_mountains                                                          --
# coast_range                                                         -0.036
# eastern_cascades_slopes_and_foothills                               -0.028
# north_cascades                                                      -0.026
# cascades                                                            -0.009
# klamath_mountains_california_high_north_coast_r...                  -0.002
# northern_rockies                                                        --
# puget_lowland                                                       -0.009
# willamette_valley                                                       --
# all                                                                 -0.058
#
#                                                     ...   nffd   bffp   effp  \
# blue_mountains                                      ...     --     --     --
# coast_range                                         ...     --     --     --
# eastern_cascades_slopes_and_foothills               ...     --     --     --
# north_cascades                                      ...     --     --     --
# cascades                                            ... -0.356     --  0.155
# klamath_mountains_california_high_north_coast_r...  ...     --  0.069     --
# northern_rockies                                    ...     --     --     --
# puget_lowland                                       ...     --     --     --
# willamette_valley                                   ...     --     --     --
# all                                                 ...     --     --  0.104
#
#                                                       ffp    pas    emt  \
# blue_mountains                                         --     --     --
# coast_range                                            --     --  0.008
# eastern_cascades_slopes_and_foothills              -0.012     --     --
# north_cascades                                         --  0.087     --
# cascades                                               -- -0.055 -0.215
# klamath_mountains_california_high_north_coast_r...     --     --     --
# northern_rockies                                       --     --     --
# puget_lowland                                          --     --     --
# willamette_valley                                      --     --     --
# all                                                    -- -0.039     --
#
#                                                       ext   eref    cmd     rh
# blue_mountains                                         --     --     --     --
# coast_range                                            --     --     --  0.074
# eastern_cascades_slopes_and_foothills                  --     --     --     --
# north_cascades                                         --     --     --     --
# cascades                                               --  0.059     --  0.096
# klamath_mountains_california_high_north_coast_r...  -0.09     --     --     --
# northern_rockies                                       --     --     --     --
# puget_lowland                                          --     --     --     --
# willamette_valley                                      --     --     --     --
# all                                                -0.128  0.341  0.113  0.164
#
# [10 rows x 64 columns]

# %% [markdown]
# Now we'll explicitly define the maximum number of features to use for fitting a linear model. We'll trim features by iteratively increasing a threshold for coefficients using LASSO regression

# %%
MAX_FEATURES = 5
sfms = [] # transformers that filter X features
trimmed_lassos = [] # re-fit lasso regressions on the subset of the features

for i, lasso in enumerate(best_lassos):
    lasso = deepcopy(lasso)
    sfm = SelectFromModel(lasso, threshold=0.001)
    X = x_scaler.transform(eco_xtrain_dfs[i])
    Y = (eco_ytrain_dfs[i].ravel())
    sfm.fit(X, Y)
    n_features = sfm.transform(X).shape[1]

    # Reset the threshold till the number of features equals two.
    # Note that the attribute can be set directly instead of repeatedly
    # fitting the metatransformer.
    while n_features > MAX_FEATURES:
        sfm.threshold += 0.001
        X_transform = sfm.transform(X)
        n_features = X_transform.shape[1]
    
    sfms.append(sfm)
    try:
        trimmed_lassos.append(lasso.fit(sfm.transform(X), Y))
    except ValueError:
        print(ecoregion_names[i])
        raise
    
trimmed_regional_scores = []
trimmed_global_scores = []
counts = []

for i, lasso in enumerate(trimmed_lassos):
    X_reg = sfms[i].transform(x_scaler.transform(eco_xtest_dfs[i]))
    X_glob = sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i]))
    observed = eco_ytest_dfs[i]
    
    reg_score = rmse(lasso.predict(X_reg), observed)
    glob_score = rmse(trimmed_lassos[-1].predict(X_glob), observed)
    
    trimmed_regional_scores.append(reg_score.round(3))
    trimmed_global_scores.append(glob_score.round(3))
    
    count = len(eco_xtrain_dfs[i] + eco_xtest_dfs[i])
    counts.append(count)
    

trimmed_lasso_res = pd.DataFrame(data=list(zip(trimmed_regional_scores, trimmed_global_scores, counts)),
                      columns=['regional_model', 'global_model', 'n'],
                      index=ecoregion_names)
trimmed_lasso_res
# Out:
#                    regional_model  global_model     n
# blue_mountains            551.123      1511.065   108
# coast_range              3713.824      6139.897  1646
# eastern_cascades         2454.299      3043.323   403
# north_cascades           3122.243      4175.658   490
# cascades                 4156.310      6308.433   728
# klamath_mountains        3973.780      5301.788   321
# northern_rockies         1897.763      2685.400   103
# puget_lowland            3149.208      5154.690   147
# willamette_valley        1472.683      3162.867    43
# all                      5485.094      5485.094  3355

# %%
coefs = []
for i in range(len(ecoregions)):
    cols = np.zeros(eco_xtest_dfs[i].columns.shape)
    cols[sfms[i].get_support()] = trimmed_lassos[i].coef_
    coefs.append(cols)
    
coefs = np.array(coefs)

coef_df = pd.DataFrame(data=coefs.T,
                       columns=ecoregions,
                       index=eco_xtest_dfs[i].columns)
coef_df.values[np.isclose(coef_df.values, 0, atol=1e-3)] = np.nan
coef_df = coef_df.round(3)
coef_df = coef_df.dropna(how='all')
coef_df = coef_df.fillna('--')
coef_df.T
# Out:
#                                                    strat1_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                          -0.217
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                       -0.265
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                     -0.143
# puget_lowland                                                        -0.225
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat2_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                    -0.036
# all                                                                      --
#
#                                                    strat3_return-proportion  \
# blue_mountains                                                         0.08
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat4_return-proportion  \
# blue_mountains                                                        0.194
# coast_range                                                              --
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                         0.16
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                       --
# northern_rockies                                                         --
# puget_lowland                                                            --
# willamette_valley                                                        --
# all                                                                      --
#
#                                                    strat5_return-proportion  \
# blue_mountains                                                           --
# coast_range                                                           0.029
# eastern_cascades_slopes_and_foothills                                    --
# north_cascades                                                           --
# cascades                                                                 --
# klamath_mountains_california_high_north_coast_r...                   -0.222
# northern_rockies                                                       0.19
# puget_lowland                                                            --
# willamette_valley                                                     0.261
# all                                                                   0.545
#
#                                                    height_25-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# eastern_cascades_slopes_and_foothills                                --
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                   --
# northern_rockies                                                     --
# puget_lowland                                                     0.055
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_75-percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# eastern_cascades_slopes_and_foothills                              0.39
# north_cascades                                                       --
# cascades                                                             --
# klamath_mountains_california_high_north_coast_r...                1.675
# northern_rockies                                                  0.142
# puget_lowland                                                     0.157
# willamette_valley                                                    --
# all                                                                  --
#
#                                                    height_95_percentile  \
# blue_mountains                                                       --
# coast_range                                                          --
# eastern_cascades_slopes_and_foothills                              0.18
# north_cascades                                                    0.528
# cascades                                                          0.419
# klamath_mountains_california_high_north_coast_r...                0.912
# northern_rockies                                                  0.113
# puget_lowland                                                        --
# willamette_valley                                                    --
# all                                                               0.894
#
#                                                    height_max  cover  ...  \
# blue_mountains                                             --  0.425  ...
# coast_range                                                --     --  ...
# eastern_cascades_slopes_and_foothills                      --     --  ...
# north_cascades                                             --     --  ...
# cascades                                               -0.397     --  ...
# klamath_mountains_california_high_north_coast_r...         --     --  ...
# northern_rockies                                           --     --  ...
# puget_lowland                                              --     --  ...
# willamette_valley                                          --     --  ...
# all                                                    -0.959     --  ...
#
#                                                    plot_size_ac  swir1  swir2  \
# blue_mountains                                               --     --  0.103
# coast_range                                                  --     --     --
# eastern_cascades_slopes_and_foothills                     0.106     -- -0.139
# north_cascades                                            0.135     --     --
# cascades                                                     --     -- -0.378
# klamath_mountains_california_high_north_coast_r...        0.449     --     --
# northern_rockies                                             --     --     --
# puget_lowland                                                --     --     --
# willamette_valley                                          0.56 -0.141     --
# all                                                          --     --     --
#
#                                                    wetness   mwmt   msp  \
# blue_mountains                                          --     --    --
# coast_range                                             --     --    --
# eastern_cascades_slopes_and_foothills                   -- -0.127    --
# north_cascades                                          --     --  0.21
# cascades                                                --     --    --
# klamath_mountains_california_high_north_coast_r...      --     --    --
# northern_rockies                                     0.126     --    --
# puget_lowland                                           --     --    --
# willamette_valley                                       --     --    --
# all                                                     --     --    --
#
#                                                     dd_18   nffd   eref     rh
# blue_mountains                                         --     --     --     --
# coast_range                                            --     --     --  0.169
# eastern_cascades_slopes_and_foothills                  --     --     --     --
# north_cascades                                         --     --     --     --
# cascades                                               -- -0.265     --     --
# klamath_mountains_california_high_north_coast_r...     --     --     --     --
# northern_rockies                                       --     --     --     --
# puget_lowland                                          --     --     --     --
# willamette_valley                                      --     --     --     --
# all                                                -0.143     -- -0.027     --
#
# [10 rows x 24 columns]

# %% [markdown]
# ## K-Nearest Neighbors Regression

# %%
# Set the parameters by cross-validation
knn_params = {'n_neighbors': [1,2,3,4,5,10,20],
              'weights': ['uniform', 'distance'],
              'metric': ['minkowski', 'manhattan']}


knn_gs = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=knn_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_knns = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    knn_gs.fit(X, y)
    best_fit = knn_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_knns.append(best_fit)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    2.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    2.6s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.4s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.2s remaining:    0.0s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  84 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    0.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# [Parallel(n_jobs=-1)]: Done  64 out of  84 | elapsed:    1.6s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    1.9s finished

# %%
knn_res = get_score_df(best_knns)
knn_res
# Out:
#                    regional_model  global_model     n
# blue_mountains            948.872       864.144   108
# coast_range              4007.589      3946.344  1646
# eastern_cascades         2769.110      2532.707   403
# north_cascades           2677.450      2704.969   490
# cascades                 4642.995      4336.248   728
# klamath_mountains        4163.519      4033.594   321
# northern_rockies         2077.030      2050.552   103
# puget_lowland            2944.885      3408.915   147
# willamette_valley        1242.945      2038.733    43
# all                      3663.018      3663.018  3355

# %% [markdown]
# ## Random Forest Regression

# %%
# Set the parameters by cross-validation
rf_params = {'n_estimators': [100, 500, 1000, 5000],
             'max_features': ['sqrt'],
             'max_depth': [3, 5, 10, 25, 50],
             'min_samples_leaf': [1,2,4],
             'bootstrap': [True, False]}


rf_gs = GridSearchCV(estimator=RandomForestRegressor(), param_grid=rf_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_rfs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i].ravel()
    rf_gs.fit(X, y)
    best_fit = rf_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_rfs.append(best_fit)
# Out:
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 297 out of 360 | elapsed:   21.9s remaining:    4.7s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   29.2s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   20.5s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  2.4min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   58.5s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:   16.0s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.1min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:   18.5s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  1.5min finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:   17.4s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   50.6s finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   36.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   39.9s finished
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   34.4s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   53.3s
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  6.9min finished

# %%
rf_res = get_score_df(best_rfs)
rf_res
# Out:
#                    regional_model  global_model     n
# blue_mountains            530.504       557.686   108
# coast_range              3691.957      3606.644  1646
# eastern_cascades         2499.396      2417.853   403
# north_cascades           2475.240      2169.712   490
# cascades                 4113.873      3705.564   728
# klamath_mountains        4236.151      4157.528   321
# northern_rockies         2066.027      2028.806   103
# puget_lowland            2354.432      2533.947   147
# willamette_valley        2091.287      2242.739    43
# all                      3306.285      3306.285  3355

# %%
### Employing feature selection to try and improve random forest regression

# %%
importances = best_rfs[-1].feature_importances_
indices = np.argsort(importances)[::-1]
features = eco_xtrain_dfs[-1].columns[indices]

# Print the feature ranking
print("Feature ranking:")

for f in range(eco_xtrain_dfs[-1].shape[1]):
    print("%d. %s (%f)" % (f+1, features[f], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. surface_volume (0.160436)
# 2. potential_volume (0.111591)
# 3. height_50-percentile (0.076147)
# 4. height_75-percentile (0.063859)
# 5. height_25-percentile (0.052357)
# 6. cover (0.046603)
# 7. strat5_return-proportion (0.036113)
# 8. surface_area_ratio (0.028147)
# 9. swir2 (0.025395)
# 10. strat1_return-proportion (0.024233)
# 11. height_95_percentile (0.023675)
# 12. stddev_height (0.021268)
# 13. strat0_return-proportion (0.019702)
# 14. swir1 (0.019039)
# 15. height_max (0.013242)
# 16. wetness (0.013112)
# 17. plot_size_ac (0.012790)
# 18. red (0.012192)
# 19. strat4_return-proportion (0.009981)
# 20. strat2_return-proportion (0.008458)
# 21. emt (0.008425)
# 22. strat3_return-proportion (0.007810)
# 23. green (0.007756)
# 24. ndvi (0.007671)
# 25. savi (0.007164)
# 26. brightness (0.006979)
# 27. td (0.006138)
# 28. strat0_intensity-median (0.006060)
# 29. strat2_intensity-median (0.005973)
# 30. strat1_intensity-median (0.005740)
# 31. strat4_intensity-median (0.005541)
# 32. blue (0.005441)
# 33. strat5_intensity-median (0.005434)
# 34. strat3_intensity-median (0.005276)
# 35. map (0.005261)
# 36. cmd (0.005256)
# 37. mcmt (0.005151)
# 38. elevation (0.005131)
# 39. slope (0.005068)
# 40. msp (0.005044)
# 41. shm (0.005041)
# 42. nir (0.004803)
# 43. greenness (0.004655)
# 44. ahm (0.004441)
# 45. solar_radiation_index (0.004312)
# 46. height_05-percentile (0.004271)
# 47. ext (0.004261)
# 48. plan_curvature (0.004199)
# 49. overall_curvature (0.004149)
# 50. dd_0 (0.004143)
# 51. nffd (0.004061)
# 52. profile_curvature (0.004044)
# 53. ffp (0.003911)
# 54. eref (0.003747)
# 55. pas (0.003645)
# 56. endvi (0.003611)
# 57. bffp (0.003606)
# 58. effp (0.003496)
# 59. aspect (0.003481)
# 60. dd5 (0.003439)
# 61. dd18 (0.003401)
# 62. dd_18 (0.003343)
# 63. returns_per_m2 (0.003339)
# 64. mwmt (0.003027)
# 65. rh (0.002476)
# 66. mat (0.002440)
# 67. surface_volume_ratio (0.000001)

# %% [markdown]
# ## Gradient Boosting Trees Regression

# %%
# Set the parameters by cross-validation
gb_params = {'n_estimators': [100, 500, 1000, 5000],
             'learning_rate': [0.01, 0.1],
             'max_depth': [2, 3, 4, 5, 10],
             'max_features': ['sqrt'] 
            }

gb_gs = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=gb_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_gbs = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    gb_gs.fit(X, y)
    best_fit = gb_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_gbs.append(best_fit)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.5s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    4.3s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   11.5s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   11.6s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    5.6s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    6.1s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    8.6s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    2.3s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.5s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.9s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.7s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    2.9s finished
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  57 out of 120 | elapsed:    1.5s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.5s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   36.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   37.3s finished

# %%
gb_res = get_score_df(best_gbs)
gb_res
# Out:
#                    regional_model  global_model     n
# blue_mountains            556.084       522.731   108
# coast_range              3633.222      3587.327  1646
# eastern_cascades         2384.183      2320.407   403
# north_cascades           2149.433      2293.399   490
# cascades                 3899.503      3638.697   728
# klamath_mountains        4422.762      4107.796   321
# northern_rockies         2167.781      1915.660   103
# puget_lowland            2100.025      2524.826   147
# willamette_valley        2623.134      2114.033    43
# all                      3281.584      3281.584  3355

# %%
### Employing feature selection to try and improve gradient boosting regression

# %% [markdown]
# ## Support Vector Machines Regression

# %%
# Set the parameters by cross-validation
svm_params = {'kernel': ['linear', 'rbf'],
              'gamma': ['scale', 'auto'],
              'C': [0.1,1,10,100,1000]
              }

svm_gs = GridSearchCV(estimator=SVR(), param_grid=svm_params, 
                     cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

best_svms = []
for i in range(len(ecoregions)):
    X = x_scaler.transform(eco_xtrain_dfs[i])
    y = eco_ytrain_dfs[i]
    svm_gs.fit(X, y)
    best_fit = svm_gs.best_estimator_
    # refit to the entire dataset, not just the CV folds
    best_fit.fit(X, y)
    best_svms.append(best_fit)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.3s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    1.0s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 10.9min finished
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    2.4s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  4.3min finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.2s remaining:    0.2s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  6.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    2.5s remaining:    2.9s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  6.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    2.4s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    5.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    0.1s remaining:    0.1s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   32.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    0.1s finished
# /storage/anaconda3/envs/forest_mapping/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Done  28 out of  60 | elapsed:    5.6s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 53.2min finished

# %%
svm_res = get_score_df(best_svms)
svm_res
# Out:
#                    regional_model  global_model     n
# blue_mountains            564.336       495.488   108
# coast_range              3593.435      3498.646  1646
# eastern_cascades         1935.998      2138.347   403
# north_cascades           2495.007      2817.393   490
# cascades                 4138.272      3749.813   728
# klamath_mountains        3626.336      3820.976   321
# northern_rockies         1935.917      2131.691   103
# puget_lowland            2530.839      2940.981   147
# willamette_valley        1834.156      2517.933    43
# all                      3289.577      3289.577  3355

# %%
### Employing feature selection to try and improve support vector regression

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

def scatter_graphs(model_dict):
    names = MODELS.keys()
    EXTEND_PCT = 0.10
    
    fig, axs = plt.subplots(len(ecoregion_names), len(names), 
                            sharex=True, sharey=True,
                            figsize=(12,15)
                           )
    
    all_obs = transformer.inverse_transform(eco_ytest_dfs[-1].reshape(-1,1))
    obs_min = all_obs.min()
    obs_max = all_obs.max()
    rng = obs_max - obs_min
        
    for i, ecoreg in enumerate(ecoregion_names):
        observed = transformer.inverse_transform(eco_ytest_dfs[i].reshape(-1,1))
        
        for j, name in enumerate(names):
            axs[0,j].set_title(name)
            axs[i,0].set_ylabel(ecoreg)
            axs[i,j].set_xlim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_ylim(obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng)
            axs[i,j].set_aspect('equal')
            
            if name == 'LASSO_{}'.format(MAX_FEATURES):
                predicted = MODELS[name][-1].predict(sfms[-1].transform(x_scaler.transform(eco_xtest_dfs[i])))
            else:
                predicted = MODELS[name][-1].predict(x_scaler.transform(eco_xtest_dfs[i]))
            
            predicted = transformer.inverse_transform(predicted.reshape(-1,1))
            axs[i,j].scatter(observed, predicted, s=0.5)
            axs[i,j].plot((obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng), 
                          (obs_min - EXTEND_PCT*rng, obs_max + EXTEND_PCT*rng),
                         color='k', lw=0.5)
            
    plt.tight_layout(pad=0.001)

# %%
MODELS = {'ElasticNet': best_lms, 
          'LASSO': best_lassos,
          'LASSO_{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

scatter_graphs(MODELS)

# %% [markdown]
# ## View scores for regional and global models

# %%
MODEL_NAMES = ['ElasticNet', 'LASSO', 'LASSO_{}'.format(MAX_FEATURES), 'KNN', 'RF', 'GB', 'SVM']
BEST_MODELS = [best_lms, best_lassos, trimmed_lassos, best_knns, best_rfs, best_gbs, best_svms]
    
def compare_models(metric):
    score_dfs = []

    for name, best_models in list(zip(MODEL_NAMES, BEST_MODELS)):
        if name == 'LASSO_{}'.format(MAX_FEATURES):
            score_df = get_score_df(best_models, metric, sfms) 
            score_dfs.append(score_df)
        else:
            score_df = get_score_df(best_models, metric) 
            score_dfs.append(score_df)
        
    counts = np.array(score_dfs[-1]['n'].values)
    regional_data = np.array([df['regional_model'].values for df in score_dfs])
    global_data = np.array([df['global_model'].values for df in score_dfs])
    
    return regional_data, global_data, counts

# %%
def highlight_best(s):
    '''
    highlight the closest value to zero in a Series yellow.
    '''
    lowest_idx = abs(s).idxmin()
    return ['background-color: yellow' if idx==lowest_idx else '' for idx in s.index]

# %%
print('Regional Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores
 .style
 .format('{:,.0f}')
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, RMSE
# <style  type="text/css" >
#     #T_36b4bfb8_4e08_11ea_9824_00505683952erow0_col4 {
#             background-color:  yellow;
#         }    #T_36b4bfb8_4e08_11ea_9824_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_36b4bfb8_4e08_11ea_9824_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_36b4bfb8_4e08_11ea_9824_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_36b4bfb8_4e08_11ea_9824_00505683952erow4_col0 {
#             background-color:  yellow;
#         }    #T_36b4bfb8_4e08_11ea_9824_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_36b4bfb8_4e08_11ea_9824_00505683952erow6_col2 {
#             background-color:  yellow;
#         }    #T_36b4bfb8_4e08_11ea_9824_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_36b4bfb8_4e08_11ea_9824_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_36b4bfb8_4e08_11ea_9824_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_36b4bfb8_4e08_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36b4bfb8_4e08_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow0_col0" class="data row0 col0" >536</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow0_col1" class="data row0 col1" >542</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow0_col2" class="data row0 col2" >551</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow0_col3" class="data row0 col3" >949</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow0_col4" class="data row0 col4" >531</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow0_col5" class="data row0 col5" >556</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow0_col6" class="data row0 col6" >564</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_36b4bfb8_4e08_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow1_col0" class="data row1 col0" >3,686</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow1_col1" class="data row1 col1" >3,677</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow1_col2" class="data row1 col2" >3,714</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow1_col3" class="data row1 col3" >4,008</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow1_col4" class="data row1 col4" >3,692</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow1_col5" class="data row1 col5" >3,633</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow1_col6" class="data row1 col6" >3,593</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_36b4bfb8_4e08_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow2_col0" class="data row2 col0" >2,439</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow2_col1" class="data row2 col1" >2,466</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow2_col2" class="data row2 col2" >2,454</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow2_col3" class="data row2 col3" >2,769</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow2_col4" class="data row2 col4" >2,499</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow2_col5" class="data row2 col5" >2,384</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow2_col6" class="data row2 col6" >1,936</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_36b4bfb8_4e08_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow3_col0" class="data row3 col0" >2,557</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow3_col1" class="data row3 col1" >2,558</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow3_col2" class="data row3 col2" >3,122</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow3_col3" class="data row3 col3" >2,677</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow3_col4" class="data row3 col4" >2,475</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow3_col5" class="data row3 col5" >2,149</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow3_col6" class="data row3 col6" >2,495</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_36b4bfb8_4e08_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow4_col0" class="data row4 col0" >3,557</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow4_col1" class="data row4 col1" >3,565</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow4_col2" class="data row4 col2" >4,156</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow4_col3" class="data row4 col3" >4,643</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow4_col4" class="data row4 col4" >4,114</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow4_col5" class="data row4 col5" >3,900</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow4_col6" class="data row4 col6" >4,138</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_36b4bfb8_4e08_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow5_col0" class="data row5 col0" >3,833</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow5_col1" class="data row5 col1" >3,795</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow5_col2" class="data row5 col2" >3,974</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow5_col3" class="data row5 col3" >4,164</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow5_col4" class="data row5 col4" >4,236</td>
#                         <td id="T_36b4bfb8_4e08_11ea_9824_00505683952erow5_col5" class="data row5 col5" >4,423<

# %%
print('Regional Models, RMSE%')
regional_data, global_data, counts = compare_models(nrmse)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores[regional_rmse.columns[:-1]]
 .style
 .format("{:.0%}")
 .highlight_min(color='yellow', axis=1))
# Out:
# Regional Models, RMSE%
# <style  type="text/css" >
#     #T_4c80fd8e_4e08_11ea_9824_00505683952erow0_col4 {
#             background-color:  yellow;
#         }    #T_4c80fd8e_4e08_11ea_9824_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_4c80fd8e_4e08_11ea_9824_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_4c80fd8e_4e08_11ea_9824_00505683952erow3_col5 {
#             background-color:  yellow;
#         }    #T_4c80fd8e_4e08_11ea_9824_00505683952erow4_col0 {
#             background-color:  yellow;
#         }    #T_4c80fd8e_4e08_11ea_9824_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_4c80fd8e_4e08_11ea_9824_00505683952erow6_col2 {
#             background-color:  yellow;
#         }    #T_4c80fd8e_4e08_11ea_9824_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_4c80fd8e_4e08_11ea_9824_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_4c80fd8e_4e08_11ea_9824_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_4c80fd8e_4e08_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c80fd8e_4e08_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow0_col0" class="data row0 col0" >34%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow0_col1" class="data row0 col1" >35%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow0_col2" class="data row0 col2" >36%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow0_col3" class="data row0 col3" >61%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow0_col4" class="data row0 col4" >34%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow0_col5" class="data row0 col5" >36%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow0_col6" class="data row0 col6" >36%</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80fd8e_4e08_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow1_col0" class="data row1 col0" >43%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow1_col1" class="data row1 col1" >43%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow1_col2" class="data row1 col2" >44%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow1_col3" class="data row1 col3" >47%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow1_col4" class="data row1 col4" >43%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow1_col5" class="data row1 col5" >43%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow1_col6" class="data row1 col6" >42%</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80fd8e_4e08_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow2_col0" class="data row2 col0" >68%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow2_col1" class="data row2 col1" >69%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow2_col2" class="data row2 col2" >69%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow2_col3" class="data row2 col3" >78%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow2_col4" class="data row2 col4" >70%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow2_col5" class="data row2 col5" >67%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow2_col6" class="data row2 col6" >54%</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80fd8e_4e08_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow3_col0" class="data row3 col0" >46%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow3_col1" class="data row3 col1" >46%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow3_col2" class="data row3 col2" >56%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow3_col3" class="data row3 col3" >48%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow3_col4" class="data row3 col4" >44%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow3_col5" class="data row3 col5" >38%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow3_col6" class="data row3 col6" >44%</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80fd8e_4e08_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow4_col0" class="data row4 col0" >44%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow4_col1" class="data row4 col1" >44%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow4_col2" class="data row4 col2" >52%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow4_col3" class="data row4 col3" >58%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow4_col4" class="data row4 col4" >51%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow4_col5" class="data row4 col5" >48%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow4_col6" class="data row4 col6" >51%</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80fd8e_4e08_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow5_col0" class="data row5 col0" >54%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow5_col1" class="data row5 col1" >53%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow5_col2" class="data row5 col2" >56%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow5_col3" class="data row5 col3" >58%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow5_col4" class="data row5 col4" >60%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow5_col5" class="data row5 col5" >62%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow5_col6" class="data row5 col6" >51%</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80fd8e_4e08_11ea_9824_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow6_col0" class="data row6 col0" >61%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow6_col1" class="data row6 col1" >61%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824_00505683952erow6_col2" class="data row6 col2" >60%</td>
#                         <td id="T_4c80fd8e_4e08_11ea_9824

# %%
print('Regional Models, Bias')
regional_data, global_data, counts = compare_models(bias)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores
 .style
 .format('{:,.0f}')
 .apply(highlight_best, axis=1, subset=regional_rmse.columns[:-1]))
# Out:
# Regional Models, Bias
# <style  type="text/css" >
#     #T_35ece3a0_4e06_11ea_9824_00505683952erow0_col2 {
#             background-color:  yellow;
#         }    #T_35ece3a0_4e06_11ea_9824_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_35ece3a0_4e06_11ea_9824_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_35ece3a0_4e06_11ea_9824_00505683952erow3_col6 {
#             background-color:  yellow;
#         }    #T_35ece3a0_4e06_11ea_9824_00505683952erow4_col3 {
#             background-color:  yellow;
#         }    #T_35ece3a0_4e06_11ea_9824_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_35ece3a0_4e06_11ea_9824_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_35ece3a0_4e06_11ea_9824_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_35ece3a0_4e06_11ea_9824_00505683952erow8_col0 {
#             background-color:  yellow;
#         }    #T_35ece3a0_4e06_11ea_9824_00505683952erow9_col6 {
#             background-color:  yellow;
#         }</style><table id="T_35ece3a0_4e06_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_35ece3a0_4e06_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow0_col0" class="data row0 col0" >-156</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow0_col1" class="data row0 col1" >-149</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow0_col2" class="data row0 col2" >-57</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow0_col3" class="data row0 col3" >-304</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow0_col4" class="data row0 col4" >-249</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow0_col5" class="data row0 col5" >-196</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow0_col6" class="data row0 col6" >-80</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_35ece3a0_4e06_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow1_col0" class="data row1 col0" >-346</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow1_col1" class="data row1 col1" >-336</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow1_col2" class="data row1 col2" >-395</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow1_col3" class="data row1 col3" >-577</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow1_col4" class="data row1 col4" >-611</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow1_col5" class="data row1 col5" >-584</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow1_col6" class="data row1 col6" >-103</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_35ece3a0_4e06_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow2_col0" class="data row2 col0" >-567</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow2_col1" class="data row2 col1" >-566</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow2_col2" class="data row2 col2" >-428</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow2_col3" class="data row2 col3" >-821</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow2_col4" class="data row2 col4" >-610</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow2_col5" class="data row2 col5" >-432</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow2_col6" class="data row2 col6" >-308</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_35ece3a0_4e06_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow3_col0" class="data row3 col0" >-567</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow3_col1" class="data row3 col1" >-556</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow3_col2" class="data row3 col2" >-802</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow3_col3" class="data row3 col3" >-567</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow3_col4" class="data row3 col4" >-702</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow3_col5" class="data row3 col5" >-304</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow3_col6" class="data row3 col6" >-78</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_35ece3a0_4e06_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow4_col0" class="data row4 col0" >-467</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow4_col1" class="data row4 col1" >-472</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow4_col2" class="data row4 col2" >-622</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow4_col3" class="data row4 col3" >-263</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow4_col4" class="data row4 col4" >-715</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow4_col5" class="data row4 col5" >-587</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow4_col6" class="data row4 col6" >-467</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_35ece3a0_4e06_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow5_col0" class="data row5 col0" >-860</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow5_col1" class="data row5 col1" >-799</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow5_col2" class="data row5 col2" >-646</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow5_col3" class="data row5 col3" >-732</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow5_col4" class="data row5 col4" >-1,169</td>
#                         <td id="T_35ece3a0_4e06_11ea_9824_00505683952erow5_col5" class="data row5 col5" >-1,133</td>

# %%
print('Regional Models, MAE')
regional_data, global_data, counts = compare_models(mae)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores
 .style
 .format('{:,.0f}')
 .highlight_min(color='yellow', axis=1, subset=regional_scores.columns[:-1]))
# Out:
# Regional Models, MAE
# <style  type="text/css" >
#     #T_4dd8bcf0_4e06_11ea_9824_00505683952erow0_col4 {
#             background-color:  yellow;
#         }    #T_4dd8bcf0_4e06_11ea_9824_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_4dd8bcf0_4e06_11ea_9824_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_4dd8bcf0_4e06_11ea_9824_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_4dd8bcf0_4e06_11ea_9824_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_4dd8bcf0_4e06_11ea_9824_00505683952erow5_col1 {
#             background-color:  yellow;
#         }    #T_4dd8bcf0_4e06_11ea_9824_00505683952erow6_col2 {
#             background-color:  yellow;
#         }    #T_4dd8bcf0_4e06_11ea_9824_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_4dd8bcf0_4e06_11ea_9824_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_4dd8bcf0_4e06_11ea_9824_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_4dd8bcf0_4e06_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4dd8bcf0_4e06_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow0_col0" class="data row0 col0" >390</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow0_col1" class="data row0 col1" >400</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow0_col2" class="data row0 col2" >408</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow0_col3" class="data row0 col3" >596</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow0_col4" class="data row0 col4" >348</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow0_col5" class="data row0 col5" >388</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow0_col6" class="data row0 col6" >402</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_4dd8bcf0_4e06_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow1_col0" class="data row1 col0" >2,438</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow1_col1" class="data row1 col1" >2,431</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow1_col2" class="data row1 col2" >2,416</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow1_col3" class="data row1 col3" >2,640</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow1_col4" class="data row1 col4" >2,374</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow1_col5" class="data row1 col5" >2,332</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow1_col6" class="data row1 col6" >2,338</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_4dd8bcf0_4e06_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow2_col0" class="data row2 col0" >1,109</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow2_col1" class="data row2 col1" >1,113</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow2_col2" class="data row2 col2" >1,200</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow2_col3" class="data row2 col3" >1,429</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow2_col4" class="data row2 col4" >1,218</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow2_col5" class="data row2 col5" >1,199</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow2_col6" class="data row2 col6" >950</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_4dd8bcf0_4e06_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow3_col0" class="data row3 col0" >1,536</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow3_col1" class="data row3 col1" >1,535</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow3_col2" class="data row3 col2" >1,926</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow3_col3" class="data row3 col3" >1,670</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow3_col4" class="data row3 col4" >1,381</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow3_col5" class="data row3 col5" >1,424</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow3_col6" class="data row3 col6" >1,493</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_4dd8bcf0_4e06_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow4_col0" class="data row4 col0" >2,331</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow4_col1" class="data row4 col1" >2,338</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow4_col2" class="data row4 col2" >2,678</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow4_col3" class="data row4 col3" >2,847</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow4_col4" class="data row4 col4" >2,263</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow4_col5" class="data row4 col5" >2,184</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow4_col6" class="data row4 col6" >2,278</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_4dd8bcf0_4e06_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow5_col0" class="data row5 col0" >2,291</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow5_col1" class="data row5 col1" >2,286</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow5_col2" class="data row5 col2" >2,707</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow5_col3" class="data row5 col3" >2,767</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow5_col4" class="data row5 col4" >2,532</td>
#                         <td id="T_4dd8bcf0_4e06_11ea_9824_00505683952erow5_col5" class="data row5 col5" >2,676</t

# %%
print('Regional Models, MAPE')
regional_data, global_data, counts = compare_models(mape)
regional_scores = pd.DataFrame(data=np.vstack((regional_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(regional_scores[regional_scores.columns[:-1]]
 .style
 .format("{:.0%}")
 .highlight_min(color='yellow', axis=1))
# Out:
# Regional Models, MAPE
# <style  type="text/css" >
#     #T_88a1d050_4d71_11ea_9824_00505683952erow0_col4 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow1_col5 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow5_col1 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow6_col2 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_88a1d050_4d71_11ea_9824_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_88a1d050_4d71_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88a1d050_4d71_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow0_col0" class="data row0 col0" >25%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow0_col1" class="data row0 col1" >26%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow0_col2" class="data row0 col2" >26%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow0_col3" class="data row0 col3" >38%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow0_col4" class="data row0 col4" >22%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow0_col5" class="data row0 col5" >25%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow0_col6" class="data row0 col6" >26%</td>
#             </tr>
#             <tr>
#                         <th id="T_88a1d050_4d71_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow1_col0" class="data row1 col0" >29%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow1_col1" class="data row1 col1" >28%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow1_col2" class="data row1 col2" >28%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow1_col3" class="data row1 col3" >31%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow1_col4" class="data row1 col4" >28%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow1_col5" class="data row1 col5" >27%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow1_col6" class="data row1 col6" >28%</td>
#             </tr>
#             <tr>
#                         <th id="T_88a1d050_4d71_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow2_col0" class="data row2 col0" >31%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow2_col1" class="data row2 col1" >31%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow2_col2" class="data row2 col2" >34%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow2_col3" class="data row2 col3" >40%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow2_col4" class="data row2 col4" >34%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow2_col5" class="data row2 col5" >34%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow2_col6" class="data row2 col6" >27%</td>
#             </tr>
#             <tr>
#                         <th id="T_88a1d050_4d71_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow3_col0" class="data row3 col0" >27%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow3_col1" class="data row3 col1" >27%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow3_col2" class="data row3 col2" >34%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow3_col3" class="data row3 col3" >30%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow3_col4" class="data row3 col4" >25%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow3_col5" class="data row3 col5" >25%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow3_col6" class="data row3 col6" >27%</td>
#             </tr>
#             <tr>
#                         <th id="T_88a1d050_4d71_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow4_col0" class="data row4 col0" >29%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow4_col1" class="data row4 col1" >29%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow4_col2" class="data row4 col2" >33%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow4_col3" class="data row4 col3" >35%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow4_col4" class="data row4 col4" >28%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow4_col5" class="data row4 col5" >27%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow4_col6" class="data row4 col6" >28%</td>
#             </tr>
#             <tr>
#                         <th id="T_88a1d050_4d71_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow5_col0" class="data row5 col0" >32%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow5_col1" class="data row5 col1" >32%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow5_col2" class="data row5 col2" >38%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow5_col3" class="data row5 col3" >39%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow5_col4" class="data row5 col4" >36%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow5_col5" class="data row5 col5" >38%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow5_col6" class="data row5 col6" >32%</td>
#             </tr>
#             <tr>
#                         <th id="T_88a1d050_4d71_11ea_9824_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow6_col0" class="data row6 col0" >45%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_00505683952erow6_col1" class="data row6 col1" >44%</td>
#                         <td id="T_88a1d050_4d71_11ea_9824_0050568395

# %%
print('Global Models, RMSE')
regional_data, global_data, counts = compare_models(rmse)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores[global_scores.columns[:-1]]
 .style
 .format('{:,.0f}')
 .highlight_min(color='yellow', axis=1))
# Out:
# Global Models, RMSE
# <style  type="text/css" >
#     #T_aef89f76_4e08_11ea_9824_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_aef89f76_4e08_11ea_9824_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_aef89f76_4e08_11ea_9824_00505683952erow2_col1 {
#             background-color:  yellow;
#         }    #T_aef89f76_4e08_11ea_9824_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_aef89f76_4e08_11ea_9824_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_aef89f76_4e08_11ea_9824_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_aef89f76_4e08_11ea_9824_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_aef89f76_4e08_11ea_9824_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_aef89f76_4e08_11ea_9824_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_aef89f76_4e08_11ea_9824_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_aef89f76_4e08_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aef89f76_4e08_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow0_col0" class="data row0 col0" >574</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow0_col1" class="data row0 col1" >578</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow0_col2" class="data row0 col2" >1,511</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow0_col3" class="data row0 col3" >864</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow0_col4" class="data row0 col4" >558</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow0_col5" class="data row0 col5" >523</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow0_col6" class="data row0 col6" >495</td>
#             </tr>
#             <tr>
#                         <th id="T_aef89f76_4e08_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow1_col0" class="data row1 col0" >4,093</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow1_col1" class="data row1 col1" >4,091</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow1_col2" class="data row1 col2" >6,140</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow1_col3" class="data row1 col3" >3,946</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow1_col4" class="data row1 col4" >3,607</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow1_col5" class="data row1 col5" >3,587</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow1_col6" class="data row1 col6" >3,499</td>
#             </tr>
#             <tr>
#                         <th id="T_aef89f76_4e08_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow2_col0" class="data row2 col0" >2,111</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow2_col1" class="data row2 col1" >2,100</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow2_col2" class="data row2 col2" >3,043</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow2_col3" class="data row2 col3" >2,533</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow2_col4" class="data row2 col4" >2,418</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow2_col5" class="data row2 col5" >2,320</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow2_col6" class="data row2 col6" >2,138</td>
#             </tr>
#             <tr>
#                         <th id="T_aef89f76_4e08_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow3_col0" class="data row3 col0" >3,006</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow3_col1" class="data row3 col1" >3,004</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow3_col2" class="data row3 col2" >4,176</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow3_col3" class="data row3 col3" >2,705</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow3_col4" class="data row3 col4" >2,170</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow3_col5" class="data row3 col5" >2,293</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow3_col6" class="data row3 col6" >2,817</td>
#             </tr>
#             <tr>
#                         <th id="T_aef89f76_4e08_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow4_col0" class="data row4 col0" >4,016</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow4_col1" class="data row4 col1" >4,026</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow4_col2" class="data row4 col2" >6,308</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow4_col3" class="data row4 col3" >4,336</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow4_col4" class="data row4 col4" >3,706</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow4_col5" class="data row4 col5" >3,639</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow4_col6" class="data row4 col6" >3,750</td>
#             </tr>
#             <tr>
#                         <th id="T_aef89f76_4e08_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow5_col0" class="data row5 col0" >4,071</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow5_col1" class="data row5 col1" >4,075</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow5_col2" class="data row5 col2" >5,302</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow5_col3" class="data row5 col3" >4,034</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow5_col4" class="data row5 col4" >4,158</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow5_col5" class="data row5 col5" >4,108</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow5_col6" class="data row5 col6" >3,821</td>
#             </tr>
#             <tr>
#                         <th id="T_aef89f76_4e08_11ea_9824_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow6_col0" class="data row6 col0" >2,153</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow6_col1" class="data row6 col1" >2,156</td>
#                         <td id="T_aef89f76_4e08_11ea_9824_00505683952erow6_col2" class="data ro

# %%
print('Global Models, RMSE%')
regional_data, global_data, counts = compare_models(nrmse)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores[global_scores.columns[:-1]]
 .style
 .format("{:.0%}")
 .highlight_min(color='yellow', axis=1))
# Out:
# Global Models, RMSE%
# <style  type="text/css" >
#     #T_9c3645a0_4e08_11ea_9824_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_9c3645a0_4e08_11ea_9824_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_9c3645a0_4e08_11ea_9824_00505683952erow2_col1 {
#             background-color:  yellow;
#         }    #T_9c3645a0_4e08_11ea_9824_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_9c3645a0_4e08_11ea_9824_00505683952erow4_col5 {
#             background-color:  yellow;
#         }    #T_9c3645a0_4e08_11ea_9824_00505683952erow5_col6 {
#             background-color:  yellow;
#         }    #T_9c3645a0_4e08_11ea_9824_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_9c3645a0_4e08_11ea_9824_00505683952erow7_col5 {
#             background-color:  yellow;
#         }    #T_9c3645a0_4e08_11ea_9824_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_9c3645a0_4e08_11ea_9824_00505683952erow9_col5 {
#             background-color:  yellow;
#         }</style><table id="T_9c3645a0_4e08_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9c3645a0_4e08_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow0_col0" class="data row0 col0" >37%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow0_col1" class="data row0 col1" >37%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow0_col2" class="data row0 col2" >97%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow0_col3" class="data row0 col3" >56%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow0_col4" class="data row0 col4" >36%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow0_col5" class="data row0 col5" >34%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow0_col6" class="data row0 col6" >32%</td>
#             </tr>
#             <tr>
#                         <th id="T_9c3645a0_4e08_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow1_col0" class="data row1 col0" >48%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow1_col1" class="data row1 col1" >48%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow1_col2" class="data row1 col2" >72%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow1_col3" class="data row1 col3" >46%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow1_col4" class="data row1 col4" >42%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow1_col5" class="data row1 col5" >42%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow1_col6" class="data row1 col6" >41%</td>
#             </tr>
#             <tr>
#                         <th id="T_9c3645a0_4e08_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow2_col0" class="data row2 col0" >59%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow2_col1" class="data row2 col1" >59%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow2_col2" class="data row2 col2" >85%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow2_col3" class="data row2 col3" >71%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow2_col4" class="data row2 col4" >68%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow2_col5" class="data row2 col5" >65%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow2_col6" class="data row2 col6" >60%</td>
#             </tr>
#             <tr>
#                         <th id="T_9c3645a0_4e08_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow3_col0" class="data row3 col0" >54%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow3_col1" class="data row3 col1" >54%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow3_col2" class="data row3 col2" >74%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow3_col3" class="data row3 col3" >48%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow3_col4" class="data row3 col4" >39%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow3_col5" class="data row3 col5" >41%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow3_col6" class="data row3 col6" >50%</td>
#             </tr>
#             <tr>
#                         <th id="T_9c3645a0_4e08_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow4_col0" class="data row4 col0" >50%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow4_col1" class="data row4 col1" >50%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow4_col2" class="data row4 col2" >78%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow4_col3" class="data row4 col3" >54%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow4_col4" class="data row4 col4" >46%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow4_col5" class="data row4 col5" >45%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow4_col6" class="data row4 col6" >47%</td>
#             </tr>
#             <tr>
#                         <th id="T_9c3645a0_4e08_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow5_col0" class="data row5 col0" >57%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow5_col1" class="data row5 col1" >57%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow5_col2" class="data row5 col2" >74%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow5_col3" class="data row5 col3" >57%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow5_col4" class="data row5 col4" >58%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow5_col5" class="data row5 col5" >58%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow5_col6" class="data row5 col6" >54%</td>
#             </tr>
#             <tr>
#                         <th id="T_9c3645a0_4e08_11ea_9824_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow6_col0" class="data row6 col0" >68%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow6_col1" class="data row6 col1" >68%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824_00505683952erow6_col2" class="data row6 col2" >85%</td>
#                         <td id="T_9c3645a0_4e08_11ea_9824

# %%
print('Global Models, Bias')
regional_data, global_data, counts = compare_models(bias)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores
 .style
 .format('{:,.0f}')
 .apply(highlight_best, axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, Bias
# <style  type="text/css" >
#     #T_0ce6d52e_4e06_11ea_9824_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_0ce6d52e_4e06_11ea_9824_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_0ce6d52e_4e06_11ea_9824_00505683952erow2_col1 {
#             background-color:  yellow;
#         }    #T_0ce6d52e_4e06_11ea_9824_00505683952erow3_col3 {
#             background-color:  yellow;
#         }    #T_0ce6d52e_4e06_11ea_9824_00505683952erow4_col6 {
#             background-color:  yellow;
#         }    #T_0ce6d52e_4e06_11ea_9824_00505683952erow5_col3 {
#             background-color:  yellow;
#         }    #T_0ce6d52e_4e06_11ea_9824_00505683952erow6_col6 {
#             background-color:  yellow;
#         }    #T_0ce6d52e_4e06_11ea_9824_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_0ce6d52e_4e06_11ea_9824_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_0ce6d52e_4e06_11ea_9824_00505683952erow9_col6 {
#             background-color:  yellow;
#         }</style><table id="T_0ce6d52e_4e06_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0ce6d52e_4e06_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow0_col0" class="data row0 col0" >-145</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow0_col1" class="data row0 col1" >-147</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow0_col2" class="data row0 col2" >379</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow0_col3" class="data row0 col3" >-454</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow0_col4" class="data row0 col4" >-216</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow0_col5" class="data row0 col5" >-128</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow0_col6" class="data row0 col6" >-34</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_0ce6d52e_4e06_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow1_col0" class="data row1 col0" >-465</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow1_col1" class="data row1 col1" >-465</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow1_col2" class="data row1 col2" >-1,936</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow1_col3" class="data row1 col3" >-537</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow1_col4" class="data row1 col4" >-495</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow1_col5" class="data row1 col5" >-361</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow1_col6" class="data row1 col6" >-336</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_0ce6d52e_4e06_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow2_col0" class="data row2 col0" >-308</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow2_col1" class="data row2 col1" >-294</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow2_col2" class="data row2 col2" >-414</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow2_col3" class="data row2 col3" >-587</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow2_col4" class="data row2 col4" >-645</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow2_col5" class="data row2 col5" >-594</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow2_col6" class="data row2 col6" >-364</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_0ce6d52e_4e06_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow3_col0" class="data row3 col0" >-389</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow3_col1" class="data row3 col1" >-394</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow3_col2" class="data row3 col2" >1,328</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow3_col3" class="data row3 col3" >-253</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow3_col4" class="data row3 col4" >-352</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow3_col5" class="data row3 col5" >-379</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow3_col6" class="data row3 col6" >-297</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_0ce6d52e_4e06_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow4_col0" class="data row4 col0" >-834</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow4_col1" class="data row4 col1" >-833</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow4_col2" class="data row4 col2" >-1,271</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow4_col3" class="data row4 col3" >-609</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow4_col4" class="data row4 col4" >-978</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow4_col5" class="data row4 col5" >-755</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow4_col6" class="data row4 col6" >-596</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_0ce6d52e_4e06_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow5_col0" class="data row5 col0" >-1,322</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow5_col1" class="data row5 col1" >-1,314</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow5_col2" class="data row5 col2" >-2,611</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow5_col3" class="data row5 col3" >-760</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow5_col4" class="data row5 col4" >-1,398</td>
#                         <td id="T_0ce6d52e_4e06_11ea_9824_00505683952erow5_col5" class="data row5 col5" >-1,320</td>

# %%
print('Global Models, MAE')
regional_data, global_data, counts = compare_models(mae)
global_scores = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_scores
 .style
 .format('{:,.0f}')
 .highlight_min(color='yellow', axis=1, subset=global_scores.columns[:-1]))
# Out:
# Global Models, MAE
# <style  type="text/css" >
#     #T_14a07f36_4e06_11ea_9824_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_14a07f36_4e06_11ea_9824_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_14a07f36_4e06_11ea_9824_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_14a07f36_4e06_11ea_9824_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_14a07f36_4e06_11ea_9824_00505683952erow4_col4 {
#             background-color:  yellow;
#         }    #T_14a07f36_4e06_11ea_9824_00505683952erow5_col4 {
#             background-color:  yellow;
#         }    #T_14a07f36_4e06_11ea_9824_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_14a07f36_4e06_11ea_9824_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_14a07f36_4e06_11ea_9824_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_14a07f36_4e06_11ea_9824_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_14a07f36_4e06_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>        <th class="col_heading level0 col7" >n</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14a07f36_4e06_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow0_col0" class="data row0 col0" >398</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow0_col1" class="data row0 col1" >401</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow0_col2" class="data row0 col2" >1,306</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow0_col3" class="data row0 col3" >568</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow0_col4" class="data row0 col4" >426</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow0_col5" class="data row0 col5" >411</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow0_col6" class="data row0 col6" >382</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow0_col7" class="data row0 col7" >108</td>
#             </tr>
#             <tr>
#                         <th id="T_14a07f36_4e06_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow1_col0" class="data row1 col0" >2,713</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow1_col1" class="data row1 col1" >2,712</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow1_col2" class="data row1 col2" >4,248</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow1_col3" class="data row1 col3" >2,579</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow1_col4" class="data row1 col4" >2,314</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow1_col5" class="data row1 col5" >2,317</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow1_col6" class="data row1 col6" >2,256</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow1_col7" class="data row1 col7" >1,646</td>
#             </tr>
#             <tr>
#                         <th id="T_14a07f36_4e06_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow2_col0" class="data row2 col0" >1,108</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow2_col1" class="data row2 col1" >1,106</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow2_col2" class="data row2 col2" >1,563</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow2_col3" class="data row2 col3" >1,385</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow2_col4" class="data row2 col4" >1,146</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow2_col5" class="data row2 col5" >1,077</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow2_col6" class="data row2 col6" >957</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow2_col7" class="data row2 col7" >403</td>
#             </tr>
#             <tr>
#                         <th id="T_14a07f36_4e06_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow3_col0" class="data row3 col0" >1,850</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow3_col1" class="data row3 col1" >1,852</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow3_col2" class="data row3 col2" >3,075</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow3_col3" class="data row3 col3" >1,710</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow3_col4" class="data row3 col4" >1,374</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow3_col5" class="data row3 col5" >1,418</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow3_col6" class="data row3 col6" >1,710</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow3_col7" class="data row3 col7" >490</td>
#             </tr>
#             <tr>
#                         <th id="T_14a07f36_4e06_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow4_col0" class="data row4 col0" >2,546</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow4_col1" class="data row4 col1" >2,546</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow4_col2" class="data row4 col2" >4,487</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow4_col3" class="data row4 col3" >2,517</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow4_col4" class="data row4 col4" >1,995</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow4_col5" class="data row4 col5" >2,006</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow4_col6" class="data row4 col6" >2,002</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow4_col7" class="data row4 col7" >728</td>
#             </tr>
#             <tr>
#                         <th id="T_14a07f36_4e06_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow5_col0" class="data row5 col0" >2,537</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow5_col1" class="data row5 col1" >2,538</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow5_col2" class="data row5 col2" >3,636</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow5_col3" class="data row5 col3" >2,661</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow5_col4" class="data row5 col4" >2,442</td>
#                         <td id="T_14a07f36_4e06_11ea_9824_00505683952erow5_col5" class="data row5 col5" >2,509<

# %%
print('Global Models, MAPE')
regional_data, global_data, counts = compare_models(mape)
global_rmse = pd.DataFrame(data=np.vstack((global_data, counts)).T,
                             columns=MODEL_NAMES + ['n'],
                             index=ecoregions)
(global_rmse[global_rmse.columns[:-1]]
 .style
 .format("{:.0%}")
 .highlight_min(color='yellow', axis=1))
# Out:
# Global Models, MAPE
# <style  type="text/css" >
#     #T_952e5fa0_4d71_11ea_9824_00505683952erow0_col6 {
#             background-color:  yellow;
#         }    #T_952e5fa0_4d71_11ea_9824_00505683952erow1_col6 {
#             background-color:  yellow;
#         }    #T_952e5fa0_4d71_11ea_9824_00505683952erow2_col6 {
#             background-color:  yellow;
#         }    #T_952e5fa0_4d71_11ea_9824_00505683952erow3_col4 {
#             background-color:  yellow;
#         }    #T_952e5fa0_4d71_11ea_9824_00505683952erow4_col4 {
#             background-color:  yellow;
#         }    #T_952e5fa0_4d71_11ea_9824_00505683952erow5_col4 {
#             background-color:  yellow;
#         }    #T_952e5fa0_4d71_11ea_9824_00505683952erow6_col5 {
#             background-color:  yellow;
#         }    #T_952e5fa0_4d71_11ea_9824_00505683952erow7_col4 {
#             background-color:  yellow;
#         }    #T_952e5fa0_4d71_11ea_9824_00505683952erow8_col3 {
#             background-color:  yellow;
#         }    #T_952e5fa0_4d71_11ea_9824_00505683952erow9_col4 {
#             background-color:  yellow;
#         }</style><table id="T_952e5fa0_4d71_11ea_9824_00505683952e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ElasticNet</th>        <th class="col_heading level0 col1" >LASSO</th>        <th class="col_heading level0 col2" >LASSO_5</th>        <th class="col_heading level0 col3" >KNN</th>        <th class="col_heading level0 col4" >RF</th>        <th class="col_heading level0 col5" >GB</th>        <th class="col_heading level0 col6" >SVM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_952e5fa0_4d71_11ea_9824_00505683952elevel0_row0" class="row_heading level0 row0" >blue_mountains</th>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow0_col0" class="data row0 col0" >26%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow0_col1" class="data row0 col1" >26%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow0_col2" class="data row0 col2" >84%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow0_col3" class="data row0 col3" >36%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow0_col4" class="data row0 col4" >27%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow0_col5" class="data row0 col5" >26%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow0_col6" class="data row0 col6" >25%</td>
#             </tr>
#             <tr>
#                         <th id="T_952e5fa0_4d71_11ea_9824_00505683952elevel0_row1" class="row_heading level0 row1" >coast_range</th>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow1_col0" class="data row1 col0" >32%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow1_col1" class="data row1 col1" >32%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow1_col2" class="data row1 col2" >50%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow1_col3" class="data row1 col3" >30%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow1_col4" class="data row1 col4" >27%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow1_col5" class="data row1 col5" >27%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow1_col6" class="data row1 col6" >26%</td>
#             </tr>
#             <tr>
#                         <th id="T_952e5fa0_4d71_11ea_9824_00505683952elevel0_row2" class="row_heading level0 row2" >eastern_cascades_slopes_and_foothills</th>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow2_col0" class="data row2 col0" >31%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow2_col1" class="data row2 col1" >31%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow2_col2" class="data row2 col2" >44%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow2_col3" class="data row2 col3" >39%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow2_col4" class="data row2 col4" >32%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow2_col5" class="data row2 col5" >30%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow2_col6" class="data row2 col6" >27%</td>
#             </tr>
#             <tr>
#                         <th id="T_952e5fa0_4d71_11ea_9824_00505683952elevel0_row3" class="row_heading level0 row3" >north_cascades</th>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow3_col0" class="data row3 col0" >33%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow3_col1" class="data row3 col1" >33%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow3_col2" class="data row3 col2" >55%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow3_col3" class="data row3 col3" >30%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow3_col4" class="data row3 col4" >24%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow3_col5" class="data row3 col5" >25%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow3_col6" class="data row3 col6" >30%</td>
#             </tr>
#             <tr>
#                         <th id="T_952e5fa0_4d71_11ea_9824_00505683952elevel0_row4" class="row_heading level0 row4" >cascades</th>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow4_col0" class="data row4 col0" >32%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow4_col1" class="data row4 col1" >32%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow4_col2" class="data row4 col2" >56%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow4_col3" class="data row4 col3" >31%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow4_col4" class="data row4 col4" >25%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow4_col5" class="data row4 col5" >25%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow4_col6" class="data row4 col6" >25%</td>
#             </tr>
#             <tr>
#                         <th id="T_952e5fa0_4d71_11ea_9824_00505683952elevel0_row5" class="row_heading level0 row5" >klamath_mountains_california_high_north_coast_range</th>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow5_col0" class="data row5 col0" >36%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow5_col1" class="data row5 col1" >36%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow5_col2" class="data row5 col2" >51%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow5_col3" class="data row5 col3" >37%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow5_col4" class="data row5 col4" >34%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow5_col5" class="data row5 col5" >35%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow5_col6" class="data row5 col6" >35%</td>
#             </tr>
#             <tr>
#                         <th id="T_952e5fa0_4d71_11ea_9824_00505683952elevel0_row6" class="row_heading level0 row6" >northern_rockies</th>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow6_col0" class="data row6 col0" >49%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow6_col1" class="data row6 col1" >49%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824_00505683952erow6_col2" class="data row6 col2" >65%</td>
#                         <td id="T_952e5fa0_4d71_11ea_9824

# %%
METRIC = 'cubic_volume'

MODELS = {'ElasticNet': best_lms,
          'LASSO': best_lassos,
          'LASSO{}'.format(MAX_FEATURES): trimmed_lassos,
          'KNN': best_knns,
          'RF': best_rfs,
          'GB': best_gbs,
          'SVM': best_svms}

pickle.dump(x_scaler, 
            open('../models/{}/sklearn/x_scaler.pkl'.format(METRIC), 'wb'))
pickle.dump(transformer, 
            open('../models/{}/sklearn/y_scaler.pkl'.format(METRIC), 'wb'))

for i in range(len(ecoregion_names)):
    for key in MODELS.keys():
        fname = ecoregion_names[i] + '_{}.pkl'.format(key)
        path_to_file = '../models/{}/sklearn/{}'.format(METRIC, fname)
        pickle.dump(MODELS[key][i], 
                    open(path_to_file, 'wb'))
        
        if key == 'LASSO{}'.format(MAX_FEATURES):
            sfm_name = ecoregion_names[i] + '_LASSO{}_featureselect.pkl'.format(MAX_FEATURES)
            path_to_file = '../models/{}/sklearn/{}'.format(METRIC, sfm_name)
            pickle.dump(sfms[i], 
                        open(path_to_file, 'wb'))
